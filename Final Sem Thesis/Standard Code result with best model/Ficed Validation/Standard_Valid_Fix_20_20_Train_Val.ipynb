# %%
#Train Aug with for 90%(20%augmented, 20%validation) and 10%test data
import keras
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout, Flatten
from keras.layers import Conv2D
from keras.layers import MaxPooling2D,MaxPool2D
from keras.layers.normalization import BatchNormalization
from keras.optimizers import Adam
from keras.preprocessing.image import ImageDataGenerator
from keras import layers
from keras import models
from keras import optimizers

from tensorflow.keras.applications.resnet50 import ResNet50

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
import os

# %%
#changing the working directory
# %cd /content/gdrive/My Drive/Thesis
# Out:
# /content/gdrive/My Drive/Thesis

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import keras
from keras.models import Sequential, Model
from keras.layers import Dense, Conv2D , MaxPool2D , Flatten , Dropout , MaxPooling2D
from keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report,confusion_matrix
from keras.applications import VGG19
import cv2
import os
import random
import tensorflow as tf
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
labels = ['dandelion', 'daisy','tulip','sunflower','rose']
img_size = 150
def get_data(data_dir):
    data = [] 
    for label in labels: 
        path = os.path.join(data_dir, label)
        class_num = labels.index(label)
        for img in os.listdir(path):
            try:
                img_arr = cv2.imread(os.path.join(path, img), cv2.IMREAD_COLOR)
                resized_arr = cv2.resize(img_arr, (img_size, img_size)) # Reshaping images to preferred size
                data.append([resized_arr, class_num])
            except Exception as e:
                print(e)
    return np.array(data)

# %%
data = get_data("/content/gdrive/My Drive/Thesis/flowers")
# Out:
# OpenCV(4.1.2) /io/opencv/modules/imgproc/src/resize.cpp:3720: error: (-215:Assertion failed) !ssize.empty() in function 'resize'
#
# OpenCV(4.1.2) /io/opencv/modules/imgproc/src/resize.cpp:3720: error: (-215:Assertion failed) !ssize.empty() in function 'resize'
#
# OpenCV(4.1.2) /io/opencv/modules/imgproc/src/resize.cpp:3720: error: (-215:Assertion failed) !ssize.empty() in function 'resize'

# %%
l = []
for i in data:
    l.append(labels[i[1]])
sns.set_style('dark')
sns.countplot(l)

# %%
fig,ax=plt.subplots(5,2)
fig.set_size_inches(15,15)
for i in range(5):
    for j in range (2):
        l=random.randint(0,len(data))
        ax[i,j].imshow(data[l][0])
        ax[i,j].set_title('Flower: '+labels[data[l][1]])
        
plt.tight_layout()

# %%
x = []
y = []

for feature, label in data:
    x.append(feature)
    y.append(label)

# %%
# Normalize the data
x = np.array(x) / 255

# %%
# Reshaping the data from 1-D to 3-D as required through input by CNN's 
x = x.reshape(-1, img_size, img_size, 3)
y = np.array(y)

# %%
from sklearn.preprocessing import LabelBinarizer
label_binarizer = LabelBinarizer()
y = label_binarizer.fit_transform(y)

# %%
x_train,x_test,y_train,y_test = train_test_split(x , y , test_size = 0.1 , random_state = 42)

# %%
x_train,x_val,y_train,y_val = train_test_split(x_train, y_train, test_size= 0.2, random_state = 42)

# %%
x_train,x_left,y_train,y_left = train_test_split(x_train, y_train, test_size= 0.75, random_state = 42)

# %%
#defining the augmentation
datagen = ImageDataGenerator(
    featurewise_center=False,  # set input mean to 0 over the dataset
    samplewise_center=False,  # set each sample mean to 0
    featurewise_std_normalization=False,  # divide inputs by std of the dataset
    samplewise_std_normalization=False,  # divide each input by its std
    rotation_range=180,  # randomly rotate images in the range (0 to 180)
    zoom_range = 0.1, # Randomly zoom image 
    width_shift_range=0.1,  # randomly shift images horizontally (fraction of total width)
    height_shift_range=0.1,
    shear_range=0.1,
    fill_mode = "reflect"
    ) 
datagen.fit(x_train)

# %%
model = Sequential()

#Adding ResNet model
model.add(ResNet50(include_top=False, pooling='avg', weights="imagenet", input_shape=(150,150,3)))
model.add(Flatten())

model.add(Dense(1024,activation="relu"))
model.add(Dropout(0.5))
model.add(BatchNormalization())

#Output layer
model.add(Dense(5, activation='softmax'))

model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94773248/94765736 [==============================] - 2s 0us/step
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# resnet50 (Functional)        (None, 2048)              23587712
# _________________________________________________________________
# flatten (Flatten)            (None, 2048)              0
# _________________________________________________________________
# dense (Dense)                (None, 1024)              2098176
# _________________________________________________________________
# dropout (Dropout)            (None, 1024)              0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 1024)              4096
# _________________________________________________________________
# dense_1 (Dense)              (None, 5)                 5125
# =================================================================
# Total params: 25,695,109
# Trainable params: 25,639,941
# Non-trainable params: 55,168
# _________________________________________________________________

# %%
#defining early stopping
from keras.callbacks import ReduceLROnPlateau
learning_rate = ReduceLROnPlateau(monitor='val_accuracy', patience = 3, verbose=1,factor=0.5, min_lr=0.000001)

es = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss', patience=10, verbose=1, mode='min')

# %%
# !pip install h5py
	
	
mc = tf.keras.callbacks.ModelCheckpoint('best_model.h5', monitor='val_accuracy', mode='max', verbose=1, save_best_only=True)
# Out:
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (2.10.0)
# Requirement already satisfied: numpy>=1.7 in /usr/local/lib/python3.6/dist-packages (from h5py) (1.18.5)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from h5py) (1.15.0)

# %%
model.compile(optimizer = "adam" , loss = 'categorical_crossentropy' , metrics = ['accuracy'])

# %%
#Fitting the augmentation data
history = model.fit(datagen.flow(x_train, y_train, batch_size=32), epochs=100, validation_data = (x_val, y_val), callbacks = [learning_rate,es,mc])
# Out:
# Epoch 1/100
# 25/25 [==============================] - ETA: 0s - loss: 0.4101 - accuracy: 0.8485
# Epoch 00001: val_accuracy did not improve from 0.21282
# 25/25 [==============================] - 287s 11s/step - loss: 0.4101 - accuracy: 0.8485 - val_loss: 1.9483 - val_accuracy: 0.2128
# Epoch 2/100
# 25/25 [==============================] - ETA: 0s - loss: 0.2989 - accuracy: 0.8896
# Epoch 00002: val_accuracy did not improve from 0.21282
# 25/25 [==============================] - 285s 11s/step - loss: 0.2989 - accuracy: 0.8896 - val_loss: 1.9460 - val_accuracy: 0.2128
# Epoch 3/100
# 25/25 [==============================] - ETA: 0s - loss: 0.3477 - accuracy: 0.8768
# Epoch 00003: val_accuracy did not improve from 0.21282
# 25/25 [==============================] - 286s 11s/step - loss: 0.3477 - accuracy: 0.8768 - val_loss: 1.9047 - val_accuracy: 0.2128
# Epoch 4/100
# 25/25 [==============================] - ETA: 0s - loss: 0.3089 - accuracy: 0.8832
# Epoch 00004: val_accuracy improved from 0.21282 to 0.21410, saving model to best_model.h5
# 25/25 [==============================] - 287s 11s/step - loss: 0.3089 - accuracy: 0.8832 - val_loss: 1.9166 - val_accuracy: 0.2141
# Epoch 5/100
# 25/25 [==============================] - ETA: 0s - loss: 0.3032 - accuracy: 0.8947
# Epoch 00005: val_accuracy did not improve from 0.21410
# 25/25 [==============================] - 286s 11s/step - loss: 0.3032 - accuracy: 0.8947 - val_loss: 1.9685 - val_accuracy: 0.2141
# Epoch 6/100
# 25/25 [==============================] - ETA: 0s - loss: 0.3514 - accuracy: 0.8691
# Epoch 00006: val_accuracy improved from 0.21410 to 0.21538, saving model to best_model.h5
# 25/25 [==============================] - 289s 12s/step - loss: 0.3514 - accuracy: 0.8691 - val_loss: 1.9416 - val_accuracy: 0.2154
# Epoch 7/100
# 25/25 [==============================] - ETA: 0s - loss: 0.3856 - accuracy: 0.8716
# Epoch 00007: val_accuracy improved from 0.21538 to 0.22821, saving model to best_model.h5
# 25/25 [==============================] - 290s 12s/step - loss: 0.3856 - accuracy: 0.8716 - val_loss: 1.9200 - val_accuracy: 0.2282
# Epoch 8/100
# 25/25 [==============================] - ETA: 0s - loss: 0.3194 - accuracy: 0.8947
# Epoch 00008: val_accuracy improved from 0.22821 to 0.24231, saving model to best_model.h5
# 25/25 [==============================] - 289s 12s/step - loss: 0.3194 - accuracy: 0.8947 - val_loss: 1.8256 - val_accuracy: 0.2423
# Epoch 9/100
# 25/25 [==============================] - ETA: 0s - loss: 0.3792 - accuracy: 0.8575
# Epoch 00009: val_accuracy improved from 0.24231 to 0.26282, saving model to best_model.h5
# 25/25 [==============================] - 287s 11s/step - loss: 0.3792 - accuracy: 0.8575 - val_loss: 1.7929 - val_accuracy: 0.2628
# Epoch 10/100
# 25/25 [==============================] - ETA: 0s - loss: 0.2709 - accuracy: 0.9037
# Epoch 00010: val_accuracy improved from 0.26282 to 0.30256, saving model to best_model.h5
# 25/25 [==============================] - 289s 12s/step - loss: 0.2709 - accuracy: 0.9037 - val_loss: 1.7482 - val_accuracy: 0.3026
# Epoch 11/100
# 25/25 [==============================] - ETA: 0s - loss: 0.2924 - accuracy: 0.9050
# Epoch 00011: val_accuracy improved from 0.30256 to 0.33462, saving model to best_model.h5
# 25/25 [==============================] - 296s 12s/step - loss: 0.2924 - accuracy: 0.9050 - val_loss: 1.7008 - val_accuracy: 0.3346
# Epoch 12/100
# 25/25 [==============================] - ETA: 0s - loss: 0.3106 - accuracy: 0.8742
# Epoch 00012: val_accuracy improved from 0.33462 to 0.35385, saving model to best_model.h5
# 25/25 [==============================] - 289s 12s/step - loss: 0.3106 - accuracy: 0.8742 - val_loss: 1.6642 - val_accuracy: 0.3538
# Epoch 13/100
# 25/25 [==============================] - ETA: 0s - loss: 0.2649 - accuracy: 0.9191
# Epoch 00013: val_accuracy improved from 0.35385 to 0.39103, saving model to best_model.h5
# 25/25 [==============================] - 289s 12s/step - loss: 0.2649 - accuracy: 0.9191 - val_loss: 1.5731 - val_accuracy: 0.3910
# Epoch 14/100
# 25/25 [==============================] - ETA: 0s - loss: 0.2762 - accuracy: 0.9127
# Epoch 00014: val_accuracy improved from 0.39103 to 0.44231, saving model to best_model.h5
# 25/25 [==============================] - 288s 12s/step - loss: 0.2762 - accuracy: 0.9127 - val_loss: 1.4404 - val_accuracy: 0.4423
# Epoch 15/100
# 25/25 [==============================] - ETA: 0s - loss: 0.2569 - accuracy: 0.9012
# Epoch 00015: val_accuracy improved from 0.44231 to 0.51667, saving model to best_model.h5
# 25/25 [==============================] - 290s 12s/step - loss: 0.2569 - accuracy: 0.9012 - val_loss: 1.3667 - val_accuracy: 0.5167
# Epoch 16/100
# 25/25 [==============================] - ETA: 0s - loss: 0.2825 - accuracy: 0.9089
# Epoch 00016: val_accuracy improved from 0.51667 to 0.57564, saving model to best_model.h5
# 25/25 [==============================] - 290s 12s/step - loss: 0.2825 - accuracy: 0.9089 - val_loss: 1.2590 - val_accuracy: 0.5756
# Epoch 17/100
# 25/25 [==============================] - ETA: 0s - loss: 0.2425 - accuracy: 0.9204
# Epoch 00017: val_accuracy improved from 0.57564 to 0.60385, saving model to best_model.h5
# 25/25 [==============================] - 290s 12s/step - loss: 0.2425 - accuracy: 0.9204 - val_loss: 1.1964 - val_accuracy: 0.6038
# Epoch 18/100
# 25/25 [==============================] - ETA: 0s - loss: 0.2314 - accuracy: 0.9076
# Epoch 00018: val_accuracy improved from 0.60385 to 0.62821, saving model to best_model.h5
# 25/25 [==============================] - 291s 12s/step - loss: 0.2314 - accuracy: 0.9076 - val_loss: 1.1810 - val_accuracy: 0.6282
# Epoch 19/100
# 25/25 [==============================] - ETA: 0s - loss: 0.2382 - accuracy: 0.9217
# Epoch 00019: val_accuracy improved from 0.62821 to 0.65769, saving model to best_model.h5
# 25/25 [==============================] - 292s 12s/step - loss: 0.2382 - accuracy: 0.9217 - val_loss: 1.1433 - val_accuracy: 0.6577
# Epoch 20/100
# 25/25 [==============================] - ETA: 0s - loss: 0.2251 - accuracy: 0.9178
# Epoch 00020: val_accuracy improved from 0.65769 to 0.67949, saving model to best_model.h5
# 25/25 [==============================] - 293s 12s/step - loss: 0.2251 - accuracy: 0.9178 - val_loss: 1.0662 - val_accuracy: 0.6795
# Epoch 21/100
# 25/25 [==============================] - ETA: 0s - loss: 0.2471 - accuracy: 0.9050
# Epoch 00021: val_accuracy improved from 0.67949 to 0.70513, saving model to best_model.h5
# 25/25 [==============================] - 293s 12s/step - loss: 0.2471 - accuracy: 0.9050 - val_loss: 0.9885 - val_accuracy: 0.7051
# Epoch 22/100
# 25/25 [==============================] - ETA: 0s - loss: 0.2416 - accuracy: 0.9166
# Epoch 00022: val_accuracy did not improve from 0.70513
# 25/25 [==============================] - 291s 12s/step - loss: 0.2416 - accuracy: 0.9166 - val_loss: 1.0035 - val_accuracy: 0.6910
# Epoch 23/100
# 25/25 [==============================] - ETA: 0s - loss: 0.2536 - accuracy: 0.9153
# Epoch 00023: val_accuracy improved from 0.70513 to 0.71923, saving model to best_model.h5
# 25/25 [==============================] - 293s 12s/step - loss: 0.2536 - accuracy: 0.9153 - val_loss: 0.9265 - val_accuracy: 0.7192
# Epoch 24/100
# 25/25 [==============================] - ETA: 0s - loss: 0.2036 - accuracy: 0.9255
# Epoch 00024: val_accuracy improved from 0.71923 to 0.74231, saving model to best_model.h5
# 25/25 [==============================] - 292s 12s/step - loss: 0.2036 - accuracy: 0.9255 - val_loss: 0.8549 - val_accuracy: 0.7423
# Epoch 25/100
# 25/25 [==============================] - ETA: 0s - loss: 0.2424 - accuracy: 0.9178
# Epoch 00025: val_accuracy improved from 0.74231 to 0.75769, saving model to best_model.h5
# 25/25 [==============================] - 293s 12s/step - loss: 0.2424 - accuracy: 0.9178 - val_loss: 0.7976 - val_accuracy: 0.7577
# Epoch 26/100
# 25/25 [==============================] - ETA: 0s - loss: 0.2016 - accuracy: 0.9281
# Epoch 00026: val_accuracy improved from 0.75769 to 0.75897, saving model to best_model.h5
# 25/25 [==============================] - 293s 12s/step - loss: 0.2016 - accuracy: 0.9281 - val_loss: 0.7987 - val_accuracy: 0.7590
# Epoch 27/100
# 25/25 [==============================] - ETA: 0s - loss: 0.2187 - accuracy: 0.9320
# Epoch 00027: val_accuracy improved from 0.75897 to 0.77436, saving model to best_model.h5
# 25/25 [==============================] - 293s 12s/step - loss: 0.2187 - accuracy: 0.9320 - val_loss: 0.8069 - val_accuracy: 0.7744
# Epoch 28/100
# 25/25 [==============================] - ETA: 0s - loss: 0.2294 - accuracy: 0.9127
# Epoch 00028: val_accuracy improved from 0.77436 to 0.77564, saving model to best_model.h5
# 25/25 [==============================] - 294s 12s/step - loss: 0.2294 - accuracy: 0.9127 - val_loss: 0.7732 - val_accuracy: 0.7756
# Epoch 29/100
# 25/25 [==============================] - ETA: 0s - loss: 0.1949 - accuracy: 0.9217
# Epoch 00029: val_accuracy did not improve from 0.77564
# 25/25 [==============================] - 289s 12s/step - loss: 0.1949 - accuracy: 0.9217 - val_loss: 0.8223 - val_accuracy: 0.7551
# Epoch 30/100
# 25/25 [==============================] - ETA: 0s - loss: 0.1904 - accuracy: 0.9397
# Epoch 00030: val_accuracy did not improve from 0.77564
# 25/25 [==============================] - 289s 12s/step - loss: 0.1904 - accuracy: 0.9397 - val_loss: 0.8069 - val_accuracy: 0.7641
# Epoch 31/100
# 25/25 [==============================] - ETA: 0s - loss: 0.1890 - accuracy: 0.9345
# Epoch 00031: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
#
# Epoch 00031: val_accuracy did not improve from 0.77564
# 25/25 [==============================] - 289s 12s/step - loss: 0.1890 - accuracy: 0.9345 - val_loss: 0.8190 - val_accuracy: 0.7679
# Epoch 32/100
# 25/25 [==============================] - ETA: 0s - loss: 0.1841 - accuracy: 0.9422
# Epoch 00032: val_accuracy did not improve from 0.77564
# 25/25 [==============================] - 289s 12s/step - loss: 0.1841 - accuracy: 0.9422 - val_loss: 0.7791 - val_accuracy: 0.7705
# Epoch 33/100
# 25/25 [==============================] - ETA: 0s - loss: 0.1868 - accuracy: 0.9320
# Epoch 00033: val_accuracy improved from 0.77564 to 0.77692, saving model to best_model.h5
# 25/25 [==============================] - 293s 12s/step - loss: 0.1868 - accuracy: 0.9320 - val_loss: 0.7416 - val_accuracy: 0.7769
# Epoch 34/100
# 25/25 [==============================] - ETA: 0s - loss: 0.2289 - accuracy: 0.9191
# Epoch 00034: val_accuracy improved from 0.77692 to 0.77949, saving model to best_model.h5
# 25/25 [==============================] - 293s 12s/step - loss: 0.2289 - accuracy: 0.9191 - val_loss: 0.7226 - val_accuracy: 0.7795
# Epoch 35/100
# 25/25 [==============================] - ETA: 0s - loss: 0.1635 - accuracy: 0.9474
# Epoch 00035: val_accuracy did not improve from 0.77949
# 25/25 [==============================] - 291s 12s/step - loss: 0.1635 - accuracy: 0.9474 - val_loss: 0.7262 - val_accuracy: 0.7769
# Epoch 36/100
# 25/25 [==============================] - ETA: 0s - loss: 0.1920 - accuracy: 0.9320
# Epoch 00036: val_accuracy did not improve from 0.77949
# 25/25 [==============================] - 290s 12s/step - loss: 0.1920 - accuracy: 0.9320 - val_loss: 0.7277 - val_accuracy: 0.7756
# Epoch 37/100
# 25/25 [==============================] - ETA: 0s - loss: 0.1926 - accuracy: 0.9332
# Epoch 00037: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
#
# Epoch 00037: val_accuracy did not improve from 0.77949
# 25/25 [==============================] - 290s 12s/step - loss: 0.1926 - accuracy: 0.9332 - val_loss: 0.7194 - val_accuracy: 0.7795
# Epoch 38/100
# 25/25 [==============================] - ETA: 0s - loss: 0.1685 - accuracy: 0.9422
# Epoch 00038: val_accuracy improved from 0.77949 to 0.78205, saving model to best_model.h5
# 25/25 [==============================] - 293s 12s/step - loss: 0.1685 - accuracy: 0.9422 - val_loss: 0.7036 - val_accuracy: 0.7821
# Epoch 39/100
# 25/25 [==============================] - ETA: 0s - loss: 0.1878 - accuracy: 0.9281
# Epoch 00039: val_accuracy improved from 0.78205 to 0.78718, saving model to best_model.h5
# 25/25 [==============================] - 294s 12s/step - loss: 0.1878 - accuracy: 0.9281 - val_loss: 0.6955 - val_accuracy: 0.7872
# Epoch 40/100
# 25/25 [==============================] - ETA: 0s - loss: 0.1629 - accuracy: 0.9371
# Epoch 00040: val_accuracy improved from 0.78718 to 0.78846, saving model to best_model.h5
# 25/25 [==============================] - 295s 12s/step - loss: 0.1629 - accuracy: 0.9371 - val_loss: 0.7041 - val_accuracy: 0.7885
# Epoch 41/100
# 25/25 [==============================] - ETA: 0s - loss: 0.1731 - accuracy: 0.9409
# Epoch 00041: val_accuracy did not improve from 0.78846
# 25/25 [==============================] - 291s 12s/step - loss: 0.1731 - accuracy: 0.9409 - val_loss: 0.7136 - val_accuracy: 0.7782
# Epoch 42/100
# 25/25 [==============================] - ETA: 0s - loss: 0.1561 - accuracy: 0.9538
# Epoch 00042: val_accuracy did not improve from 0.78846
# 25/25 [==============================] - 291s 12s/step - loss: 0.1561 - accuracy: 0.9538 - val_loss: 0.7156 - val_accuracy: 0.7795
# Epoch 43/100
# 25/25 [==============================] - ETA: 0s - loss: 0.1400 - accuracy: 0.9461
# Epoch 00043: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
#
# Epoch 00043: val_accuracy did not improve from 0.78846
# 25/25 [==============================] - 291s 12s/step - loss: 0.1400 - accuracy: 0.9461 - val_loss: 0.7270 - val_accuracy: 0.7769
# Epoch 44/100
# 25/25 [==============================] - ETA: 0s - loss: 0.1426 - accuracy: 0.9641
# Epoch 00044: val_accuracy did not improve from 0.78846
# 25/25 [==============================] - 291s 12s/step - loss: 0.1426 - accuracy: 0.9641 - val_loss: 0.7218 - val_accuracy: 0.7782
# Epoch 45/100
# 25/25 [==============================] - ETA: 0s - loss: 0.1566 - accuracy: 0.9397
# Epoch 00045: val_accuracy did not improve from 0.78846
# 25/25 [==============================] - 291s 12s/step - loss: 0.1566 - accuracy: 0.9397 - val_loss: 0.7269 - val_accuracy: 0.7769
# Epoch 46/100
# 25/25 [==============================] - ETA: 0s - loss: 0.1628 - accuracy: 0.9499
# Epoch 00046: ReduceLROnPlateau reducing learning rate to 1.9531250927684596e-06.
#
# Epoch 00046: val_accuracy did not improve from 0.78846
# 25/25 [==============================] - 292s 12s/step - loss: 0.1628 - accuracy: 0.9499 - val_loss: 0.7243 - val_accuracy: 0.7795
# Epoch 47/100
# 25/25 [==============================] - ETA: 0s - loss: 0.1320 - accuracy: 0.9551
# Epoch 00047: val_accuracy did not improve from 0.78846
# 25/25 [==============================] - 291s 12s/step - loss: 0.1320 - accuracy: 0.9551 - val_loss: 0.7242 - val_accuracy: 0.7769
# Epoch 48/100
# 25/25 [==============================] - ETA: 0s - loss: 0.1400 - accuracy: 0.9564
# Epoch 00048: val_accuracy did not improve from 0.78846
# 25/25 [==============================] - 299s 12s/step - loss: 0.1400 - accuracy: 0.9564 - val_loss: 0.7253 - val_accuracy: 0.7782
# Epoch 49/100
# 25/25 [==============================] - ETA: 0s - loss: 0.1532 - accuracy: 0.9525
# Epoch 00049: ReduceLROnPlateau reducing learning rate to 1e-06.
#
# Epoch 00049: val_accuracy did not improve from 0.78846
# 25/25 [==============================] - 291s 12s/step - loss: 0.1532 - accuracy: 0.9525 - val_loss: 0.7256 - val_accuracy: 0.7756
# Epoch 00049: early stopping

# %%
import seaborn as sns
sns.set_style('darkgrid')
import matplotlib.pyplot as plt
import matplotlib.image as mimg

# %%
accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(accuracy) + 1)

f, axes = plt.subplots(1,2,figsize=(14,4))

axes[0].plot(epochs, accuracy, 'g', label='Training accuracy')
axes[0].plot(epochs, val_accuracy, 'b', label='Validation accuracy')
axes[0].legend()

axes[1].plot(epochs, loss, 'g', label='Training loss')
axes[1].plot(epochs, val_loss, 'b', label='Validation loss')
axes[1].yaxis.set_label_position("right")
axes[1].legend()

plt.show()

# %%
saved_model = tf.keras.models.load_model('best_model.h5')
print("Test Accuracy: {0:.2f}%".format(saved_model.evaluate(x_test,y_test)[1]*100)) #get score acording to test datas
# Out:
# 14/14 [==============================] - 26s 2s/step - loss: 0.5603 - accuracy: 0.8065
# Test Accuracy: 80.65%

# %%
from sklearn.metrics import confusion_matrix
Y_pred = saved_model.predict(x_test)
Y_pred_classes = np.argmax(Y_pred,axis = 1)
Y_true = np.argmax(y_test,axis = 1)
confusion_mtx = confusion_matrix(Y_true,Y_pred_classes)
f,ax = plt.subplots(figsize = (8,8))
sns.heatmap(confusion_mtx,annot=True,linewidths = 0.01,cmap="Reds",
            linecolor = "gray",fmt = ".2f",ax=ax
            )
plt.xlabel("predicted label")
plt.ylabel("True Label")
plt.title("confusion matrix")
plt.show()

from sklearn.metrics import classification_report

print(classification_report(Y_true, Y_pred_classes))

y_test_inv = label_binarizer.inverse_transform(y_test)
print(classification_report(y_test_inv, Y_pred_classes, target_names = labels))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.86      0.90       111
#            1       0.93      0.77      0.84        84
#            2       0.71      0.74      0.72       104
#            3       0.82      0.92      0.87        60
#            4       0.67      0.77      0.72        75
#
#     accuracy                           0.81       434
#    macro avg       0.81      0.81      0.81       434
# weighted avg       0.82      0.81      0.81       434
#
#               precision    recall  f1-score   support
#
#    dandelion       0.94      0.86      0.90       111
#        daisy       0.93      0.77      0.84        84
#        tulip       0.71      0.74      0.72       104
#    sunflower       0.82      0.92      0.87        60
#         rose       0.67      0.77      0.72        75
#
#     accuracy                           0.81       434
#    macro avg       0.81      0.81      0.81       434
# weighted avg       0.82      0.81      0.81       434
