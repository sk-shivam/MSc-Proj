# %%
#Train Real with for 90%(60%real, 20%validation) and 10%test data
import keras
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout, Flatten
from keras.layers import Conv2D
from keras.layers import MaxPooling2D,MaxPool2D
from keras.layers.normalization import BatchNormalization
from keras.optimizers import Adam
from keras.preprocessing.image import ImageDataGenerator
from keras import layers
from keras import models
from keras import optimizers

from tensorflow.keras.applications.resnet50 import ResNet50

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
import os

# %%
#changing the working directory
# %cd /content/gdrive/My Drive/Thesis
# Out:
# /content/gdrive/My Drive/Thesis

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import keras
from keras.models import Sequential, Model
from keras.layers import Dense, Conv2D , MaxPool2D , Flatten , Dropout , MaxPooling2D
from keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report,confusion_matrix
from keras.applications import VGG19
import cv2
import os
import random
import tensorflow as tf
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
labels = ['dandelion', 'daisy','tulip','sunflower','rose']
img_size = 150
def get_data(data_dir):
    data = [] 
    for label in labels: 
        path = os.path.join(data_dir, label)
        class_num = labels.index(label)
        for img in os.listdir(path):
            try:
                img_arr = cv2.imread(os.path.join(path, img), cv2.IMREAD_COLOR)
                resized_arr = cv2.resize(img_arr, (img_size, img_size)) # Reshaping images to preferred size
                data.append([resized_arr, class_num])
            except Exception as e:
                print(e)
    return np.array(data)

# %%
data = get_data("/content/gdrive/My Drive/Thesis/flowers")
# Out:
# OpenCV(4.1.2) /io/opencv/modules/imgproc/src/resize.cpp:3720: error: (-215:Assertion failed) !ssize.empty() in function 'resize'
#
# OpenCV(4.1.2) /io/opencv/modules/imgproc/src/resize.cpp:3720: error: (-215:Assertion failed) !ssize.empty() in function 'resize'
#
# OpenCV(4.1.2) /io/opencv/modules/imgproc/src/resize.cpp:3720: error: (-215:Assertion failed) !ssize.empty() in function 'resize'

# %%
l = []
for i in data:
    l.append(labels[i[1]])
sns.set_style('dark')
sns.countplot(l)

# %%
fig,ax=plt.subplots(5,2)
fig.set_size_inches(15,15)
for i in range(5):
    for j in range (2):
        l=random.randint(0,len(data))
        ax[i,j].imshow(data[l][0])
        ax[i,j].set_title('Flower: '+labels[data[l][1]])
        
plt.tight_layout()

# %%
x = []
y = []

for feature, label in data:
    x.append(feature)
    y.append(label)

# %%
# Normalize the data
x = np.array(x) / 255

# %%
# Reshaping the data from 1-D to 3-D as required through input by CNN's 
x = x.reshape(-1, img_size, img_size, 3)
y = np.array(y)

# %%
from sklearn.preprocessing import LabelBinarizer
label_binarizer = LabelBinarizer()
y = label_binarizer.fit_transform(y)

# %%
x_train,x_test,y_train,y_test = train_test_split(x , y , test_size = 0.1 , random_state = 42)

# %%
x_train,x_val,y_train,y_val = train_test_split(x_train, y_train, test_size= 0.2, random_state = 42)

# %%
x_train,x_left,y_train,y_left = train_test_split(x_train, y_train, test_size= 0.25, random_state = 42)

# %%
model = Sequential()

#Adding ResNet model
model.add(ResNet50(include_top=False, pooling='avg', weights="imagenet", input_shape=(150,150,3)))
model.add(Flatten())

model.add(Dense(1024,activation="relu"))
model.add(Dropout(0.5))
model.add(BatchNormalization())

#Output layer
model.add(Dense(5, activation='softmax'))

model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94773248/94765736 [==============================] - 1s 0us/step
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# resnet50 (Functional)        (None, 2048)              23587712
# _________________________________________________________________
# flatten (Flatten)            (None, 2048)              0
# _________________________________________________________________
# dense (Dense)                (None, 1024)              2098176
# _________________________________________________________________
# dropout (Dropout)            (None, 1024)              0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 1024)              4096
# _________________________________________________________________
# dense_1 (Dense)              (None, 5)                 5125
# =================================================================
# Total params: 25,695,109
# Trainable params: 25,639,941
# Non-trainable params: 55,168
# _________________________________________________________________

# %%
#defining early stopping
from keras.callbacks import ReduceLROnPlateau
learning_rate = ReduceLROnPlateau(monitor='val_accuracy', patience = 3, verbose=1,factor=0.5, min_lr=0.000001)

es = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss', patience=10, verbose=1, mode='min')

# %%
# !pip install h5py
	
	
mc = tf.keras.callbacks.ModelCheckpoint('best_model.h5', monitor='val_accuracy', mode='max', verbose=1, save_best_only=True)
# Out:
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (2.10.0)
# Requirement already satisfied: numpy>=1.7 in /usr/local/lib/python3.6/dist-packages (from h5py) (1.18.5)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from h5py) (1.15.0)

# %%
model.compile(optimizer = "adam" , loss = 'categorical_crossentropy' , metrics = ['accuracy'])

# %%
#Fitting the augmentation data
history = model.fit(x_train, y_train, batch_size=32, epochs=100, validation_data = (x_val, y_val), callbacks = [learning_rate,es,mc])
# Out:
# Epoch 1/100
# 74/74 [==============================] - ETA: 0s - loss: 1.1441 - accuracy: 0.6020
# Epoch 00001: val_accuracy improved from -inf to 0.21282, saving model to best_model.h5
# 74/74 [==============================] - 845s 11s/step - loss: 1.1441 - accuracy: 0.6020 - val_loss: 9.1611 - val_accuracy: 0.2128
# Epoch 2/100
# 74/74 [==============================] - ETA: 0s - loss: 0.8631 - accuracy: 0.6922
# Epoch 00002: val_accuracy did not improve from 0.21282
# 74/74 [==============================] - 848s 11s/step - loss: 0.8631 - accuracy: 0.6922 - val_loss: 2.0695 - val_accuracy: 0.2128
# Epoch 3/100
# 74/74 [==============================] - ETA: 0s - loss: 0.6871 - accuracy: 0.7623
# Epoch 00003: val_accuracy did not improve from 0.21282
# 74/74 [==============================] - 844s 11s/step - loss: 0.6871 - accuracy: 0.7623 - val_loss: 2.2522 - val_accuracy: 0.2128
# Epoch 4/100
# 74/74 [==============================] - ETA: 0s - loss: 0.6093 - accuracy: 0.7841
# Epoch 00004: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00004: val_accuracy did not improve from 0.21282
# 74/74 [==============================] - 854s 12s/step - loss: 0.6093 - accuracy: 0.7841 - val_loss: 2.1930 - val_accuracy: 0.2128
# Epoch 5/100
# 74/74 [==============================] - ETA: 0s - loss: 0.4659 - accuracy: 0.8367
# Epoch 00005: val_accuracy did not improve from 0.21282
# 74/74 [==============================] - 856s 12s/step - loss: 0.4659 - accuracy: 0.8367 - val_loss: 1.9882 - val_accuracy: 0.2128
# Epoch 6/100
# 74/74 [==============================] - ETA: 0s - loss: 0.2994 - accuracy: 0.9042
# Epoch 00006: val_accuracy did not improve from 0.21282
# 74/74 [==============================] - 848s 11s/step - loss: 0.2994 - accuracy: 0.9042 - val_loss: 1.7888 - val_accuracy: 0.2128
# Epoch 7/100
# 74/74 [==============================] - ETA: 0s - loss: 0.2187 - accuracy: 0.9282
# Epoch 00007: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 00007: val_accuracy did not improve from 0.21282
# 74/74 [==============================] - 852s 12s/step - loss: 0.2187 - accuracy: 0.9282 - val_loss: 1.7333 - val_accuracy: 0.2128
# Epoch 8/100
# 74/74 [==============================] - ETA: 0s - loss: 0.1345 - accuracy: 0.9568
# Epoch 00008: val_accuracy improved from 0.21282 to 0.21410, saving model to best_model.h5
# 74/74 [==============================] - 846s 11s/step - loss: 0.1345 - accuracy: 0.9568 - val_loss: 1.8100 - val_accuracy: 0.2141
# Epoch 9/100
# 74/74 [==============================] - ETA: 0s - loss: 0.0898 - accuracy: 0.9761
# Epoch 00009: val_accuracy improved from 0.21410 to 0.28205, saving model to best_model.h5
# 74/74 [==============================] - 838s 11s/step - loss: 0.0898 - accuracy: 0.9761 - val_loss: 1.6998 - val_accuracy: 0.2821
# Epoch 10/100
# 74/74 [==============================] - ETA: 0s - loss: 0.0450 - accuracy: 0.9889
# Epoch 00010: val_accuracy improved from 0.28205 to 0.51282, saving model to best_model.h5
# 74/74 [==============================] - 839s 11s/step - loss: 0.0450 - accuracy: 0.9889 - val_loss: 1.2959 - val_accuracy: 0.5128
# Epoch 11/100
# 74/74 [==============================] - ETA: 0s - loss: 0.0535 - accuracy: 0.9846
# Epoch 00011: val_accuracy improved from 0.51282 to 0.62564, saving model to best_model.h5
# 74/74 [==============================] - 843s 11s/step - loss: 0.0535 - accuracy: 0.9846 - val_loss: 1.1331 - val_accuracy: 0.6256
# Epoch 12/100
# 74/74 [==============================] - ETA: 0s - loss: 0.0380 - accuracy: 0.9893
# Epoch 00012: val_accuracy improved from 0.62564 to 0.73205, saving model to best_model.h5
# 74/74 [==============================] - 841s 11s/step - loss: 0.0380 - accuracy: 0.9893 - val_loss: 0.8415 - val_accuracy: 0.7321
# Epoch 13/100
# 74/74 [==============================] - ETA: 0s - loss: 0.0569 - accuracy: 0.9846
# Epoch 00013: val_accuracy improved from 0.73205 to 0.78974, saving model to best_model.h5
# 74/74 [==============================] - 848s 11s/step - loss: 0.0569 - accuracy: 0.9846 - val_loss: 0.6804 - val_accuracy: 0.7897
# Epoch 14/100
# 74/74 [==============================] - ETA: 0s - loss: 0.0360 - accuracy: 0.9910
# Epoch 00014: val_accuracy improved from 0.78974 to 0.82949, saving model to best_model.h5
# 74/74 [==============================] - 865s 12s/step - loss: 0.0360 - accuracy: 0.9910 - val_loss: 0.5195 - val_accuracy: 0.8295
# Epoch 15/100
# 74/74 [==============================] - ETA: 0s - loss: 0.0457 - accuracy: 0.9872
# Epoch 00015: val_accuracy did not improve from 0.82949
# 74/74 [==============================] - 865s 12s/step - loss: 0.0457 - accuracy: 0.9872 - val_loss: 0.6974 - val_accuracy: 0.7987
# Epoch 16/100
# 74/74 [==============================] - ETA: 0s - loss: 0.0574 - accuracy: 0.9842
# Epoch 00016: val_accuracy improved from 0.82949 to 0.84487, saving model to best_model.h5
# 74/74 [==============================] - 846s 11s/step - loss: 0.0574 - accuracy: 0.9842 - val_loss: 0.5618 - val_accuracy: 0.8449
# Epoch 17/100
# 74/74 [==============================] - ETA: 0s - loss: 0.0554 - accuracy: 0.9838
# Epoch 00017: val_accuracy did not improve from 0.84487
# 74/74 [==============================] - 844s 11s/step - loss: 0.0554 - accuracy: 0.9838 - val_loss: 0.7874 - val_accuracy: 0.8000
# Epoch 18/100
# 74/74 [==============================] - ETA: 0s - loss: 0.0351 - accuracy: 0.9885
# Epoch 00018: val_accuracy improved from 0.84487 to 0.84744, saving model to best_model.h5
# 74/74 [==============================] - 853s 12s/step - loss: 0.0351 - accuracy: 0.9885 - val_loss: 0.5778 - val_accuracy: 0.8474
# Epoch 19/100
# 74/74 [==============================] - ETA: 0s - loss: 0.0400 - accuracy: 0.9893
# Epoch 00019: val_accuracy did not improve from 0.84744
# 74/74 [==============================] - 846s 11s/step - loss: 0.0400 - accuracy: 0.9893 - val_loss: 0.6413 - val_accuracy: 0.8192
# Epoch 20/100
# 74/74 [==============================] - ETA: 0s - loss: 0.0549 - accuracy: 0.9842
# Epoch 00020: val_accuracy did not improve from 0.84744
# 74/74 [==============================] - 842s 11s/step - loss: 0.0549 - accuracy: 0.9842 - val_loss: 0.5932 - val_accuracy: 0.8308
# Epoch 21/100
# 74/74 [==============================] - ETA: 0s - loss: 0.0597 - accuracy: 0.9872
# Epoch 00021: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 00021: val_accuracy did not improve from 0.84744
# 74/74 [==============================] - 863s 12s/step - loss: 0.0597 - accuracy: 0.9872 - val_loss: 0.5420 - val_accuracy: 0.8397
# Epoch 22/100
# 74/74 [==============================] - ETA: 0s - loss: 0.0406 - accuracy: 0.9889
# Epoch 00022: val_accuracy did not improve from 0.84744
# 74/74 [==============================] - 858s 12s/step - loss: 0.0406 - accuracy: 0.9889 - val_loss: 0.4885 - val_accuracy: 0.8462
# Epoch 23/100
# 74/74 [==============================] - ETA: 0s - loss: 0.0389 - accuracy: 0.9910
# Epoch 00023: val_accuracy did not improve from 0.84744
# 74/74 [==============================] - 854s 12s/step - loss: 0.0389 - accuracy: 0.9910 - val_loss: 0.6268 - val_accuracy: 0.8282
# Epoch 24/100
# 74/74 [==============================] - ETA: 0s - loss: 0.0476 - accuracy: 0.9880
# Epoch 00024: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
#
# Epoch 00024: val_accuracy did not improve from 0.84744
# 74/74 [==============================] - 847s 11s/step - loss: 0.0476 - accuracy: 0.9880 - val_loss: 0.8868 - val_accuracy: 0.8090
# Epoch 25/100
# 74/74 [==============================] - ETA: 0s - loss: 0.0294 - accuracy: 0.9962
# Epoch 00025: val_accuracy did not improve from 0.84744
# 74/74 [==============================] - 857s 12s/step - loss: 0.0294 - accuracy: 0.9962 - val_loss: 0.4725 - val_accuracy: 0.8449
# Epoch 26/100
# 74/74 [==============================] - ETA: 0s - loss: 0.0179 - accuracy: 0.9957
# Epoch 00026: val_accuracy improved from 0.84744 to 0.85385, saving model to best_model.h5
# 74/74 [==============================] - 849s 11s/step - loss: 0.0179 - accuracy: 0.9957 - val_loss: 0.4761 - val_accuracy: 0.8538
# Epoch 27/100
# 74/74 [==============================] - ETA: 0s - loss: 0.0209 - accuracy: 0.9957
# Epoch 00027: val_accuracy did not improve from 0.85385
# 74/74 [==============================] - 850s 11s/step - loss: 0.0209 - accuracy: 0.9957 - val_loss: 0.5151 - val_accuracy: 0.8423
# Epoch 28/100
# 74/74 [==============================] - ETA: 0s - loss: 0.0141 - accuracy: 0.9962
# Epoch 00028: val_accuracy did not improve from 0.85385
# 74/74 [==============================] - 856s 12s/step - loss: 0.0141 - accuracy: 0.9962 - val_loss: 0.5005 - val_accuracy: 0.8500
# Epoch 29/100
# 74/74 [==============================] - ETA: 0s - loss: 0.0142 - accuracy: 0.9974
# Epoch 00029: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
#
# Epoch 00029: val_accuracy did not improve from 0.85385
# 74/74 [==============================] - 855s 12s/step - loss: 0.0142 - accuracy: 0.9974 - val_loss: 0.5445 - val_accuracy: 0.8462
# Epoch 30/100
# 74/74 [==============================] - ETA: 0s - loss: 0.0287 - accuracy: 0.9936
# Epoch 00030: val_accuracy did not improve from 0.85385
# 74/74 [==============================] - 842s 11s/step - loss: 0.0287 - accuracy: 0.9936 - val_loss: 0.4977 - val_accuracy: 0.8500
# Epoch 31/100
# 74/74 [==============================] - ETA: 0s - loss: 0.0146 - accuracy: 0.9949
# Epoch 00031: val_accuracy did not improve from 0.85385
# 74/74 [==============================] - 835s 11s/step - loss: 0.0146 - accuracy: 0.9949 - val_loss: 0.4967 - val_accuracy: 0.8423
# Epoch 32/100
# 74/74 [==============================] - ETA: 0s - loss: 0.0185 - accuracy: 0.9962
# Epoch 00032: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
#
# Epoch 00032: val_accuracy did not improve from 0.85385
# 74/74 [==============================] - 840s 11s/step - loss: 0.0185 - accuracy: 0.9962 - val_loss: 0.4959 - val_accuracy: 0.8436
# Epoch 33/100
# 74/74 [==============================] - ETA: 0s - loss: 0.0112 - accuracy: 0.9987
# Epoch 00033: val_accuracy did not improve from 0.85385
# 74/74 [==============================] - 842s 11s/step - loss: 0.0112 - accuracy: 0.9987 - val_loss: 0.4932 - val_accuracy: 0.8513
# Epoch 34/100
# 74/74 [==============================] - ETA: 0s - loss: 0.0124 - accuracy: 0.9970
# Epoch 00034: val_accuracy did not improve from 0.85385
# 74/74 [==============================] - 836s 11s/step - loss: 0.0124 - accuracy: 0.9970 - val_loss: 0.4918 - val_accuracy: 0.8474
# Epoch 35/100
# 74/74 [==============================] - ETA: 0s - loss: 0.0187 - accuracy: 0.9983
# Epoch 00035: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
#
# Epoch 00035: val_accuracy did not improve from 0.85385
# 74/74 [==============================] - 835s 11s/step - loss: 0.0187 - accuracy: 0.9983 - val_loss: 0.4946 - val_accuracy: 0.8462
# Epoch 00035: early stopping

# %%
import seaborn as sns
sns.set_style('darkgrid')
import matplotlib.pyplot as plt
import matplotlib.image as mimg

# %%
accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(accuracy) + 1)

f, axes = plt.subplots(1,2,figsize=(14,4))

axes[0].plot(epochs, accuracy, 'g', label='Training accuracy')
axes[0].plot(epochs, val_accuracy, 'b', label='Validation accuracy')
axes[0].legend()

axes[1].plot(epochs, loss, 'g', label='Training loss')
axes[1].plot(epochs, val_loss, 'b', label='Validation loss')
axes[1].yaxis.set_label_position("right")
axes[1].legend()

plt.show()

# %%
saved_model = tf.keras.models.load_model('best_model.h5')
print("Test Accuracy: {0:.2f}%".format(saved_model.evaluate(x_test,y_test)[1]*100)) #get score acording to test datas
# Out:
# 14/14 [==============================] - 29s 2s/step - loss: 0.5003 - accuracy: 0.8571
# Test Accuracy: 85.71%

# %%
from sklearn.metrics import confusion_matrix
Y_pred = saved_model.predict(x_test)
Y_pred_classes = np.argmax(Y_pred,axis = 1)
Y_true = np.argmax(y_test,axis = 1)
confusion_mtx = confusion_matrix(Y_true,Y_pred_classes)
f,ax = plt.subplots(figsize = (8,8))
sns.heatmap(confusion_mtx,annot=True,linewidths = 0.01,cmap="Reds",
            linecolor = "gray",ax=ax
            )
plt.xlabel("predicted label")
plt.ylabel("True Label")
plt.title("confusion matrix")
plt.show()

from sklearn.metrics import classification_report

print(classification_report(Y_true, Y_pred_classes))


y_test_inv = label_binarizer.inverse_transform(y_test)
print(classification_report(y_test_inv, Y_pred_classes, target_names = labels))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      0.92      0.90       111
#            1       0.91      0.85      0.88        84
#            2       0.83      0.82      0.83       104
#            3       0.93      0.92      0.92        60
#            4       0.74      0.79      0.76        75
#
#     accuracy                           0.86       434
#    macro avg       0.86      0.86      0.86       434
# weighted avg       0.86      0.86      0.86       434
#
#               precision    recall  f1-score   support
#
#    dandelion       0.89      0.92      0.90       111
#        daisy       0.91      0.85      0.88        84
#        tulip       0.83      0.82      0.83       104
#    sunflower       0.93      0.92      0.92        60
#         rose       0.74      0.79      0.76        75
#
#     accuracy                           0.86       434
#    macro avg       0.86      0.86      0.86       434
# weighted avg       0.86      0.86      0.86       434
