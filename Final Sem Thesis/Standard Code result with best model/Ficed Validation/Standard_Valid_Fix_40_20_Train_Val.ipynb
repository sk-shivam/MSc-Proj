# %%
#Train Aug for 90%(40%train augmnented,20%validation) and 10%test data
import keras
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout, Flatten
from keras.layers import Conv2D
from keras.layers import MaxPooling2D,MaxPool2D
from keras.layers.normalization import BatchNormalization
from keras.optimizers import Adam
from keras.preprocessing.image import ImageDataGenerator
from keras import layers
from keras import models
from keras import optimizers

from tensorflow.keras.applications.resnet50 import ResNet50

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
import os

# %%
#changing the working directory
# %cd /content/gdrive/My Drive/Thesis
# Out:
# /content/gdrive/My Drive/Thesis

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import keras
from keras.models import Sequential, Model
from keras.layers import Dense, Conv2D , MaxPool2D , Flatten , Dropout , MaxPooling2D
from keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report,confusion_matrix
from keras.applications import VGG19
import cv2
import os
import random
import tensorflow as tf
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
labels = ['dandelion', 'daisy','tulip','sunflower','rose']
img_size = 150
def get_data(data_dir):
    data = [] 
    for label in labels: 
        path = os.path.join(data_dir, label)
        class_num = labels.index(label)
        for img in os.listdir(path):
            try:
                img_arr = cv2.imread(os.path.join(path, img), cv2.IMREAD_COLOR)
                resized_arr = cv2.resize(img_arr, (img_size, img_size)) # Reshaping images to preferred size
                data.append([resized_arr, class_num])
            except Exception as e:
                print(e)
    return np.array(data)

# %%
data = get_data("/content/gdrive/My Drive/Thesis/flowers")
# Out:
# OpenCV(4.1.2) /io/opencv/modules/imgproc/src/resize.cpp:3720: error: (-215:Assertion failed) !ssize.empty() in function 'resize'
#
# OpenCV(4.1.2) /io/opencv/modules/imgproc/src/resize.cpp:3720: error: (-215:Assertion failed) !ssize.empty() in function 'resize'
#
# OpenCV(4.1.2) /io/opencv/modules/imgproc/src/resize.cpp:3720: error: (-215:Assertion failed) !ssize.empty() in function 'resize'

# %%
l = []
for i in data:
    l.append(labels[i[1]])
sns.set_style('dark')
sns.countplot(l)

# %%
fig,ax=plt.subplots(5,2)
fig.set_size_inches(15,15)
for i in range(5):
    for j in range (2):
        l=random.randint(0,len(data))
        ax[i,j].imshow(data[l][0])
        ax[i,j].set_title('Flower: '+labels[data[l][1]])
        
plt.tight_layout()

# %%
x = []
y = []

for feature, label in data:
    x.append(feature)
    y.append(label)

# %%
# Normalize the data
x = np.array(x) / 255

# %%
# Reshaping the data from 1-D to 3-D as required through input by CNN's 
x = x.reshape(-1, img_size, img_size, 3)
y = np.array(y)

# %%
from sklearn.preprocessing import LabelBinarizer
label_binarizer = LabelBinarizer()
y = label_binarizer.fit_transform(y)

# %%
x_train,x_test,y_train,y_test = train_test_split(x , y , test_size = 0.1 , random_state = 42)

# %%
x_train,x_val,y_train,y_val = train_test_split(x_train, y_train, test_size= 0.2, random_state = 42)

# %%
x_train,x_left,y_train,y_left = train_test_split(x_train, y_train, test_size= 0.5, random_state = 42)

# %%
#defining the augmentation
datagen = ImageDataGenerator(
    featurewise_center=False,  # set input mean to 0 over the dataset
    samplewise_center=False,  # set each sample mean to 0
    featurewise_std_normalization=False,  # divide inputs by std of the dataset
    samplewise_std_normalization=False,  # divide each input by its std
    rotation_range=180,  # randomly rotate images in the range (0 to 180)
    zoom_range = 0.1, # Randomly zoom image 
    width_shift_range=0.1,  # randomly shift images horizontally (fraction of total width)
    height_shift_range=0.1,
    shear_range=0.1,
    fill_mode = "reflect"
    ) 
datagen.fit(x_train)

# %%
model = Sequential()

#Adding ResNet model
model.add(ResNet50(include_top=False, pooling='avg', weights="imagenet", input_shape=(150,150,3)))
model.add(Flatten())

model.add(Dense(1024,activation="relu"))
model.add(Dropout(0.5))
model.add(BatchNormalization())

#Output layer
model.add(Dense(5, activation='softmax'))

model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94773248/94765736 [==============================] - 2s 0us/step
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# resnet50 (Functional)        (None, 2048)              23587712
# _________________________________________________________________
# flatten (Flatten)            (None, 2048)              0
# _________________________________________________________________
# dense (Dense)                (None, 1024)              2098176
# _________________________________________________________________
# dropout (Dropout)            (None, 1024)              0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 1024)              4096
# _________________________________________________________________
# dense_1 (Dense)              (None, 5)                 5125
# =================================================================
# Total params: 25,695,109
# Trainable params: 25,639,941
# Non-trainable params: 55,168
# _________________________________________________________________

# %%
#defining early stopping
from keras.callbacks import ReduceLROnPlateau
learning_rate = ReduceLROnPlateau(monitor='val_accuracy', patience = 3, verbose=1,factor=0.5, min_lr=0.000001)

es = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss', patience=10, verbose=1, mode='min')

# %%
# !pip install h5py
	
	
mc = tf.keras.callbacks.ModelCheckpoint('best_model.h5', monitor='val_accuracy', mode='max', verbose=1, save_best_only=True)
# Out:
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (2.10.0)
# Requirement already satisfied: numpy>=1.7 in /usr/local/lib/python3.6/dist-packages (from h5py) (1.18.5)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from h5py) (1.15.0)

# %%
model.compile(optimizer = "adam" , loss = 'categorical_crossentropy' , metrics = ['accuracy'])

# %%
#Fitting the augmentation data
history = model.fit(datagen.flow(x_train, y_train, batch_size=32), epochs=100, validation_data = (x_val, y_val), callbacks = [learning_rate,es,mc])
# Out:
# Epoch 1/100
# 49/49 [==============================] - ETA: 0s - loss: 0.5140 - accuracy: 0.8153
# Epoch 00001: val_accuracy improved from 0.22949 to 0.32436, saving model to best_model.h5
# 49/49 [==============================] - 554s 11s/step - loss: 0.5140 - accuracy: 0.8153 - val_loss: 1.6115 - val_accuracy: 0.3244
# Epoch 2/100
# 49/49 [==============================] - ETA: 0s - loss: 0.5014 - accuracy: 0.8140
# Epoch 00002: val_accuracy improved from 0.32436 to 0.36410, saving model to best_model.h5
# 49/49 [==============================] - 560s 11s/step - loss: 0.5014 - accuracy: 0.8140 - val_loss: 1.4919 - val_accuracy: 0.3641
# Epoch 3/100
# 49/49 [==============================] - ETA: 0s - loss: 0.5291 - accuracy: 0.8159
# Epoch 00003: val_accuracy improved from 0.36410 to 0.47821, saving model to best_model.h5
# 49/49 [==============================] - 560s 11s/step - loss: 0.5291 - accuracy: 0.8159 - val_loss: 1.2711 - val_accuracy: 0.4782
# Epoch 4/100
# 49/49 [==============================] - ETA: 0s - loss: 0.5496 - accuracy: 0.8056
# Epoch 00004: val_accuracy improved from 0.47821 to 0.56795, saving model to best_model.h5
# 49/49 [==============================] - 563s 11s/step - loss: 0.5496 - accuracy: 0.8056 - val_loss: 1.0891 - val_accuracy: 0.5679
# Epoch 5/100
# 49/49 [==============================] - ETA: 0s - loss: 0.5476 - accuracy: 0.8108
# Epoch 00005: val_accuracy improved from 0.56795 to 0.64744, saving model to best_model.h5
# 49/49 [==============================] - 556s 11s/step - loss: 0.5476 - accuracy: 0.8108 - val_loss: 0.9890 - val_accuracy: 0.6474
# Epoch 6/100
# 49/49 [==============================] - ETA: 0s - loss: 0.5585 - accuracy: 0.8005
# Epoch 00006: val_accuracy improved from 0.64744 to 0.67179, saving model to best_model.h5
# 49/49 [==============================] - 556s 11s/step - loss: 0.5585 - accuracy: 0.8005 - val_loss: 0.9357 - val_accuracy: 0.6718
# Epoch 7/100
# 49/49 [==============================] - ETA: 0s - loss: 0.5690 - accuracy: 0.7922
# Epoch 00007: val_accuracy did not improve from 0.67179
# 49/49 [==============================] - 553s 11s/step - loss: 0.5690 - accuracy: 0.7922 - val_loss: 0.9829 - val_accuracy: 0.5795
# Epoch 8/100
# 49/49 [==============================] - ETA: 0s - loss: 0.5639 - accuracy: 0.8024
# Epoch 00008: val_accuracy improved from 0.67179 to 0.67308, saving model to best_model.h5
# 49/49 [==============================] - 560s 11s/step - loss: 0.5639 - accuracy: 0.8024 - val_loss: 0.8572 - val_accuracy: 0.6731
# Epoch 9/100
# 49/49 [==============================] - ETA: 0s - loss: 0.5570 - accuracy: 0.8076
# Epoch 00009: val_accuracy improved from 0.67308 to 0.76282, saving model to best_model.h5
# 49/49 [==============================] - 560s 11s/step - loss: 0.5570 - accuracy: 0.8076 - val_loss: 0.6473 - val_accuracy: 0.7628
# Epoch 10/100
# 49/49 [==============================] - ETA: 0s - loss: 0.4589 - accuracy: 0.8191
# Epoch 00010: val_accuracy did not improve from 0.76282
# 49/49 [==============================] - 559s 11s/step - loss: 0.4589 - accuracy: 0.8191 - val_loss: 0.7369 - val_accuracy: 0.7218
# Epoch 11/100
# 49/49 [==============================] - ETA: 0s - loss: 0.4633 - accuracy: 0.8319
# Epoch 00011: val_accuracy improved from 0.76282 to 0.76538, saving model to best_model.h5
# 49/49 [==============================] - 559s 11s/step - loss: 0.4633 - accuracy: 0.8319 - val_loss: 0.6435 - val_accuracy: 0.7654
# Epoch 12/100
# 49/49 [==============================] - ETA: 0s - loss: 0.4774 - accuracy: 0.8319
# Epoch 00012: val_accuracy did not improve from 0.76538
# 49/49 [==============================] - 555s 11s/step - loss: 0.4774 - accuracy: 0.8319 - val_loss: 0.7213 - val_accuracy: 0.7551
# Epoch 13/100
# 49/49 [==============================] - ETA: 0s - loss: 0.5021 - accuracy: 0.8101
# Epoch 00013: val_accuracy improved from 0.76538 to 0.77051, saving model to best_model.h5
# 49/49 [==============================] - 557s 11s/step - loss: 0.5021 - accuracy: 0.8101 - val_loss: 0.6036 - val_accuracy: 0.7705
# Epoch 14/100
# 49/49 [==============================] - ETA: 0s - loss: 0.4538 - accuracy: 0.8371
# Epoch 00014: val_accuracy did not improve from 0.77051
# 49/49 [==============================] - 553s 11s/step - loss: 0.4538 - accuracy: 0.8371 - val_loss: 1.5286 - val_accuracy: 0.7513
# Epoch 15/100
# 49/49 [==============================] - ETA: 0s - loss: 0.4614 - accuracy: 0.8204
# Epoch 00015: val_accuracy did not improve from 0.77051
# 49/49 [==============================] - 553s 11s/step - loss: 0.4614 - accuracy: 0.8204 - val_loss: 1.0517 - val_accuracy: 0.7026
# Epoch 16/100
# 49/49 [==============================] - ETA: 0s - loss: 0.4116 - accuracy: 0.8512
# Epoch 00016: val_accuracy improved from 0.77051 to 0.78462, saving model to best_model.h5
# 49/49 [==============================] - 558s 11s/step - loss: 0.4116 - accuracy: 0.8512 - val_loss: 0.9127 - val_accuracy: 0.7846
# Epoch 17/100
# 49/49 [==============================] - ETA: 0s - loss: 0.4178 - accuracy: 0.8435
# Epoch 00017: val_accuracy did not improve from 0.78462
# 49/49 [==============================] - 555s 11s/step - loss: 0.4178 - accuracy: 0.8435 - val_loss: 0.7146 - val_accuracy: 0.7538
# Epoch 18/100
# 49/49 [==============================] - ETA: 0s - loss: 0.3905 - accuracy: 0.8570
# Epoch 00018: val_accuracy did not improve from 0.78462
# 49/49 [==============================] - 554s 11s/step - loss: 0.3905 - accuracy: 0.8570 - val_loss: 0.6129 - val_accuracy: 0.7782
# Epoch 19/100
# 49/49 [==============================] - ETA: 0s - loss: 0.3745 - accuracy: 0.8563
# Epoch 00019: val_accuracy improved from 0.78462 to 0.78590, saving model to best_model.h5
# 49/49 [==============================] - 558s 11s/step - loss: 0.3745 - accuracy: 0.8563 - val_loss: 0.7717 - val_accuracy: 0.7859
# Epoch 20/100
# 49/49 [==============================] - ETA: 0s - loss: 0.3788 - accuracy: 0.8563
# Epoch 00020: val_accuracy improved from 0.78590 to 0.78846, saving model to best_model.h5
# 49/49 [==============================] - 556s 11s/step - loss: 0.3788 - accuracy: 0.8563 - val_loss: 1.1057 - val_accuracy: 0.7885
# Epoch 21/100
# 49/49 [==============================] - ETA: 0s - loss: 0.3417 - accuracy: 0.8756
# Epoch 00021: val_accuracy improved from 0.78846 to 0.80128, saving model to best_model.h5
# 49/49 [==============================] - 559s 11s/step - loss: 0.3417 - accuracy: 0.8756 - val_loss: 1.0960 - val_accuracy: 0.8013
# Epoch 22/100
# 49/49 [==============================] - ETA: 0s - loss: 0.3472 - accuracy: 0.8762
# Epoch 00022: val_accuracy did not improve from 0.80128
# 49/49 [==============================] - 556s 11s/step - loss: 0.3472 - accuracy: 0.8762 - val_loss: 2.3058 - val_accuracy: 0.7397
# Epoch 23/100
# 49/49 [==============================] - ETA: 0s - loss: 0.3040 - accuracy: 0.8948
# Epoch 00023: val_accuracy did not improve from 0.80128
# 49/49 [==============================] - 556s 11s/step - loss: 0.3040 - accuracy: 0.8948 - val_loss: 0.6264 - val_accuracy: 0.7962
# Epoch 00023: early stopping

# %%
import seaborn as sns
sns.set_style('darkgrid')
import matplotlib.pyplot as plt
import matplotlib.image as mimg

# %%
accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(accuracy) + 1)

f, axes = plt.subplots(1,2,figsize=(14,4))

axes[0].plot(epochs, accuracy, 'g', label='Training accuracy')
axes[0].plot(epochs, val_accuracy, 'b', label='Validation accuracy')
axes[0].legend()

axes[1].plot(epochs, loss, 'g', label='Training loss')
axes[1].plot(epochs, val_loss, 'b', label='Validation loss')
axes[1].yaxis.set_label_position("right")
axes[1].legend()

plt.show()

# %%
saved_model = tf.keras.models.load_model('best_model.h5')
print("Test Accuracy: {0:.2f}%".format(saved_model.evaluate(x_test,y_test)[1]*100)) #get score acording to test datas
# Out:
# 14/14 [==============================] - 28s 2s/step - loss: 0.7865 - accuracy: 0.8525
# Test Accuracy: 85.25%

# %%
from sklearn.metrics import confusion_matrix
Y_pred = saved_model.predict(x_test)
Y_pred_classes = np.argmax(Y_pred,axis = 1)
Y_true = np.argmax(y_test,axis = 1)
confusion_mtx = confusion_matrix(Y_true,Y_pred_classes)
f,ax = plt.subplots(figsize = (8,8))
sns.heatmap(confusion_mtx,annot=True,linewidths = 0.01,cmap="Reds",
            linecolor = "gray",fmt = ".2f",ax=ax
            )
plt.xlabel("predicted label")
plt.ylabel("True Label")
plt.title("confusion matrix")
plt.show()



y_test_inv = label_binarizer.inverse_transform(y_test)
print(classification_report(y_test_inv, Y_pred_classes, target_names = labels))
# Out:
#               precision    recall  f1-score   support
#
#    dandelion       0.96      0.92      0.94       111
#        daisy       0.93      0.85      0.89        84
#        tulip       0.73      0.79      0.76       104
#    sunflower       0.96      0.87      0.91        60
#         rose       0.73      0.84      0.78        75
#
#     accuracy                           0.85       434
#    macro avg       0.86      0.85      0.86       434
# weighted avg       0.86      0.85      0.86       434
