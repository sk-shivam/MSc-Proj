# %%
#Train Real with for 90%(20%real, 20%validation) and 10%test data
import keras
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout, Flatten
from keras.layers import Conv2D
from keras.layers import MaxPooling2D,MaxPool2D
from keras.layers.normalization import BatchNormalization
from keras.optimizers import Adam
from keras.preprocessing.image import ImageDataGenerator
from keras import layers
from keras import models
from keras import optimizers

from tensorflow.keras.applications.resnet50 import ResNet50

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
import os

# %%
#changing the working directory
# %cd /content/gdrive/My Drive/Thesis
# Out:
# /content/gdrive/My Drive/Thesis

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import keras
from keras.models import Sequential, Model
from keras.layers import Dense, Conv2D , MaxPool2D , Flatten , Dropout , MaxPooling2D
from keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report,confusion_matrix
from keras.applications import VGG19
import cv2
import os
import random
import tensorflow as tf
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
labels = ['dandelion', 'daisy','tulip','sunflower','rose']
img_size = 150
def get_data(data_dir):
    data = [] 
    for label in labels: 
        path = os.path.join(data_dir, label)
        class_num = labels.index(label)
        for img in os.listdir(path):
            try:
                img_arr = cv2.imread(os.path.join(path, img), cv2.IMREAD_COLOR)
                resized_arr = cv2.resize(img_arr, (img_size, img_size)) # Reshaping images to preferred size
                data.append([resized_arr, class_num])
            except Exception as e:
                print(e)
    return np.array(data)

# %%
data = get_data("/content/gdrive/My Drive/Thesis/flowers")
# Out:
# OpenCV(4.1.2) /io/opencv/modules/imgproc/src/resize.cpp:3720: error: (-215:Assertion failed) !ssize.empty() in function 'resize'
#
# OpenCV(4.1.2) /io/opencv/modules/imgproc/src/resize.cpp:3720: error: (-215:Assertion failed) !ssize.empty() in function 'resize'
#
# OpenCV(4.1.2) /io/opencv/modules/imgproc/src/resize.cpp:3720: error: (-215:Assertion failed) !ssize.empty() in function 'resize'

# %%
l = []
for i in data:
    l.append(labels[i[1]])
sns.set_style('dark')
sns.countplot(l)

# %%
fig,ax=plt.subplots(5,2)
fig.set_size_inches(15,15)
for i in range(5):
    for j in range (2):
        l=random.randint(0,len(data))
        ax[i,j].imshow(data[l][0])
        ax[i,j].set_title('Flower: '+labels[data[l][1]])
        
plt.tight_layout()

# %%
x = []
y = []

for feature, label in data:
    x.append(feature)
    y.append(label)

# %%
# Normalize the data
x = np.array(x) / 255

# %%
# Reshaping the data from 1-D to 3-D as required through input by CNN's 
x = x.reshape(-1, img_size, img_size, 3)
y = np.array(y)

# %%
from sklearn.preprocessing import LabelBinarizer
label_binarizer = LabelBinarizer()
y = label_binarizer.fit_transform(y)

# %%
x_train,x_test,y_train,y_test = train_test_split(x , y , test_size = 0.1 , random_state = 42)

# %%
x_train,x_val,y_train,y_val = train_test_split(x_train, y_train, test_size= 0.2, random_state = 42)

# %%
x_train,x_left,y_train,y_left = train_test_split(x_train, y_train, test_size= 0.75, random_state = 42)

# %%
model = Sequential()

#Adding ResNet model
model.add(ResNet50(include_top=False, pooling='avg', weights="imagenet", input_shape=(150,150,3)))
model.add(Flatten())

model.add(Dense(1024,activation="relu"))
model.add(Dropout(0.5))
model.add(BatchNormalization())

#Output layer
model.add(Dense(5, activation='softmax'))

model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94773248/94765736 [==============================] - 1s 0us/step
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# resnet50 (Functional)        (None, 2048)              23587712
# _________________________________________________________________
# flatten (Flatten)            (None, 2048)              0
# _________________________________________________________________
# dense (Dense)                (None, 1024)              2098176
# _________________________________________________________________
# dropout (Dropout)            (None, 1024)              0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 1024)              4096
# _________________________________________________________________
# dense_1 (Dense)              (None, 5)                 5125
# =================================================================
# Total params: 25,695,109
# Trainable params: 25,639,941
# Non-trainable params: 55,168
# _________________________________________________________________

# %%
#defining early stopping
from keras.callbacks import ReduceLROnPlateau
learning_rate = ReduceLROnPlateau(monitor='val_accuracy', patience = 3, verbose=1,factor=0.5, min_lr=0.000001)

es = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss', patience=10, verbose=1, mode='min')

# %%
# !pip install h5py
	
	
mc = tf.keras.callbacks.ModelCheckpoint('best_model.h5', monitor='val_accuracy', mode='max', verbose=1, save_best_only=True)
# Out:
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (2.10.0)
# Requirement already satisfied: numpy>=1.7 in /usr/local/lib/python3.6/dist-packages (from h5py) (1.18.5)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from h5py) (1.15.0)

# %%
model.compile(optimizer = "adam" , loss = 'categorical_crossentropy' , metrics = ['accuracy'])

# %%
#Fitting the augmentation data
history = model.fit(x_train, y_train, batch_size=32, epochs=100, validation_data = (x_val, y_val), callbacks = [learning_rate,es,mc])
# Out:
# Epoch 1/100
# 25/25 [==============================] - ETA: 0s - loss: 0.0245 - accuracy: 0.9949
# Epoch 00001: val_accuracy did not improve from 0.23265
# 25/25 [==============================] - 320s 13s/step - loss: 0.0245 - accuracy: 0.9949 - val_loss: 5.5856 - val_accuracy: 0.2326
# Epoch 2/100
# 25/25 [==============================] - ETA: 0s - loss: 0.0175 - accuracy: 0.9974
# Epoch 00002: val_accuracy did not improve from 0.23265
# 25/25 [==============================] - 328s 13s/step - loss: 0.0175 - accuracy: 0.9974 - val_loss: 5.8864 - val_accuracy: 0.2326
# Epoch 3/100
# 25/25 [==============================] - ETA: 0s - loss: 0.0264 - accuracy: 0.9961
# Epoch 00003: val_accuracy did not improve from 0.23265
# 25/25 [==============================] - 324s 13s/step - loss: 0.0264 - accuracy: 0.9961 - val_loss: 5.9682 - val_accuracy: 0.2326
# Epoch 4/100
# 25/25 [==============================] - ETA: 0s - loss: 0.0093 - accuracy: 1.0000
# Epoch 00004: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
#
# Epoch 00004: val_accuracy did not improve from 0.23265
# 25/25 [==============================] - 317s 13s/step - loss: 0.0093 - accuracy: 1.0000 - val_loss: 6.0445 - val_accuracy: 0.2326
# Epoch 5/100
# 25/25 [==============================] - ETA: 0s - loss: 0.0148 - accuracy: 0.9987
# Epoch 00005: val_accuracy did not improve from 0.23265
# 25/25 [==============================] - 317s 13s/step - loss: 0.0148 - accuracy: 0.9987 - val_loss: 6.2011 - val_accuracy: 0.2326
# Epoch 6/100
# 25/25 [==============================] - ETA: 0s - loss: 0.0099 - accuracy: 0.9987
# Epoch 00006: val_accuracy did not improve from 0.23265
# 25/25 [==============================] - 312s 12s/step - loss: 0.0099 - accuracy: 0.9987 - val_loss: 6.2000 - val_accuracy: 0.2326
# Epoch 7/100
# 25/25 [==============================] - ETA: 0s - loss: 0.0085 - accuracy: 1.0000
# Epoch 00007: val_accuracy improved from 0.23265 to 0.23393, saving model to best_model.h5
# 25/25 [==============================] - 318s 13s/step - loss: 0.0085 - accuracy: 1.0000 - val_loss: 6.0320 - val_accuracy: 0.2339
# Epoch 8/100
# 25/25 [==============================] - ETA: 0s - loss: 0.0122 - accuracy: 0.9987
# Epoch 00008: val_accuracy improved from 0.23393 to 0.23522, saving model to best_model.h5
# 25/25 [==============================] - 328s 13s/step - loss: 0.0122 - accuracy: 0.9987 - val_loss: 5.7310 - val_accuracy: 0.2352
# Epoch 9/100
# 25/25 [==============================] - ETA: 0s - loss: 0.0097 - accuracy: 0.9974
# Epoch 00009: val_accuracy improved from 0.23522 to 0.23779, saving model to best_model.h5
# 25/25 [==============================] - 319s 13s/step - loss: 0.0097 - accuracy: 0.9974 - val_loss: 5.1471 - val_accuracy: 0.2378
# Epoch 10/100
# 25/25 [==============================] - ETA: 0s - loss: 0.0116 - accuracy: 0.9974
# Epoch 00010: val_accuracy improved from 0.23779 to 0.24807, saving model to best_model.h5
# 25/25 [==============================] - 318s 13s/step - loss: 0.0116 - accuracy: 0.9974 - val_loss: 4.5927 - val_accuracy: 0.2481
# Epoch 11/100
# 25/25 [==============================] - ETA: 0s - loss: 0.0183 - accuracy: 0.9961
# Epoch 00011: val_accuracy improved from 0.24807 to 0.29049, saving model to best_model.h5
# 25/25 [==============================] - 313s 13s/step - loss: 0.0183 - accuracy: 0.9961 - val_loss: 3.6076 - val_accuracy: 0.2905
# Epoch 12/100
# 25/25 [==============================] - ETA: 0s - loss: 0.0199 - accuracy: 0.9961
# Epoch 00012: val_accuracy improved from 0.29049 to 0.36504, saving model to best_model.h5
# 25/25 [==============================] - 311s 12s/step - loss: 0.0199 - accuracy: 0.9961 - val_loss: 2.5165 - val_accuracy: 0.3650
# Epoch 13/100
# 25/25 [==============================] - ETA: 0s - loss: 0.0095 - accuracy: 0.9987
# Epoch 00013: val_accuracy improved from 0.36504 to 0.43830, saving model to best_model.h5
# 25/25 [==============================] - 314s 13s/step - loss: 0.0095 - accuracy: 0.9987 - val_loss: 2.0658 - val_accuracy: 0.4383
# Epoch 14/100
# 25/25 [==============================] - ETA: 0s - loss: 0.0435 - accuracy: 0.9884
# Epoch 00014: val_accuracy improved from 0.43830 to 0.51542, saving model to best_model.h5
# 25/25 [==============================] - 322s 13s/step - loss: 0.0435 - accuracy: 0.9884 - val_loss: 1.7633 - val_accuracy: 0.5154
# Epoch 15/100
# 25/25 [==============================] - ETA: 0s - loss: 0.0061 - accuracy: 0.9987
# Epoch 00015: val_accuracy improved from 0.51542 to 0.56555, saving model to best_model.h5
# 25/25 [==============================] - 316s 13s/step - loss: 0.0061 - accuracy: 0.9987 - val_loss: 1.5441 - val_accuracy: 0.5656
# Epoch 16/100
# 25/25 [==============================] - ETA: 0s - loss: 0.0072 - accuracy: 0.9987
# Epoch 00016: val_accuracy improved from 0.56555 to 0.61183, saving model to best_model.h5
# 25/25 [==============================] - 311s 12s/step - loss: 0.0072 - accuracy: 0.9987 - val_loss: 1.3850 - val_accuracy: 0.6118
# Epoch 17/100
# 25/25 [==============================] - ETA: 0s - loss: 0.0160 - accuracy: 0.9961
# Epoch 00017: val_accuracy improved from 0.61183 to 0.64267, saving model to best_model.h5
# 25/25 [==============================] - 313s 13s/step - loss: 0.0160 - accuracy: 0.9961 - val_loss: 1.2579 - val_accuracy: 0.6427
# Epoch 18/100
# 25/25 [==============================] - ETA: 0s - loss: 0.0163 - accuracy: 0.9987
# Epoch 00018: val_accuracy improved from 0.64267 to 0.68252, saving model to best_model.h5
# 25/25 [==============================] - 309s 12s/step - loss: 0.0163 - accuracy: 0.9987 - val_loss: 1.1705 - val_accuracy: 0.6825
# Epoch 19/100
# 25/25 [==============================] - ETA: 0s - loss: 0.0080 - accuracy: 1.0000
# Epoch 00019: val_accuracy improved from 0.68252 to 0.69923, saving model to best_model.h5
# 25/25 [==============================] - 307s 12s/step - loss: 0.0080 - accuracy: 1.0000 - val_loss: 1.1040 - val_accuracy: 0.6992
# Epoch 20/100
# 25/25 [==============================] - ETA: 0s - loss: 0.0073 - accuracy: 0.9987
# Epoch 00020: val_accuracy improved from 0.69923 to 0.71979, saving model to best_model.h5
# 25/25 [==============================] - 309s 12s/step - loss: 0.0073 - accuracy: 0.9987 - val_loss: 1.0552 - val_accuracy: 0.7198
# Epoch 21/100
# 25/25 [==============================] - ETA: 0s - loss: 0.0043 - accuracy: 1.0000
# Epoch 00021: val_accuracy improved from 0.71979 to 0.73650, saving model to best_model.h5
# 25/25 [==============================] - 308s 12s/step - loss: 0.0043 - accuracy: 1.0000 - val_loss: 0.9995 - val_accuracy: 0.7365
# Epoch 22/100
# 25/25 [==============================] - ETA: 0s - loss: 0.0097 - accuracy: 0.9987
# Epoch 00022: val_accuracy improved from 0.73650 to 0.74293, saving model to best_model.h5
# 25/25 [==============================] - 309s 12s/step - loss: 0.0097 - accuracy: 0.9987 - val_loss: 0.9489 - val_accuracy: 0.7429
# Epoch 23/100
# 25/25 [==============================] - ETA: 0s - loss: 0.0116 - accuracy: 0.9974
# Epoch 00023: val_accuracy improved from 0.74293 to 0.75835, saving model to best_model.h5
# 25/25 [==============================] - 312s 12s/step - loss: 0.0116 - accuracy: 0.9974 - val_loss: 0.9233 - val_accuracy: 0.7584
# Epoch 24/100
# 25/25 [==============================] - ETA: 0s - loss: 0.0198 - accuracy: 0.9974
# Epoch 00024: val_accuracy improved from 0.75835 to 0.77506, saving model to best_model.h5
# 25/25 [==============================] - 315s 13s/step - loss: 0.0198 - accuracy: 0.9974 - val_loss: 0.8677 - val_accuracy: 0.7751
# Epoch 25/100
# 25/25 [==============================] - ETA: 0s - loss: 0.0110 - accuracy: 1.0000
# Epoch 00025: val_accuracy did not improve from 0.77506
# 25/25 [==============================] - 316s 13s/step - loss: 0.0110 - accuracy: 1.0000 - val_loss: 0.8585 - val_accuracy: 0.7751
# Epoch 26/100
# 25/25 [==============================] - ETA: 0s - loss: 0.0109 - accuracy: 0.9974
# Epoch 00026: val_accuracy improved from 0.77506 to 0.79306, saving model to best_model.h5
# 25/25 [==============================] - 317s 13s/step - loss: 0.0109 - accuracy: 0.9974 - val_loss: 0.8136 - val_accuracy: 0.7931
# Epoch 27/100
# 25/25 [==============================] - ETA: 0s - loss: 0.0052 - accuracy: 1.0000
# Epoch 00027: val_accuracy did not improve from 0.79306
# 25/25 [==============================] - 317s 13s/step - loss: 0.0052 - accuracy: 1.0000 - val_loss: 0.7904 - val_accuracy: 0.7931
# Epoch 28/100
# 25/25 [==============================] - ETA: 0s - loss: 0.0180 - accuracy: 0.9961
# Epoch 00028: val_accuracy improved from 0.79306 to 0.80848, saving model to best_model.h5
# 25/25 [==============================] - 322s 13s/step - loss: 0.0180 - accuracy: 0.9961 - val_loss: 0.7755 - val_accuracy: 0.8085
# Epoch 29/100
# 25/25 [==============================] - ETA: 0s - loss: 0.0359 - accuracy: 0.9949
# Epoch 00029: val_accuracy did not improve from 0.80848
# 25/25 [==============================] - 311s 12s/step - loss: 0.0359 - accuracy: 0.9949 - val_loss: 0.8307 - val_accuracy: 0.7995
# Epoch 30/100
# 25/25 [==============================] - ETA: 0s - loss: 0.0069 - accuracy: 1.0000
# Epoch 00030: val_accuracy did not improve from 0.80848
# 25/25 [==============================] - 307s 12s/step - loss: 0.0069 - accuracy: 1.0000 - val_loss: 0.8210 - val_accuracy: 0.7982
# Epoch 31/100
# 25/25 [==============================] - ETA: 0s - loss: 0.0065 - accuracy: 1.0000
# Epoch 00031: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
#
# Epoch 00031: val_accuracy did not improve from 0.80848
# 25/25 [==============================] - 307s 12s/step - loss: 0.0065 - accuracy: 1.0000 - val_loss: 0.8084 - val_accuracy: 0.8021
# Epoch 32/100
# 25/25 [==============================] - ETA: 0s - loss: 0.0173 - accuracy: 0.9961
# Epoch 00032: val_accuracy did not improve from 0.80848
# 25/25 [==============================] - 306s 12s/step - loss: 0.0173 - accuracy: 0.9961 - val_loss: 0.7999 - val_accuracy: 0.8072
# Epoch 33/100
# 25/25 [==============================] - ETA: 0s - loss: 0.0137 - accuracy: 0.9974
# Epoch 00033: val_accuracy improved from 0.80848 to 0.80977, saving model to best_model.h5
# 25/25 [==============================] - 311s 12s/step - loss: 0.0137 - accuracy: 0.9974 - val_loss: 0.7727 - val_accuracy: 0.8098
# Epoch 34/100
# 25/25 [==============================] - ETA: 0s - loss: 0.0070 - accuracy: 0.9987
# Epoch 00034: val_accuracy improved from 0.80977 to 0.81105, saving model to best_model.h5
# 25/25 [==============================] - 317s 13s/step - loss: 0.0070 - accuracy: 0.9987 - val_loss: 0.7667 - val_accuracy: 0.8111
# Epoch 35/100
# 25/25 [==============================] - ETA: 0s - loss: 0.0109 - accuracy: 0.9987
# Epoch 00035: val_accuracy improved from 0.81105 to 0.81234, saving model to best_model.h5
# 25/25 [==============================] - 321s 13s/step - loss: 0.0109 - accuracy: 0.9987 - val_loss: 0.7615 - val_accuracy: 0.8123
# Epoch 36/100
# 25/25 [==============================] - ETA: 0s - loss: 0.0077 - accuracy: 0.9987
# Epoch 00036: val_accuracy did not improve from 0.81234
# 25/25 [==============================] - 312s 12s/step - loss: 0.0077 - accuracy: 0.9987 - val_loss: 0.7578 - val_accuracy: 0.8111
# Epoch 37/100
# 25/25 [==============================] - ETA: 0s - loss: 0.0077 - accuracy: 1.0000
# Epoch 00037: val_accuracy did not improve from 0.81234
# 25/25 [==============================] - 314s 13s/step - loss: 0.0077 - accuracy: 1.0000 - val_loss: 0.7605 - val_accuracy: 0.8123
# Epoch 38/100
# 25/25 [==============================] - ETA: 0s - loss: 0.0069 - accuracy: 1.0000
# Epoch 00038: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
#
# Epoch 00038: val_accuracy did not improve from 0.81234
# 25/25 [==============================] - 318s 13s/step - loss: 0.0069 - accuracy: 1.0000 - val_loss: 0.7687 - val_accuracy: 0.8059
# Epoch 39/100
# 25/25 [==============================] - ETA: 0s - loss: 0.0174 - accuracy: 0.9961
# Epoch 00039: val_accuracy did not improve from 0.81234
# 25/25 [==============================] - 324s 13s/step - loss: 0.0174 - accuracy: 0.9961 - val_loss: 0.7663 - val_accuracy: 0.8098
# Epoch 40/100
# 25/25 [==============================] - ETA: 0s - loss: 0.0057 - accuracy: 0.9987
# Epoch 00040: val_accuracy did not improve from 0.81234
# 25/25 [==============================] - 321s 13s/step - loss: 0.0057 - accuracy: 0.9987 - val_loss: 0.7666 - val_accuracy: 0.8098
# Epoch 41/100
# 25/25 [==============================] - ETA: 0s - loss: 0.0060 - accuracy: 1.0000
# Epoch 00041: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
#
# Epoch 00041: val_accuracy did not improve from 0.81234
# 25/25 [==============================] - 315s 13s/step - loss: 0.0060 - accuracy: 1.0000 - val_loss: 0.7668 - val_accuracy: 0.8098
# Epoch 42/100
# 25/25 [==============================] - ETA: 0s - loss: 0.0111 - accuracy: 0.9974
# Epoch 00042: val_accuracy did not improve from 0.81234
# 25/25 [==============================] - 317s 13s/step - loss: 0.0111 - accuracy: 0.9974 - val_loss: 0.7703 - val_accuracy: 0.8085
# Epoch 43/100
# 25/25 [==============================] - ETA: 0s - loss: 0.0060 - accuracy: 1.0000
# Epoch 00043: val_accuracy did not improve from 0.81234
# 25/25 [==============================] - 318s 13s/step - loss: 0.0060 - accuracy: 1.0000 - val_loss: 0.7707 - val_accuracy: 0.8072
# Epoch 44/100
# 25/25 [==============================] - ETA: 0s - loss: 0.0060 - accuracy: 1.0000
# Epoch 00044: ReduceLROnPlateau reducing learning rate to 1.9531250927684596e-06.
#
# Epoch 00044: val_accuracy did not improve from 0.81234
# 25/25 [==============================] - 315s 13s/step - loss: 0.0060 - accuracy: 1.0000 - val_loss: 0.7714 - val_accuracy: 0.8072
# Epoch 45/100
# 25/25 [==============================] - ETA: 0s - loss: 0.0056 - accuracy: 1.0000
# Epoch 00045: val_accuracy did not improve from 0.81234
# 25/25 [==============================] - 316s 13s/step - loss: 0.0056 - accuracy: 1.0000 - val_loss: 0.7723 - val_accuracy: 0.8098
# Epoch 46/100
# 25/25 [==============================] - ETA: 0s - loss: 0.0043 - accuracy: 1.0000
# Epoch 00046: val_accuracy did not improve from 0.81234
# 25/25 [==============================] - 313s 13s/step - loss: 0.0043 - accuracy: 1.0000 - val_loss: 0.7729 - val_accuracy: 0.8098
# Epoch 00046: early stopping

# %%
import seaborn as sns
sns.set_style('darkgrid')
import matplotlib.pyplot as plt
import matplotlib.image as mimg

# %%
accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(accuracy) + 1)

f, axes = plt.subplots(1,2,figsize=(14,4))

axes[0].plot(epochs, accuracy, 'g', label='Training accuracy')
axes[0].plot(epochs, val_accuracy, 'b', label='Validation accuracy')
axes[0].legend()

axes[1].plot(epochs, loss, 'g', label='Training loss')
axes[1].plot(epochs, val_loss, 'b', label='Validation loss')
axes[1].yaxis.set_label_position("right")
axes[1].legend()

plt.show()

# %%
saved_model = tf.keras.models.load_model('best_model.h5')
print("Test Accuracy: {0:.2f}%".format(saved_model.evaluate(x_test,y_test)[1]*100)) #get score acording to test datas
# Out:
# 14/14 [==============================] - 28s 2s/step - loss: 0.6416 - accuracy: 0.8222
# Test Accuracy: 82.22%

# %%
from sklearn.metrics import confusion_matrix
Y_pred = saved_model.predict(x_test)
Y_pred_classes = np.argmax(Y_pred,axis = 1)
Y_true = np.argmax(y_test,axis = 1)
confusion_mtx = confusion_matrix(Y_true,Y_pred_classes)
f,ax = plt.subplots(figsize = (8,8))
sns.heatmap(confusion_mtx,annot=True,linewidths = 0.01,cmap="Reds",
            linecolor = "gray",fmt = ".2f",ax=ax
            )
plt.xlabel("predicted label")
plt.ylabel("True Label")
plt.title("confusion matrix")
plt.show()

from sklearn.metrics import classification_report

print(classification_report(Y_true, Y_pred_classes))

y_test_inv = label_binarizer.inverse_transform(y_test)
print(classification_report(y_test_inv, Y_pred_classes, target_names = labels))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.79      0.93      0.86       123
#            1       0.97      0.75      0.85        89
#            2       0.80      0.70      0.75        84
#            3       0.87      0.88      0.87        67
#            4       0.73      0.80      0.76        70
#
#     accuracy                           0.82       433
#    macro avg       0.83      0.81      0.82       433
# weighted avg       0.83      0.82      0.82       433
#
#               precision    recall  f1-score   support
#
#    dandelion       0.79      0.93      0.86       123
#        daisy       0.97      0.75      0.85        89
#        tulip       0.80      0.70      0.75        84
#    sunflower       0.87      0.88      0.87        67
#         rose       0.73      0.80      0.76        70
#
#     accuracy                           0.82       433
#    macro avg       0.83      0.81      0.82       433
# weighted avg       0.83      0.82      0.82       433
