# %%
#Train Aug with for 90%(50%augmented, 20%validation) and 10%test data
import keras
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout, Flatten
from keras.layers import Conv2D
from keras.layers import MaxPooling2D,MaxPool2D
from keras.layers.normalization import BatchNormalization
from keras.optimizers import Adam
from keras.preprocessing.image import ImageDataGenerator
from keras import layers
from keras import models
from keras import optimizers

from tensorflow.keras.applications.resnet50 import ResNet50

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
import os

# %%
#changing the working directory
# %cd /content/gdrive/My Drive/Thesis
# Out:
# /content/gdrive/My Drive/Thesis

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import keras
from keras.models import Sequential, Model
from keras.layers import Dense, Conv2D , MaxPool2D , Flatten , Dropout , MaxPooling2D
from keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report,confusion_matrix
from keras.applications import VGG19
import cv2
import os
import random
import tensorflow as tf
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
labels = ['dandelion', 'daisy','tulip','sunflower','rose']
img_size = 150
def get_data(data_dir):
    data = [] 
    for label in labels: 
        path = os.path.join(data_dir, label)
        class_num = labels.index(label)
        for img in os.listdir(path):
            try:
                img_arr = cv2.imread(os.path.join(path, img), cv2.IMREAD_COLOR)
                resized_arr = cv2.resize(img_arr, (img_size, img_size)) # Reshaping images to preferred size
                data.append([resized_arr, class_num])
            except Exception as e:
                print(e)
    return np.array(data)

# %%
data = get_data("/content/gdrive/My Drive/Thesis/flowers")
# Out:
# OpenCV(4.1.2) /io/opencv/modules/imgproc/src/resize.cpp:3720: error: (-215:Assertion failed) !ssize.empty() in function 'resize'
#
# OpenCV(4.1.2) /io/opencv/modules/imgproc/src/resize.cpp:3720: error: (-215:Assertion failed) !ssize.empty() in function 'resize'
#
# OpenCV(4.1.2) /io/opencv/modules/imgproc/src/resize.cpp:3720: error: (-215:Assertion failed) !ssize.empty() in function 'resize'

# %%
l = []
for i in data:
    l.append(labels[i[1]])
sns.set_style('dark')
sns.countplot(l)

# %%
fig,ax=plt.subplots(5,2)
fig.set_size_inches(15,15)
for i in range(5):
    for j in range (2):
        l=random.randint(0,len(data))
        ax[i,j].imshow(data[l][0])
        ax[i,j].set_title('Flower: '+labels[data[l][1]])
        
plt.tight_layout()

# %%
x = []
y = []

for feature, label in data:
    x.append(feature)
    y.append(label)

# %%
# Normalize the data
x = np.array(x) / 255

# %%
# Reshaping the data from 1-D to 3-D as required through input by CNN's 
x = x.reshape(-1, img_size, img_size, 3)
y = np.array(y)

# %%
from sklearn.preprocessing import LabelBinarizer
label_binarizer = LabelBinarizer()
y = label_binarizer.fit_transform(y)

# %%
x_train,x_test,y_train,y_test = train_test_split(x , y , test_size = 0.1 , random_state = 42)

# %%
x_train,x_val,y_train,y_val = train_test_split(x_train, y_train, test_size= 0.2, random_state = 42)

# %%
x_train,x_left,y_train,y_left = train_test_split(x_train, y_train, test_size= 0.375, random_state = 42)

# %%
#defining the augmentation
datagen = ImageDataGenerator(
    featurewise_center=False,  # set input mean to 0 over the dataset
    samplewise_center=False,  # set each sample mean to 0
    featurewise_std_normalization=False,  # divide inputs by std of the dataset
    samplewise_std_normalization=False,  # divide each input by its std
    rotation_range=180,  # randomly rotate images in the range (0 to 180)
    zoom_range = 0.1, # Randomly zoom image 
    width_shift_range=0.1,  # randomly shift images horizontally (fraction of total width)
    height_shift_range=0.1,
    shear_range=0.1,
    fill_mode = "reflect"
    ) 
datagen.fit(x_train)

# %%
model = Sequential()


#Adding ResNet model
model.add(ResNet50(include_top=False, pooling='avg', weights="imagenet", input_shape=(150,150,3)))
model.add(Flatten())

model.add(Dense(1024,activation="relu"))
model.add(Dropout(0.5))
model.add(BatchNormalization())

#Output layer
model.add(Dense(5, activation='softmax'))

model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94773248/94765736 [==============================] - 1s 0us/step
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# resnet50 (Functional)        (None, 2048)              23587712
# _________________________________________________________________
# flatten (Flatten)            (None, 2048)              0
# _________________________________________________________________
# dense (Dense)                (None, 1024)              2098176
# _________________________________________________________________
# dropout (Dropout)            (None, 1024)              0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 1024)              4096
# _________________________________________________________________
# dense_1 (Dense)              (None, 5)                 5125
# =================================================================
# Total params: 25,695,109
# Trainable params: 25,639,941
# Non-trainable params: 55,168
# _________________________________________________________________

# %%
#defining early stopping
from keras.callbacks import ReduceLROnPlateau
learning_rate = ReduceLROnPlateau(monitor='val_accuracy', patience = 3, verbose=1,factor=0.5, min_lr=0.000001)

es = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss', patience=10, verbose=1, mode='min')

# %%
# !pip install h5py
	
	
mc = tf.keras.callbacks.ModelCheckpoint('best_model.h5', monitor='val_accuracy', mode='max', verbose=1, save_best_only=True)
# Out:
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (2.10.0)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from h5py) (1.15.0)
# Requirement already satisfied: numpy>=1.7 in /usr/local/lib/python3.6/dist-packages (from h5py) (1.18.5)

# %%
model.compile(optimizer = "adam" , loss = 'categorical_crossentropy' , metrics = ['accuracy'])

# %%
#Fitting the augmentation data
history = model.fit(datagen.flow(x_train, y_train, batch_size=32), epochs=100, validation_data = (x_val, y_val), callbacks = [learning_rate,es,mc])
# Out:
# Epoch 1/100
# 61/61 [==============================] - ETA: 0s - loss: 1.2896 - accuracy: 0.5377
# Epoch 00001: val_accuracy improved from -inf to 0.21282, saving model to best_model.h5
# 61/61 [==============================] - 683s 11s/step - loss: 1.2896 - accuracy: 0.5377 - val_loss: 441.1598 - val_accuracy: 0.2128
# Epoch 2/100
# 61/61 [==============================] - ETA: 0s - loss: 1.0788 - accuracy: 0.6147
# Epoch 00002: val_accuracy did not improve from 0.21282
# 61/61 [==============================] - 694s 11s/step - loss: 1.0788 - accuracy: 0.6147 - val_loss: 2.4715 - val_accuracy: 0.2128
# Epoch 3/100
# 61/61 [==============================] - ETA: 0s - loss: 1.0701 - accuracy: 0.6198
# Epoch 00003: val_accuracy did not improve from 0.21282
# 61/61 [==============================] - 691s 11s/step - loss: 1.0701 - accuracy: 0.6198 - val_loss: 1.6537 - val_accuracy: 0.2013
# Epoch 4/100
# 61/61 [==============================] - ETA: 0s - loss: 0.9614 - accuracy: 0.6496
# Epoch 00004: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00004: val_accuracy did not improve from 0.21282
# 61/61 [==============================] - 690s 11s/step - loss: 0.9614 - accuracy: 0.6496 - val_loss: 2.2182 - val_accuracy: 0.2128
# Epoch 5/100
# 61/61 [==============================] - ETA: 0s - loss: 0.7630 - accuracy: 0.7091
# Epoch 00005: val_accuracy did not improve from 0.21282
# 61/61 [==============================] - 683s 11s/step - loss: 0.7630 - accuracy: 0.7091 - val_loss: 1.6685 - val_accuracy: 0.2013
# Epoch 6/100
# 61/61 [==============================] - ETA: 0s - loss: 0.6339 - accuracy: 0.7753
# Epoch 00006: val_accuracy did not improve from 0.21282
# 61/61 [==============================] - 681s 11s/step - loss: 0.6339 - accuracy: 0.7753 - val_loss: 1.6670 - val_accuracy: 0.2013
# Epoch 7/100
# 61/61 [==============================] - ETA: 0s - loss: 0.5937 - accuracy: 0.7922
# Epoch 00007: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 00007: val_accuracy did not improve from 0.21282
# 61/61 [==============================] - 678s 11s/step - loss: 0.5937 - accuracy: 0.7922 - val_loss: 1.6667 - val_accuracy: 0.2013
# Epoch 8/100
# 61/61 [==============================] - ETA: 0s - loss: 0.5596 - accuracy: 0.7917
# Epoch 00008: val_accuracy did not improve from 0.21282
# 61/61 [==============================] - 680s 11s/step - loss: 0.5596 - accuracy: 0.7917 - val_loss: 1.6643 - val_accuracy: 0.2013
# Epoch 9/100
# 61/61 [==============================] - ETA: 0s - loss: 0.5293 - accuracy: 0.8235
# Epoch 00009: val_accuracy did not improve from 0.21282
# 61/61 [==============================] - 682s 11s/step - loss: 0.5293 - accuracy: 0.8235 - val_loss: 1.7085 - val_accuracy: 0.2026
# Epoch 10/100
# 61/61 [==============================] - ETA: 0s - loss: 0.4884 - accuracy: 0.8220
# Epoch 00010: val_accuracy improved from 0.21282 to 0.25641, saving model to best_model.h5
# 61/61 [==============================] - 688s 11s/step - loss: 0.4884 - accuracy: 0.8220 - val_loss: 1.7182 - val_accuracy: 0.2564
# Epoch 11/100
# 61/61 [==============================] - ETA: 0s - loss: 0.4308 - accuracy: 0.8384
# Epoch 00011: val_accuracy improved from 0.25641 to 0.43077, saving model to best_model.h5
# 61/61 [==============================] - 685s 11s/step - loss: 0.4308 - accuracy: 0.8384 - val_loss: 1.3925 - val_accuracy: 0.4308
# Epoch 12/100
# 61/61 [==============================] - ETA: 0s - loss: 0.4405 - accuracy: 0.8507
# Epoch 00012: val_accuracy improved from 0.43077 to 0.46026, saving model to best_model.h5
# 61/61 [==============================] - 681s 11s/step - loss: 0.4405 - accuracy: 0.8507 - val_loss: 1.3199 - val_accuracy: 0.4603
# Epoch 13/100
# 61/61 [==============================] - ETA: 0s - loss: 0.5022 - accuracy: 0.8240
# Epoch 00013: val_accuracy improved from 0.46026 to 0.55897, saving model to best_model.h5
# 61/61 [==============================] - 682s 11s/step - loss: 0.5022 - accuracy: 0.8240 - val_loss: 1.1549 - val_accuracy: 0.5590
# Epoch 14/100
# 61/61 [==============================] - ETA: 0s - loss: 0.4112 - accuracy: 0.8507
# Epoch 00014: val_accuracy improved from 0.55897 to 0.68333, saving model to best_model.h5
# 61/61 [==============================] - 685s 11s/step - loss: 0.4112 - accuracy: 0.8507 - val_loss: 0.8623 - val_accuracy: 0.6833
# Epoch 15/100
# 61/61 [==============================] - ETA: 0s - loss: 0.4004 - accuracy: 0.8563
# Epoch 00015: val_accuracy improved from 0.68333 to 0.72436, saving model to best_model.h5
# 61/61 [==============================] - 689s 11s/step - loss: 0.4004 - accuracy: 0.8563 - val_loss: 0.7792 - val_accuracy: 0.7244
# Epoch 16/100
# 61/61 [==============================] - ETA: 0s - loss: 0.3972 - accuracy: 0.8543
# Epoch 00016: val_accuracy improved from 0.72436 to 0.76410, saving model to best_model.h5
# 61/61 [==============================] - 697s 11s/step - loss: 0.3972 - accuracy: 0.8543 - val_loss: 0.6563 - val_accuracy: 0.7641
# Epoch 17/100
# 61/61 [==============================] - ETA: 0s - loss: 0.3788 - accuracy: 0.8635
# Epoch 00017: val_accuracy improved from 0.76410 to 0.78974, saving model to best_model.h5
# 61/61 [==============================] - 694s 11s/step - loss: 0.3788 - accuracy: 0.8635 - val_loss: 0.6392 - val_accuracy: 0.7897
# Epoch 18/100
# 61/61 [==============================] - ETA: 0s - loss: 0.3648 - accuracy: 0.8753
# Epoch 00018: val_accuracy did not improve from 0.78974
# 61/61 [==============================] - 690s 11s/step - loss: 0.3648 - accuracy: 0.8753 - val_loss: 0.6496 - val_accuracy: 0.7603
# Epoch 19/100
# 61/61 [==============================] - ETA: 0s - loss: 0.3895 - accuracy: 0.8676
# Epoch 00019: val_accuracy did not improve from 0.78974
# 61/61 [==============================] - 687s 11s/step - loss: 0.3895 - accuracy: 0.8676 - val_loss: 0.9641 - val_accuracy: 0.6897
# Epoch 20/100
# 61/61 [==============================] - ETA: 0s - loss: 0.4115 - accuracy: 0.8517
# Epoch 00020: val_accuracy improved from 0.78974 to 0.80385, saving model to best_model.h5
# 61/61 [==============================] - 691s 11s/step - loss: 0.4115 - accuracy: 0.8517 - val_loss: 0.5353 - val_accuracy: 0.8038
# Epoch 21/100
# 61/61 [==============================] - ETA: 0s - loss: 0.3421 - accuracy: 0.8743
# Epoch 00021: val_accuracy did not improve from 0.80385
# 61/61 [==============================] - 683s 11s/step - loss: 0.3421 - accuracy: 0.8743 - val_loss: 0.6509 - val_accuracy: 0.7821
# Epoch 22/100
# 61/61 [==============================] - ETA: 0s - loss: 0.3701 - accuracy: 0.8728
# Epoch 00022: val_accuracy did not improve from 0.80385
# 61/61 [==============================] - 686s 11s/step - loss: 0.3701 - accuracy: 0.8728 - val_loss: 0.6099 - val_accuracy: 0.7833
# Epoch 23/100
# 61/61 [==============================] - ETA: 0s - loss: 0.3483 - accuracy: 0.8743
# Epoch 00023: val_accuracy improved from 0.80385 to 0.83590, saving model to best_model.h5
# 61/61 [==============================] - 698s 11s/step - loss: 0.3483 - accuracy: 0.8743 - val_loss: 0.4734 - val_accuracy: 0.8359
# Epoch 24/100
# 61/61 [==============================] - ETA: 0s - loss: 0.3166 - accuracy: 0.8881
# Epoch 00024: val_accuracy did not improve from 0.83590
# 61/61 [==============================] - 703s 12s/step - loss: 0.3166 - accuracy: 0.8881 - val_loss: 0.6005 - val_accuracy: 0.8000
# Epoch 25/100
# 61/61 [==============================] - ETA: 0s - loss: 0.2889 - accuracy: 0.8917
# Epoch 00025: val_accuracy did not improve from 0.83590
# 61/61 [==============================] - 704s 12s/step - loss: 0.2889 - accuracy: 0.8917 - val_loss: 0.5770 - val_accuracy: 0.7962
# Epoch 26/100
# 61/61 [==============================] - ETA: 0s - loss: 0.2879 - accuracy: 0.8979
# Epoch 00026: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 00026: val_accuracy did not improve from 0.83590
# 61/61 [==============================] - 706s 12s/step - loss: 0.2879 - accuracy: 0.8979 - val_loss: 0.5605 - val_accuracy: 0.8038
# Epoch 27/100
# 61/61 [==============================] - ETA: 0s - loss: 0.2440 - accuracy: 0.9123
# Epoch 00027: val_accuracy improved from 0.83590 to 0.85385, saving model to best_model.h5
# 61/61 [==============================] - 713s 12s/step - loss: 0.2440 - accuracy: 0.9123 - val_loss: 0.4877 - val_accuracy: 0.8538
# Epoch 28/100
# 61/61 [==============================] - ETA: 0s - loss: 0.2097 - accuracy: 0.9282
# Epoch 00028: val_accuracy did not improve from 0.85385
# 61/61 [==============================] - 697s 11s/step - loss: 0.2097 - accuracy: 0.9282 - val_loss: 0.4385 - val_accuracy: 0.8462
# Epoch 29/100
# 61/61 [==============================] - ETA: 0s - loss: 0.2164 - accuracy: 0.9241
# Epoch 00029: val_accuracy did not improve from 0.85385
# 61/61 [==============================] - 698s 11s/step - loss: 0.2164 - accuracy: 0.9241 - val_loss: 0.4953 - val_accuracy: 0.8179
# Epoch 30/100
# 61/61 [==============================] - ETA: 0s - loss: 0.2127 - accuracy: 0.9225
# Epoch 00030: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
#
# Epoch 00030: val_accuracy did not improve from 0.85385
# 61/61 [==============================] - 698s 11s/step - loss: 0.2127 - accuracy: 0.9225 - val_loss: 0.4854 - val_accuracy: 0.8269
# Epoch 31/100
# 61/61 [==============================] - ETA: 0s - loss: 0.1928 - accuracy: 0.9374
# Epoch 00031: val_accuracy did not improve from 0.85385
# 61/61 [==============================] - 702s 12s/step - loss: 0.1928 - accuracy: 0.9374 - val_loss: 0.4667 - val_accuracy: 0.8372
# Epoch 32/100
# 61/61 [==============================] - ETA: 0s - loss: 0.1719 - accuracy: 0.9374
# Epoch 00032: val_accuracy did not improve from 0.85385
# 61/61 [==============================] - 700s 11s/step - loss: 0.1719 - accuracy: 0.9374 - val_loss: 0.5060 - val_accuracy: 0.8295
# Epoch 33/100
# 61/61 [==============================] - ETA: 0s - loss: 0.1744 - accuracy: 0.9425
# Epoch 00033: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
#
# Epoch 00033: val_accuracy did not improve from 0.85385
# 61/61 [==============================] - 699s 11s/step - loss: 0.1744 - accuracy: 0.9425 - val_loss: 0.4982 - val_accuracy: 0.8372
# Epoch 34/100
# 61/61 [==============================] - ETA: 0s - loss: 0.1367 - accuracy: 0.9482
# Epoch 00034: val_accuracy did not improve from 0.85385
# 61/61 [==============================] - 704s 12s/step - loss: 0.1367 - accuracy: 0.9482 - val_loss: 0.4530 - val_accuracy: 0.8500
# Epoch 35/100
# 61/61 [==============================] - ETA: 0s - loss: 0.1768 - accuracy: 0.9425
# Epoch 00035: val_accuracy did not improve from 0.85385
# 61/61 [==============================] - 704s 12s/step - loss: 0.1768 - accuracy: 0.9425 - val_loss: 0.4613 - val_accuracy: 0.8397
# Epoch 36/100
# 61/61 [==============================] - ETA: 0s - loss: 0.1483 - accuracy: 0.9502
# Epoch 00036: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
#
# Epoch 00036: val_accuracy did not improve from 0.85385
# 61/61 [==============================] - 708s 12s/step - loss: 0.1483 - accuracy: 0.9502 - val_loss: 0.4479 - val_accuracy: 0.8538
# Epoch 37/100
# 61/61 [==============================] - ETA: 0s - loss: 0.1428 - accuracy: 0.9543
# Epoch 00037: val_accuracy did not improve from 0.85385
# 61/61 [==============================] - 714s 12s/step - loss: 0.1428 - accuracy: 0.9543 - val_loss: 0.4486 - val_accuracy: 0.8513
# Epoch 38/100
# 61/61 [==============================] - ETA: 0s - loss: 0.1315 - accuracy: 0.9559
# Epoch 00038: val_accuracy improved from 0.85385 to 0.85897, saving model to best_model.h5
# 61/61 [==============================] - 704s 12s/step - loss: 0.1315 - accuracy: 0.9559 - val_loss: 0.4371 - val_accuracy: 0.8590
# Epoch 39/100
# 61/61 [==============================] - ETA: 0s - loss: 0.1427 - accuracy: 0.9477
# Epoch 00039: val_accuracy improved from 0.85897 to 0.86154, saving model to best_model.h5
# 61/61 [==============================] - 727s 12s/step - loss: 0.1427 - accuracy: 0.9477 - val_loss: 0.4429 - val_accuracy: 0.8615
# Epoch 40/100
# 61/61 [==============================] - ETA: 0s - loss: 0.1398 - accuracy: 0.9492
# Epoch 00040: val_accuracy did not improve from 0.86154
# 61/61 [==============================] - 771s 13s/step - loss: 0.1398 - accuracy: 0.9492 - val_loss: 0.4493 - val_accuracy: 0.8577
# Epoch 41/100
# 61/61 [==============================] - ETA: 0s - loss: 0.1604 - accuracy: 0.9461
# Epoch 00041: val_accuracy improved from 0.86154 to 0.86282, saving model to best_model.h5
# 61/61 [==============================] - 770s 13s/step - loss: 0.1604 - accuracy: 0.9461 - val_loss: 0.4541 - val_accuracy: 0.8628
# Epoch 42/100
# 61/61 [==============================] - ETA: 0s - loss: 0.1292 - accuracy: 0.9584
# Epoch 00042: val_accuracy did not improve from 0.86282
# 61/61 [==============================] - 699s 11s/step - loss: 0.1292 - accuracy: 0.9584 - val_loss: 0.4634 - val_accuracy: 0.8615
# Epoch 43/100
# 61/61 [==============================] - ETA: 0s - loss: 0.1255 - accuracy: 0.9595
# Epoch 00043: val_accuracy did not improve from 0.86282
# 61/61 [==============================] - 741s 12s/step - loss: 0.1255 - accuracy: 0.9595 - val_loss: 0.4613 - val_accuracy: 0.8628
# Epoch 44/100
# 61/61 [==============================] - ETA: 0s - loss: 0.1300 - accuracy: 0.9564
# Epoch 00044: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
#
# Epoch 00044: val_accuracy did not improve from 0.86282
# 61/61 [==============================] - 736s 12s/step - loss: 0.1300 - accuracy: 0.9564 - val_loss: 0.4561 - val_accuracy: 0.8590
# Epoch 45/100
# 61/61 [==============================] - ETA: 0s - loss: 0.1216 - accuracy: 0.9590
# Epoch 00045: val_accuracy did not improve from 0.86282
# 61/61 [==============================] - 709s 12s/step - loss: 0.1216 - accuracy: 0.9590 - val_loss: 0.4569 - val_accuracy: 0.8603
# Epoch 46/100
# 61/61 [==============================] - ETA: 0s - loss: 0.1306 - accuracy: 0.9574
# Epoch 00046: val_accuracy did not improve from 0.86282
# 61/61 [==============================] - 691s 11s/step - loss: 0.1306 - accuracy: 0.9574 - val_loss: 0.4582 - val_accuracy: 0.8603
# Epoch 47/100
# 61/61 [==============================] - ETA: 0s - loss: 0.1160 - accuracy: 0.9584
# Epoch 00047: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
#
# Epoch 00047: val_accuracy did not improve from 0.86282
# 61/61 [==============================] - 703s 12s/step - loss: 0.1160 - accuracy: 0.9584 - val_loss: 0.4660 - val_accuracy: 0.8603
# Epoch 48/100
# 61/61 [==============================] - ETA: 0s - loss: 0.1210 - accuracy: 0.9610
# Epoch 00048: val_accuracy did not improve from 0.86282
# 61/61 [==============================] - 690s 11s/step - loss: 0.1210 - accuracy: 0.9610 - val_loss: 0.4594 - val_accuracy: 0.8615
# Epoch 00048: early stopping

# %%
import seaborn as sns
sns.set_style('darkgrid')
import matplotlib.pyplot as plt
import matplotlib.image as mimg

# %%
accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(accuracy) + 1)

f, axes = plt.subplots(1,2,figsize=(14,4))

axes[0].plot(epochs, accuracy, 'g', label='Training accuracy')
axes[0].plot(epochs, val_accuracy, 'b', label='Validation accuracy')
axes[0].legend()

axes[1].plot(epochs, loss, 'g', label='Training loss')
axes[1].plot(epochs, val_loss, 'b', label='Validation loss')
axes[1].yaxis.set_label_position("right")
axes[1].legend()

plt.show()

# %%
saved_model = tf.keras.models.load_model('best_model.h5')
print("Test Accuracy: {0:.2f}%".format(saved_model.evaluate(x_test,y_test)[1]*100)) #get score acording to test datas
# Out:
# 14/14 [==============================] - 28s 2s/step - loss: 0.3427 - accuracy: 0.8963
# Test Accuracy: 89.63%

# %%
from sklearn.metrics import confusion_matrix
Y_pred = saved_model.predict(x_test)
Y_pred_classes = np.argmax(Y_pred,axis = 1)
Y_true = np.argmax(y_test,axis = 1)
confusion_mtx = confusion_matrix(Y_true,Y_pred_classes)
f,ax = plt.subplots(figsize = (8,8))
sns.heatmap(confusion_mtx,annot=True,linewidths = 0.01,cmap="Reds",
            linecolor = "gray",ax=ax
            )
plt.xlabel("predicted label")
plt.ylabel("True Label")
plt.title("confusion matrix")
plt.show()


y_test_inv = label_binarizer.inverse_transform(y_test)
print(classification_report(y_test_inv, Y_pred_classes, target_names = labels))
# Out:
#               precision    recall  f1-score   support
#
#    dandelion       0.96      0.93      0.94       111
#        daisy       0.95      0.83      0.89        84
#        tulip       0.82      0.89      0.86       104
#    sunflower       0.90      0.93      0.92        60
#         rose       0.86      0.89      0.88        75
#
#     accuracy                           0.90       434
#    macro avg       0.90      0.90      0.90       434
# weighted avg       0.90      0.90      0.90       434
