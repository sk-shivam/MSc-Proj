# %%
#Train Aug with for 90%(60%augmented, 20%validation) and 10%test data
import keras
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout, Flatten
from keras.layers import Conv2D
from keras.layers import MaxPooling2D,MaxPool2D
from keras.layers.normalization import BatchNormalization
from keras.optimizers import Adam
from keras.preprocessing.image import ImageDataGenerator
from keras import layers
from keras import models
from keras import optimizers

from tensorflow.keras.applications.resnet50 import ResNet50

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
import os

# %%
#changing the working directory
# %cd /content/gdrive/My Drive/Thesis
# Out:
# /content/gdrive/My Drive/Thesis

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import keras
from keras.models import Sequential, Model
from keras.layers import Dense, Conv2D , MaxPool2D , Flatten , Dropout , MaxPooling2D
from keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report,confusion_matrix
from keras.applications import VGG19
import cv2
import os
import random
import tensorflow as tf
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
labels = ['dandelion', 'daisy','tulip','sunflower','rose']
img_size = 150
def get_data(data_dir):
    data = [] 
    for label in labels: 
        path = os.path.join(data_dir, label)
        class_num = labels.index(label)
        for img in os.listdir(path):
            try:
                img_arr = cv2.imread(os.path.join(path, img), cv2.IMREAD_COLOR)
                resized_arr = cv2.resize(img_arr, (img_size, img_size)) # Reshaping images to preferred size
                data.append([resized_arr, class_num])
            except Exception as e:
                print(e)
    return np.array(data)

# %%
data = get_data("/content/gdrive/My Drive/Thesis/flowers")
# Out:
# OpenCV(4.1.2) /io/opencv/modules/imgproc/src/resize.cpp:3720: error: (-215:Assertion failed) !ssize.empty() in function 'resize'
#
# OpenCV(4.1.2) /io/opencv/modules/imgproc/src/resize.cpp:3720: error: (-215:Assertion failed) !ssize.empty() in function 'resize'
#
# OpenCV(4.1.2) /io/opencv/modules/imgproc/src/resize.cpp:3720: error: (-215:Assertion failed) !ssize.empty() in function 'resize'

# %%
l = []
for i in data:
    l.append(labels[i[1]])
sns.set_style('dark')
sns.countplot(l)

# %%
fig,ax=plt.subplots(5,2)
fig.set_size_inches(15,15)
for i in range(5):
    for j in range (2):
        l=random.randint(0,len(data))
        ax[i,j].imshow(data[l][0])
        ax[i,j].set_title('Flower: '+labels[data[l][1]])
        
plt.tight_layout()

# %%
x = []
y = []

for feature, label in data:
    x.append(feature)
    y.append(label)

# %%
# Normalize the data
x = np.array(x) / 255

# %%
# Reshaping the data from 1-D to 3-D as required through input by CNN's 
x = x.reshape(-1, img_size, img_size, 3)
y = np.array(y)

# %%
from sklearn.preprocessing import LabelBinarizer
label_binarizer = LabelBinarizer()
y = label_binarizer.fit_transform(y)

# %%
x_train,x_test,y_train,y_test = train_test_split(x , y , test_size = 0.1 , random_state = 42)

# %%
x_train,x_val,y_train,y_val = train_test_split(x_train, y_train, test_size= 0.2, random_state = 42)

# %%
x_train,x_left,y_train,y_left = train_test_split(x_train, y_train, test_size= 0.25, random_state = 42)

# %%
#defining the augmentation
datagen = ImageDataGenerator(
    featurewise_center=False,  # set input mean to 0 over the dataset
    samplewise_center=False,  # set each sample mean to 0
    featurewise_std_normalization=False,  # divide inputs by std of the dataset
    samplewise_std_normalization=False,  # divide each input by its std
    rotation_range=180,  # randomly rotate images in the range (0 to 180)
    zoom_range = 0.1, # Randomly zoom image 
    width_shift_range=0.1,  # randomly shift images horizontally (fraction of total width)
    height_shift_range=0.1,
    shear_range=0.1,
    fill_mode = "reflect"
    ) 
datagen.fit(x_train)

# %%
model = Sequential()

#Adding ResNet model
model.add(ResNet50(include_top=False, pooling='avg', weights="imagenet", input_shape=(150,150,3)))
model.add(Flatten())

model.add(Dense(1024,activation="relu"))
model.add(Dropout(0.5))
model.add(BatchNormalization())

#Output layer
model.add(Dense(5, activation='softmax'))

model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94773248/94765736 [==============================] - 2s 0us/step
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# resnet50 (Functional)        (None, 2048)              23587712
# _________________________________________________________________
# flatten (Flatten)            (None, 2048)              0
# _________________________________________________________________
# dense (Dense)                (None, 1024)              2098176
# _________________________________________________________________
# dropout (Dropout)            (None, 1024)              0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 1024)              4096
# _________________________________________________________________
# dense_1 (Dense)              (None, 5)                 5125
# =================================================================
# Total params: 25,695,109
# Trainable params: 25,639,941
# Non-trainable params: 55,168
# _________________________________________________________________

# %%
#defining early stopping
from keras.callbacks import ReduceLROnPlateau
learning_rate = ReduceLROnPlateau(monitor='val_accuracy', patience = 3, verbose=1,factor=0.5, min_lr=0.000001)

es = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss', patience=10, verbose=1, mode='min')

# %%
# !pip install h5py
	
	
mc = tf.keras.callbacks.ModelCheckpoint('best_model.h5', monitor='val_accuracy', mode='max', verbose=1, save_best_only=True)
# Out:
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (2.10.0)
# Requirement already satisfied: numpy>=1.7 in /usr/local/lib/python3.6/dist-packages (from h5py) (1.18.5)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from h5py) (1.15.0)

# %%
model.compile(optimizer = "adam" , loss = 'categorical_crossentropy' , metrics = ['accuracy'])

# %%
#Fitting the augmentation data
history = model.fit(datagen.flow(x_train, y_train, batch_size=32), epochs=100, validation_data = (x_val, y_val), callbacks = [learning_rate,es,mc])
# Out:
# Epoch 1/100
# 73/73 [==============================] - ETA: 0s - loss: 1.2210 - accuracy: 0.5951
# Epoch 00001: val_accuracy improved from -inf to 0.16967, saving model to best_model.h5
# 73/73 [==============================] - 830s 11s/step - loss: 1.2210 - accuracy: 0.5951 - val_loss: 124.9287 - val_accuracy: 0.1697
# Epoch 2/100
# 73/73 [==============================] - ETA: 0s - loss: 1.0210 - accuracy: 0.6478
# Epoch 00002: val_accuracy improved from 0.16967 to 0.23265, saving model to best_model.h5
# 73/73 [==============================] - 831s 11s/step - loss: 1.0210 - accuracy: 0.6478 - val_loss: 2.0413 - val_accuracy: 0.2326
# Epoch 3/100
# 73/73 [==============================] - ETA: 0s - loss: 0.8180 - accuracy: 0.7065
# Epoch 00003: val_accuracy did not improve from 0.23265
# 73/73 [==============================] - 828s 11s/step - loss: 0.8180 - accuracy: 0.7065 - val_loss: 1.6760 - val_accuracy: 0.2326
# Epoch 4/100
# 73/73 [==============================] - ETA: 0s - loss: 0.7298 - accuracy: 0.7429
# Epoch 00004: val_accuracy did not improve from 0.23265
# 73/73 [==============================] - 835s 11s/step - loss: 0.7298 - accuracy: 0.7429 - val_loss: 1.8858 - val_accuracy: 0.2326
# Epoch 5/100
# 73/73 [==============================] - ETA: 0s - loss: 0.7031 - accuracy: 0.7536
# Epoch 00005: val_accuracy improved from 0.23265 to 0.23393, saving model to best_model.h5
# 73/73 [==============================] - 833s 11s/step - loss: 0.7031 - accuracy: 0.7536 - val_loss: 1.6363 - val_accuracy: 0.2339
# Epoch 6/100
# 73/73 [==============================] - ETA: 0s - loss: 0.6704 - accuracy: 0.7605
# Epoch 00006: val_accuracy did not improve from 0.23393
# 73/73 [==============================] - 827s 11s/step - loss: 0.6704 - accuracy: 0.7605 - val_loss: 1.7525 - val_accuracy: 0.2262
# Epoch 7/100
# 73/73 [==============================] - ETA: 0s - loss: 0.6395 - accuracy: 0.7725
# Epoch 00007: val_accuracy did not improve from 0.23393
# 73/73 [==============================] - 828s 11s/step - loss: 0.6395 - accuracy: 0.7725 - val_loss: 1.9077 - val_accuracy: 0.1671
# Epoch 8/100
# 73/73 [==============================] - ETA: 0s - loss: 0.6869 - accuracy: 0.7631
# Epoch 00008: val_accuracy improved from 0.23393 to 0.29692, saving model to best_model.h5
# 73/73 [==============================] - 832s 11s/step - loss: 0.6869 - accuracy: 0.7631 - val_loss: 1.6627 - val_accuracy: 0.2969
# Epoch 9/100
# 73/73 [==============================] - ETA: 0s - loss: 0.7308 - accuracy: 0.7485
# Epoch 00009: val_accuracy did not improve from 0.29692
# 73/73 [==============================] - 827s 11s/step - loss: 0.7308 - accuracy: 0.7485 - val_loss: 2.2443 - val_accuracy: 0.2404
# Epoch 10/100
# 73/73 [==============================] - ETA: 0s - loss: 0.6068 - accuracy: 0.7712
# Epoch 00010: val_accuracy did not improve from 0.29692
# 73/73 [==============================] - 828s 11s/step - loss: 0.6068 - accuracy: 0.7712 - val_loss: 1.6496 - val_accuracy: 0.2918
# Epoch 11/100
# 73/73 [==============================] - ETA: 0s - loss: 0.5553 - accuracy: 0.8119
# Epoch 00011: val_accuracy improved from 0.29692 to 0.53470, saving model to best_model.h5
# 73/73 [==============================] - 836s 11s/step - loss: 0.5553 - accuracy: 0.8119 - val_loss: 1.1805 - val_accuracy: 0.5347
# Epoch 12/100
# 73/73 [==============================] - ETA: 0s - loss: 0.5156 - accuracy: 0.8115
# Epoch 00012: val_accuracy improved from 0.53470 to 0.73907, saving model to best_model.h5
# 73/73 [==============================] - 835s 11s/step - loss: 0.5156 - accuracy: 0.8115 - val_loss: 0.8130 - val_accuracy: 0.7391
# Epoch 13/100
# 73/73 [==============================] - ETA: 0s - loss: 0.4945 - accuracy: 0.8196
# Epoch 00013: val_accuracy improved from 0.73907 to 0.78406, saving model to best_model.h5
# 73/73 [==============================] - 841s 12s/step - loss: 0.4945 - accuracy: 0.8196 - val_loss: 0.6671 - val_accuracy: 0.7841
# Epoch 14/100
# 73/73 [==============================] - ETA: 0s - loss: 0.4894 - accuracy: 0.8175
# Epoch 00014: val_accuracy did not improve from 0.78406
# 73/73 [==============================] - 842s 12s/step - loss: 0.4894 - accuracy: 0.8175 - val_loss: 0.6771 - val_accuracy: 0.7404
# Epoch 15/100
# 73/73 [==============================] - ETA: 0s - loss: 0.4687 - accuracy: 0.8325
# Epoch 00015: val_accuracy did not improve from 0.78406
# 73/73 [==============================] - 831s 11s/step - loss: 0.4687 - accuracy: 0.8325 - val_loss: 0.6492 - val_accuracy: 0.7532
# Epoch 16/100
# 73/73 [==============================] - ETA: 0s - loss: 0.5170 - accuracy: 0.8222
# Epoch 00016: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00016: val_accuracy did not improve from 0.78406
# 73/73 [==============================] - 830s 11s/step - loss: 0.5170 - accuracy: 0.8222 - val_loss: 0.7845 - val_accuracy: 0.6864
# Epoch 17/100
# 73/73 [==============================] - ETA: 0s - loss: 0.3962 - accuracy: 0.8556
# Epoch 00017: val_accuracy improved from 0.78406 to 0.84062, saving model to best_model.h5
# 73/73 [==============================] - 840s 12s/step - loss: 0.3962 - accuracy: 0.8556 - val_loss: 0.4359 - val_accuracy: 0.8406
# Epoch 18/100
# 73/73 [==============================] - ETA: 0s - loss: 0.3722 - accuracy: 0.8685
# Epoch 00018: val_accuracy did not improve from 0.84062
# 73/73 [==============================] - 832s 11s/step - loss: 0.3722 - accuracy: 0.8685 - val_loss: 0.5658 - val_accuracy: 0.7943
# Epoch 19/100
# 73/73 [==============================] - ETA: 0s - loss: 0.3774 - accuracy: 0.8710
# Epoch 00019: val_accuracy did not improve from 0.84062
# 73/73 [==============================] - 834s 11s/step - loss: 0.3774 - accuracy: 0.8710 - val_loss: 0.5676 - val_accuracy: 0.7982
# Epoch 20/100
# 73/73 [==============================] - ETA: 0s - loss: 0.3489 - accuracy: 0.8770
# Epoch 00020: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 00020: val_accuracy did not improve from 0.84062
# 73/73 [==============================] - 834s 11s/step - loss: 0.3489 - accuracy: 0.8770 - val_loss: 0.5643 - val_accuracy: 0.7943
# Epoch 21/100
# 73/73 [==============================] - ETA: 0s - loss: 0.2905 - accuracy: 0.8963
# Epoch 00021: val_accuracy improved from 0.84062 to 0.85090, saving model to best_model.h5
# 73/73 [==============================] - 843s 12s/step - loss: 0.2905 - accuracy: 0.8963 - val_loss: 0.4615 - val_accuracy: 0.8509
# Epoch 22/100
# 73/73 [==============================] - ETA: 0s - loss: 0.2829 - accuracy: 0.8976
# Epoch 00022: val_accuracy did not improve from 0.85090
# 73/73 [==============================] - 831s 11s/step - loss: 0.2829 - accuracy: 0.8976 - val_loss: 0.4352 - val_accuracy: 0.8470
# Epoch 23/100
# 73/73 [==============================] - ETA: 0s - loss: 0.2771 - accuracy: 0.8989
# Epoch 00023: val_accuracy improved from 0.85090 to 0.87532, saving model to best_model.h5
# 73/73 [==============================] - 835s 11s/step - loss: 0.2771 - accuracy: 0.8989 - val_loss: 0.3892 - val_accuracy: 0.8753
# Epoch 24/100
# 73/73 [==============================] - ETA: 0s - loss: 0.2408 - accuracy: 0.9113
# Epoch 00024: val_accuracy did not improve from 0.87532
# 73/73 [==============================] - 830s 11s/step - loss: 0.2408 - accuracy: 0.9113 - val_loss: 0.5587 - val_accuracy: 0.8059
# Epoch 25/100
# 73/73 [==============================] - ETA: 0s - loss: 0.2593 - accuracy: 0.9066
# Epoch 00025: val_accuracy did not improve from 0.87532
# 73/73 [==============================] - 833s 11s/step - loss: 0.2593 - accuracy: 0.9066 - val_loss: 0.4634 - val_accuracy: 0.8265
# Epoch 26/100
# 73/73 [==============================] - ETA: 0s - loss: 0.2362 - accuracy: 0.9199
# Epoch 00026: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 00026: val_accuracy did not improve from 0.87532
# 73/73 [==============================] - 830s 11s/step - loss: 0.2362 - accuracy: 0.9199 - val_loss: 0.4591 - val_accuracy: 0.8470
# Epoch 27/100
# 73/73 [==============================] - ETA: 0s - loss: 0.2140 - accuracy: 0.9272
# Epoch 00027: val_accuracy did not improve from 0.87532
# 73/73 [==============================] - 830s 11s/step - loss: 0.2140 - accuracy: 0.9272 - val_loss: 0.4030 - val_accuracy: 0.8599
# Epoch 28/100
# 73/73 [==============================] - ETA: 0s - loss: 0.1990 - accuracy: 0.9310
# Epoch 00028: val_accuracy did not improve from 0.87532
# 73/73 [==============================] - 830s 11s/step - loss: 0.1990 - accuracy: 0.9310 - val_loss: 0.3592 - val_accuracy: 0.8689
# Epoch 29/100
# 73/73 [==============================] - ETA: 0s - loss: 0.1839 - accuracy: 0.9392
# Epoch 00029: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
#
# Epoch 00029: val_accuracy did not improve from 0.87532
# 73/73 [==============================] - 834s 11s/step - loss: 0.1839 - accuracy: 0.9392 - val_loss: 0.3575 - val_accuracy: 0.8676
# Epoch 30/100
# 73/73 [==============================] - ETA: 0s - loss: 0.1664 - accuracy: 0.9404
# Epoch 00030: val_accuracy did not improve from 0.87532
# 73/73 [==============================] - 831s 11s/step - loss: 0.1664 - accuracy: 0.9404 - val_loss: 0.3706 - val_accuracy: 0.8715
# Epoch 31/100
# 73/73 [==============================] - ETA: 0s - loss: 0.1643 - accuracy: 0.9439
# Epoch 00031: val_accuracy did not improve from 0.87532
# 73/73 [==============================] - 832s 11s/step - loss: 0.1643 - accuracy: 0.9439 - val_loss: 0.3810 - val_accuracy: 0.8676
# Epoch 32/100
# 73/73 [==============================] - ETA: 0s - loss: 0.1538 - accuracy: 0.9443
# Epoch 00032: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
#
# Epoch 00032: val_accuracy did not improve from 0.87532
# 73/73 [==============================] - 832s 11s/step - loss: 0.1538 - accuracy: 0.9443 - val_loss: 0.3983 - val_accuracy: 0.8586
# Epoch 33/100
# 73/73 [==============================] - ETA: 0s - loss: 0.1545 - accuracy: 0.9486
# Epoch 00033: val_accuracy did not improve from 0.87532
# 73/73 [==============================] - 836s 11s/step - loss: 0.1545 - accuracy: 0.9486 - val_loss: 0.3952 - val_accuracy: 0.8702
# Epoch 34/100
# 73/73 [==============================] - ETA: 0s - loss: 0.1636 - accuracy: 0.9417
# Epoch 00034: val_accuracy did not improve from 0.87532
# 73/73 [==============================] - 833s 11s/step - loss: 0.1636 - accuracy: 0.9417 - val_loss: 0.4020 - val_accuracy: 0.8586
# Epoch 35/100
# 73/73 [==============================] - ETA: 0s - loss: 0.1399 - accuracy: 0.9469
# Epoch 00035: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
#
# Epoch 00035: val_accuracy did not improve from 0.87532
# 73/73 [==============================] - 830s 11s/step - loss: 0.1399 - accuracy: 0.9469 - val_loss: 0.3998 - val_accuracy: 0.8638
# Epoch 36/100
# 73/73 [==============================] - ETA: 0s - loss: 0.1379 - accuracy: 0.9482
# Epoch 00036: val_accuracy did not improve from 0.87532
# 73/73 [==============================] - 830s 11s/step - loss: 0.1379 - accuracy: 0.9482 - val_loss: 0.3980 - val_accuracy: 0.8612
# Epoch 37/100
# 73/73 [==============================] - ETA: 0s - loss: 0.1340 - accuracy: 0.9512
# Epoch 00037: val_accuracy did not improve from 0.87532
# 73/73 [==============================] - 838s 11s/step - loss: 0.1340 - accuracy: 0.9512 - val_loss: 0.3909 - val_accuracy: 0.8676
# Epoch 38/100
# 73/73 [==============================] - ETA: 0s - loss: 0.1370 - accuracy: 0.9494
# Epoch 00038: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
#
# Epoch 00038: val_accuracy did not improve from 0.87532
# 73/73 [==============================] - 835s 11s/step - loss: 0.1370 - accuracy: 0.9494 - val_loss: 0.3969 - val_accuracy: 0.8689
# Epoch 39/100
# 73/73 [==============================] - ETA: 0s - loss: 0.1359 - accuracy: 0.9546
# Epoch 00039: val_accuracy did not improve from 0.87532
# 73/73 [==============================] - 836s 11s/step - loss: 0.1359 - accuracy: 0.9546 - val_loss: 0.4035 - val_accuracy: 0.8650
# Epoch 00039: early stopping

# %%
import seaborn as sns
sns.set_style('darkgrid')
import matplotlib.pyplot as plt
import matplotlib.image as mimg

# %%
accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(accuracy) + 1)

f, axes = plt.subplots(1,2,figsize=(14,4))

axes[0].plot(epochs, accuracy, 'g', label='Training accuracy')
axes[0].plot(epochs, val_accuracy, 'b', label='Validation accuracy')
axes[0].legend()

axes[1].plot(epochs, loss, 'g', label='Training loss')
axes[1].plot(epochs, val_loss, 'b', label='Validation loss')
axes[1].yaxis.set_label_position("right")
axes[1].legend()

plt.show()

# %%
saved_model = tf.keras.models.load_model('best_model.h5')
print("Test Accuracy: {0:.2f}%".format(saved_model.evaluate(x_test,y_test)[1]*100)) #get score acording to test datas
# Out:
# 14/14 [==============================] - 28s 2s/step - loss: 0.3654 - accuracy: 0.8799
# Test Accuracy: 87.99%

# %%
from sklearn.metrics import confusion_matrix
Y_pred = saved_model.predict(x_test)
Y_pred_classes = np.argmax(Y_pred,axis = 1)
Y_true = np.argmax(y_test,axis = 1)
confusion_mtx = confusion_matrix(Y_true,Y_pred_classes)
f,ax = plt.subplots(figsize = (8,8))
sns.heatmap(confusion_mtx,annot=True,linewidths = 0.01,cmap="Reds",
            linecolor = "gray",ax=ax
            )
plt.xlabel("predicted label")
plt.ylabel("True Label")
plt.title("confusion matrix")
plt.show()

from sklearn.metrics import classification_report

print(classification_report(Y_true, Y_pred_classes))


y_test_inv = label_binarizer.inverse_transform(y_test)
print(classification_report(y_test_inv, Y_pred_classes, target_names = labels))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.89      0.92       123
#            1       0.92      0.93      0.93        89
#            2       0.78      0.88      0.83        84
#            3       0.95      0.85      0.90        67
#            4       0.79      0.81      0.80        70
#
#     accuracy                           0.88       433
#    macro avg       0.88      0.87      0.88       433
# weighted avg       0.89      0.88      0.88       433
#
#               precision    recall  f1-score   support
#
#    dandelion       0.95      0.89      0.92       123
#        daisy       0.92      0.93      0.93        89
#        tulip       0.78      0.88      0.83        84
#    sunflower       0.95      0.85      0.90        67
#         rose       0.79      0.81      0.80        70
#
#     accuracy                           0.88       433
#    macro avg       0.88      0.87      0.88       433
# weighted avg       0.89      0.88      0.88       433
