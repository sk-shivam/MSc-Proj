# %%
#Normal data 90-10 with for 90%(20%training, 80%validation) and 10%test data
import keras
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout, Flatten
from keras.layers import Conv2D
from keras.layers import MaxPooling2D,MaxPool2D
from keras.layers.normalization import BatchNormalization
from keras.optimizers import Adam
from keras.preprocessing.image import ImageDataGenerator
from keras import layers
from keras import models
from keras import optimizers

from tensorflow.keras.applications.resnet50 import ResNet50

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
import os

# %%
#changing the working directory
# %cd /content/gdrive/My Drive/Thesis
# Out:
# /content/gdrive/My Drive/Thesis

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import keras
from keras.models import Sequential, Model
from keras.layers import Dense, Conv2D , MaxPool2D , Flatten , Dropout , MaxPooling2D
from keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report,confusion_matrix
from keras.applications import VGG19
import cv2
import os
import random
import tensorflow as tf
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
labels = ['dandelion', 'daisy','tulip','sunflower','rose']
img_size = 150
def get_data(data_dir):
    data = [] 
    for label in labels: 
        path = os.path.join(data_dir, label)
        class_num = labels.index(label)
        for img in os.listdir(path):
            try:
                img_arr = cv2.imread(os.path.join(path, img), cv2.IMREAD_COLOR)
                resized_arr = cv2.resize(img_arr, (img_size, img_size)) # Reshaping images to preferred size
                data.append([resized_arr, class_num])
            except Exception as e:
                print(e)
    return np.array(data)

# %%
data = get_data("/content/gdrive/My Drive/Thesis/flowers")
# Out:
# OpenCV(4.1.2) /io/opencv/modules/imgproc/src/resize.cpp:3720: error: (-215:Assertion failed) !ssize.empty() in function 'resize'
#
# OpenCV(4.1.2) /io/opencv/modules/imgproc/src/resize.cpp:3720: error: (-215:Assertion failed) !ssize.empty() in function 'resize'
#
# OpenCV(4.1.2) /io/opencv/modules/imgproc/src/resize.cpp:3720: error: (-215:Assertion failed) !ssize.empty() in function 'resize'

# %%
l = []
for i in data:
    l.append(labels[i[1]])
sns.set_style('dark')
sns.countplot(l)

# %%
fig,ax=plt.subplots(5,2)
fig.set_size_inches(15,15)
for i in range(5):
    for j in range (2):
        l=random.randint(0,len(data))
        ax[i,j].imshow(data[l][0])
        ax[i,j].set_title('Flower: '+labels[data[l][1]])
        
plt.tight_layout()

# %%
x = []
y = []

for feature, label in data:
    x.append(feature)
    y.append(label)

# %%
# Normalize the data
x = np.array(x) / 255

# %%
# Reshaping the data from 1-D to 3-D as required through input by CNN's 
x = x.reshape(-1, img_size, img_size, 3)
y = np.array(y)

# %%
from sklearn.preprocessing import LabelBinarizer
label_binarizer = LabelBinarizer()
y = label_binarizer.fit_transform(y)

# %%
x_train,x_test,y_train,y_test = train_test_split(x , y , test_size = 0.1 , random_state = 42)

# %%
x_train,x_val,y_train,y_val = train_test_split(x_train, y_train, test_size= 0.8, random_state = 42)

# %%
model = Sequential()

#Adding ResNet model
model.add(ResNet50(include_top=False, pooling='avg', weights="imagenet", input_shape=(150,150,3)))
model.add(Flatten())

model.add(Dense(1024,activation="relu"))
model.add(Dropout(0.5))
model.add(BatchNormalization())

#Output layer
model.add(Dense(5, activation='softmax'))

model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94773248/94765736 [==============================] - 2s 0us/step
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# resnet50 (Functional)        (None, 2048)              23587712
# _________________________________________________________________
# flatten (Flatten)            (None, 2048)              0
# _________________________________________________________________
# dense (Dense)                (None, 1024)              2098176
# _________________________________________________________________
# dropout (Dropout)            (None, 1024)              0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 1024)              4096
# _________________________________________________________________
# dense_1 (Dense)              (None, 5)                 5125
# =================================================================
# Total params: 25,695,109
# Trainable params: 25,639,941
# Non-trainable params: 55,168
# _________________________________________________________________

# %%
#defining early stopping
from keras.callbacks import ReduceLROnPlateau
learning_rate = ReduceLROnPlateau(monitor='val_accuracy', patience = 3, verbose=1,factor=0.5, min_lr=0.000001)

es = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss', patience=10, verbose=1, mode='min')

# %%
# !pip install h5py
	
	
mc = tf.keras.callbacks.ModelCheckpoint('best_model.h5', monitor='val_accuracy', mode='max', verbose=1, save_best_only=True)
# Out:
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (2.10.0)
# Requirement already satisfied: numpy>=1.7 in /usr/local/lib/python3.6/dist-packages (from h5py) (1.18.5)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from h5py) (1.15.0)

# %%
model.compile(optimizer = "adam" , loss = 'categorical_crossentropy' , metrics = ['accuracy'])

# %%
#Fitting the augmentation data
history = model.fit(x_train, y_train, batch_size=32, epochs=100, validation_data = (x_val, y_val), callbacks = [learning_rate,es,mc])
# Out:
# Epoch 1/100
# 25/25 [==============================] - ETA: 0s - loss: 0.0456 - accuracy: 0.9884
# Epoch 00001: val_accuracy did not improve from 0.23747
# 25/25 [==============================] - 472s 19s/step - loss: 0.0456 - accuracy: 0.9884 - val_loss: 4.1381 - val_accuracy: 0.2375
# Epoch 2/100
# 25/25 [==============================] - ETA: 0s - loss: 0.0156 - accuracy: 0.9961
# Epoch 00002: val_accuracy did not improve from 0.23747
# 25/25 [==============================] - 473s 19s/step - loss: 0.0156 - accuracy: 0.9961 - val_loss: 4.3421 - val_accuracy: 0.2375
# Epoch 3/100
# 25/25 [==============================] - ETA: 0s - loss: 0.0212 - accuracy: 0.9974
# Epoch 00003: val_accuracy did not improve from 0.23747
# 25/25 [==============================] - 465s 19s/step - loss: 0.0212 - accuracy: 0.9974 - val_loss: 4.5748 - val_accuracy: 0.2375
# Epoch 4/100
# 25/25 [==============================] - ETA: 0s - loss: 0.0181 - accuracy: 0.9987
# Epoch 00004: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
#
# Epoch 00004: val_accuracy did not improve from 0.23747
# 25/25 [==============================] - 472s 19s/step - loss: 0.0181 - accuracy: 0.9987 - val_loss: 4.7139 - val_accuracy: 0.2375
# Epoch 5/100
# 25/25 [==============================] - ETA: 0s - loss: 0.0310 - accuracy: 0.9949
# Epoch 00005: val_accuracy did not improve from 0.23747
# 25/25 [==============================] - 471s 19s/step - loss: 0.0310 - accuracy: 0.9949 - val_loss: 4.8432 - val_accuracy: 0.2375
# Epoch 6/100
# 25/25 [==============================] - ETA: 0s - loss: 0.0336 - accuracy: 0.9961
# Epoch 00006: val_accuracy improved from 0.23747 to 0.23779, saving model to best_model.h5
# 25/25 [==============================] - 472s 19s/step - loss: 0.0336 - accuracy: 0.9961 - val_loss: 4.8319 - val_accuracy: 0.2378
# Epoch 7/100
# 25/25 [==============================] - ETA: 0s - loss: 0.0157 - accuracy: 0.9987
# Epoch 00007: val_accuracy improved from 0.23779 to 0.23940, saving model to best_model.h5
# 25/25 [==============================] - 472s 19s/step - loss: 0.0157 - accuracy: 0.9987 - val_loss: 4.7203 - val_accuracy: 0.2394
# Epoch 8/100
# 25/25 [==============================] - ETA: 0s - loss: 0.0220 - accuracy: 0.9949
# Epoch 00008: val_accuracy improved from 0.23940 to 0.24454, saving model to best_model.h5
# 25/25 [==============================] - 472s 19s/step - loss: 0.0220 - accuracy: 0.9949 - val_loss: 4.8073 - val_accuracy: 0.2445
# Epoch 9/100
# 25/25 [==============================] - ETA: 0s - loss: 0.0242 - accuracy: 0.9949
# Epoch 00009: val_accuracy improved from 0.24454 to 0.25771, saving model to best_model.h5
# 25/25 [==============================] - 473s 19s/step - loss: 0.0242 - accuracy: 0.9949 - val_loss: 4.4953 - val_accuracy: 0.2577
# Epoch 10/100
# 25/25 [==============================] - ETA: 0s - loss: 0.0370 - accuracy: 0.9961
# Epoch 00010: val_accuracy improved from 0.25771 to 0.28952, saving model to best_model.h5
# 25/25 [==============================] - 474s 19s/step - loss: 0.0370 - accuracy: 0.9961 - val_loss: 3.8801 - val_accuracy: 0.2895
# Epoch 11/100
# 25/25 [==============================] - ETA: 0s - loss: 0.0241 - accuracy: 0.9961
# Epoch 00011: val_accuracy improved from 0.28952 to 0.34062, saving model to best_model.h5
# 25/25 [==============================] - 470s 19s/step - loss: 0.0241 - accuracy: 0.9961 - val_loss: 3.2831 - val_accuracy: 0.3406
# Epoch 12/100
# 25/25 [==============================] - ETA: 0s - loss: 0.0070 - accuracy: 0.9987
# Epoch 00012: val_accuracy improved from 0.34062 to 0.40328, saving model to best_model.h5
# 25/25 [==============================] - 470s 19s/step - loss: 0.0070 - accuracy: 0.9987 - val_loss: 2.6674 - val_accuracy: 0.4033
# Epoch 13/100
# 25/25 [==============================] - ETA: 0s - loss: 0.0208 - accuracy: 0.9961
# Epoch 00013: val_accuracy improved from 0.40328 to 0.47333, saving model to best_model.h5
# 25/25 [==============================] - 468s 19s/step - loss: 0.0208 - accuracy: 0.9961 - val_loss: 2.1775 - val_accuracy: 0.4733
# Epoch 14/100
# 25/25 [==============================] - ETA: 0s - loss: 0.0103 - accuracy: 1.0000
# Epoch 00014: val_accuracy improved from 0.47333 to 0.53985, saving model to best_model.h5
# 25/25 [==============================] - 468s 19s/step - loss: 0.0103 - accuracy: 1.0000 - val_loss: 1.7884 - val_accuracy: 0.5398
# Epoch 15/100
# 25/25 [==============================] - ETA: 0s - loss: 0.0279 - accuracy: 0.9974
# Epoch 00015: val_accuracy improved from 0.53985 to 0.60026, saving model to best_model.h5
# 25/25 [==============================] - 466s 19s/step - loss: 0.0279 - accuracy: 0.9974 - val_loss: 1.4518 - val_accuracy: 0.6003
# Epoch 16/100
# 25/25 [==============================] - ETA: 0s - loss: 0.0126 - accuracy: 0.9974
# Epoch 00016: val_accuracy improved from 0.60026 to 0.65039, saving model to best_model.h5
# 25/25 [==============================] - 468s 19s/step - loss: 0.0126 - accuracy: 0.9974 - val_loss: 1.1995 - val_accuracy: 0.6504
# Epoch 17/100
# 25/25 [==============================] - ETA: 0s - loss: 0.0144 - accuracy: 0.9987
# Epoch 00017: val_accuracy improved from 0.65039 to 0.69569, saving model to best_model.h5
# 25/25 [==============================] - 469s 19s/step - loss: 0.0144 - accuracy: 0.9987 - val_loss: 1.0206 - val_accuracy: 0.6957
# Epoch 18/100
# 25/25 [==============================] - ETA: 0s - loss: 0.0164 - accuracy: 0.9987
# Epoch 00018: val_accuracy improved from 0.69569 to 0.74357, saving model to best_model.h5
# 25/25 [==============================] - 476s 19s/step - loss: 0.0164 - accuracy: 0.9987 - val_loss: 0.8739 - val_accuracy: 0.7436
# Epoch 19/100
# 25/25 [==============================] - ETA: 0s - loss: 0.0079 - accuracy: 0.9987
# Epoch 00019: val_accuracy improved from 0.74357 to 0.77217, saving model to best_model.h5
# 25/25 [==============================] - 469s 19s/step - loss: 0.0079 - accuracy: 0.9987 - val_loss: 0.7731 - val_accuracy: 0.7722
# Epoch 20/100
# 25/25 [==============================] - ETA: 0s - loss: 0.0073 - accuracy: 0.9987
# Epoch 00020: val_accuracy improved from 0.77217 to 0.78985, saving model to best_model.h5
# 25/25 [==============================] - 470s 19s/step - loss: 0.0073 - accuracy: 0.9987 - val_loss: 0.6999 - val_accuracy: 0.7898
# Epoch 21/100
# 25/25 [==============================] - ETA: 0s - loss: 0.0063 - accuracy: 0.9987
# Epoch 00021: val_accuracy improved from 0.78985 to 0.80013, saving model to best_model.h5
# 25/25 [==============================] - 474s 19s/step - loss: 0.0063 - accuracy: 0.9987 - val_loss: 0.6468 - val_accuracy: 0.8001
# Epoch 22/100
# 25/25 [==============================] - ETA: 0s - loss: 0.0090 - accuracy: 0.9987
# Epoch 00022: val_accuracy improved from 0.80013 to 0.80880, saving model to best_model.h5
# 25/25 [==============================] - 472s 19s/step - loss: 0.0090 - accuracy: 0.9987 - val_loss: 0.6093 - val_accuracy: 0.8088
# Epoch 23/100
# 25/25 [==============================] - ETA: 0s - loss: 0.0275 - accuracy: 0.9974
# Epoch 00023: val_accuracy improved from 0.80880 to 0.81716, saving model to best_model.h5
# 25/25 [==============================] - 468s 19s/step - loss: 0.0275 - accuracy: 0.9974 - val_loss: 0.5786 - val_accuracy: 0.8172
# Epoch 24/100
# 25/25 [==============================] - ETA: 0s - loss: 0.0235 - accuracy: 0.9974
# Epoch 00024: val_accuracy improved from 0.81716 to 0.82102, saving model to best_model.h5
# 25/25 [==============================] - 467s 19s/step - loss: 0.0235 - accuracy: 0.9974 - val_loss: 0.5593 - val_accuracy: 0.8210
# Epoch 25/100
# 25/25 [==============================] - ETA: 0s - loss: 0.0191 - accuracy: 0.9949
# Epoch 00025: val_accuracy improved from 0.82102 to 0.82326, saving model to best_model.h5
# 25/25 [==============================] - 471s 19s/step - loss: 0.0191 - accuracy: 0.9949 - val_loss: 0.5527 - val_accuracy: 0.8233
# Epoch 26/100
# 25/25 [==============================] - ETA: 0s - loss: 0.0208 - accuracy: 0.9974
# Epoch 00026: val_accuracy improved from 0.82326 to 0.82455, saving model to best_model.h5
# 25/25 [==============================] - 480s 19s/step - loss: 0.0208 - accuracy: 0.9974 - val_loss: 0.5636 - val_accuracy: 0.8246
# Epoch 27/100
# 25/25 [==============================] - ETA: 0s - loss: 0.0214 - accuracy: 0.9974
# Epoch 00027: val_accuracy did not improve from 0.82455
# 25/25 [==============================] - 471s 19s/step - loss: 0.0214 - accuracy: 0.9974 - val_loss: 0.5472 - val_accuracy: 0.8242
# Epoch 28/100
# 25/25 [==============================] - ETA: 0s - loss: 0.0282 - accuracy: 0.9949
# Epoch 00028: val_accuracy improved from 0.82455 to 0.82584, saving model to best_model.h5
# 25/25 [==============================] - 469s 19s/step - loss: 0.0282 - accuracy: 0.9949 - val_loss: 0.5424 - val_accuracy: 0.8258
# Epoch 29/100
# 25/25 [==============================] - ETA: 0s - loss: 0.0087 - accuracy: 1.0000
# Epoch 00029: val_accuracy did not improve from 0.82584
# 25/25 [==============================] - 470s 19s/step - loss: 0.0087 - accuracy: 1.0000 - val_loss: 0.5390 - val_accuracy: 0.8249
# Epoch 30/100
# 25/25 [==============================] - ETA: 0s - loss: 0.0119 - accuracy: 1.0000
# Epoch 00030: val_accuracy did not improve from 0.82584
# 25/25 [==============================] - 468s 19s/step - loss: 0.0119 - accuracy: 1.0000 - val_loss: 0.5379 - val_accuracy: 0.8252
# Epoch 31/100
# 25/25 [==============================] - ETA: 0s - loss: 0.0070 - accuracy: 1.0000
# Epoch 00031: val_accuracy improved from 0.82584 to 0.82680, saving model to best_model.h5
# 25/25 [==============================] - 470s 19s/step - loss: 0.0070 - accuracy: 1.0000 - val_loss: 0.5370 - val_accuracy: 0.8268
# Epoch 32/100
# 25/25 [==============================] - ETA: 0s - loss: 0.0056 - accuracy: 1.0000
# Epoch 00032: val_accuracy did not improve from 0.82680
# 25/25 [==============================] - 468s 19s/step - loss: 0.0056 - accuracy: 1.0000 - val_loss: 0.5356 - val_accuracy: 0.8265
# Epoch 33/100
# 25/25 [==============================] - ETA: 0s - loss: 0.0053 - accuracy: 1.0000
# Epoch 00033: val_accuracy improved from 0.82680 to 0.82712, saving model to best_model.h5
# 25/25 [==============================] - 473s 19s/step - loss: 0.0053 - accuracy: 1.0000 - val_loss: 0.5349 - val_accuracy: 0.8271
# Epoch 34/100
# 25/25 [==============================] - ETA: 0s - loss: 0.0058 - accuracy: 1.0000
# Epoch 00034: val_accuracy improved from 0.82712 to 0.82776, saving model to best_model.h5
# 25/25 [==============================] - 474s 19s/step - loss: 0.0058 - accuracy: 1.0000 - val_loss: 0.5328 - val_accuracy: 0.8278
# Epoch 35/100
# 25/25 [==============================] - ETA: 0s - loss: 0.0072 - accuracy: 0.9987
# Epoch 00035: val_accuracy did not improve from 0.82776
# 25/25 [==============================] - 470s 19s/step - loss: 0.0072 - accuracy: 0.9987 - val_loss: 0.5325 - val_accuracy: 0.8274
# Epoch 36/100
# 25/25 [==============================] - ETA: 0s - loss: 0.0073 - accuracy: 0.9987
# Epoch 00036: val_accuracy improved from 0.82776 to 0.82873, saving model to best_model.h5
# 25/25 [==============================] - 472s 19s/step - loss: 0.0073 - accuracy: 0.9987 - val_loss: 0.5401 - val_accuracy: 0.8287
# Epoch 37/100
# 25/25 [==============================] - ETA: 0s - loss: 0.0051 - accuracy: 1.0000
# Epoch 00037: val_accuracy improved from 0.82873 to 0.82905, saving model to best_model.h5
# 25/25 [==============================] - 473s 19s/step - loss: 0.0051 - accuracy: 1.0000 - val_loss: 0.5382 - val_accuracy: 0.8290
# Epoch 38/100
# 25/25 [==============================] - ETA: 0s - loss: 0.0123 - accuracy: 0.9987
# Epoch 00038: val_accuracy did not improve from 0.82905
# 25/25 [==============================] - 469s 19s/step - loss: 0.0123 - accuracy: 0.9987 - val_loss: 0.5375 - val_accuracy: 0.8287
# Epoch 39/100
# 25/25 [==============================] - ETA: 0s - loss: 0.0094 - accuracy: 0.9987
# Epoch 00039: val_accuracy did not improve from 0.82905
# 25/25 [==============================] - 469s 19s/step - loss: 0.0094 - accuracy: 0.9987 - val_loss: 0.5379 - val_accuracy: 0.8252
# Epoch 40/100
# 25/25 [==============================] - ETA: 0s - loss: 0.0088 - accuracy: 0.9987
# Epoch 00040: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
#
# Epoch 00040: val_accuracy did not improve from 0.82905
# 25/25 [==============================] - 467s 19s/step - loss: 0.0088 - accuracy: 0.9987 - val_loss: 0.5352 - val_accuracy: 0.8278
# Epoch 41/100
# 25/25 [==============================] - ETA: 0s - loss: 0.0103 - accuracy: 0.9987
# Epoch 00041: val_accuracy did not improve from 0.82905
# 25/25 [==============================] - 469s 19s/step - loss: 0.0103 - accuracy: 0.9987 - val_loss: 0.5364 - val_accuracy: 0.8281
# Epoch 42/100
# 25/25 [==============================] - ETA: 0s - loss: 0.0305 - accuracy: 0.9936
# Epoch 00042: val_accuracy did not improve from 0.82905
# 25/25 [==============================] - 466s 19s/step - loss: 0.0305 - accuracy: 0.9936 - val_loss: 0.5360 - val_accuracy: 0.8287
# Epoch 43/100
# 25/25 [==============================] - ETA: 0s - loss: 0.0067 - accuracy: 1.0000
# Epoch 00043: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
#
# Epoch 00043: val_accuracy did not improve from 0.82905
# 25/25 [==============================] - 466s 19s/step - loss: 0.0067 - accuracy: 1.0000 - val_loss: 0.5365 - val_accuracy: 0.8290
# Epoch 44/100
# 25/25 [==============================] - ETA: 0s - loss: 0.0054 - accuracy: 1.0000
# Epoch 00044: val_accuracy did not improve from 0.82905
# 25/25 [==============================] - 470s 19s/step - loss: 0.0054 - accuracy: 1.0000 - val_loss: 0.5364 - val_accuracy: 0.8290
# Epoch 45/100
# 25/25 [==============================] - ETA: 0s - loss: 0.0036 - accuracy: 1.0000
# Epoch 00045: val_accuracy improved from 0.82905 to 0.82969, saving model to best_model.h5
# 25/25 [==============================] - 473s 19s/step - loss: 0.0036 - accuracy: 1.0000 - val_loss: 0.5374 - val_accuracy: 0.8297
# Epoch 00045: early stopping

# %%
import seaborn as sns
sns.set_style('darkgrid')
import matplotlib.pyplot as plt
import matplotlib.image as mimg

# %%
accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(accuracy) + 1)

f, axes = plt.subplots(1,2,figsize=(14,4))

axes[0].plot(epochs, accuracy, 'g', label='Training accuracy')
axes[0].plot(epochs, val_accuracy, 'b', label='Validation accuracy')
axes[0].legend()

axes[1].plot(epochs, loss, 'g', label='Training loss')
axes[1].plot(epochs, val_loss, 'b', label='Validation loss')
axes[1].yaxis.set_label_position("right")
axes[1].legend()

plt.show()

# %%
saved_model = tf.keras.models.load_model('best_model.h5')
print("Test Accuracy: {0:.2f}%".format(saved_model.evaluate(x_test,y_test)[1]*100)) #get score acording to test datas
# Out:
# 14/14 [==============================] - 29s 2s/step - loss: 0.5492 - accuracy: 0.8152
# Test Accuracy: 81.52%

# %%
from sklearn.metrics import confusion_matrix
Y_pred = saved_model.predict(x_test)
Y_pred_classes = np.argmax(Y_pred,axis = 1)
Y_true = np.argmax(y_test,axis = 1)
confusion_mtx = confusion_matrix(Y_true,Y_pred_classes)
f,ax = plt.subplots(figsize = (8,8))
sns.heatmap(confusion_mtx,annot=True,linewidths = 0.01,cmap="Reds",
            linecolor = "gray",fmt = ".2f",ax=ax
            )
plt.xlabel("predicted label")
plt.ylabel("True Label")
plt.title("confusion matrix")
plt.show()

from sklearn.metrics import classification_report

print(classification_report(Y_true, Y_pred_classes))

y_test_inv = label_binarizer.inverse_transform(y_test)
print(classification_report(y_test_inv, Y_pred_classes, target_names = labels))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.90      0.88       123
#            1       0.92      0.78      0.84        89
#            2       0.70      0.88      0.78        84
#            3       0.78      0.76      0.77        67
#            4       0.83      0.69      0.75        70
#
#     accuracy                           0.82       433
#    macro avg       0.82      0.80      0.80       433
# weighted avg       0.82      0.82      0.81       433
#
#               precision    recall  f1-score   support
#
#    dandelion       0.85      0.90      0.88       123
#        daisy       0.92      0.78      0.84        89
#        tulip       0.70      0.88      0.78        84
#    sunflower       0.78      0.76      0.77        67
#         rose       0.83      0.69      0.75        70
#
#     accuracy                           0.82       433
#    macro avg       0.82      0.80      0.80       433
# weighted avg       0.82      0.82      0.81       433
