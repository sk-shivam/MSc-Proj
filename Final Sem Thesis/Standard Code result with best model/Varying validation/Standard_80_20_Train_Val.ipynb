# %%
#70-20-10 with for 90%(80%augmented, 20%validation) and 10%test data
import keras
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout, Flatten
from keras.layers import Conv2D
from keras.layers import MaxPooling2D,MaxPool2D
from keras.layers.normalization import BatchNormalization
from keras.optimizers import Adam
from keras.preprocessing.image import ImageDataGenerator
from keras import layers
from keras import models
from keras import optimizers

from tensorflow.keras.applications.resnet50 import ResNet50

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
import os

# %%
#changing the working directory
# %cd /content/gdrive/My Drive/Thesis
# Out:
# /content/gdrive/My Drive/Thesis

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import keras
from keras.models import Sequential, Model
from keras.layers import Dense, Conv2D , MaxPool2D , Flatten , Dropout , MaxPooling2D
from keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report,confusion_matrix
from keras.applications import VGG19
import cv2
import os
import random
import tensorflow as tf
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
labels = ['dandelion', 'daisy','tulip','sunflower','rose']
img_size = 150
def get_data(data_dir):
    data = [] 
    for label in labels: 
        path = os.path.join(data_dir, label)
        class_num = labels.index(label)
        for img in os.listdir(path):
            try:
                img_arr = cv2.imread(os.path.join(path, img), cv2.IMREAD_COLOR)
                resized_arr = cv2.resize(img_arr, (img_size, img_size)) # Reshaping images to preferred size
                data.append([resized_arr, class_num])
            except Exception as e:
                print(e)
    return np.array(data)

# %%
data = get_data("/content/gdrive/My Drive/Thesis/flowers")
# Out:
# OpenCV(4.1.2) /io/opencv/modules/imgproc/src/resize.cpp:3720: error: (-215:Assertion failed) !ssize.empty() in function 'resize'
#
# OpenCV(4.1.2) /io/opencv/modules/imgproc/src/resize.cpp:3720: error: (-215:Assertion failed) !ssize.empty() in function 'resize'
#
# OpenCV(4.1.2) /io/opencv/modules/imgproc/src/resize.cpp:3720: error: (-215:Assertion failed) !ssize.empty() in function 'resize'

# %%
l = []
for i in data:
    l.append(labels[i[1]])
sns.set_style('dark')
sns.countplot(l)

# %%
fig,ax=plt.subplots(5,2)
fig.set_size_inches(15,15)
for i in range(5):
    for j in range (2):
        l=random.randint(0,len(data))
        ax[i,j].imshow(data[l][0])
        ax[i,j].set_title('Flower: '+labels[data[l][1]])
        
plt.tight_layout()

# %%
x = []
y = []

for feature, label in data:
    x.append(feature)
    y.append(label)

# %%
# Normalize the data
x = np.array(x) / 255

# %%
# Reshaping the data from 1-D to 3-D as required through input by CNN's 
x = x.reshape(-1, img_size, img_size, 3)
y = np.array(y)

# %%
from sklearn.preprocessing import LabelBinarizer
label_binarizer = LabelBinarizer()
y = label_binarizer.fit_transform(y)

# %%
x_train,x_test,y_train,y_test = train_test_split(x , y , test_size = 0.1 , random_state = 42)

# %%
x_train,x_val,y_train,y_val = train_test_split(x_train, y_train, test_size= 0.2, random_state = 42)

# %%
#defining the augmentation
datagen = ImageDataGenerator(
    featurewise_center=False,  # set input mean to 0 over the dataset
    samplewise_center=False,  # set each sample mean to 0
    featurewise_std_normalization=False,  # divide inputs by std of the dataset
    samplewise_std_normalization=False,  # divide each input by its std
    rotation_range=30,  # randomly rotate images in the range (60, 0 to 180)
    zoom_range = 0.1, # Randomly zoom image 
    width_shift_range=0.1,  # randomly shift images horizontally (fraction of total width)
    height_shift_range=0.1,
    shear_range=0.1,
    fill_mode = "reflect"
    ) 
datagen.fit(x_train)

# %%
model = Sequential()

#Adding ResNet model
model.add(ResNet50(include_top=False, pooling='avg', weights="imagenet", input_shape=(150,150,3)))
model.add(Flatten())

model.add(Dense(1024,activation="relu"))
model.add(Dropout(0.5))
model.add(BatchNormalization())

#Output layer
model.add(Dense(5, activation='softmax'))

model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94773248/94765736 [==============================] - 1s 0us/step
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# resnet50 (Functional)        (None, 2048)              23587712
# _________________________________________________________________
# flatten (Flatten)            (None, 2048)              0
# _________________________________________________________________
# dense (Dense)                (None, 1024)              2098176
# _________________________________________________________________
# dropout (Dropout)            (None, 1024)              0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 1024)              4096
# _________________________________________________________________
# dense_1 (Dense)              (None, 5)                 5125
# =================================================================
# Total params: 25,695,109
# Trainable params: 25,639,941
# Non-trainable params: 55,168
# _________________________________________________________________

# %%
#defining early stopping
from keras.callbacks import ReduceLROnPlateau
learning_rate = ReduceLROnPlateau(monitor='val_accuracy', patience = 3, verbose=1,factor=0.5, min_lr=0.000001)

es = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss', patience=10, verbose=1, mode='min')

# %%
# !pip install h5py
	
	
mc = tf.keras.callbacks.ModelCheckpoint('best_model.h5', monitor='val_accuracy', mode='max', verbose=1, save_best_only=True)
# Out:
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (2.10.0)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from h5py) (1.15.0)
# Requirement already satisfied: numpy>=1.7 in /usr/local/lib/python3.6/dist-packages (from h5py) (1.18.5)

# %%
model.compile(optimizer = "adam" , loss = 'categorical_crossentropy' , metrics = ['accuracy'])

# %%
#Fitting the augmentation data
history = model.fit(datagen.flow(x_train, y_train, batch_size=32), epochs=100, validation_data = (x_val, y_val), callbacks = [learning_rate,es,mc])
# Out:
# Epoch 1/100
# 98/98 [==============================] - ETA: 0s - loss: 1.0758 - accuracy: 0.6359
# Epoch 00001: val_accuracy improved from -inf to 0.16710, saving model to best_model.h5
# 98/98 [==============================] - 1028s 10s/step - loss: 1.0758 - accuracy: 0.6359 - val_loss: 9.2019 - val_accuracy: 0.1671
# Epoch 2/100
# 98/98 [==============================] - ETA: 0s - loss: 0.9430 - accuracy: 0.6732
# Epoch 00002: val_accuracy improved from 0.16710 to 0.16967, saving model to best_model.h5
# 98/98 [==============================] - 1029s 10s/step - loss: 0.9430 - accuracy: 0.6732 - val_loss: 3.5817 - val_accuracy: 0.1697
# Epoch 3/100
# 98/98 [==============================] - ETA: 0s - loss: 0.9148 - accuracy: 0.6713
# Epoch 00003: val_accuracy improved from 0.16967 to 0.23265, saving model to best_model.h5
# 98/98 [==============================] - 1028s 10s/step - loss: 0.9148 - accuracy: 0.6713 - val_loss: 1.6814 - val_accuracy: 0.2326
# Epoch 4/100
# 98/98 [==============================] - ETA: 0s - loss: 0.8640 - accuracy: 0.6944
# Epoch 00004: val_accuracy did not improve from 0.23265
# 98/98 [==============================] - 1022s 10s/step - loss: 0.8640 - accuracy: 0.6944 - val_loss: 1.6790 - val_accuracy: 0.2044
# Epoch 5/100
# 98/98 [==============================] - ETA: 0s - loss: 0.9441 - accuracy: 0.6401
# Epoch 00005: val_accuracy improved from 0.23265 to 0.24422, saving model to best_model.h5
# 98/98 [==============================] - 1020s 10s/step - loss: 0.9441 - accuracy: 0.6401 - val_loss: 1.6757 - val_accuracy: 0.2442
# Epoch 6/100
# 98/98 [==============================] - ETA: 0s - loss: 0.7542 - accuracy: 0.7179
# Epoch 00006: val_accuracy did not improve from 0.24422
# 98/98 [==============================] - 1018s 10s/step - loss: 0.7542 - accuracy: 0.7179 - val_loss: 1.7534 - val_accuracy: 0.2326
# Epoch 7/100
# 98/98 [==============================] - ETA: 0s - loss: 0.6629 - accuracy: 0.7561
# Epoch 00007: val_accuracy improved from 0.24422 to 0.26735, saving model to best_model.h5
# 98/98 [==============================] - 1021s 10s/step - loss: 0.6629 - accuracy: 0.7561 - val_loss: 1.6698 - val_accuracy: 0.2674
# Epoch 8/100
# 98/98 [==============================] - ETA: 0s - loss: 0.6527 - accuracy: 0.7680
# Epoch 00008: val_accuracy improved from 0.26735 to 0.33933, saving model to best_model.h5
# 98/98 [==============================] - 1025s 10s/step - loss: 0.6527 - accuracy: 0.7680 - val_loss: 1.8775 - val_accuracy: 0.3393
# Epoch 9/100
# 98/98 [==============================] - ETA: 0s - loss: 0.6034 - accuracy: 0.7763
# Epoch 00009: val_accuracy improved from 0.33933 to 0.60925, saving model to best_model.h5
# 98/98 [==============================] - 1027s 10s/step - loss: 0.6034 - accuracy: 0.7763 - val_loss: 0.9806 - val_accuracy: 0.6093
# Epoch 10/100
# 98/98 [==============================] - ETA: 0s - loss: 0.4995 - accuracy: 0.8133
# Epoch 00010: val_accuracy did not improve from 0.60925
# 98/98 [==============================] - 1026s 10s/step - loss: 0.4995 - accuracy: 0.8133 - val_loss: 1.1065 - val_accuracy: 0.5964
# Epoch 11/100
# 98/98 [==============================] - ETA: 0s - loss: 0.4639 - accuracy: 0.8387
# Epoch 00011: val_accuracy improved from 0.60925 to 0.68123, saving model to best_model.h5
# 98/98 [==============================] - 1038s 11s/step - loss: 0.4639 - accuracy: 0.8387 - val_loss: 1.0863 - val_accuracy: 0.6812
# Epoch 12/100
# 98/98 [==============================] - ETA: 0s - loss: 0.4247 - accuracy: 0.8435
# Epoch 00012: val_accuracy improved from 0.68123 to 0.85090, saving model to best_model.h5
# 98/98 [==============================] - 1034s 11s/step - loss: 0.4247 - accuracy: 0.8435 - val_loss: 0.4553 - val_accuracy: 0.8509
# Epoch 13/100
# 98/98 [==============================] - ETA: 0s - loss: 0.4121 - accuracy: 0.8535
# Epoch 00013: val_accuracy did not improve from 0.85090
# 98/98 [==============================] - 1031s 11s/step - loss: 0.4121 - accuracy: 0.8535 - val_loss: 0.4929 - val_accuracy: 0.8252
# Epoch 14/100
# 98/98 [==============================] - ETA: 0s - loss: 0.3932 - accuracy: 0.8586
# Epoch 00014: val_accuracy did not improve from 0.85090
# 98/98 [==============================] - 1034s 11s/step - loss: 0.3932 - accuracy: 0.8586 - val_loss: 0.6403 - val_accuracy: 0.7609
# Epoch 15/100
# 98/98 [==============================] - ETA: 0s - loss: 0.3826 - accuracy: 0.8641
# Epoch 00015: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00015: val_accuracy did not improve from 0.85090
# 98/98 [==============================] - 1033s 11s/step - loss: 0.3826 - accuracy: 0.8641 - val_loss: 0.7445 - val_accuracy: 0.7468
# Epoch 16/100
# 98/98 [==============================] - ETA: 0s - loss: 0.3199 - accuracy: 0.8856
# Epoch 00016: val_accuracy did not improve from 0.85090
# 98/98 [==============================] - 1034s 11s/step - loss: 0.3199 - accuracy: 0.8856 - val_loss: 0.7333 - val_accuracy: 0.7828
# Epoch 17/100
# 98/98 [==============================] - ETA: 0s - loss: 0.3011 - accuracy: 0.8891
# Epoch 00017: val_accuracy did not improve from 0.85090
# 98/98 [==============================] - 1033s 11s/step - loss: 0.3011 - accuracy: 0.8891 - val_loss: 0.4128 - val_accuracy: 0.8483
# Epoch 18/100
# 98/98 [==============================] - ETA: 0s - loss: 0.2678 - accuracy: 0.9023
# Epoch 00018: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 00018: val_accuracy did not improve from 0.85090
# 98/98 [==============================] - 1030s 11s/step - loss: 0.2678 - accuracy: 0.9023 - val_loss: 0.5291 - val_accuracy: 0.8149
# Epoch 19/100
# 98/98 [==============================] - ETA: 0s - loss: 0.1945 - accuracy: 0.9312
# Epoch 00019: val_accuracy improved from 0.85090 to 0.86247, saving model to best_model.h5
# 98/98 [==============================] - 1030s 11s/step - loss: 0.1945 - accuracy: 0.9312 - val_loss: 0.4051 - val_accuracy: 0.8625
# Epoch 20/100
# 98/98 [==============================] - ETA: 0s - loss: 0.1860 - accuracy: 0.9354
# Epoch 00020: val_accuracy improved from 0.86247 to 0.87532, saving model to best_model.h5
# 98/98 [==============================] - 1030s 11s/step - loss: 0.1860 - accuracy: 0.9354 - val_loss: 0.3872 - val_accuracy: 0.8753
# Epoch 21/100
# 98/98 [==============================] - ETA: 0s - loss: 0.1862 - accuracy: 0.9351
# Epoch 00021: val_accuracy did not improve from 0.87532
# 98/98 [==============================] - 1029s 10s/step - loss: 0.1862 - accuracy: 0.9351 - val_loss: 0.4186 - val_accuracy: 0.8650
# Epoch 22/100
# 98/98 [==============================] - ETA: 0s - loss: 0.1669 - accuracy: 0.9418
# Epoch 00022: val_accuracy did not improve from 0.87532
# 98/98 [==============================] - 1031s 11s/step - loss: 0.1669 - accuracy: 0.9418 - val_loss: 0.4079 - val_accuracy: 0.8612
# Epoch 23/100
# 98/98 [==============================] - ETA: 0s - loss: 0.1514 - accuracy: 0.9434
# Epoch 00023: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 00023: val_accuracy did not improve from 0.87532
# 98/98 [==============================] - 1032s 11s/step - loss: 0.1514 - accuracy: 0.9434 - val_loss: 0.4701 - val_accuracy: 0.8548
# Epoch 24/100
# 98/98 [==============================] - ETA: 0s - loss: 0.1156 - accuracy: 0.9611
# Epoch 00024: val_accuracy improved from 0.87532 to 0.89332, saving model to best_model.h5
# 98/98 [==============================] - 1035s 11s/step - loss: 0.1156 - accuracy: 0.9611 - val_loss: 0.3598 - val_accuracy: 0.8933
# Epoch 25/100
# 98/98 [==============================] - ETA: 0s - loss: 0.1198 - accuracy: 0.9592
# Epoch 00025: val_accuracy did not improve from 0.89332
# 98/98 [==============================] - 1035s 11s/step - loss: 0.1198 - accuracy: 0.9592 - val_loss: 0.3876 - val_accuracy: 0.8830
# Epoch 26/100
# 98/98 [==============================] - ETA: 0s - loss: 0.1040 - accuracy: 0.9627
# Epoch 00026: val_accuracy did not improve from 0.89332
# 98/98 [==============================] - 1033s 11s/step - loss: 0.1040 - accuracy: 0.9627 - val_loss: 0.3835 - val_accuracy: 0.8856
# Epoch 27/100
# 98/98 [==============================] - ETA: 0s - loss: 0.1058 - accuracy: 0.9621
# Epoch 00027: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
#
# Epoch 00027: val_accuracy did not improve from 0.89332
# 98/98 [==============================] - 1033s 11s/step - loss: 0.1058 - accuracy: 0.9621 - val_loss: 0.4392 - val_accuracy: 0.8779
# Epoch 28/100
# 98/98 [==============================] - ETA: 0s - loss: 0.0831 - accuracy: 0.9720
# Epoch 00028: val_accuracy did not improve from 0.89332
# 98/98 [==============================] - 1032s 11s/step - loss: 0.0831 - accuracy: 0.9720 - val_loss: 0.4020 - val_accuracy: 0.8856
# Epoch 29/100
# 98/98 [==============================] - ETA: 0s - loss: 0.0730 - accuracy: 0.9701
# Epoch 00029: val_accuracy did not improve from 0.89332
# 98/98 [==============================] - 1034s 11s/step - loss: 0.0730 - accuracy: 0.9701 - val_loss: 0.4103 - val_accuracy: 0.8907
# Epoch 30/100
# 98/98 [==============================] - ETA: 0s - loss: 0.0722 - accuracy: 0.9759
# Epoch 00030: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
#
# Epoch 00030: val_accuracy did not improve from 0.89332
# 98/98 [==============================] - 1033s 11s/step - loss: 0.0722 - accuracy: 0.9759 - val_loss: 0.4308 - val_accuracy: 0.8882
# Epoch 31/100
# 98/98 [==============================] - ETA: 0s - loss: 0.0704 - accuracy: 0.9769
# Epoch 00031: val_accuracy did not improve from 0.89332
# 98/98 [==============================] - 1030s 11s/step - loss: 0.0704 - accuracy: 0.9769 - val_loss: 0.4399 - val_accuracy: 0.8882
# Epoch 32/100
# 98/98 [==============================] - ETA: 0s - loss: 0.0741 - accuracy: 0.9740
# Epoch 00032: val_accuracy did not improve from 0.89332
# 98/98 [==============================] - 1032s 11s/step - loss: 0.0741 - accuracy: 0.9740 - val_loss: 0.4487 - val_accuracy: 0.8869
# Epoch 33/100
# 98/98 [==============================] - ETA: 0s - loss: 0.0688 - accuracy: 0.9759
# Epoch 00033: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
#
# Epoch 00033: val_accuracy did not improve from 0.89332
# 98/98 [==============================] - 1030s 11s/step - loss: 0.0688 - accuracy: 0.9759 - val_loss: 0.4630 - val_accuracy: 0.8856
# Epoch 34/100
# 98/98 [==============================] - ETA: 0s - loss: 0.0649 - accuracy: 0.9769
# Epoch 00034: val_accuracy did not improve from 0.89332
# 98/98 [==============================] - 1031s 11s/step - loss: 0.0649 - accuracy: 0.9769 - val_loss: 0.4545 - val_accuracy: 0.8830
# Epoch 00034: early stopping

# %%
import seaborn as sns
sns.set_style('darkgrid')
import matplotlib.pyplot as plt
import matplotlib.image as mimg

# %%
accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(accuracy) + 1)

f, axes = plt.subplots(1,2,figsize=(14,4))

axes[0].plot(epochs, accuracy, 'g', label='Training accuracy')
axes[0].plot(epochs, val_accuracy, 'b', label='Validation accuracy')
axes[0].legend()

axes[1].plot(epochs, loss, 'g', label='Training loss')
axes[1].plot(epochs, val_loss, 'b', label='Validation loss')
axes[1].yaxis.set_label_position("right")
axes[1].legend()

plt.show()

# %%
saved_model = tf.keras.models.load_model('best_model.h5')
print("Test Accuracy: {0:.2f}%".format(saved_model.evaluate(x_test,y_test)[1]*100)) #get score acording to test datas
# Out:
# 14/14 [==============================] - 26s 2s/step - loss: 0.2901 - accuracy: 0.8938
# Test Accuracy: 89.38%

# %%
from sklearn.metrics import confusion_matrix
Y_pred = saved_model.predict(x_test)
Y_pred_classes = np.argmax(Y_pred,axis = 1)
Y_true = np.argmax(y_test,axis = 1)
confusion_mtx = confusion_matrix(Y_true,Y_pred_classes)
f,ax = plt.subplots(figsize = (8,8))
sns.heatmap(confusion_mtx,annot=True,linewidths = 0.01,cmap="Reds",
            linecolor = "gray",fmt = ".2f",ax=ax
            )
plt.xlabel("predicted label")
plt.ylabel("True Label")
plt.title("confusion matrix")
plt.show()

from sklearn.metrics import classification_report

print(classification_report(Y_true, Y_pred_classes))

y_test_inv = label_binarizer.inverse_transform(y_test)
print(classification_report(y_test_inv, Y_pred_classes, target_names = labels))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.91      0.93       123
#            1       0.91      0.88      0.89        89
#            2       0.87      0.88      0.88        84
#            3       0.89      0.94      0.91        67
#            4       0.83      0.86      0.85        70
#
#     accuracy                           0.89       433
#    macro avg       0.89      0.89      0.89       433
# weighted avg       0.89      0.89      0.89       433
#
#               precision    recall  f1-score   support
#
#    dandelion       0.94      0.91      0.93       123
#        daisy       0.91      0.88      0.89        89
#        tulip       0.87      0.88      0.88        84
#    sunflower       0.89      0.94      0.91        67
#         rose       0.83      0.86      0.85        70
#
#     accuracy                           0.89       433
#    macro avg       0.89      0.89      0.89       433
# weighted avg       0.89      0.89      0.89       433
