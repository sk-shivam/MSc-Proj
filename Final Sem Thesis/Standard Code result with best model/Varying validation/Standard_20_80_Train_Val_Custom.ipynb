# %%
#54-36-10 with for 90%(20%augmented, 80%validation) and 10%test data
import keras
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout, Flatten
from keras.layers import Conv2D
from keras.layers import MaxPooling2D,MaxPool2D
from keras.layers.normalization import BatchNormalization
from keras.optimizers import Adam
from keras.preprocessing.image import ImageDataGenerator
from keras import layers
from keras import models
from keras import optimizers

from tensorflow.keras.applications.resnet50 import ResNet50

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
import os

# %%
#changing the working directory
# %cd /content/gdrive/My Drive/Thesis
# Out:
# /content/gdrive/My Drive/Thesis

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import keras
from keras.models import Sequential, Model
from keras.layers import Dense, Conv2D , MaxPool2D , Flatten , Dropout , MaxPooling2D
from keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report,confusion_matrix
from keras.applications import VGG19
import cv2
import os
import random
import tensorflow as tf

# %%
labels = ['dandelion', 'daisy','tulip','sunflower','rose']
img_size = 150
def get_data(data_dir):
    data = [] 
    for label in labels: 
        path = os.path.join(data_dir, label)
        class_num = labels.index(label)
        for img in os.listdir(path):
            try:
                img_arr = cv2.imread(os.path.join(path, img), cv2.IMREAD_COLOR)
                resized_arr = cv2.resize(img_arr, (img_size, img_size)) # Reshaping images to preferred size
                data.append([resized_arr, class_num])
            except Exception as e:
                print(e)
    return np.array(data)

# %%
data = get_data("/content/gdrive/My Drive/Thesis/flowers")
# Out:
# OpenCV(4.1.2) /io/opencv/modules/imgproc/src/resize.cpp:3720: error: (-215:Assertion failed) !ssize.empty() in function 'resize'
#
# OpenCV(4.1.2) /io/opencv/modules/imgproc/src/resize.cpp:3720: error: (-215:Assertion failed) !ssize.empty() in function 'resize'
#
# OpenCV(4.1.2) /io/opencv/modules/imgproc/src/resize.cpp:3720: error: (-215:Assertion failed) !ssize.empty() in function 'resize'

# %%
l = []
for i in data:
    l.append(labels[i[1]])
sns.set_style('dark')
sns.countplot(l)

# %%
fig,ax=plt.subplots(5,2)
fig.set_size_inches(15,15)
for i in range(5):
    for j in range (2):
        l=random.randint(0,len(data))
        ax[i,j].imshow(data[l][0])
        ax[i,j].set_title('Flower: '+labels[data[l][1]])
        
plt.tight_layout()

# %%
x = []
y = []

for feature, label in data:
    x.append(feature)
    y.append(label)

# %%
# Normalize the data
x = np.array(x) / 255

# %%
# Reshaping the data from 1-D to 3-D as required through input by CNN's 
x = x.reshape(-1, img_size, img_size, 3)
y = np.array(y)

# %%
from sklearn.preprocessing import LabelBinarizer
label_binarizer = LabelBinarizer()
y = label_binarizer.fit_transform(y)

# %%
x_train,x_test,y_train,y_test = train_test_split(x , y , test_size = 0.1 , random_state = 42)

# %%
x_train,x_val,y_train,y_val = train_test_split(x_train, y_train, test_size= 0.8, random_state = 42)

# %%
#defining the augmentation
datagen = ImageDataGenerator(
    featurewise_center=False,  # set input mean to 0 over the dataset
    samplewise_center=False,  # set each sample mean to 0
    featurewise_std_normalization=False,  # divide inputs by std of the dataset
    samplewise_std_normalization=False,  # divide each input by its std
    rotation_range=30,  # randomly rotate images in the range (60, 0 to 180)
    zoom_range = 0.1, # Randomly zoom image 
    width_shift_range=0.1,  # randomly shift images horizontally (fraction of total width)
    height_shift_range=0.1,
    shear_range=0.1,
    fill_mode = "reflect"
    ) 
datagen.fit(x_train)

# %%
model = Sequential()

#Adding ResNet model
model.add(ResNet50(include_top=False, pooling='avg', weights="imagenet", input_shape=(150,150,3)))
model.add(Flatten())

model.add(Dense(1024,activation="relu"))
model.add(Dropout(0.5))
model.add(BatchNormalization())

#Output layer
model.add(Dense(5, activation='softmax'))

model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94773248/94765736 [==============================] - 1s 0us/step
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# resnet50 (Functional)        (None, 2048)              23587712
# _________________________________________________________________
# flatten (Flatten)            (None, 2048)              0
# _________________________________________________________________
# dense (Dense)                (None, 1024)              2098176
# _________________________________________________________________
# dropout (Dropout)            (None, 1024)              0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 1024)              4096
# _________________________________________________________________
# dense_1 (Dense)              (None, 5)                 5125
# =================================================================
# Total params: 25,695,109
# Trainable params: 25,639,941
# Non-trainable params: 55,168
# _________________________________________________________________

# %%
#defining early stopping
from keras.callbacks import ReduceLROnPlateau
learning_rate = ReduceLROnPlateau(monitor='val_accuracy', patience = 3, verbose=1,factor=0.5, min_lr=0.000001)

es = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss', patience=15, verbose=1, mode='min')

# %%
# !pip install h5py
	
	
mc = tf.keras.callbacks.ModelCheckpoint('best_model.h5', monitor='val_accuracy', mode='max', verbose=1, save_best_only=True)
# Out:
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (2.10.0)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from h5py) (1.15.0)
# Requirement already satisfied: numpy>=1.7 in /usr/local/lib/python3.6/dist-packages (from h5py) (1.18.5)

# %%
model.compile(optimizer = "adam" , loss = 'categorical_crossentropy' , metrics = ['accuracy'])

# %%
#Fitting the augmentation data
history = model.fit(datagen.flow(x_train, y_train, batch_size=32), epochs=100, validation_data = (x_val, y_val), callbacks = [learning_rate,es,mc])
# Out:
# Epoch 1/100
# 25/25 [==============================] - ETA: 0s - loss: 0.0901 - accuracy: 0.9769
# Epoch 00001: val_accuracy improved from 0.24359 to 0.25288, saving model to best_model.h5
# 25/25 [==============================] - 484s 19s/step - loss: 0.0901 - accuracy: 0.9769 - val_loss: 1.8663 - val_accuracy: 0.2529
# Epoch 2/100
# 25/25 [==============================] - ETA: 0s - loss: 0.1018 - accuracy: 0.9628
# Epoch 00002: val_accuracy improved from 0.25288 to 0.27308, saving model to best_model.h5
# 25/25 [==============================] - 483s 19s/step - loss: 0.1018 - accuracy: 0.9628 - val_loss: 1.8861 - val_accuracy: 0.2731
# Epoch 3/100
# 25/25 [==============================] - ETA: 0s - loss: 0.0776 - accuracy: 0.9769
# Epoch 00003: val_accuracy improved from 0.27308 to 0.30353, saving model to best_model.h5
# 25/25 [==============================] - 483s 19s/step - loss: 0.0776 - accuracy: 0.9769 - val_loss: 1.8376 - val_accuracy: 0.3035
# Epoch 4/100
# 25/25 [==============================] - ETA: 0s - loss: 0.0788 - accuracy: 0.9769
# Epoch 00004: val_accuracy improved from 0.30353 to 0.35321, saving model to best_model.h5
# 25/25 [==============================] - 484s 19s/step - loss: 0.0788 - accuracy: 0.9769 - val_loss: 1.7611 - val_accuracy: 0.3532
# Epoch 5/100
# 25/25 [==============================] - ETA: 0s - loss: 0.0841 - accuracy: 0.9718
# Epoch 00005: val_accuracy improved from 0.35321 to 0.40096, saving model to best_model.h5
# 25/25 [==============================] - 483s 19s/step - loss: 0.0841 - accuracy: 0.9718 - val_loss: 1.6865 - val_accuracy: 0.4010
# Epoch 6/100
# 25/25 [==============================] - ETA: 0s - loss: 0.1233 - accuracy: 0.9641
# Epoch 00006: val_accuracy improved from 0.40096 to 0.44679, saving model to best_model.h5
# 25/25 [==============================] - 485s 19s/step - loss: 0.1233 - accuracy: 0.9641 - val_loss: 1.6219 - val_accuracy: 0.4468
# Epoch 7/100
# 25/25 [==============================] - ETA: 0s - loss: 0.1065 - accuracy: 0.9653
# Epoch 00007: val_accuracy improved from 0.44679 to 0.48910, saving model to best_model.h5
# 25/25 [==============================] - 485s 19s/step - loss: 0.1065 - accuracy: 0.9653 - val_loss: 1.5188 - val_accuracy: 0.4891
# Epoch 8/100
# 25/25 [==============================] - ETA: 0s - loss: 0.1112 - accuracy: 0.9641
# Epoch 00008: val_accuracy improved from 0.48910 to 0.52724, saving model to best_model.h5
# 25/25 [==============================] - 481s 19s/step - loss: 0.1112 - accuracy: 0.9641 - val_loss: 1.4000 - val_accuracy: 0.5272
# Epoch 9/100
# 25/25 [==============================] - ETA: 0s - loss: 0.0798 - accuracy: 0.9795
# Epoch 00009: val_accuracy improved from 0.52724 to 0.56442, saving model to best_model.h5
# 25/25 [==============================] - 477s 19s/step - loss: 0.0798 - accuracy: 0.9795 - val_loss: 1.2866 - val_accuracy: 0.5644
# Epoch 10/100
# 25/25 [==============================] - ETA: 0s - loss: 0.0716 - accuracy: 0.9782
# Epoch 00010: val_accuracy improved from 0.56442 to 0.60577, saving model to best_model.h5
# 25/25 [==============================] - 480s 19s/step - loss: 0.0716 - accuracy: 0.9782 - val_loss: 1.1580 - val_accuracy: 0.6058
# Epoch 11/100
# 25/25 [==============================] - ETA: 0s - loss: 0.0651 - accuracy: 0.9859
# Epoch 00011: val_accuracy improved from 0.60577 to 0.63429, saving model to best_model.h5
# 25/25 [==============================] - 484s 19s/step - loss: 0.0651 - accuracy: 0.9859 - val_loss: 1.0814 - val_accuracy: 0.6343
# Epoch 12/100
# 25/25 [==============================] - ETA: 0s - loss: 0.0968 - accuracy: 0.9666
# Epoch 00012: val_accuracy improved from 0.63429 to 0.67212, saving model to best_model.h5
# 25/25 [==============================] - 497s 20s/step - loss: 0.0968 - accuracy: 0.9666 - val_loss: 0.9879 - val_accuracy: 0.6721
# Epoch 13/100
# 25/25 [==============================] - ETA: 0s - loss: 0.0906 - accuracy: 0.9666
# Epoch 00013: val_accuracy improved from 0.67212 to 0.70673, saving model to best_model.h5
# 25/25 [==============================] - 504s 20s/step - loss: 0.0906 - accuracy: 0.9666 - val_loss: 0.8883 - val_accuracy: 0.7067
# Epoch 14/100
# 25/25 [==============================] - ETA: 0s - loss: 0.0948 - accuracy: 0.9807
# Epoch 00014: val_accuracy improved from 0.70673 to 0.73365, saving model to best_model.h5
# 25/25 [==============================] - 497s 20s/step - loss: 0.0948 - accuracy: 0.9807 - val_loss: 0.8138 - val_accuracy: 0.7337
# Epoch 15/100
# 25/25 [==============================] - ETA: 0s - loss: 0.0734 - accuracy: 0.9718
# Epoch 00015: val_accuracy improved from 0.73365 to 0.76026, saving model to best_model.h5
# 25/25 [==============================] - 493s 20s/step - loss: 0.0734 - accuracy: 0.9718 - val_loss: 0.7442 - val_accuracy: 0.7603
# Epoch 16/100
# 25/25 [==============================] - ETA: 0s - loss: 0.0771 - accuracy: 0.9769
# Epoch 00016: val_accuracy improved from 0.76026 to 0.77853, saving model to best_model.h5
# 25/25 [==============================] - 481s 19s/step - loss: 0.0771 - accuracy: 0.9769 - val_loss: 0.6933 - val_accuracy: 0.7785
# Epoch 17/100
# 25/25 [==============================] - ETA: 0s - loss: 0.0742 - accuracy: 0.9769
# Epoch 00017: val_accuracy improved from 0.77853 to 0.78974, saving model to best_model.h5
# 25/25 [==============================] - 481s 19s/step - loss: 0.0742 - accuracy: 0.9769 - val_loss: 0.6522 - val_accuracy: 0.7897
# Epoch 18/100
# 25/25 [==============================] - ETA: 0s - loss: 0.0865 - accuracy: 0.9679
# Epoch 00018: val_accuracy improved from 0.78974 to 0.79647, saving model to best_model.h5
# 25/25 [==============================] - 482s 19s/step - loss: 0.0865 - accuracy: 0.9679 - val_loss: 0.6312 - val_accuracy: 0.7965
# Epoch 19/100
# 25/25 [==============================] - ETA: 0s - loss: 0.0940 - accuracy: 0.9666
# Epoch 00019: val_accuracy improved from 0.79647 to 0.80481, saving model to best_model.h5
# 25/25 [==============================] - 492s 20s/step - loss: 0.0940 - accuracy: 0.9666 - val_loss: 0.6017 - val_accuracy: 0.8048
# Epoch 20/100
# 25/25 [==============================] - ETA: 0s - loss: 0.0773 - accuracy: 0.9730
# Epoch 00020: val_accuracy improved from 0.80481 to 0.82244, saving model to best_model.h5
# 25/25 [==============================] - 493s 20s/step - loss: 0.0773 - accuracy: 0.9730 - val_loss: 0.5631 - val_accuracy: 0.8224
# Epoch 21/100
# 25/25 [==============================] - ETA: 0s - loss: 0.0673 - accuracy: 0.9769
# Epoch 00021: val_accuracy improved from 0.82244 to 0.83013, saving model to best_model.h5
# 25/25 [==============================] - 502s 20s/step - loss: 0.0673 - accuracy: 0.9769 - val_loss: 0.5419 - val_accuracy: 0.8301
# Epoch 22/100
# 25/25 [==============================] - ETA: 0s - loss: 0.0634 - accuracy: 0.9833
# Epoch 00022: val_accuracy improved from 0.83013 to 0.83397, saving model to best_model.h5
# 25/25 [==============================] - 500s 20s/step - loss: 0.0634 - accuracy: 0.9833 - val_loss: 0.5226 - val_accuracy: 0.8340
# Epoch 23/100
# 25/25 [==============================] - ETA: 0s - loss: 0.0947 - accuracy: 0.9743
# Epoch 00023: val_accuracy did not improve from 0.83397
# 25/25 [==============================] - 490s 20s/step - loss: 0.0947 - accuracy: 0.9743 - val_loss: 0.5302 - val_accuracy: 0.8321
# Epoch 24/100
# 25/25 [==============================] - ETA: 0s - loss: 0.0839 - accuracy: 0.9743
# Epoch 00024: val_accuracy did not improve from 0.83397
# 25/25 [==============================] - 488s 20s/step - loss: 0.0839 - accuracy: 0.9743 - val_loss: 0.5251 - val_accuracy: 0.8340
# Epoch 25/100
# 25/25 [==============================] - ETA: 0s - loss: 0.0805 - accuracy: 0.9705
# Epoch 00025: val_accuracy improved from 0.83397 to 0.83846, saving model to best_model.h5
# 25/25 [==============================] - 502s 20s/step - loss: 0.0805 - accuracy: 0.9705 - val_loss: 0.5170 - val_accuracy: 0.8385
# Epoch 26/100
# 25/25 [==============================] - ETA: 0s - loss: 0.0729 - accuracy: 0.9846
# Epoch 00026: val_accuracy improved from 0.83846 to 0.84006, saving model to best_model.h5
# 25/25 [==============================] - 496s 20s/step - loss: 0.0729 - accuracy: 0.9846 - val_loss: 0.5100 - val_accuracy: 0.8401
# Epoch 27/100
# 25/25 [==============================] - ETA: 0s - loss: 0.0585 - accuracy: 0.9859
# Epoch 00027: val_accuracy improved from 0.84006 to 0.84199, saving model to best_model.h5
# 25/25 [==============================] - 490s 20s/step - loss: 0.0585 - accuracy: 0.9859 - val_loss: 0.5064 - val_accuracy: 0.8420
# Epoch 28/100
# 25/25 [==============================] - ETA: 0s - loss: 0.0616 - accuracy: 0.9807
# Epoch 00028: val_accuracy improved from 0.84199 to 0.84391, saving model to best_model.h5
# 25/25 [==============================] - 489s 20s/step - loss: 0.0616 - accuracy: 0.9807 - val_loss: 0.5029 - val_accuracy: 0.8439
# Epoch 29/100
# 25/25 [==============================] - ETA: 0s - loss: 0.0551 - accuracy: 0.9884
# Epoch 00029: val_accuracy did not improve from 0.84391
# 25/25 [==============================] - 478s 19s/step - loss: 0.0551 - accuracy: 0.9884 - val_loss: 0.5035 - val_accuracy: 0.8433
# Epoch 30/100
# 25/25 [==============================] - ETA: 0s - loss: 0.0676 - accuracy: 0.9782
# Epoch 00030: val_accuracy improved from 0.84391 to 0.84423, saving model to best_model.h5
# 25/25 [==============================] - 481s 19s/step - loss: 0.0676 - accuracy: 0.9782 - val_loss: 0.5074 - val_accuracy: 0.8442
# Epoch 31/100
# 25/25 [==============================] - ETA: 0s - loss: 0.0597 - accuracy: 0.9872
# Epoch 00031: val_accuracy improved from 0.84423 to 0.84519, saving model to best_model.h5
# 25/25 [==============================] - 481s 19s/step - loss: 0.0597 - accuracy: 0.9872 - val_loss: 0.5051 - val_accuracy: 0.8452
# Epoch 32/100
# 25/25 [==============================] - ETA: 0s - loss: 0.0528 - accuracy: 0.9846
# Epoch 00032: val_accuracy did not improve from 0.84519
# 25/25 [==============================] - 480s 19s/step - loss: 0.0528 - accuracy: 0.9846 - val_loss: 0.5114 - val_accuracy: 0.8449
# Epoch 33/100
# 25/25 [==============================] - ETA: 0s - loss: 0.0383 - accuracy: 0.9923
# Epoch 00033: val_accuracy did not improve from 0.84519
# 25/25 [==============================] - 484s 19s/step - loss: 0.0383 - accuracy: 0.9923 - val_loss: 0.5150 - val_accuracy: 0.8452
# Epoch 34/100
# 25/25 [==============================] - ETA: 0s - loss: 0.0551 - accuracy: 0.9859
# Epoch 00034: val_accuracy improved from 0.84519 to 0.84551, saving model to best_model.h5
# 25/25 [==============================] - 492s 20s/step - loss: 0.0551 - accuracy: 0.9859 - val_loss: 0.5149 - val_accuracy: 0.8455
# Epoch 35/100
# 25/25 [==============================] - ETA: 0s - loss: 0.0486 - accuracy: 0.9859
# Epoch 00035: val_accuracy improved from 0.84551 to 0.84712, saving model to best_model.h5
# 25/25 [==============================] - 490s 20s/step - loss: 0.0486 - accuracy: 0.9859 - val_loss: 0.5122 - val_accuracy: 0.8471
# Epoch 36/100
# 25/25 [==============================] - ETA: 0s - loss: 0.0545 - accuracy: 0.9897
# Epoch 00036: val_accuracy did not improve from 0.84712
# 25/25 [==============================] - 488s 20s/step - loss: 0.0545 - accuracy: 0.9897 - val_loss: 0.5158 - val_accuracy: 0.8468
# Epoch 37/100
# 25/25 [==============================] - ETA: 0s - loss: 0.0462 - accuracy: 0.9884
# Epoch 00037: val_accuracy did not improve from 0.84712
# 25/25 [==============================] - 488s 20s/step - loss: 0.0462 - accuracy: 0.9884 - val_loss: 0.5208 - val_accuracy: 0.8462
# Epoch 38/100
# 25/25 [==============================] - ETA: 0s - loss: 0.0384 - accuracy: 0.9897
# Epoch 00038: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
#
# Epoch 00038: val_accuracy did not improve from 0.84712
# 25/25 [==============================] - 485s 19s/step - loss: 0.0384 - accuracy: 0.9897 - val_loss: 0.5221 - val_accuracy: 0.8455
# Epoch 39/100
# 25/25 [==============================] - ETA: 0s - loss: 0.0519 - accuracy: 0.9910
# Epoch 00039: val_accuracy did not improve from 0.84712
# 25/25 [==============================] - 494s 20s/step - loss: 0.0519 - accuracy: 0.9910 - val_loss: 0.5285 - val_accuracy: 0.8465
# Epoch 40/100
# 25/25 [==============================] - ETA: 0s - loss: 0.0428 - accuracy: 0.9897
# Epoch 00040: val_accuracy did not improve from 0.84712
# 25/25 [==============================] - 509s 20s/step - loss: 0.0428 - accuracy: 0.9897 - val_loss: 0.5296 - val_accuracy: 0.8468
# Epoch 41/100
# 25/25 [==============================] - ETA: 0s - loss: 0.0539 - accuracy: 0.9846
# Epoch 00041: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
#
# Epoch 00041: val_accuracy did not improve from 0.84712
# 25/25 [==============================] - 496s 20s/step - loss: 0.0539 - accuracy: 0.9846 - val_loss: 0.5320 - val_accuracy: 0.8462
# Epoch 42/100
# 25/25 [==============================] - ETA: 0s - loss: 0.0645 - accuracy: 0.9769
# Epoch 00042: val_accuracy did not improve from 0.84712
# 25/25 [==============================] - 488s 20s/step - loss: 0.0645 - accuracy: 0.9769 - val_loss: 0.5306 - val_accuracy: 0.8471
# Epoch 43/100
# 25/25 [==============================] - ETA: 0s - loss: 0.0484 - accuracy: 0.9846
# Epoch 00043: val_accuracy did not improve from 0.84712
# 25/25 [==============================] - 480s 19s/step - loss: 0.0484 - accuracy: 0.9846 - val_loss: 0.5283 - val_accuracy: 0.8458
# Epoch 00043: early stopping

# %%
import seaborn as sns
sns.set_style('darkgrid')
import matplotlib.pyplot as plt
import matplotlib.image as mimg

# %%
accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(accuracy) + 1)

f, axes = plt.subplots(1,2,figsize=(14,4))

axes[0].plot(epochs, accuracy, 'g', label='Training accuracy')
axes[0].plot(epochs, val_accuracy, 'b', label='Validation accuracy')
axes[0].legend()

axes[1].plot(epochs, loss, 'g', label='Training loss')
axes[1].plot(epochs, val_loss, 'b', label='Validation loss')
axes[1].yaxis.set_label_position("right")
axes[1].legend()

plt.show()

# %%
saved_model = tf.keras.models.load_model('best_model.h5')
print("Test Accuracy: {0:.2f}%".format(saved_model.evaluate(x_test,y_test)[1]*100)) #get score acording to test datas
# Out:
# 14/14 [==============================] - 29s 2s/step - loss: 0.4961 - accuracy: 0.8502
# Test Accuracy: 85.02%

# %%
from sklearn.metrics import confusion_matrix
Y_pred = saved_model.predict(x_test)
Y_pred_classes = np.argmax(Y_pred,axis = 1)
Y_true = np.argmax(y_test,axis = 1)
confusion_mtx = confusion_matrix(Y_true,Y_pred_classes)
f,ax = plt.subplots(figsize = (8,8))
sns.heatmap(confusion_mtx,annot=True,linewidths = 0.01,cmap="Reds",
            linecolor = "gray",ax=ax
            )
plt.xlabel("predicted label")
plt.ylabel("True Label")
plt.title("confusion matrix")
plt.show()

from sklearn.metrics import classification_report

print(classification_report(Y_true, Y_pred_classes))


y_test_inv = label_binarizer.inverse_transform(y_test)
print(classification_report(y_test_inv, Y_pred_classes, target_names = labels))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.89      0.93       111
#            1       0.87      0.92      0.89        84
#            2       0.77      0.79      0.78       104
#            3       0.91      0.88      0.90        60
#            4       0.74      0.77      0.76        75
#
#     accuracy                           0.85       434
#    macro avg       0.85      0.85      0.85       434
# weighted avg       0.85      0.85      0.85       434
#
#               precision    recall  f1-score   support
#
#    dandelion       0.97      0.89      0.93       111
#        daisy       0.87      0.92      0.89        84
#        tulip       0.77      0.79      0.78       104
#    sunflower       0.91      0.88      0.90        60
#         rose       0.74      0.77      0.76        75
#
#     accuracy                           0.85       434
#    macro avg       0.85      0.85      0.85       434
# weighted avg       0.85      0.85      0.85       434
