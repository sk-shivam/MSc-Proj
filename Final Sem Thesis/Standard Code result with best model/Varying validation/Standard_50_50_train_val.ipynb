# %%
#45-45-10 with for 90%(50%augmented, 50%validation) and 10%test data
import keras
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout, Flatten
from keras.layers import Conv2D
from keras.layers import MaxPooling2D,MaxPool2D
from keras.layers.normalization import BatchNormalization
from keras.optimizers import Adam
from keras.preprocessing.image import ImageDataGenerator
from keras import layers
from keras import models
from keras import optimizers

from tensorflow.keras.applications.resnet50 import ResNet50

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
import os

# %%
#changing the working directory
# %cd /content/gdrive/My Drive/Thesis
# Out:
# /content/gdrive/My Drive/Thesis

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import keras
from keras.models import Sequential, Model
from keras.layers import Dense, Conv2D , MaxPool2D , Flatten , Dropout , MaxPooling2D
from keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report,confusion_matrix
from keras.applications import VGG19
import cv2
import os
import random
import tensorflow as tf
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
labels = ['dandelion', 'daisy','tulip','sunflower','rose']
img_size = 150
def get_data(data_dir):
    data = [] 
    for label in labels: 
        path = os.path.join(data_dir, label)
        class_num = labels.index(label)
        for img in os.listdir(path):
            try:
                img_arr = cv2.imread(os.path.join(path, img), cv2.IMREAD_COLOR)
                resized_arr = cv2.resize(img_arr, (img_size, img_size)) # Reshaping images to preferred size
                data.append([resized_arr, class_num])
            except Exception as e:
                print(e)
    return np.array(data)

# %%
data = get_data("/content/gdrive/My Drive/Thesis/flowers")
# Out:
# OpenCV(4.1.2) /io/opencv/modules/imgproc/src/resize.cpp:3720: error: (-215:Assertion failed) !ssize.empty() in function 'resize'
#
# OpenCV(4.1.2) /io/opencv/modules/imgproc/src/resize.cpp:3720: error: (-215:Assertion failed) !ssize.empty() in function 'resize'
#
# OpenCV(4.1.2) /io/opencv/modules/imgproc/src/resize.cpp:3720: error: (-215:Assertion failed) !ssize.empty() in function 'resize'

# %%
l = []
for i in data:
    l.append(labels[i[1]])
sns.set_style('dark')
sns.countplot(l)

# %%
fig,ax=plt.subplots(5,2)
fig.set_size_inches(15,15)
for i in range(5):
    for j in range (2):
        l=random.randint(0,len(data))
        ax[i,j].imshow(data[l][0])
        ax[i,j].set_title('Flower: '+labels[data[l][1]])
        
plt.tight_layout()

# %%
x = []
y = []

for feature, label in data:
    x.append(feature)
    y.append(label)

# %%
# Normalize the data
x = np.array(x) / 255

# %%
# Reshaping the data from 1-D to 3-D as required through input by CNN's 
x = x.reshape(-1, img_size, img_size, 3)
y = np.array(y)

# %%
from sklearn.preprocessing import LabelBinarizer
label_binarizer = LabelBinarizer()
y = label_binarizer.fit_transform(y)

# %%
x_train,x_test,y_train,y_test = train_test_split(x , y , test_size = 0.1 , random_state = 42)

# %%
x_train,x_val,y_train,y_val = train_test_split(x_train, y_train, test_size= 0.5, random_state = 42)

# %%
#defining the augmentation
datagen = ImageDataGenerator(
    featurewise_center=False,  # set input mean to 0 over the dataset
    samplewise_center=False,  # set each sample mean to 0
    featurewise_std_normalization=False,  # divide inputs by std of the dataset
    samplewise_std_normalization=False,  # divide each input by its std
    rotation_range=30,  # randomly rotate images in the range (60, 0 to 180)
    zoom_range = 0.1, # Randomly zoom image 
    width_shift_range=0.1,  # randomly shift images horizontally (fraction of total width)
    height_shift_range=0.1,
    shear_range=0.1,
    fill_mode = "reflect"
    ) 
datagen.fit(x_train)

# %%
model = Sequential()

#Adding ResNet model
model.add(ResNet50(include_top=False, pooling='avg', weights="imagenet", input_shape=(150,150,3)))
model.add(Flatten())

model.add(Dense(1024,activation="relu"))
model.add(Dropout(0.5))
model.add(BatchNormalization())

#Output layer
model.add(Dense(5, activation='softmax'))

model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94773248/94765736 [==============================] - 1s 0us/step
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# resnet50 (Functional)        (None, 2048)              23587712
# _________________________________________________________________
# flatten (Flatten)            (None, 2048)              0
# _________________________________________________________________
# dense (Dense)                (None, 1024)              2098176
# _________________________________________________________________
# dropout (Dropout)            (None, 1024)              0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 1024)              4096
# _________________________________________________________________
# dense_1 (Dense)              (None, 5)                 5125
# =================================================================
# Total params: 25,695,109
# Trainable params: 25,639,941
# Non-trainable params: 55,168
# _________________________________________________________________

# %%
#defining early stopping
from keras.callbacks import ReduceLROnPlateau
learning_rate = ReduceLROnPlateau(monitor='val_accuracy', patience = 3, verbose=1,factor=0.5, min_lr=0.000001)

es = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss', patience=10, verbose=1, mode='min')

# %%
# !pip install h5py
	
	
mc = tf.keras.callbacks.ModelCheckpoint('best_model.h5', monitor='val_accuracy', mode='max', verbose=1, save_best_only=True)
# Out:
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (2.10.0)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from h5py) (1.15.0)
# Requirement already satisfied: numpy>=1.7 in /usr/local/lib/python3.6/dist-packages (from h5py) (1.18.5)

# %%
model.compile(optimizer = "adam" , loss = 'categorical_crossentropy' , metrics = ['accuracy'])

# %%
#Fitting the augmentation data
history = model.fit(datagen.flow(x_train, y_train, batch_size=32), epochs=100, validation_data = (x_val, y_val), callbacks = [learning_rate,es,mc])
# Out:
# Epoch 1/100
# 61/61 [==============================] - ETA: 0s - loss: 1.1947 - accuracy: 0.6106
# Epoch 00001: val_accuracy improved from -inf to 0.18462, saving model to best_model.h5
# 61/61 [==============================] - 725s 12s/step - loss: 1.1947 - accuracy: 0.6106 - val_loss: 9.0865 - val_accuracy: 0.1846
# Epoch 2/100
# 61/61 [==============================] - ETA: 0s - loss: 0.9892 - accuracy: 0.6665
# Epoch 00002: val_accuracy improved from 0.18462 to 0.24103, saving model to best_model.h5
# 61/61 [==============================] - 728s 12s/step - loss: 0.9892 - accuracy: 0.6665 - val_loss: 3.5822 - val_accuracy: 0.2410
# Epoch 3/100
# 61/61 [==============================] - ETA: 0s - loss: 0.7947 - accuracy: 0.7373
# Epoch 00003: val_accuracy did not improve from 0.24103
# 61/61 [==============================] - 723s 12s/step - loss: 0.7947 - accuracy: 0.7373 - val_loss: 1.8985 - val_accuracy: 0.2410
# Epoch 4/100
# 61/61 [==============================] - ETA: 0s - loss: 0.6987 - accuracy: 0.7624
# Epoch 00004: val_accuracy did not improve from 0.24103
# 61/61 [==============================] - 723s 12s/step - loss: 0.6987 - accuracy: 0.7624 - val_loss: 1.6632 - val_accuracy: 0.2410
# Epoch 5/100
# 61/61 [==============================] - ETA: 0s - loss: 0.6973 - accuracy: 0.7650
# Epoch 00005: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00005: val_accuracy did not improve from 0.24103
# 61/61 [==============================] - 724s 12s/step - loss: 0.6973 - accuracy: 0.7650 - val_loss: 1.6551 - val_accuracy: 0.2410
# Epoch 6/100
# 61/61 [==============================] - ETA: 0s - loss: 0.4951 - accuracy: 0.8220
# Epoch 00006: val_accuracy did not improve from 0.24103
# 61/61 [==============================] - 723s 12s/step - loss: 0.4951 - accuracy: 0.8220 - val_loss: 1.7125 - val_accuracy: 0.2410
# Epoch 7/100
# 61/61 [==============================] - ETA: 0s - loss: 0.4015 - accuracy: 0.8584
# Epoch 00007: val_accuracy did not improve from 0.24103
# 61/61 [==============================] - 724s 12s/step - loss: 0.4015 - accuracy: 0.8584 - val_loss: 2.1319 - val_accuracy: 0.2410
# Epoch 8/100
# 61/61 [==============================] - ETA: 0s - loss: 0.3890 - accuracy: 0.8681
# Epoch 00008: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 00008: val_accuracy did not improve from 0.24103
# 61/61 [==============================] - 723s 12s/step - loss: 0.3890 - accuracy: 0.8681 - val_loss: 2.2465 - val_accuracy: 0.2410
# Epoch 9/100
# 61/61 [==============================] - ETA: 0s - loss: 0.3091 - accuracy: 0.8943
# Epoch 00009: val_accuracy did not improve from 0.24103
# 61/61 [==============================] - 723s 12s/step - loss: 0.3091 - accuracy: 0.8943 - val_loss: 2.7713 - val_accuracy: 0.2410
# Epoch 10/100
# 61/61 [==============================] - ETA: 0s - loss: 0.2733 - accuracy: 0.9041
# Epoch 00010: val_accuracy improved from 0.24103 to 0.24667, saving model to best_model.h5
# 61/61 [==============================] - 729s 12s/step - loss: 0.2733 - accuracy: 0.9041 - val_loss: 2.6023 - val_accuracy: 0.2467
# Epoch 11/100
# 61/61 [==============================] - ETA: 0s - loss: 0.2589 - accuracy: 0.9066
# Epoch 00011: val_accuracy improved from 0.24667 to 0.34000, saving model to best_model.h5
# 61/61 [==============================] - 726s 12s/step - loss: 0.2589 - accuracy: 0.9066 - val_loss: 2.3971 - val_accuracy: 0.3400
# Epoch 12/100
# 61/61 [==============================] - ETA: 0s - loss: 0.1804 - accuracy: 0.9364
# Epoch 00012: val_accuracy improved from 0.34000 to 0.47385, saving model to best_model.h5
# 61/61 [==============================] - 731s 12s/step - loss: 0.1804 - accuracy: 0.9364 - val_loss: 1.4527 - val_accuracy: 0.4738
# Epoch 13/100
# 61/61 [==============================] - ETA: 0s - loss: 0.1972 - accuracy: 0.9297
# Epoch 00013: val_accuracy improved from 0.47385 to 0.61692, saving model to best_model.h5
# 61/61 [==============================] - 728s 12s/step - loss: 0.1972 - accuracy: 0.9297 - val_loss: 1.1411 - val_accuracy: 0.6169
# Epoch 14/100
# 61/61 [==============================] - ETA: 0s - loss: 0.1809 - accuracy: 0.9389
# Epoch 00014: val_accuracy improved from 0.61692 to 0.71333, saving model to best_model.h5
# 61/61 [==============================] - 730s 12s/step - loss: 0.1809 - accuracy: 0.9389 - val_loss: 0.7717 - val_accuracy: 0.7133
# Epoch 15/100
# 61/61 [==============================] - ETA: 0s - loss: 0.1290 - accuracy: 0.9543
# Epoch 00015: val_accuracy improved from 0.71333 to 0.81077, saving model to best_model.h5
# 61/61 [==============================] - 729s 12s/step - loss: 0.1290 - accuracy: 0.9543 - val_loss: 0.5528 - val_accuracy: 0.8108
# Epoch 16/100
# 61/61 [==============================] - ETA: 0s - loss: 0.1664 - accuracy: 0.9466
# Epoch 00016: val_accuracy improved from 0.81077 to 0.82564, saving model to best_model.h5
# 61/61 [==============================] - 728s 12s/step - loss: 0.1664 - accuracy: 0.9466 - val_loss: 0.6491 - val_accuracy: 0.8256
# Epoch 17/100
# 61/61 [==============================] - ETA: 0s - loss: 0.1608 - accuracy: 0.9461
# Epoch 00017: val_accuracy did not improve from 0.82564
# 61/61 [==============================] - 728s 12s/step - loss: 0.1608 - accuracy: 0.9461 - val_loss: 0.5786 - val_accuracy: 0.8113
# Epoch 18/100
# 61/61 [==============================] - ETA: 0s - loss: 0.1545 - accuracy: 0.9425
# Epoch 00018: val_accuracy improved from 0.82564 to 0.84205, saving model to best_model.h5
# 61/61 [==============================] - 736s 12s/step - loss: 0.1545 - accuracy: 0.9425 - val_loss: 0.4819 - val_accuracy: 0.8421
# Epoch 19/100
# 61/61 [==============================] - ETA: 0s - loss: 0.1349 - accuracy: 0.9518
# Epoch 00019: val_accuracy improved from 0.84205 to 0.85282, saving model to best_model.h5
# 61/61 [==============================] - 735s 12s/step - loss: 0.1349 - accuracy: 0.9518 - val_loss: 0.4188 - val_accuracy: 0.8528
# Epoch 20/100
# 61/61 [==============================] - ETA: 0s - loss: 0.1272 - accuracy: 0.9564
# Epoch 00020: val_accuracy did not improve from 0.85282
# 61/61 [==============================] - 731s 12s/step - loss: 0.1272 - accuracy: 0.9564 - val_loss: 0.5574 - val_accuracy: 0.8144
# Epoch 21/100
# 61/61 [==============================] - ETA: 0s - loss: 0.1113 - accuracy: 0.9666
# Epoch 00021: val_accuracy did not improve from 0.85282
# 61/61 [==============================] - 731s 12s/step - loss: 0.1113 - accuracy: 0.9666 - val_loss: 0.4545 - val_accuracy: 0.8492
# Epoch 22/100
# 61/61 [==============================] - ETA: 0s - loss: 0.1155 - accuracy: 0.9574
# Epoch 00022: val_accuracy improved from 0.85282 to 0.85846, saving model to best_model.h5
# 61/61 [==============================] - 737s 12s/step - loss: 0.1155 - accuracy: 0.9574 - val_loss: 0.4643 - val_accuracy: 0.8585
# Epoch 23/100
# 61/61 [==============================] - ETA: 0s - loss: 0.1448 - accuracy: 0.9461
# Epoch 00023: val_accuracy did not improve from 0.85846
# 61/61 [==============================] - 734s 12s/step - loss: 0.1448 - accuracy: 0.9461 - val_loss: 0.5856 - val_accuracy: 0.8497
# Epoch 24/100
# 61/61 [==============================] - ETA: 0s - loss: 0.1537 - accuracy: 0.9472
# Epoch 00024: val_accuracy did not improve from 0.85846
# 61/61 [==============================] - 734s 12s/step - loss: 0.1537 - accuracy: 0.9472 - val_loss: 9.9145 - val_accuracy: 0.6256
# Epoch 25/100
# 61/61 [==============================] - ETA: 0s - loss: 0.1692 - accuracy: 0.9502
# Epoch 00025: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 00025: val_accuracy did not improve from 0.85846
# 61/61 [==============================] - 736s 12s/step - loss: 0.1692 - accuracy: 0.9502 - val_loss: 0.4863 - val_accuracy: 0.8456
# Epoch 26/100
# 61/61 [==============================] - ETA: 0s - loss: 0.0943 - accuracy: 0.9702
# Epoch 00026: val_accuracy improved from 0.85846 to 0.86872, saving model to best_model.h5
# 61/61 [==============================] - 739s 12s/step - loss: 0.0943 - accuracy: 0.9702 - val_loss: 0.3983 - val_accuracy: 0.8687
# Epoch 27/100
# 61/61 [==============================] - ETA: 0s - loss: 0.0612 - accuracy: 0.9795
# Epoch 00027: val_accuracy improved from 0.86872 to 0.87436, saving model to best_model.h5
# 61/61 [==============================] - 739s 12s/step - loss: 0.0612 - accuracy: 0.9795 - val_loss: 0.3817 - val_accuracy: 0.8744
# Epoch 28/100
# 61/61 [==============================] - ETA: 0s - loss: 0.0628 - accuracy: 0.9785
# Epoch 00028: val_accuracy improved from 0.87436 to 0.87487, saving model to best_model.h5
# 61/61 [==============================] - 743s 12s/step - loss: 0.0628 - accuracy: 0.9785 - val_loss: 0.4028 - val_accuracy: 0.8749
# Epoch 29/100
# 61/61 [==============================] - ETA: 0s - loss: 0.0548 - accuracy: 0.9846
# Epoch 00029: val_accuracy did not improve from 0.87487
# 61/61 [==============================] - 740s 12s/step - loss: 0.0548 - accuracy: 0.9846 - val_loss: 0.4613 - val_accuracy: 0.8672
# Epoch 30/100
# 61/61 [==============================] - ETA: 0s - loss: 0.0555 - accuracy: 0.9826
# Epoch 00030: val_accuracy did not improve from 0.87487
# 61/61 [==============================] - 737s 12s/step - loss: 0.0555 - accuracy: 0.9826 - val_loss: 0.4709 - val_accuracy: 0.8626
# Epoch 31/100
# 61/61 [==============================] - ETA: 0s - loss: 0.0351 - accuracy: 0.9892
# Epoch 00031: val_accuracy improved from 0.87487 to 0.88513, saving model to best_model.h5
# 61/61 [==============================] - 748s 12s/step - loss: 0.0351 - accuracy: 0.9892 - val_loss: 0.4150 - val_accuracy: 0.8851
# Epoch 32/100
# 61/61 [==============================] - ETA: 0s - loss: 0.0583 - accuracy: 0.9826
# Epoch 00032: val_accuracy did not improve from 0.88513
# 61/61 [==============================] - 735s 12s/step - loss: 0.0583 - accuracy: 0.9826 - val_loss: 0.4547 - val_accuracy: 0.8723
# Epoch 33/100
# 61/61 [==============================] - ETA: 0s - loss: 0.0587 - accuracy: 0.9841
# Epoch 00033: val_accuracy did not improve from 0.88513
# 61/61 [==============================] - 735s 12s/step - loss: 0.0587 - accuracy: 0.9841 - val_loss: 0.4871 - val_accuracy: 0.8682
# Epoch 34/100
# 61/61 [==============================] - ETA: 0s - loss: 0.0488 - accuracy: 0.9856
# Epoch 00034: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
#
# Epoch 00034: val_accuracy did not improve from 0.88513
# 61/61 [==============================] - 735s 12s/step - loss: 0.0488 - accuracy: 0.9856 - val_loss: 0.5355 - val_accuracy: 0.8436
# Epoch 35/100
# 61/61 [==============================] - ETA: 0s - loss: 0.0230 - accuracy: 0.9933
# Epoch 00035: val_accuracy did not improve from 0.88513
# 61/61 [==============================] - 734s 12s/step - loss: 0.0230 - accuracy: 0.9933 - val_loss: 0.4410 - val_accuracy: 0.8749
# Epoch 36/100
# 61/61 [==============================] - ETA: 0s - loss: 0.0259 - accuracy: 0.9923
# Epoch 00036: val_accuracy did not improve from 0.88513
# 61/61 [==============================] - 735s 12s/step - loss: 0.0259 - accuracy: 0.9923 - val_loss: 0.4491 - val_accuracy: 0.8774
# Epoch 37/100
# 61/61 [==============================] - ETA: 0s - loss: 0.0419 - accuracy: 0.9918
# Epoch 00037: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
#
# Epoch 00037: val_accuracy did not improve from 0.88513
# 61/61 [==============================] - 735s 12s/step - loss: 0.0419 - accuracy: 0.9918 - val_loss: 0.4664 - val_accuracy: 0.8774
# Epoch 00037: early stopping

# %%
import seaborn as sns
sns.set_style('darkgrid')
import matplotlib.pyplot as plt
import matplotlib.image as mimg

# %%
accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(accuracy) + 1)

f, axes = plt.subplots(1,2,figsize=(14,4))

axes[0].plot(epochs, accuracy, 'g', label='Training accuracy')
axes[0].plot(epochs, val_accuracy, 'b', label='Validation accuracy')
axes[0].legend()

axes[1].plot(epochs, loss, 'g', label='Training loss')
axes[1].plot(epochs, val_loss, 'b', label='Validation loss')
axes[1].yaxis.set_label_position("right")
axes[1].legend()

plt.show()

# %%
saved_model = tf.keras.models.load_model('best_model.h5')
print("Test Accuracy: {0:.2f}%".format(saved_model.evaluate(x_test,y_test)[1]*100)) #get score acording to test datas
# Out:
# 14/14 [==============================] - 26s 2s/step - loss: 0.3422 - accuracy: 0.8802
# Test Accuracy: 88.02%

# %%
from sklearn.metrics import confusion_matrix
Y_pred = saved_model.predict(x_test)
Y_pred_classes = np.argmax(Y_pred,axis = 1)
Y_true = np.argmax(y_test,axis = 1)
confusion_mtx = confusion_matrix(Y_true,Y_pred_classes)
f,ax = plt.subplots(figsize = (8,8))
sns.heatmap(confusion_mtx,annot=True,linewidths = 0.01,cmap="Reds",
            linecolor = "gray",ax=ax
            )
plt.xlabel("predicted label")
plt.ylabel("True Label")
plt.title("confusion matrix")
plt.show()


y_test_inv = label_binarizer.inverse_transform(y_test)
print(classification_report(y_test_inv, Y_pred_classes, target_names = labels))
# Out:
#               precision    recall  f1-score   support
#
#    dandelion       0.90      0.95      0.93       111
#        daisy       0.95      0.88      0.91        84
#        tulip       0.85      0.79      0.82       104
#    sunflower       0.93      0.95      0.94        60
#         rose       0.79      0.84      0.81        75
#
#     accuracy                           0.88       434
#    macro avg       0.88      0.88      0.88       434
# weighted avg       0.88      0.88      0.88       434
