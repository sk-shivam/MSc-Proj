# %%
#36-54-10 with for 90%(40%train,60%validation) and 10%test data
import keras
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout, Flatten
from keras.layers import Conv2D
from keras.layers import MaxPooling2D,MaxPool2D
from keras.layers.normalization import BatchNormalization
from keras.optimizers import Adam
from keras.preprocessing.image import ImageDataGenerator
from keras import layers
from keras import models
from keras import optimizers

from tensorflow.keras.applications.resnet50 import ResNet50

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
import os

# %%
#changing the working directory
# %cd /content/gdrive/My Drive/Thesis
# Out:
# /content/gdrive/My Drive/Thesis

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import keras
from keras.models import Sequential, Model
from keras.layers import Dense, Conv2D , MaxPool2D , Flatten , Dropout , MaxPooling2D
from keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report,confusion_matrix
from keras.applications import VGG19
import cv2
import os
import random
import tensorflow as tf
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
labels = ['dandelion', 'daisy','tulip','sunflower','rose']
img_size = 150
def get_data(data_dir):
    data = [] 
    for label in labels: 
        path = os.path.join(data_dir, label)
        class_num = labels.index(label)
        for img in os.listdir(path):
            try:
                img_arr = cv2.imread(os.path.join(path, img), cv2.IMREAD_COLOR)
                resized_arr = cv2.resize(img_arr, (img_size, img_size)) # Reshaping images to preferred size
                data.append([resized_arr, class_num])
            except Exception as e:
                print(e)
    return np.array(data)

# %%
data = get_data("/content/gdrive/My Drive/Thesis/flowers")
# Out:
# OpenCV(4.1.2) /io/opencv/modules/imgproc/src/resize.cpp:3720: error: (-215:Assertion failed) !ssize.empty() in function 'resize'
#
# OpenCV(4.1.2) /io/opencv/modules/imgproc/src/resize.cpp:3720: error: (-215:Assertion failed) !ssize.empty() in function 'resize'
#
# OpenCV(4.1.2) /io/opencv/modules/imgproc/src/resize.cpp:3720: error: (-215:Assertion failed) !ssize.empty() in function 'resize'

# %%
l = []
for i in data:
    l.append(labels[i[1]])
sns.set_style('dark')
sns.countplot(l)

# %%
fig,ax=plt.subplots(5,2)
fig.set_size_inches(15,15)
for i in range(5):
    for j in range (2):
        l=random.randint(0,len(data))
        ax[i,j].imshow(data[l][0])
        ax[i,j].set_title('Flower: '+labels[data[l][1]])
        
plt.tight_layout()

# %%
x = []
y = []

for feature, label in data:
    x.append(feature)
    y.append(label)

# %%
# Normalize the data
x = np.array(x) / 255

# %%
# Reshaping the data from 1-D to 3-D as required through input by CNN's 
x = x.reshape(-1, img_size, img_size, 3)
y = np.array(y)

# %%
from sklearn.preprocessing import LabelBinarizer
label_binarizer = LabelBinarizer()
y = label_binarizer.fit_transform(y)

# %%
x_train,x_test,y_train,y_test = train_test_split(x , y , test_size = 0.1 , random_state = 42)

# %%
x_train,x_val,y_train,y_val = train_test_split(x_train, y_train, test_size= 0.6, random_state = 42)

# %%
#defining the augmentation
datagen = ImageDataGenerator(
    featurewise_center=False,  # set input mean to 0 over the dataset
    samplewise_center=False,  # set each sample mean to 0
    featurewise_std_normalization=False,  # divide inputs by std of the dataset
    samplewise_std_normalization=False,  # divide each input by its std
    rotation_range=30,  # randomly rotate images in the range (60, 0 to 180)
    zoom_range = 0.1, # Randomly zoom image 
    width_shift_range=0.1,  # randomly shift images horizontally (fraction of total width)
    height_shift_range=0.1,
    shear_range=0.1,
    fill_mode = "reflect"
    ) 
datagen.fit(x_train)

# %%
model = Sequential()

#Adding ResNet model
model.add(ResNet50(include_top=False, pooling='avg', weights="imagenet", input_shape=(150,150,3)))
model.add(Flatten())

model.add(Dense(1024,activation="relu"))
model.add(Dropout(0.5))
model.add(BatchNormalization())

#Output layer
model.add(Dense(5, activation='softmax'))

model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94773248/94765736 [==============================] - 1s 0us/step
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# resnet50 (Functional)        (None, 2048)              23587712
# _________________________________________________________________
# flatten (Flatten)            (None, 2048)              0
# _________________________________________________________________
# dense (Dense)                (None, 1024)              2098176
# _________________________________________________________________
# dropout (Dropout)            (None, 1024)              0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 1024)              4096
# _________________________________________________________________
# dense_1 (Dense)              (None, 5)                 5125
# =================================================================
# Total params: 25,695,109
# Trainable params: 25,639,941
# Non-trainable params: 55,168
# _________________________________________________________________

# %%
#defining early stopping
from keras.callbacks import ReduceLROnPlateau
learning_rate = ReduceLROnPlateau(monitor='val_accuracy', patience = 3, verbose=1,factor=0.5, min_lr=0.000001)

es = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss', patience=10, verbose=1, mode='min')

# %%
# !pip install h5py
	
	
mc = tf.keras.callbacks.ModelCheckpoint('best_model.h5', monitor='val_accuracy', mode='max', verbose=1, save_best_only=True)
# Out:
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (2.10.0)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from h5py) (1.15.0)
# Requirement already satisfied: numpy>=1.7 in /usr/local/lib/python3.6/dist-packages (from h5py) (1.18.5)

# %%
model.compile(optimizer = "adam" , loss = 'categorical_crossentropy' , metrics = ['accuracy'])

# %%
#Fitting the augmentation data
history = model.fit(datagen.flow(x_train, y_train, batch_size=32), epochs=100, validation_data = (x_val, y_val), callbacks = [learning_rate,es,mc])
# Out:
# Epoch 1/100
# 49/49 [==============================] - ETA: 0s - loss: 1.1135 - accuracy: 0.6240
# Epoch 00001: val_accuracy improved from -inf to 0.17652, saving model to best_model.h5
# 49/49 [==============================] - 702s 14s/step - loss: 1.1135 - accuracy: 0.6240 - val_loss: 74.7431 - val_accuracy: 0.1765
# Epoch 2/100
# 49/49 [==============================] - ETA: 0s - loss: 0.8590 - accuracy: 0.6992
# Epoch 00002: val_accuracy improved from 0.17652 to 0.23907, saving model to best_model.h5
# 49/49 [==============================] - 703s 14s/step - loss: 0.8590 - accuracy: 0.6992 - val_loss: 24.9523 - val_accuracy: 0.2391
# Epoch 3/100
# 49/49 [==============================] - ETA: 0s - loss: 0.8098 - accuracy: 0.7153
# Epoch 00003: val_accuracy did not improve from 0.23907
# 49/49 [==============================] - 708s 14s/step - loss: 0.8098 - accuracy: 0.7153 - val_loss: 2.7646 - val_accuracy: 0.2262
# Epoch 4/100
# 49/49 [==============================] - ETA: 0s - loss: 0.7149 - accuracy: 0.7468
# Epoch 00004: val_accuracy did not improve from 0.23907
# 49/49 [==============================] - 757s 15s/step - loss: 0.7149 - accuracy: 0.7468 - val_loss: 3.2819 - val_accuracy: 0.2391
# Epoch 5/100
# 49/49 [==============================] - ETA: 0s - loss: 0.5721 - accuracy: 0.7976
# Epoch 00005: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00005: val_accuracy did not improve from 0.23907
# 49/49 [==============================] - 784s 16s/step - loss: 0.5721 - accuracy: 0.7976 - val_loss: 1.7657 - val_accuracy: 0.2262
# Epoch 6/100
# 49/49 [==============================] - ETA: 0s - loss: 0.5107 - accuracy: 0.8361
# Epoch 00006: val_accuracy did not improve from 0.23907
# 49/49 [==============================] - 718s 15s/step - loss: 0.5107 - accuracy: 0.8361 - val_loss: 2.6328 - val_accuracy: 0.2391
# Epoch 7/100
# 49/49 [==============================] - ETA: 0s - loss: 0.3828 - accuracy: 0.8631
# Epoch 00007: val_accuracy did not improve from 0.23907
# 49/49 [==============================] - 678s 14s/step - loss: 0.3828 - accuracy: 0.8631 - val_loss: 5.9070 - val_accuracy: 0.2391
# Epoch 8/100
# 49/49 [==============================] - ETA: 0s - loss: 0.3637 - accuracy: 0.8728
# Epoch 00008: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 00008: val_accuracy did not improve from 0.23907
# 49/49 [==============================] - 679s 14s/step - loss: 0.3637 - accuracy: 0.8728 - val_loss: 2.4647 - val_accuracy: 0.2391
# Epoch 9/100
# 49/49 [==============================] - ETA: 0s - loss: 0.3092 - accuracy: 0.8914
# Epoch 00009: val_accuracy did not improve from 0.23907
# 49/49 [==============================] - 661s 13s/step - loss: 0.3092 - accuracy: 0.8914 - val_loss: 3.0113 - val_accuracy: 0.2391
# Epoch 10/100
# 49/49 [==============================] - ETA: 0s - loss: 0.2657 - accuracy: 0.9055
# Epoch 00010: val_accuracy did not improve from 0.23907
# 49/49 [==============================] - 687s 14s/step - loss: 0.2657 - accuracy: 0.9055 - val_loss: 2.1254 - val_accuracy: 0.2078
# Epoch 11/100
# 49/49 [==============================] - ETA: 0s - loss: 0.2286 - accuracy: 0.9261
# Epoch 00011: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 00011: val_accuracy did not improve from 0.23907
# 49/49 [==============================] - 698s 14s/step - loss: 0.2286 - accuracy: 0.9261 - val_loss: 2.0836 - val_accuracy: 0.2296
# Epoch 12/100
# 49/49 [==============================] - ETA: 0s - loss: 0.1707 - accuracy: 0.9434
# Epoch 00012: val_accuracy improved from 0.23907 to 0.28406, saving model to best_model.h5
# 49/49 [==============================] - 741s 15s/step - loss: 0.1707 - accuracy: 0.9434 - val_loss: 1.9084 - val_accuracy: 0.2841
# Epoch 13/100
# 49/49 [==============================] - ETA: 0s - loss: 0.1642 - accuracy: 0.9447
# Epoch 00013: val_accuracy improved from 0.28406 to 0.33333, saving model to best_model.h5
# 49/49 [==============================] - 769s 16s/step - loss: 0.1642 - accuracy: 0.9447 - val_loss: 1.8539 - val_accuracy: 0.3333
# Epoch 14/100
# 49/49 [==============================] - ETA: 0s - loss: 0.1580 - accuracy: 0.9460
# Epoch 00014: val_accuracy improved from 0.33333 to 0.43059, saving model to best_model.h5
# 49/49 [==============================] - 832s 17s/step - loss: 0.1580 - accuracy: 0.9460 - val_loss: 1.6850 - val_accuracy: 0.4306
# Epoch 15/100
# 49/49 [==============================] - ETA: 0s - loss: 0.1336 - accuracy: 0.9557
# Epoch 00015: val_accuracy improved from 0.43059 to 0.51971, saving model to best_model.h5
# 49/49 [==============================] - 818s 17s/step - loss: 0.1336 - accuracy: 0.9557 - val_loss: 1.2969 - val_accuracy: 0.5197
# Epoch 16/100
# 49/49 [==============================] - ETA: 0s - loss: 0.1236 - accuracy: 0.9550
# Epoch 00016: val_accuracy improved from 0.51971 to 0.64653, saving model to best_model.h5
# 49/49 [==============================] - 771s 16s/step - loss: 0.1236 - accuracy: 0.9550 - val_loss: 0.9776 - val_accuracy: 0.6465
# Epoch 17/100
# 49/49 [==============================] - ETA: 0s - loss: 0.1046 - accuracy: 0.9698
# Epoch 00017: val_accuracy improved from 0.64653 to 0.72322, saving model to best_model.h5
# 49/49 [==============================] - 699s 14s/step - loss: 0.1046 - accuracy: 0.9698 - val_loss: 0.8276 - val_accuracy: 0.7232
# Epoch 18/100
# 49/49 [==============================] - ETA: 0s - loss: 0.1434 - accuracy: 0.9608
# Epoch 00018: val_accuracy improved from 0.72322 to 0.78021, saving model to best_model.h5
# 49/49 [==============================] - 668s 14s/step - loss: 0.1434 - accuracy: 0.9608 - val_loss: 0.6566 - val_accuracy: 0.7802
# Epoch 19/100
# 49/49 [==============================] - ETA: 0s - loss: 0.1148 - accuracy: 0.9679
# Epoch 00019: val_accuracy improved from 0.78021 to 0.82562, saving model to best_model.h5
# 49/49 [==============================] - 665s 14s/step - loss: 0.1148 - accuracy: 0.9679 - val_loss: 0.5318 - val_accuracy: 0.8256
# Epoch 20/100
# 49/49 [==============================] - ETA: 0s - loss: 0.0925 - accuracy: 0.9704
# Epoch 00020: val_accuracy improved from 0.82562 to 0.83805, saving model to best_model.h5
# 49/49 [==============================] - 665s 14s/step - loss: 0.0925 - accuracy: 0.9704 - val_loss: 0.4936 - val_accuracy: 0.8380
# Epoch 21/100
# 49/49 [==============================] - ETA: 0s - loss: 0.1013 - accuracy: 0.9679
# Epoch 00021: val_accuracy improved from 0.83805 to 0.85433, saving model to best_model.h5
# 49/49 [==============================] - 668s 14s/step - loss: 0.1013 - accuracy: 0.9679 - val_loss: 0.4910 - val_accuracy: 0.8543
# Epoch 22/100
# 49/49 [==============================] - ETA: 0s - loss: 0.0858 - accuracy: 0.9672
# Epoch 00022: val_accuracy improved from 0.85433 to 0.86332, saving model to best_model.h5
# 49/49 [==============================] - 666s 14s/step - loss: 0.0858 - accuracy: 0.9672 - val_loss: 0.4341 - val_accuracy: 0.8633
# Epoch 23/100
# 49/49 [==============================] - ETA: 0s - loss: 0.0706 - accuracy: 0.9749
# Epoch 00023: val_accuracy did not improve from 0.86332
# 49/49 [==============================] - 665s 14s/step - loss: 0.0706 - accuracy: 0.9749 - val_loss: 0.4421 - val_accuracy: 0.8629
# Epoch 24/100
# 49/49 [==============================] - ETA: 0s - loss: 0.0969 - accuracy: 0.9685
# Epoch 00024: val_accuracy improved from 0.86332 to 0.87361, saving model to best_model.h5
# 49/49 [==============================] - 669s 14s/step - loss: 0.0969 - accuracy: 0.9685 - val_loss: 0.4274 - val_accuracy: 0.8736
# Epoch 25/100
# 49/49 [==============================] - ETA: 0s - loss: 0.0584 - accuracy: 0.9839
# Epoch 00025: val_accuracy did not improve from 0.87361
# 49/49 [==============================] - 665s 14s/step - loss: 0.0584 - accuracy: 0.9839 - val_loss: 0.4747 - val_accuracy: 0.8599
# Epoch 26/100
# 49/49 [==============================] - ETA: 0s - loss: 0.0552 - accuracy: 0.9801
# Epoch 00026: val_accuracy did not improve from 0.87361
# 49/49 [==============================] - 667s 14s/step - loss: 0.0552 - accuracy: 0.9801 - val_loss: 0.5415 - val_accuracy: 0.8599
# Epoch 27/100
# 49/49 [==============================] - ETA: 0s - loss: 0.0605 - accuracy: 0.9814
# Epoch 00027: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
#
# Epoch 00027: val_accuracy did not improve from 0.87361
# 49/49 [==============================] - 672s 14s/step - loss: 0.0605 - accuracy: 0.9814 - val_loss: 0.4770 - val_accuracy: 0.8612
# Epoch 28/100
# 49/49 [==============================] - ETA: 0s - loss: 0.0739 - accuracy: 0.9769
# Epoch 00028: val_accuracy did not improve from 0.87361
# 49/49 [==============================] - 684s 14s/step - loss: 0.0739 - accuracy: 0.9769 - val_loss: 0.4623 - val_accuracy: 0.8646
# Epoch 29/100
# 49/49 [==============================] - ETA: 0s - loss: 0.0411 - accuracy: 0.9884
# Epoch 00029: val_accuracy improved from 0.87361 to 0.88003, saving model to best_model.h5
# 49/49 [==============================] - 687s 14s/step - loss: 0.0411 - accuracy: 0.9884 - val_loss: 0.4523 - val_accuracy: 0.8800
# Epoch 30/100
# 49/49 [==============================] - ETA: 0s - loss: 0.0488 - accuracy: 0.9852
# Epoch 00030: val_accuracy did not improve from 0.88003
# 49/49 [==============================] - 669s 14s/step - loss: 0.0488 - accuracy: 0.9852 - val_loss: 0.4094 - val_accuracy: 0.8779
# Epoch 31/100
# 49/49 [==============================] - ETA: 0s - loss: 0.0347 - accuracy: 0.9897
# Epoch 00031: val_accuracy did not improve from 0.88003
# 49/49 [==============================] - 665s 14s/step - loss: 0.0347 - accuracy: 0.9897 - val_loss: 0.4275 - val_accuracy: 0.8736
# Epoch 32/100
# 49/49 [==============================] - ETA: 0s - loss: 0.0408 - accuracy: 0.9878
# Epoch 00032: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
#
# Epoch 00032: val_accuracy did not improve from 0.88003
# 49/49 [==============================] - 678s 14s/step - loss: 0.0408 - accuracy: 0.9878 - val_loss: 0.4055 - val_accuracy: 0.8796
# Epoch 33/100
# 49/49 [==============================] - ETA: 0s - loss: 0.0436 - accuracy: 0.9891
# Epoch 00033: val_accuracy did not improve from 0.88003
# 49/49 [==============================] - 676s 14s/step - loss: 0.0436 - accuracy: 0.9891 - val_loss: 0.4229 - val_accuracy: 0.8762
# Epoch 34/100
# 49/49 [==============================] - ETA: 0s - loss: 0.0298 - accuracy: 0.9884
# Epoch 00034: val_accuracy improved from 0.88003 to 0.88389, saving model to best_model.h5
# 49/49 [==============================] - 676s 14s/step - loss: 0.0298 - accuracy: 0.9884 - val_loss: 0.4126 - val_accuracy: 0.8839
# Epoch 35/100
# 49/49 [==============================] - ETA: 0s - loss: 0.0208 - accuracy: 0.9949
# Epoch 00035: val_accuracy did not improve from 0.88389
# 49/49 [==============================] - 670s 14s/step - loss: 0.0208 - accuracy: 0.9949 - val_loss: 0.4150 - val_accuracy: 0.8830
# Epoch 36/100
# 49/49 [==============================] - ETA: 0s - loss: 0.0168 - accuracy: 0.9949
# Epoch 00036: val_accuracy did not improve from 0.88389
# 49/49 [==============================] - 687s 14s/step - loss: 0.0168 - accuracy: 0.9949 - val_loss: 0.4384 - val_accuracy: 0.8792
# Epoch 37/100
# 49/49 [==============================] - ETA: 0s - loss: 0.0281 - accuracy: 0.9929
# Epoch 00037: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
#
# Epoch 00037: val_accuracy did not improve from 0.88389
# 49/49 [==============================] - 682s 14s/step - loss: 0.0281 - accuracy: 0.9929 - val_loss: 0.4359 - val_accuracy: 0.8813
# Epoch 38/100
# 49/49 [==============================] - ETA: 0s - loss: 0.0222 - accuracy: 0.9929
# Epoch 00038: val_accuracy did not improve from 0.88389
# 49/49 [==============================] - 679s 14s/step - loss: 0.0222 - accuracy: 0.9929 - val_loss: 0.4251 - val_accuracy: 0.8835
# Epoch 39/100
# 49/49 [==============================] - ETA: 0s - loss: 0.0246 - accuracy: 0.9949
# Epoch 00039: val_accuracy did not improve from 0.88389
# 49/49 [==============================] - 682s 14s/step - loss: 0.0246 - accuracy: 0.9949 - val_loss: 0.4322 - val_accuracy: 0.8826
# Epoch 40/100
# 49/49 [==============================] - ETA: 0s - loss: 0.0188 - accuracy: 0.9961
# Epoch 00040: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
#
# Epoch 00040: val_accuracy did not improve from 0.88389
# 49/49 [==============================] - 681s 14s/step - loss: 0.0188 - accuracy: 0.9961 - val_loss: 0.4315 - val_accuracy: 0.8830
# Epoch 41/100
# 49/49 [==============================] - ETA: 0s - loss: 0.0180 - accuracy: 0.9955
# Epoch 00041: val_accuracy did not improve from 0.88389
# 49/49 [==============================] - 681s 14s/step - loss: 0.0180 - accuracy: 0.9955 - val_loss: 0.4341 - val_accuracy: 0.8839
# Epoch 42/100
# 49/49 [==============================] - ETA: 0s - loss: 0.0151 - accuracy: 0.9968
# Epoch 00042: val_accuracy did not improve from 0.88389
# 49/49 [==============================] - 679s 14s/step - loss: 0.0151 - accuracy: 0.9968 - val_loss: 0.4321 - val_accuracy: 0.8839
# Epoch 00042: early stopping

# %%
import seaborn as sns
sns.set_style('darkgrid')
import matplotlib.pyplot as plt
import matplotlib.image as mimg

# %%
accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(accuracy) + 1)

f, axes = plt.subplots(1,2,figsize=(14,4))

axes[0].plot(epochs, accuracy, 'g', label='Training accuracy')
axes[0].plot(epochs, val_accuracy, 'b', label='Validation accuracy')
axes[0].legend()

axes[1].plot(epochs, loss, 'g', label='Training loss')
axes[1].plot(epochs, val_loss, 'b', label='Validation loss')
axes[1].yaxis.set_label_position("right")
axes[1].legend()

plt.show()

# %%
saved_model = tf.keras.models.load_model('best_model.h5')
print("Test Accuracy: {0:.2f}%".format(saved_model.evaluate(x_test,y_test)[1]*100)) #get score acording to test datas
# Out:
# 14/14 [==============================] - 28s 2s/step - loss: 0.4577 - accuracy: 0.8730
# Test Accuracy: 87.30%

# %%
from sklearn.metrics import confusion_matrix
Y_pred = saved_model.predict(x_test)
Y_pred_classes = np.argmax(Y_pred,axis = 1)
Y_true = np.argmax(y_test,axis = 1)
confusion_mtx = confusion_matrix(Y_true,Y_pred_classes)
f,ax = plt.subplots(figsize = (8,8))
sns.heatmap(confusion_mtx,annot=True,linewidths = 0.01,cmap="Reds",
            linecolor = "gray",fmt = ".2f",ax=ax
            )
plt.xlabel("predicted label")
plt.ylabel("True Label")
plt.title("confusion matrix")
plt.show()



y_test_inv = label_binarizer.inverse_transform(y_test)
print(classification_report(y_test_inv, Y_pred_classes, target_names = labels))
# Out:
#               precision    recall  f1-score   support
#
#    dandelion       0.93      0.91      0.92       123
#        daisy       0.95      0.89      0.92        89
#        tulip       0.76      0.89      0.82        84
#    sunflower       0.92      0.87      0.89        67
#         rose       0.79      0.77      0.78        70
#
#     accuracy                           0.87       433
#    macro avg       0.87      0.87      0.87       433
# weighted avg       0.88      0.87      0.87       433
