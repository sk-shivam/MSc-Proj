# %%
#Normal data 90-10 with for 90%(20%training, 80%validation) and 10%test data
import keras
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout, Flatten
from keras.layers import Conv2D
from keras.layers import MaxPooling2D,MaxPool2D
from keras.layers.normalization import BatchNormalization
from keras.optimizers import Adam
from keras.preprocessing.image import ImageDataGenerator
from keras import layers
from keras import models
from keras import optimizers

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
import os

# %%
#changing the working directory
# %cd /content/gdrive/My Drive/Thesis
# Out:
# /content/gdrive/My Drive/Thesis

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import keras
from keras.models import Sequential, Model
from keras.layers import Dense, Conv2D , MaxPool2D , Flatten , Dropout , MaxPooling2D
from keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report,confusion_matrix
from keras.applications import VGG19
import cv2
import os
import random
import tensorflow as tf
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
labels = ['dandelion', 'daisy','tulip','sunflower','rose']
img_size = 150
def get_data(data_dir):
    data = [] 
    for label in labels: 
        path = os.path.join(data_dir, label)
        class_num = labels.index(label)
        for img in os.listdir(path):
            try:
                img_arr = cv2.imread(os.path.join(path, img), cv2.IMREAD_COLOR)
                resized_arr = cv2.resize(img_arr, (img_size, img_size)) # Reshaping images to preferred size
                data.append([resized_arr, class_num])
            except Exception as e:
                print(e)
    return np.array(data)

# %%
data = get_data("/content/gdrive/My Drive/Thesis/flowers")
# Out:
# OpenCV(4.1.2) /io/opencv/modules/imgproc/src/resize.cpp:3720: error: (-215:Assertion failed) !ssize.empty() in function 'resize'
#
# OpenCV(4.1.2) /io/opencv/modules/imgproc/src/resize.cpp:3720: error: (-215:Assertion failed) !ssize.empty() in function 'resize'
#
# OpenCV(4.1.2) /io/opencv/modules/imgproc/src/resize.cpp:3720: error: (-215:Assertion failed) !ssize.empty() in function 'resize'

# %%
l = []
for i in data:
    l.append(labels[i[1]])
sns.set_style('dark')
sns.countplot(l)

# %%
fig,ax=plt.subplots(5,2)
fig.set_size_inches(15,15)
for i in range(5):
    for j in range (2):
        l=random.randint(0,len(data))
        ax[i,j].imshow(data[l][0])
        ax[i,j].set_title('Flower: '+labels[data[l][1]])
        
plt.tight_layout()

# %%
x = []
y = []

for feature, label in data:
    x.append(feature)
    y.append(label)

# %%
# Normalize the data
x = np.array(x) / 255

# %%
# Reshaping the data from 1-D to 3-D as required through input by CNN's 
x = x.reshape(-1, img_size, img_size, 3)
y = np.array(y)

# %%
from sklearn.preprocessing import LabelBinarizer
label_binarizer = LabelBinarizer()
y = label_binarizer.fit_transform(y)

# %%
x_train,x_test,y_train,y_test = train_test_split(x , y , test_size = 0.1 , random_state = 42)

# %%
x_train,x_val,y_train,y_val = train_test_split(x_train, y_train, test_size= 0.8, random_state = 42)

# %%
model = Sequential()
# 1st Convolutional Layer
model.add(Conv2D(filters=64, kernel_size=(3,3),padding="Same",activation="relu" , input_shape = (150,150,3)))
model.add(MaxPool2D(pool_size=(2,2),strides=(2,2)))
model.add(BatchNormalization())
model.add(Dropout(0.2))
# 2nd Convolutional Layer
model.add(Conv2D(filters=128, kernel_size=(3,3),padding="Same",activation="relu"))
model.add(MaxPool2D(pool_size=(2,2),strides=(2,2)))
model.add(BatchNormalization())
model.add(Dropout(0.3))
# 3rd Convolutional Layer
model.add(Conv2D(filters=128, kernel_size=(3,3),padding="Same",activation="relu"))
model.add(MaxPool2D(pool_size=(2,2),strides=(2,2)))
model.add(BatchNormalization())
model.add(Dropout(0.2))
# 4th Convolutional Layer
model.add(Conv2D(filters=256, kernel_size=(3,3),padding="Same",activation="relu"))
model.add(MaxPool2D(pool_size=(2,2),strides=(2,2)))
model.add(BatchNormalization())
model.add(Dropout(0.3))
# 5th Convolutional Layer
model.add(Conv2D(filters=256,kernel_size = (3,3),padding="Same",activation="relu"))
model.add(MaxPool2D(pool_size=(2,2),strides=(2,2)))
model.add(BatchNormalization())
model.add(Dropout(0.2))
# 6th Convolutional Layer
model.add(Conv2D(filters=512,kernel_size = (3,3),padding="Same",activation="relu"))
model.add(MaxPool2D(pool_size=(2,2),strides=(2,2)))
model.add(BatchNormalization())
model.add(Dropout(0.2))

model.add(Flatten())
# 1st Fully Connected Layer
model.add(Dense(1024,activation="relu"))
model.add(Dropout(0.5))
model.add(BatchNormalization())
# Output layer
model.add(Dense(5,activation="softmax"))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 150, 150, 64)      1792
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 75, 75, 64)        0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 75, 75, 64)        256
# _________________________________________________________________
# dropout (Dropout)            (None, 75, 75, 64)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 75, 75, 128)       73856
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 37, 37, 128)       0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 37, 37, 128)       512
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 37, 37, 128)       0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 37, 37, 128)       147584
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 18, 18, 128)       0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 18, 18, 128)       512
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 18, 18, 128)       0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 18, 18, 256)       295168
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 9, 9, 256)         0
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 9, 9, 256)         1024
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 9, 9, 256)         0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 9, 9, 256)         590080
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 4, 4, 256)         0
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 4, 4, 256)         1024
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 4, 4, 256)         0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 4, 4, 512)         1180160
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 2, 2, 512)         0
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 2, 2, 512)         2048
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 2, 2, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 2048)              0
# _________________________________________________________________
# dense (Dense)                (None, 1024)              2098176
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 1024)              4096
# _________________________________________________________________
# dense_1 (Dense)              (None, 5)                 5125
# =================================================================
# Total params: 4,401,413
# Trainable params: 4,396,677
# Non-trainable params: 4,736
# _________________________________________________________________

# %%
#defining early stopping
from keras.callbacks import ReduceLROnPlateau
learning_rate = ReduceLROnPlateau(monitor='val_accuracy', patience = 3, verbose=1,factor=0.5, min_lr=0.000001)

es = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss', patience=10, verbose=1, mode='min')

# %%
# !pip install h5py
	
	
mc = tf.keras.callbacks.ModelCheckpoint('best_model.h5', monitor='val_accuracy', mode='max', verbose=1, save_best_only=True)
# Out:
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (2.10.0)
# Requirement already satisfied: numpy>=1.7 in /usr/local/lib/python3.6/dist-packages (from h5py) (1.18.5)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from h5py) (1.15.0)

# %%
model.compile(optimizer = "adam" , loss = 'categorical_crossentropy' , metrics = ['accuracy'])

# %%
#Fitting the augmentation data
history = model.fit(x_train, y_train, batch_size=32, epochs=100, validation_data = (x_val, y_val), callbacks = [learning_rate,es,mc])
# Out:
# Epoch 1/100
# 25/25 [==============================] - ETA: 0s - loss: 0.6495 - accuracy: 0.7416
# Epoch 00001: val_accuracy did not improve from 0.23747
# 25/25 [==============================] - 179s 7s/step - loss: 0.6495 - accuracy: 0.7416 - val_loss: 4.3141 - val_accuracy: 0.2375
# Epoch 2/100
# 25/25 [==============================] - ETA: 0s - loss: 0.6288 - accuracy: 0.7635
# Epoch 00002: val_accuracy did not improve from 0.23747
# 25/25 [==============================] - 178s 7s/step - loss: 0.6288 - accuracy: 0.7635 - val_loss: 3.7708 - val_accuracy: 0.2375
# Epoch 3/100
# 25/25 [==============================] - ETA: 0s - loss: 0.5877 - accuracy: 0.7751
# Epoch 00003: val_accuracy did not improve from 0.23747
# 25/25 [==============================] - 178s 7s/step - loss: 0.5877 - accuracy: 0.7751 - val_loss: 4.9926 - val_accuracy: 0.2375
# Epoch 4/100
# 25/25 [==============================] - ETA: 0s - loss: 0.4991 - accuracy: 0.8175
# Epoch 00004: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
#
# Epoch 00004: val_accuracy did not improve from 0.23747
# 25/25 [==============================] - 178s 7s/step - loss: 0.4991 - accuracy: 0.8175 - val_loss: 4.1887 - val_accuracy: 0.2375
# Epoch 5/100
# 25/25 [==============================] - ETA: 0s - loss: 0.5204 - accuracy: 0.8123
# Epoch 00005: val_accuracy did not improve from 0.23747
# 25/25 [==============================] - 178s 7s/step - loss: 0.5204 - accuracy: 0.8123 - val_loss: 4.5579 - val_accuracy: 0.2375
# Epoch 6/100
# 25/25 [==============================] - ETA: 0s - loss: 0.4444 - accuracy: 0.8342
# Epoch 00006: val_accuracy did not improve from 0.23747
# 25/25 [==============================] - 178s 7s/step - loss: 0.4444 - accuracy: 0.8342 - val_loss: 4.3368 - val_accuracy: 0.2375
# Epoch 7/100
# 25/25 [==============================] - ETA: 0s - loss: 0.5054 - accuracy: 0.8188
# Epoch 00007: val_accuracy improved from 0.23747 to 0.23779, saving model to best_model.h5
# 25/25 [==============================] - 178s 7s/step - loss: 0.5054 - accuracy: 0.8188 - val_loss: 4.0407 - val_accuracy: 0.2378
# Epoch 8/100
# 25/25 [==============================] - ETA: 0s - loss: 0.4403 - accuracy: 0.8458
# Epoch 00008: val_accuracy improved from 0.23779 to 0.24036, saving model to best_model.h5
# 25/25 [==============================] - 178s 7s/step - loss: 0.4403 - accuracy: 0.8458 - val_loss: 4.2891 - val_accuracy: 0.2404
# Epoch 9/100
# 25/25 [==============================] - ETA: 0s - loss: 0.4528 - accuracy: 0.8213
# Epoch 00009: val_accuracy improved from 0.24036 to 0.25321, saving model to best_model.h5
# 25/25 [==============================] - 178s 7s/step - loss: 0.4528 - accuracy: 0.8213 - val_loss: 3.7391 - val_accuracy: 0.2532
# Epoch 10/100
# 25/25 [==============================] - ETA: 0s - loss: 0.4126 - accuracy: 0.8406
# Epoch 00010: val_accuracy improved from 0.25321 to 0.27121, saving model to best_model.h5
# 25/25 [==============================] - 180s 7s/step - loss: 0.4126 - accuracy: 0.8406 - val_loss: 3.6982 - val_accuracy: 0.2712
# Epoch 11/100
# 25/25 [==============================] - ETA: 0s - loss: 0.4067 - accuracy: 0.8419
# Epoch 00011: val_accuracy improved from 0.27121 to 0.29788, saving model to best_model.h5
# 25/25 [==============================] - 178s 7s/step - loss: 0.4067 - accuracy: 0.8419 - val_loss: 3.4014 - val_accuracy: 0.2979
# Epoch 12/100
# 25/25 [==============================] - ETA: 0s - loss: 0.3914 - accuracy: 0.8650
# Epoch 00012: val_accuracy improved from 0.29788 to 0.30398, saving model to best_model.h5
# 25/25 [==============================] - 178s 7s/step - loss: 0.3914 - accuracy: 0.8650 - val_loss: 3.3604 - val_accuracy: 0.3040
# Epoch 13/100
# 25/25 [==============================] - ETA: 0s - loss: 0.3881 - accuracy: 0.8612
# Epoch 00013: val_accuracy improved from 0.30398 to 0.33997, saving model to best_model.h5
# 25/25 [==============================] - 178s 7s/step - loss: 0.3881 - accuracy: 0.8612 - val_loss: 2.7082 - val_accuracy: 0.3400
# Epoch 14/100
# 25/25 [==============================] - ETA: 0s - loss: 0.3201 - accuracy: 0.8817
# Epoch 00014: val_accuracy did not improve from 0.33997
# 25/25 [==============================] - 177s 7s/step - loss: 0.3201 - accuracy: 0.8817 - val_loss: 3.5029 - val_accuracy: 0.3255
# Epoch 15/100
# 25/25 [==============================] - ETA: 0s - loss: 0.4104 - accuracy: 0.8393
# Epoch 00015: val_accuracy improved from 0.33997 to 0.37179, saving model to best_model.h5
# 25/25 [==============================] - 179s 7s/step - loss: 0.4104 - accuracy: 0.8393 - val_loss: 2.6053 - val_accuracy: 0.3718
# Epoch 16/100
# 25/25 [==============================] - ETA: 0s - loss: 0.3603 - accuracy: 0.8689
# Epoch 00016: val_accuracy did not improve from 0.37179
# 25/25 [==============================] - 177s 7s/step - loss: 0.3603 - accuracy: 0.8689 - val_loss: 2.6425 - val_accuracy: 0.3663
# Epoch 17/100
# 25/25 [==============================] - ETA: 0s - loss: 0.3542 - accuracy: 0.8612
# Epoch 00017: val_accuracy improved from 0.37179 to 0.37886, saving model to best_model.h5
# 25/25 [==============================] - 178s 7s/step - loss: 0.3542 - accuracy: 0.8612 - val_loss: 2.8305 - val_accuracy: 0.3789
# Epoch 18/100
# 25/25 [==============================] - ETA: 0s - loss: 0.3463 - accuracy: 0.8650
# Epoch 00018: val_accuracy improved from 0.37886 to 0.41967, saving model to best_model.h5
# 25/25 [==============================] - 178s 7s/step - loss: 0.3463 - accuracy: 0.8650 - val_loss: 2.4396 - val_accuracy: 0.4197
# Epoch 19/100
# 25/25 [==============================] - ETA: 0s - loss: 0.3136 - accuracy: 0.8856
# Epoch 00019: val_accuracy did not improve from 0.41967
# 25/25 [==============================] - 177s 7s/step - loss: 0.3136 - accuracy: 0.8856 - val_loss: 3.0061 - val_accuracy: 0.3766
# Epoch 20/100
# 25/25 [==============================] - ETA: 0s - loss: 0.3389 - accuracy: 0.8766
# Epoch 00020: val_accuracy improved from 0.41967 to 0.42577, saving model to best_model.h5
# 25/25 [==============================] - 178s 7s/step - loss: 0.3389 - accuracy: 0.8766 - val_loss: 2.5869 - val_accuracy: 0.4258
# Epoch 21/100
# 25/25 [==============================] - ETA: 0s - loss: 0.3327 - accuracy: 0.8663
# Epoch 00021: val_accuracy did not improve from 0.42577
# 25/25 [==============================] - 177s 7s/step - loss: 0.3327 - accuracy: 0.8663 - val_loss: 2.7796 - val_accuracy: 0.4123
# Epoch 22/100
# 25/25 [==============================] - ETA: 0s - loss: 0.2687 - accuracy: 0.9010
# Epoch 00022: val_accuracy did not improve from 0.42577
# 25/25 [==============================] - 177s 7s/step - loss: 0.2687 - accuracy: 0.9010 - val_loss: 2.7194 - val_accuracy: 0.4158
# Epoch 23/100
# 25/25 [==============================] - ETA: 0s - loss: 0.3299 - accuracy: 0.8792
# Epoch 00023: val_accuracy improved from 0.42577 to 0.45180, saving model to best_model.h5
# 25/25 [==============================] - 177s 7s/step - loss: 0.3299 - accuracy: 0.8792 - val_loss: 2.2050 - val_accuracy: 0.4518
# Epoch 24/100
# 25/25 [==============================] - ETA: 0s - loss: 0.2749 - accuracy: 0.8972
# Epoch 00024: val_accuracy did not improve from 0.45180
# 25/25 [==============================] - 177s 7s/step - loss: 0.2749 - accuracy: 0.8972 - val_loss: 2.4144 - val_accuracy: 0.4515
# Epoch 25/100
# 25/25 [==============================] - ETA: 0s - loss: 0.2642 - accuracy: 0.9126
# Epoch 00025: val_accuracy improved from 0.45180 to 0.45566, saving model to best_model.h5
# 25/25 [==============================] - 177s 7s/step - loss: 0.2642 - accuracy: 0.9126 - val_loss: 2.2252 - val_accuracy: 0.4557
# Epoch 26/100
# 25/25 [==============================] - ETA: 0s - loss: 0.2400 - accuracy: 0.9036
# Epoch 00026: val_accuracy improved from 0.45566 to 0.46658, saving model to best_model.h5
# 25/25 [==============================] - 178s 7s/step - loss: 0.2400 - accuracy: 0.9036 - val_loss: 2.1608 - val_accuracy: 0.4666
# Epoch 27/100
# 25/25 [==============================] - ETA: 0s - loss: 0.2394 - accuracy: 0.9203
# Epoch 00027: val_accuracy did not improve from 0.46658
# 25/25 [==============================] - 177s 7s/step - loss: 0.2394 - accuracy: 0.9203 - val_loss: 2.3264 - val_accuracy: 0.4576
# Epoch 28/100
# 25/25 [==============================] - ETA: 0s - loss: 0.2338 - accuracy: 0.9203
# Epoch 00028: val_accuracy did not improve from 0.46658
# 25/25 [==============================] - 177s 7s/step - loss: 0.2338 - accuracy: 0.9203 - val_loss: 2.4107 - val_accuracy: 0.4563
# Epoch 29/100
# 25/25 [==============================] - ETA: 0s - loss: 0.2142 - accuracy: 0.9139
# Epoch 00029: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
#
# Epoch 00029: val_accuracy did not improve from 0.46658
# 25/25 [==============================] - 177s 7s/step - loss: 0.2142 - accuracy: 0.9139 - val_loss: 2.6584 - val_accuracy: 0.4428
# Epoch 30/100
# 25/25 [==============================] - ETA: 0s - loss: 0.2101 - accuracy: 0.9216
# Epoch 00030: val_accuracy did not improve from 0.46658
# 25/25 [==============================] - 176s 7s/step - loss: 0.2101 - accuracy: 0.9216 - val_loss: 2.5298 - val_accuracy: 0.4618
# Epoch 31/100
# 25/25 [==============================] - ETA: 0s - loss: 0.1859 - accuracy: 0.9357
# Epoch 00031: val_accuracy did not improve from 0.46658
# 25/25 [==============================] - 176s 7s/step - loss: 0.1859 - accuracy: 0.9357 - val_loss: 2.6030 - val_accuracy: 0.4518
# Epoch 32/100
# 25/25 [==============================] - ETA: 0s - loss: 0.2175 - accuracy: 0.9254
# Epoch 00032: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
#
# Epoch 00032: val_accuracy did not improve from 0.46658
# 25/25 [==============================] - 177s 7s/step - loss: 0.2175 - accuracy: 0.9254 - val_loss: 2.5489 - val_accuracy: 0.4614
# Epoch 33/100
# 25/25 [==============================] - ETA: 0s - loss: 0.1739 - accuracy: 0.9383
# Epoch 00033: val_accuracy did not improve from 0.46658
# 25/25 [==============================] - 177s 7s/step - loss: 0.1739 - accuracy: 0.9383 - val_loss: 2.7395 - val_accuracy: 0.4412
# Epoch 34/100
# 25/25 [==============================] - ETA: 0s - loss: 0.1687 - accuracy: 0.9357
# Epoch 00034: val_accuracy did not improve from 0.46658
# 25/25 [==============================] - 177s 7s/step - loss: 0.1687 - accuracy: 0.9357 - val_loss: 2.6890 - val_accuracy: 0.4486
# Epoch 35/100
# 25/25 [==============================] - ETA: 0s - loss: 0.1591 - accuracy: 0.9563
# Epoch 00035: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
#
# Epoch 00035: val_accuracy did not improve from 0.46658
# 25/25 [==============================] - 177s 7s/step - loss: 0.1591 - accuracy: 0.9563 - val_loss: 2.7791 - val_accuracy: 0.4457
# Epoch 36/100
# 25/25 [==============================] - ETA: 0s - loss: 0.1718 - accuracy: 0.9434
# Epoch 00036: val_accuracy did not improve from 0.46658
# 25/25 [==============================] - 177s 7s/step - loss: 0.1718 - accuracy: 0.9434 - val_loss: 2.7822 - val_accuracy: 0.4444
# Epoch 00036: early stopping

# %%
import seaborn as sns
sns.set_style('darkgrid')
import matplotlib.pyplot as plt
import matplotlib.image as mimg

# %%
accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(accuracy) + 1)

f, axes = plt.subplots(1,2,figsize=(14,4))

axes[0].plot(epochs, accuracy, 'g', label='Training accuracy')
axes[0].plot(epochs, val_accuracy, 'b', label='Validation accuracy')
axes[0].legend()

axes[1].plot(epochs, loss, 'g', label='Training loss')
axes[1].plot(epochs, val_loss, 'b', label='Validation loss')
axes[1].yaxis.set_label_position("right")
axes[1].legend()

plt.show()

# %%
saved_model = tf.keras.models.load_model('best_model.h5')
print("Test Accuracy: {0:.2f}%".format(saved_model.evaluate(x_test,y_test)[1]*100)) #get score acording to test datas
# Out:
# 14/14 [==============================] - 12s 854ms/step - loss: 2.3022 - accuracy: 0.4688
# Test Accuracy: 46.88%

# %%
from sklearn.metrics import confusion_matrix
Y_pred = saved_model.predict(x_test)
Y_pred_classes = np.argmax(Y_pred,axis = 1)
Y_true = np.argmax(y_test,axis = 1)
confusion_mtx = confusion_matrix(Y_true,Y_pred_classes)
f,ax = plt.subplots(figsize = (8,8))
sns.heatmap(confusion_mtx,annot=True,linewidths = 0.01,cmap="Reds",
            linecolor = "gray",fmt = ".2f",ax=ax
            )
plt.xlabel("predicted label")
plt.ylabel("True Label")
plt.title("confusion matrix")
plt.show()

from sklearn.metrics import classification_report

print(classification_report(Y_true, Y_pred_classes))

y_test_inv = label_binarizer.inverse_transform(y_test)
print(classification_report(y_test_inv, Y_pred_classes, target_names = labels))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.39      0.93      0.55       123
#            1       0.87      0.15      0.25        89
#            2       0.51      0.42      0.46        84
#            3       0.90      0.39      0.54        67
#            4       0.48      0.21      0.30        70
#
#     accuracy                           0.47       433
#    macro avg       0.63      0.42      0.42       433
# weighted avg       0.61      0.47      0.43       433
#
#               precision    recall  f1-score   support
#
#    dandelion       0.39      0.93      0.55       123
#        daisy       0.87      0.15      0.25        89
#        tulip       0.51      0.42      0.46        84
#    sunflower       0.90      0.39      0.54        67
#         rose       0.48      0.21      0.30        70
#
#     accuracy                           0.47       433
#    macro avg       0.63      0.42      0.42       433
# weighted avg       0.61      0.47      0.43       433
