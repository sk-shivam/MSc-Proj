# %%
#Normal data 54-36-10 with for 90%(60%training, 40%validation) and 10%test data
import keras
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout, Flatten
from keras.layers import Conv2D
from keras.layers import MaxPooling2D,MaxPool2D
from keras.layers.normalization import BatchNormalization
from keras.optimizers import Adam
from keras.preprocessing.image import ImageDataGenerator
from keras import layers
from keras import models
from keras import optimizers

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
import os

# %%
#changing the working directory
# %cd /content/gdrive/My Drive/Thesis
# Out:
# /content/gdrive/My Drive/Thesis

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import keras
from keras.models import Sequential, Model
from keras.layers import Dense, Conv2D , MaxPool2D , Flatten , Dropout , MaxPooling2D
from keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report,confusion_matrix
from keras.applications import VGG19
import cv2
import os
import random
import tensorflow as tf
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
labels = ['dandelion', 'daisy','tulip','sunflower','rose']
img_size = 150
def get_data(data_dir):
    data = [] 
    for label in labels: 
        path = os.path.join(data_dir, label)
        class_num = labels.index(label)
        for img in os.listdir(path):
            try:
                img_arr = cv2.imread(os.path.join(path, img), cv2.IMREAD_COLOR)
                resized_arr = cv2.resize(img_arr, (img_size, img_size)) # Reshaping images to preferred size
                data.append([resized_arr, class_num])
            except Exception as e:
                print(e)
    return np.array(data)

# %%
data = get_data("/content/gdrive/My Drive/Thesis/flowers")
# Out:
# OpenCV(4.1.2) /io/opencv/modules/imgproc/src/resize.cpp:3720: error: (-215:Assertion failed) !ssize.empty() in function 'resize'
#
# OpenCV(4.1.2) /io/opencv/modules/imgproc/src/resize.cpp:3720: error: (-215:Assertion failed) !ssize.empty() in function 'resize'
#
# OpenCV(4.1.2) /io/opencv/modules/imgproc/src/resize.cpp:3720: error: (-215:Assertion failed) !ssize.empty() in function 'resize'

# %%
l = []
for i in data:
    l.append(labels[i[1]])
sns.set_style('dark')
sns.countplot(l)

# %%
fig,ax=plt.subplots(5,2)
fig.set_size_inches(15,15)
for i in range(5):
    for j in range (2):
        l=random.randint(0,len(data))
        ax[i,j].imshow(data[l][0])
        ax[i,j].set_title('Flower: '+labels[data[l][1]])
        
plt.tight_layout()

# %%
x = []
y = []

for feature, label in data:
    x.append(feature)
    y.append(label)

# %%
# Normalize the data
x = np.array(x) / 255

# %%
# Reshaping the data from 1-D to 3-D as required through input by CNN's 
x = x.reshape(-1, img_size, img_size, 3)
y = np.array(y)

# %%
from sklearn.preprocessing import LabelBinarizer
label_binarizer = LabelBinarizer()
y = label_binarizer.fit_transform(y)

# %%
x_train,x_test,y_train,y_test = train_test_split(x , y , test_size = 0.1 , random_state = 42)

# %%
x_train,x_val,y_train,y_val = train_test_split(x_train, y_train, test_size= 0.4, random_state = 42)

# %%
model = Sequential()
# 1st Convolutional Layer
model.add(Conv2D(filters=64, kernel_size=(3,3),padding="Same",activation="relu" , input_shape = (150,150,3)))
model.add(MaxPool2D(pool_size=(2,2),strides=(2,2)))
model.add(BatchNormalization())
model.add(Dropout(0.2))
# 2nd Convolutional Layer
model.add(Conv2D(filters=128, kernel_size=(3,3),padding="Same",activation="relu"))
model.add(MaxPool2D(pool_size=(2,2),strides=(2,2)))
model.add(BatchNormalization())
model.add(Dropout(0.3))
# 3rd Convolutional Layer
model.add(Conv2D(filters=128, kernel_size=(3,3),padding="Same",activation="relu"))
model.add(MaxPool2D(pool_size=(2,2),strides=(2,2)))
model.add(BatchNormalization())
model.add(Dropout(0.2))
# 4th Convolutional Layer
model.add(Conv2D(filters=256, kernel_size=(3,3),padding="Same",activation="relu"))
model.add(MaxPool2D(pool_size=(2,2),strides=(2,2)))
model.add(BatchNormalization())
model.add(Dropout(0.3))
# 5th Convolutional Layer
model.add(Conv2D(filters=256,kernel_size = (3,3),padding="Same",activation="relu"))
model.add(MaxPool2D(pool_size=(2,2),strides=(2,2)))
model.add(BatchNormalization())
model.add(Dropout(0.2))
# 6th Convolutional Layer
model.add(Conv2D(filters=512,kernel_size = (3,3),padding="Same",activation="relu"))
model.add(MaxPool2D(pool_size=(2,2),strides=(2,2)))
model.add(BatchNormalization())
model.add(Dropout(0.2))

model.add(Flatten())
# 1st Fully Connected Layer
model.add(Dense(1024,activation="relu"))
model.add(Dropout(0.5))
model.add(BatchNormalization())
# Output layer
model.add(Dense(5,activation="softmax"))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 150, 150, 64)      1792
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 75, 75, 64)        0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 75, 75, 64)        256
# _________________________________________________________________
# dropout (Dropout)            (None, 75, 75, 64)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 75, 75, 128)       73856
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 37, 37, 128)       0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 37, 37, 128)       512
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 37, 37, 128)       0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 37, 37, 128)       147584
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 18, 18, 128)       0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 18, 18, 128)       512
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 18, 18, 128)       0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 18, 18, 256)       295168
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 9, 9, 256)         0
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 9, 9, 256)         1024
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 9, 9, 256)         0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 9, 9, 256)         590080
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 4, 4, 256)         0
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 4, 4, 256)         1024
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 4, 4, 256)         0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 4, 4, 512)         1180160
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 2, 2, 512)         0
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 2, 2, 512)         2048
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 2, 2, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 2048)              0
# _________________________________________________________________
# dense (Dense)                (None, 1024)              2098176
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 1024)              4096
# _________________________________________________________________
# dense_1 (Dense)              (None, 5)                 5125
# =================================================================
# Total params: 4,401,413
# Trainable params: 4,396,677
# Non-trainable params: 4,736
# _________________________________________________________________

# %%
#defining early stopping
from keras.callbacks import ReduceLROnPlateau
learning_rate = ReduceLROnPlateau(monitor='val_accuracy', patience = 3, verbose=1,factor=0.5, min_lr=0.000001)

es = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss', patience=10, verbose=1, mode='min')

# %%
# !pip install h5py
	
	
mc = tf.keras.callbacks.ModelCheckpoint('best_model.h5', monitor='val_accuracy', mode='max', verbose=1, save_best_only=True)
# Out:
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (2.10.0)
# Requirement already satisfied: numpy>=1.7 in /usr/local/lib/python3.6/dist-packages (from h5py) (1.18.5)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from h5py) (1.15.0)

# %%
model.compile(optimizer = "adam" , loss = 'categorical_crossentropy' , metrics = ['accuracy'])

# %%
#Fitting the augmentation data
history = model.fit(x_train, y_train, batch_size=32, epochs=100, validation_data = (x_val, y_val), callbacks = [learning_rate,es,mc])
# Out:
# Epoch 1/100
# 74/74 [==============================] - ETA: 0s - loss: 1.6813 - accuracy: 0.4280
# Epoch 00001: val_accuracy improved from -inf to 0.23590, saving model to best_model.h5
# 74/74 [==============================] - 313s 4s/step - loss: 1.6813 - accuracy: 0.4280 - val_loss: 5.1450 - val_accuracy: 0.2359
# Epoch 2/100
# 74/74 [==============================] - ETA: 0s - loss: 1.4495 - accuracy: 0.4703
# Epoch 00002: val_accuracy did not improve from 0.23590
# 74/74 [==============================] - 313s 4s/step - loss: 1.4495 - accuracy: 0.4703 - val_loss: 4.0159 - val_accuracy: 0.2359
# Epoch 3/100
# 74/74 [==============================] - ETA: 0s - loss: 1.1968 - accuracy: 0.5460
# Epoch 00003: val_accuracy did not improve from 0.23590
# 74/74 [==============================] - 310s 4s/step - loss: 1.1968 - accuracy: 0.5460 - val_loss: 4.8982 - val_accuracy: 0.2359
# Epoch 4/100
# 74/74 [==============================] - ETA: 0s - loss: 1.1468 - accuracy: 0.5703
# Epoch 00004: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00004: val_accuracy did not improve from 0.23590
# 74/74 [==============================] - 314s 4s/step - loss: 1.1468 - accuracy: 0.5703 - val_loss: 3.2542 - val_accuracy: 0.2359
# Epoch 5/100
# 74/74 [==============================] - ETA: 0s - loss: 0.9620 - accuracy: 0.6353
# Epoch 00005: val_accuracy improved from 0.23590 to 0.35192, saving model to best_model.h5
# 74/74 [==============================] - 313s 4s/step - loss: 0.9620 - accuracy: 0.6353 - val_loss: 1.5982 - val_accuracy: 0.3519
# Epoch 6/100
# 74/74 [==============================] - ETA: 0s - loss: 0.9279 - accuracy: 0.6460
# Epoch 00006: val_accuracy improved from 0.35192 to 0.40897, saving model to best_model.h5
# 74/74 [==============================] - 313s 4s/step - loss: 0.9279 - accuracy: 0.6460 - val_loss: 1.5735 - val_accuracy: 0.4090
# Epoch 7/100
# 74/74 [==============================] - ETA: 0s - loss: 0.8691 - accuracy: 0.6721
# Epoch 00007: val_accuracy did not improve from 0.40897
# 74/74 [==============================] - 314s 4s/step - loss: 0.8691 - accuracy: 0.6721 - val_loss: 1.9821 - val_accuracy: 0.3833
# Epoch 8/100
# 74/74 [==============================] - ETA: 0s - loss: 0.8110 - accuracy: 0.6819
# Epoch 00008: val_accuracy improved from 0.40897 to 0.58013, saving model to best_model.h5
# 74/74 [==============================] - 317s 4s/step - loss: 0.8110 - accuracy: 0.6819 - val_loss: 1.1278 - val_accuracy: 0.5801
# Epoch 9/100
# 74/74 [==============================] - ETA: 0s - loss: 0.7688 - accuracy: 0.7067
# Epoch 00009: val_accuracy did not improve from 0.58013
# 74/74 [==============================] - 314s 4s/step - loss: 0.7688 - accuracy: 0.7067 - val_loss: 1.2482 - val_accuracy: 0.5538
# Epoch 10/100
# 74/74 [==============================] - ETA: 0s - loss: 0.7829 - accuracy: 0.7076
# Epoch 00010: val_accuracy improved from 0.58013 to 0.64359, saving model to best_model.h5
# 74/74 [==============================] - 318s 4s/step - loss: 0.7829 - accuracy: 0.7076 - val_loss: 0.9349 - val_accuracy: 0.6436
# Epoch 11/100
# 74/74 [==============================] - ETA: 0s - loss: 0.7979 - accuracy: 0.6930
# Epoch 00011: val_accuracy improved from 0.64359 to 0.65577, saving model to best_model.h5
# 74/74 [==============================] - 322s 4s/step - loss: 0.7979 - accuracy: 0.6930 - val_loss: 0.9382 - val_accuracy: 0.6558
# Epoch 12/100
# 74/74 [==============================] - ETA: 0s - loss: 0.7704 - accuracy: 0.7114
# Epoch 00012: val_accuracy did not improve from 0.65577
# 74/74 [==============================] - 323s 4s/step - loss: 0.7704 - accuracy: 0.7114 - val_loss: 0.9250 - val_accuracy: 0.6487
# Epoch 13/100
# 74/74 [==============================] - ETA: 0s - loss: 0.6619 - accuracy: 0.7533
# Epoch 00013: val_accuracy did not improve from 0.65577
# 74/74 [==============================] - 321s 4s/step - loss: 0.6619 - accuracy: 0.7533 - val_loss: 1.1515 - val_accuracy: 0.6308
# Epoch 14/100
# 74/74 [==============================] - ETA: 0s - loss: 0.7094 - accuracy: 0.7268
# Epoch 00014: val_accuracy improved from 0.65577 to 0.69423, saving model to best_model.h5
# 74/74 [==============================] - 321s 4s/step - loss: 0.7094 - accuracy: 0.7268 - val_loss: 0.8569 - val_accuracy: 0.6942
# Epoch 15/100
# 74/74 [==============================] - ETA: 0s - loss: 0.5561 - accuracy: 0.7965
# Epoch 00015: val_accuracy improved from 0.69423 to 0.70769, saving model to best_model.h5
# 74/74 [==============================] - 325s 4s/step - loss: 0.5561 - accuracy: 0.7965 - val_loss: 0.7991 - val_accuracy: 0.7077
# Epoch 16/100
# 74/74 [==============================] - ETA: 0s - loss: 0.6334 - accuracy: 0.7614
# Epoch 00016: val_accuracy improved from 0.70769 to 0.73718, saving model to best_model.h5
# 74/74 [==============================] - 331s 4s/step - loss: 0.6334 - accuracy: 0.7614 - val_loss: 0.7920 - val_accuracy: 0.7372
# Epoch 17/100
# 74/74 [==============================] - ETA: 0s - loss: 0.5758 - accuracy: 0.7828
# Epoch 00017: val_accuracy did not improve from 0.73718
# 74/74 [==============================] - 333s 5s/step - loss: 0.5758 - accuracy: 0.7828 - val_loss: 0.7633 - val_accuracy: 0.7288
# Epoch 18/100
# 74/74 [==============================] - ETA: 0s - loss: 0.4953 - accuracy: 0.8166
# Epoch 00018: val_accuracy did not improve from 0.73718
# 74/74 [==============================] - 334s 5s/step - loss: 0.4953 - accuracy: 0.8166 - val_loss: 0.9496 - val_accuracy: 0.6853
# Epoch 19/100
# 74/74 [==============================] - ETA: 0s - loss: 0.4771 - accuracy: 0.8303
# Epoch 00019: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 00019: val_accuracy did not improve from 0.73718
# 74/74 [==============================] - 335s 5s/step - loss: 0.4771 - accuracy: 0.8303 - val_loss: 0.9216 - val_accuracy: 0.6904
# Epoch 20/100
# 74/74 [==============================] - ETA: 0s - loss: 0.4055 - accuracy: 0.8551
# Epoch 00020: val_accuracy did not improve from 0.73718
# 74/74 [==============================] - 333s 5s/step - loss: 0.4055 - accuracy: 0.8551 - val_loss: 0.7932 - val_accuracy: 0.7141
# Epoch 21/100
# 74/74 [==============================] - ETA: 0s - loss: 0.3725 - accuracy: 0.8666
# Epoch 00021: val_accuracy did not improve from 0.73718
# 74/74 [==============================] - 344s 5s/step - loss: 0.3725 - accuracy: 0.8666 - val_loss: 0.7573 - val_accuracy: 0.7346
# Epoch 22/100
# 74/74 [==============================] - ETA: 0s - loss: 0.3054 - accuracy: 0.8906
# Epoch 00022: val_accuracy improved from 0.73718 to 0.74487, saving model to best_model.h5
# 74/74 [==============================] - 335s 5s/step - loss: 0.3054 - accuracy: 0.8906 - val_loss: 0.7333 - val_accuracy: 0.7449
# Epoch 23/100
# 74/74 [==============================] - ETA: 0s - loss: 0.3094 - accuracy: 0.8846
# Epoch 00023: val_accuracy improved from 0.74487 to 0.75513, saving model to best_model.h5
# 74/74 [==============================] - 333s 5s/step - loss: 0.3094 - accuracy: 0.8846 - val_loss: 0.7356 - val_accuracy: 0.7551
# Epoch 24/100
# 74/74 [==============================] - ETA: 0s - loss: 0.2684 - accuracy: 0.9098
# Epoch 00024: val_accuracy did not improve from 0.75513
# 74/74 [==============================] - 347s 5s/step - loss: 0.2684 - accuracy: 0.9098 - val_loss: 0.8073 - val_accuracy: 0.7327
# Epoch 25/100
# 74/74 [==============================] - ETA: 0s - loss: 0.2388 - accuracy: 0.9098
# Epoch 00025: val_accuracy did not improve from 0.75513
# 74/74 [==============================] - 361s 5s/step - loss: 0.2388 - accuracy: 0.9098 - val_loss: 0.8107 - val_accuracy: 0.7308
# Epoch 26/100
# 74/74 [==============================] - ETA: 0s - loss: 0.2735 - accuracy: 0.9017
# Epoch 00026: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 00026: val_accuracy did not improve from 0.75513
# 74/74 [==============================] - 357s 5s/step - loss: 0.2735 - accuracy: 0.9017 - val_loss: 0.7983 - val_accuracy: 0.7462
# Epoch 27/100
# 74/74 [==============================] - ETA: 0s - loss: 0.1974 - accuracy: 0.9320
# Epoch 00027: val_accuracy did not improve from 0.75513
# 74/74 [==============================] - 339s 5s/step - loss: 0.1974 - accuracy: 0.9320 - val_loss: 0.7490 - val_accuracy: 0.7551
# Epoch 28/100
# 74/74 [==============================] - ETA: 0s - loss: 0.1806 - accuracy: 0.9397
# Epoch 00028: val_accuracy improved from 0.75513 to 0.76538, saving model to best_model.h5
# 74/74 [==============================] - 349s 5s/step - loss: 0.1806 - accuracy: 0.9397 - val_loss: 0.7375 - val_accuracy: 0.7654
# Epoch 29/100
# 74/74 [==============================] - ETA: 0s - loss: 0.1605 - accuracy: 0.9555
# Epoch 00029: val_accuracy did not improve from 0.76538
# 74/74 [==============================] - 339s 5s/step - loss: 0.1605 - accuracy: 0.9555 - val_loss: 0.7757 - val_accuracy: 0.7609
# Epoch 30/100
# 74/74 [==============================] - ETA: 0s - loss: 0.1887 - accuracy: 0.9380
# Epoch 00030: val_accuracy did not improve from 0.76538
# 74/74 [==============================] - 337s 5s/step - loss: 0.1887 - accuracy: 0.9380 - val_loss: 0.7596 - val_accuracy: 0.7635
# Epoch 31/100
# 74/74 [==============================] - ETA: 0s - loss: 0.1397 - accuracy: 0.9611
# Epoch 00031: val_accuracy improved from 0.76538 to 0.77308, saving model to best_model.h5
# 74/74 [==============================] - 358s 5s/step - loss: 0.1397 - accuracy: 0.9611 - val_loss: 0.7439 - val_accuracy: 0.7731
# Epoch 32/100
# 74/74 [==============================] - ETA: 0s - loss: 0.1431 - accuracy: 0.9560
# Epoch 00032: val_accuracy did not improve from 0.77308
# 74/74 [==============================] - 364s 5s/step - loss: 0.1431 - accuracy: 0.9560 - val_loss: 0.7682 - val_accuracy: 0.7596
# Epoch 00032: early stopping

# %%
import seaborn as sns
sns.set_style('darkgrid')
import matplotlib.pyplot as plt
import matplotlib.image as mimg

# %%
accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(accuracy) + 1)

f, axes = plt.subplots(1,2,figsize=(14,4))

axes[0].plot(epochs, accuracy, 'g', label='Training accuracy')
axes[0].plot(epochs, val_accuracy, 'b', label='Validation accuracy')
axes[0].legend()

axes[1].plot(epochs, loss, 'g', label='Training loss')
axes[1].plot(epochs, val_loss, 'b', label='Validation loss')
axes[1].yaxis.set_label_position("right")
axes[1].legend()

plt.show()

# %%
saved_model = tf.keras.models.load_model('best_model.h5')
print("Test Accuracy: {0:.2f}%".format(saved_model.evaluate(x_test,y_test)[1]*100)) #get score acording to test datas
# Out:
# 14/14 [==============================] - 13s 921ms/step - loss: 0.7921 - accuracy: 0.7604
# Test Accuracy: 76.04%

# %%
from sklearn.metrics import confusion_matrix
Y_pred = saved_model.predict(x_test)
Y_pred_classes = np.argmax(Y_pred,axis = 1)
Y_true = np.argmax(y_test,axis = 1)
confusion_mtx = confusion_matrix(Y_true,Y_pred_classes)
f,ax = plt.subplots(figsize = (8,8))
sns.heatmap(confusion_mtx,annot=True,linewidths = 0.01,cmap="Reds",
            linecolor = "gray",ax=ax
            )
plt.xlabel("predicted label")
plt.ylabel("True Label")
plt.title("confusion matrix")
plt.show()


y_test_inv = label_binarizer.inverse_transform(y_test)
print(classification_report(y_test_inv, Y_pred_classes, target_names = labels))
# Out:
#               precision    recall  f1-score   support
#
#    dandelion       0.78      0.84      0.81       111
#        daisy       0.83      0.80      0.81        84
#        tulip       0.76      0.71      0.74       104
#    sunflower       0.80      0.73      0.77        60
#         rose       0.64      0.69      0.67        75
#
#     accuracy                           0.76       434
#    macro avg       0.76      0.75      0.76       434
# weighted avg       0.76      0.76      0.76       434
