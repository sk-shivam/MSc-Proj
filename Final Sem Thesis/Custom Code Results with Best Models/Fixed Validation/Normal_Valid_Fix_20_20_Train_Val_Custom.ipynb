# %%
#Train Real with for 90%(20%real, 20%validation) and 10%test data
import keras
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout, Flatten
from keras.layers import Conv2D
from keras.layers import MaxPooling2D,MaxPool2D
from keras.layers.normalization import BatchNormalization
from keras.optimizers import Adam
from keras.preprocessing.image import ImageDataGenerator
from keras import layers
from keras import models
from keras import optimizers

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
import os

# %%
#changing the working directory
# %cd /content/gdrive/My Drive/Thesis
# Out:
# /content/gdrive/My Drive/Thesis

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import keras
from keras.models import Sequential, Model
from keras.layers import Dense, Conv2D , MaxPool2D , Flatten , Dropout , MaxPooling2D
from keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report,confusion_matrix
from keras.applications import VGG19
import cv2
import os
import random
import tensorflow as tf
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
labels = ['dandelion', 'daisy','tulip','sunflower','rose']
img_size = 150
def get_data(data_dir):
    data = [] 
    for label in labels: 
        path = os.path.join(data_dir, label)
        class_num = labels.index(label)
        for img in os.listdir(path):
            try:
                img_arr = cv2.imread(os.path.join(path, img), cv2.IMREAD_COLOR)
                resized_arr = cv2.resize(img_arr, (img_size, img_size)) # Reshaping images to preferred size
                data.append([resized_arr, class_num])
            except Exception as e:
                print(e)
    return np.array(data)

# %%
data = get_data("/content/gdrive/My Drive/Thesis/flowers")
# Out:
# OpenCV(4.1.2) /io/opencv/modules/imgproc/src/resize.cpp:3720: error: (-215:Assertion failed) !ssize.empty() in function 'resize'
#
# OpenCV(4.1.2) /io/opencv/modules/imgproc/src/resize.cpp:3720: error: (-215:Assertion failed) !ssize.empty() in function 'resize'
#
# OpenCV(4.1.2) /io/opencv/modules/imgproc/src/resize.cpp:3720: error: (-215:Assertion failed) !ssize.empty() in function 'resize'

# %%
l = []
for i in data:
    l.append(labels[i[1]])
sns.set_style('dark')
sns.countplot(l)

# %%
fig,ax=plt.subplots(5,2)
fig.set_size_inches(15,15)
for i in range(5):
    for j in range (2):
        l=random.randint(0,len(data))
        ax[i,j].imshow(data[l][0])
        ax[i,j].set_title('Flower: '+labels[data[l][1]])
        
plt.tight_layout()

# %%
x = []
y = []

for feature, label in data:
    x.append(feature)
    y.append(label)

# %%
# Normalize the data
x = np.array(x) / 255

# %%
# Reshaping the data from 1-D to 3-D as required through input by CNN's 
x = x.reshape(-1, img_size, img_size, 3)
y = np.array(y)

# %%
from sklearn.preprocessing import LabelBinarizer
label_binarizer = LabelBinarizer()
y = label_binarizer.fit_transform(y)

# %%
x_train,x_test,y_train,y_test = train_test_split(x , y , test_size = 0.1 , random_state = 42)

# %%
x_train,x_val,y_train,y_val = train_test_split(x_train, y_train, test_size= 0.2, random_state = 42)

# %%
x_train,x_left,y_train,y_left = train_test_split(x_train, y_train, test_size= 0.75, random_state = 42)

# %%
model = Sequential()
# 1st Convolutional Layer
model.add(Conv2D(filters=64, kernel_size=(3,3),padding="Same",activation="relu" , input_shape = (150,150,3)))
model.add(MaxPool2D(pool_size=(2,2),strides=(2,2)))
model.add(BatchNormalization())
model.add(Dropout(0.2))
# 2nd Convolutional Layer
model.add(Conv2D(filters=128, kernel_size=(3,3),padding="Same",activation="relu"))
model.add(MaxPool2D(pool_size=(2,2),strides=(2,2)))
model.add(BatchNormalization())
model.add(Dropout(0.3))
# 3rd Convolutional Layer
model.add(Conv2D(filters=128, kernel_size=(3,3),padding="Same",activation="relu"))
model.add(MaxPool2D(pool_size=(2,2),strides=(2,2)))
model.add(BatchNormalization())
model.add(Dropout(0.2))
# 4th Convolutional Layer
model.add(Conv2D(filters=256, kernel_size=(3,3),padding="Same",activation="relu"))
model.add(MaxPool2D(pool_size=(2,2),strides=(2,2)))
model.add(BatchNormalization())
model.add(Dropout(0.3))
# 5th Convolutional Layer
model.add(Conv2D(filters=256,kernel_size = (3,3),padding="Same",activation="relu"))
model.add(MaxPool2D(pool_size=(2,2),strides=(2,2)))
model.add(BatchNormalization())
model.add(Dropout(0.2))
# 6th Convolutional Layer
model.add(Conv2D(filters=512,kernel_size = (3,3),padding="Same",activation="relu"))
model.add(MaxPool2D(pool_size=(2,2),strides=(2,2)))
model.add(BatchNormalization())
model.add(Dropout(0.2))

model.add(Flatten())
# 1st Fully Connected Layer
model.add(Dense(1024,activation="relu"))
model.add(Dropout(0.5))
model.add(BatchNormalization())
# Output layer
model.add(Dense(5,activation="softmax"))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 150, 150, 64)      1792
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 75, 75, 64)        0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 75, 75, 64)        256
# _________________________________________________________________
# dropout (Dropout)            (None, 75, 75, 64)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 75, 75, 128)       73856
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 37, 37, 128)       0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 37, 37, 128)       512
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 37, 37, 128)       0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 37, 37, 128)       147584
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 18, 18, 128)       0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 18, 18, 128)       512
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 18, 18, 128)       0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 18, 18, 256)       295168
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 9, 9, 256)         0
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 9, 9, 256)         1024
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 9, 9, 256)         0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 9, 9, 256)         590080
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 4, 4, 256)         0
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 4, 4, 256)         1024
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 4, 4, 256)         0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 4, 4, 512)         1180160
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 2, 2, 512)         0
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 2, 2, 512)         2048
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 2, 2, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 2048)              0
# _________________________________________________________________
# dense (Dense)                (None, 1024)              2098176
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 1024)              4096
# _________________________________________________________________
# dense_1 (Dense)              (None, 5)                 5125
# =================================================================
# Total params: 4,401,413
# Trainable params: 4,396,677
# Non-trainable params: 4,736
# _________________________________________________________________

# %%
#defining early stopping
from keras.callbacks import ReduceLROnPlateau
learning_rate = ReduceLROnPlateau(monitor='val_accuracy', patience = 3, verbose=1,factor=0.5, min_lr=0.000001)

es = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss', patience=10, verbose=1, mode='min')

# %%
# !pip install h5py
	
	
mc = tf.keras.callbacks.ModelCheckpoint('best_model.h5', monitor='val_accuracy', mode='max', verbose=1, save_best_only=True)
# Out:
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (2.10.0)
# Requirement already satisfied: numpy>=1.7 in /usr/local/lib/python3.6/dist-packages (from h5py) (1.18.5)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from h5py) (1.15.0)

# %%
model.compile(optimizer = "adam" , loss = 'categorical_crossentropy' , metrics = ['accuracy'])

# %%
#Fitting the augmentation data
history = model.fit(x_train, y_train, batch_size=32, epochs=100, validation_data = (x_val, y_val), callbacks = [learning_rate,es,mc])
# Out:
# Epoch 1/100
# 25/25 [==============================] - ETA: 0s - loss: 0.5964 - accuracy: 0.7763
# Epoch 00001: val_accuracy improved from 0.23265 to 0.23393, saving model to best_model.h5
# 25/25 [==============================] - 108s 4s/step - loss: 0.5964 - accuracy: 0.7763 - val_loss: 2.7791 - val_accuracy: 0.2339
# Epoch 2/100
# 25/25 [==============================] - ETA: 0s - loss: 0.5547 - accuracy: 0.7943
# Epoch 00002: val_accuracy did not improve from 0.23393
# 25/25 [==============================] - 109s 4s/step - loss: 0.5547 - accuracy: 0.7943 - val_loss: 3.2269 - val_accuracy: 0.2326
# Epoch 3/100
# 25/25 [==============================] - ETA: 0s - loss: 0.5241 - accuracy: 0.8021
# Epoch 00003: val_accuracy did not improve from 0.23393
# 25/25 [==============================] - 108s 4s/step - loss: 0.5241 - accuracy: 0.8021 - val_loss: 3.3367 - val_accuracy: 0.2339
# Epoch 4/100
# 25/25 [==============================] - ETA: 0s - loss: 0.4791 - accuracy: 0.8072
# Epoch 00004: val_accuracy improved from 0.23393 to 0.23907, saving model to best_model.h5
# 25/25 [==============================] - 111s 4s/step - loss: 0.4791 - accuracy: 0.8072 - val_loss: 2.6952 - val_accuracy: 0.2391
# Epoch 5/100
# 25/25 [==============================] - ETA: 0s - loss: 0.4604 - accuracy: 0.8355
# Epoch 00005: val_accuracy did not improve from 0.23907
# 25/25 [==============================] - 109s 4s/step - loss: 0.4604 - accuracy: 0.8355 - val_loss: 3.8847 - val_accuracy: 0.2339
# Epoch 6/100
# 25/25 [==============================] - ETA: 0s - loss: 0.4791 - accuracy: 0.8368
# Epoch 00006: val_accuracy improved from 0.23907 to 0.25450, saving model to best_model.h5
# 25/25 [==============================] - 109s 4s/step - loss: 0.4791 - accuracy: 0.8368 - val_loss: 2.8025 - val_accuracy: 0.2545
# Epoch 7/100
# 25/25 [==============================] - ETA: 0s - loss: 0.4383 - accuracy: 0.8162
# Epoch 00007: val_accuracy improved from 0.25450 to 0.27249, saving model to best_model.h5
# 25/25 [==============================] - 109s 4s/step - loss: 0.4383 - accuracy: 0.8162 - val_loss: 2.9443 - val_accuracy: 0.2725
# Epoch 8/100
# 25/25 [==============================] - ETA: 0s - loss: 0.4377 - accuracy: 0.8329
# Epoch 00008: val_accuracy did not improve from 0.27249
# 25/25 [==============================] - 108s 4s/step - loss: 0.4377 - accuracy: 0.8329 - val_loss: 3.6576 - val_accuracy: 0.2532
# Epoch 9/100
# 25/25 [==============================] - ETA: 0s - loss: 0.4847 - accuracy: 0.8342
# Epoch 00009: val_accuracy improved from 0.27249 to 0.35861, saving model to best_model.h5
# 25/25 [==============================] - 108s 4s/step - loss: 0.4847 - accuracy: 0.8342 - val_loss: 2.4228 - val_accuracy: 0.3586
# Epoch 10/100
# 25/25 [==============================] - ETA: 0s - loss: 0.4697 - accuracy: 0.8111
# Epoch 00010: val_accuracy did not improve from 0.35861
# 25/25 [==============================] - 108s 4s/step - loss: 0.4697 - accuracy: 0.8111 - val_loss: 3.0722 - val_accuracy: 0.3098
# Epoch 11/100
# 25/25 [==============================] - ETA: 0s - loss: 0.3972 - accuracy: 0.8419
# Epoch 00011: val_accuracy did not improve from 0.35861
# 25/25 [==============================] - 108s 4s/step - loss: 0.3972 - accuracy: 0.8419 - val_loss: 2.9879 - val_accuracy: 0.3213
# Epoch 12/100
# 25/25 [==============================] - ETA: 0s - loss: 0.3429 - accuracy: 0.8625
# Epoch 00012: val_accuracy improved from 0.35861 to 0.40103, saving model to best_model.h5
# 25/25 [==============================] - 108s 4s/step - loss: 0.3429 - accuracy: 0.8625 - val_loss: 2.1289 - val_accuracy: 0.4010
# Epoch 13/100
# 25/25 [==============================] - ETA: 0s - loss: 0.3421 - accuracy: 0.8753
# Epoch 00013: val_accuracy did not improve from 0.40103
# 25/25 [==============================] - 108s 4s/step - loss: 0.3421 - accuracy: 0.8753 - val_loss: 2.5874 - val_accuracy: 0.3689
# Epoch 14/100
# 25/25 [==============================] - ETA: 0s - loss: 0.2993 - accuracy: 0.8856
# Epoch 00014: val_accuracy improved from 0.40103 to 0.43702, saving model to best_model.h5
# 25/25 [==============================] - 109s 4s/step - loss: 0.2993 - accuracy: 0.8856 - val_loss: 1.9086 - val_accuracy: 0.4370
# Epoch 15/100
# 25/25 [==============================] - ETA: 0s - loss: 0.2820 - accuracy: 0.8920
# Epoch 00015: val_accuracy did not improve from 0.43702
# 25/25 [==============================] - 108s 4s/step - loss: 0.2820 - accuracy: 0.8920 - val_loss: 2.6989 - val_accuracy: 0.3728
# Epoch 16/100
# 25/25 [==============================] - ETA: 0s - loss: 0.2663 - accuracy: 0.9049
# Epoch 00016: val_accuracy improved from 0.43702 to 0.44473, saving model to best_model.h5
# 25/25 [==============================] - 109s 4s/step - loss: 0.2663 - accuracy: 0.9049 - val_loss: 2.6203 - val_accuracy: 0.4447
# Epoch 17/100
# 25/25 [==============================] - ETA: 0s - loss: 0.2934 - accuracy: 0.8895
# Epoch 00017: val_accuracy improved from 0.44473 to 0.46530, saving model to best_model.h5
# 25/25 [==============================] - 108s 4s/step - loss: 0.2934 - accuracy: 0.8895 - val_loss: 2.1091 - val_accuracy: 0.4653
# Epoch 18/100
# 25/25 [==============================] - ETA: 0s - loss: 0.2902 - accuracy: 0.8959
# Epoch 00018: val_accuracy improved from 0.46530 to 0.47172, saving model to best_model.h5
# 25/25 [==============================] - 109s 4s/step - loss: 0.2902 - accuracy: 0.8959 - val_loss: 2.2401 - val_accuracy: 0.4717
# Epoch 19/100
# 25/25 [==============================] - ETA: 0s - loss: 0.3249 - accuracy: 0.8805
# Epoch 00019: val_accuracy improved from 0.47172 to 0.49486, saving model to best_model.h5
# 25/25 [==============================] - 109s 4s/step - loss: 0.3249 - accuracy: 0.8805 - val_loss: 1.9552 - val_accuracy: 0.4949
# Epoch 20/100
# 25/25 [==============================] - ETA: 0s - loss: 0.2400 - accuracy: 0.9126
# Epoch 00020: val_accuracy improved from 0.49486 to 0.51157, saving model to best_model.h5
# 25/25 [==============================] - 109s 4s/step - loss: 0.2400 - accuracy: 0.9126 - val_loss: 1.8670 - val_accuracy: 0.5116
# Epoch 21/100
# 25/25 [==============================] - ETA: 0s - loss: 0.2114 - accuracy: 0.9293
# Epoch 00021: val_accuracy improved from 0.51157 to 0.51928, saving model to best_model.h5
# 25/25 [==============================] - 109s 4s/step - loss: 0.2114 - accuracy: 0.9293 - val_loss: 1.9170 - val_accuracy: 0.5193
# Epoch 22/100
# 25/25 [==============================] - ETA: 0s - loss: 0.2562 - accuracy: 0.8997
# Epoch 00022: val_accuracy did not improve from 0.51928
# 25/25 [==============================] - 108s 4s/step - loss: 0.2562 - accuracy: 0.8997 - val_loss: 1.9383 - val_accuracy: 0.5193
# Epoch 23/100
# 25/25 [==============================] - ETA: 0s - loss: 0.2339 - accuracy: 0.9113
# Epoch 00023: val_accuracy improved from 0.51928 to 0.54499, saving model to best_model.h5
# 25/25 [==============================] - 109s 4s/step - loss: 0.2339 - accuracy: 0.9113 - val_loss: 1.5631 - val_accuracy: 0.5450
# Epoch 24/100
# 25/25 [==============================] - ETA: 0s - loss: 0.2158 - accuracy: 0.9229
# Epoch 00024: val_accuracy improved from 0.54499 to 0.56041, saving model to best_model.h5
# 25/25 [==============================] - 109s 4s/step - loss: 0.2158 - accuracy: 0.9229 - val_loss: 1.6285 - val_accuracy: 0.5604
# Epoch 25/100
# 25/25 [==============================] - ETA: 0s - loss: 0.2348 - accuracy: 0.9203
# Epoch 00025: val_accuracy did not improve from 0.56041
# 25/25 [==============================] - 108s 4s/step - loss: 0.2348 - accuracy: 0.9203 - val_loss: 2.1018 - val_accuracy: 0.5180
# Epoch 26/100
# 25/25 [==============================] - ETA: 0s - loss: 0.2315 - accuracy: 0.9254
# Epoch 00026: val_accuracy did not improve from 0.56041
# 25/25 [==============================] - 108s 4s/step - loss: 0.2315 - accuracy: 0.9254 - val_loss: 2.5794 - val_accuracy: 0.4781
# Epoch 27/100
# 25/25 [==============================] - ETA: 0s - loss: 0.1999 - accuracy: 0.9332
# Epoch 00027: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
#
# Epoch 00027: val_accuracy did not improve from 0.56041
# 25/25 [==============================] - 109s 4s/step - loss: 0.1999 - accuracy: 0.9332 - val_loss: 1.7423 - val_accuracy: 0.5527
# Epoch 28/100
# 25/25 [==============================] - ETA: 0s - loss: 0.1191 - accuracy: 0.9666
# Epoch 00028: val_accuracy did not improve from 0.56041
# 25/25 [==============================] - 108s 4s/step - loss: 0.1191 - accuracy: 0.9666 - val_loss: 1.7806 - val_accuracy: 0.5591
# Epoch 29/100
# 25/25 [==============================] - ETA: 0s - loss: 0.1626 - accuracy: 0.9409
# Epoch 00029: val_accuracy did not improve from 0.56041
# 25/25 [==============================] - 108s 4s/step - loss: 0.1626 - accuracy: 0.9409 - val_loss: 1.8259 - val_accuracy: 0.5437
# Epoch 30/100
# 25/25 [==============================] - ETA: 0s - loss: 0.1356 - accuracy: 0.9589
# Epoch 00030: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
#
# Epoch 00030: val_accuracy did not improve from 0.56041
# 25/25 [==============================] - 108s 4s/step - loss: 0.1356 - accuracy: 0.9589 - val_loss: 1.8745 - val_accuracy: 0.5450
# Epoch 31/100
# 25/25 [==============================] - ETA: 0s - loss: 0.1325 - accuracy: 0.9589
# Epoch 00031: val_accuracy did not improve from 0.56041
# 25/25 [==============================] - 108s 4s/step - loss: 0.1325 - accuracy: 0.9589 - val_loss: 1.7558 - val_accuracy: 0.5553
# Epoch 32/100
# 25/25 [==============================] - ETA: 0s - loss: 0.1137 - accuracy: 0.9666
# Epoch 00032: val_accuracy did not improve from 0.56041
# 25/25 [==============================] - 108s 4s/step - loss: 0.1137 - accuracy: 0.9666 - val_loss: 1.9836 - val_accuracy: 0.5283
# Epoch 33/100
# 25/25 [==============================] - ETA: 0s - loss: 0.0822 - accuracy: 0.9756
# Epoch 00033: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
#
# Epoch 00033: val_accuracy did not improve from 0.56041
# 25/25 [==============================] - 108s 4s/step - loss: 0.0822 - accuracy: 0.9756 - val_loss: 1.8862 - val_accuracy: 0.5450
# Epoch 00033: early stopping

# %%
import seaborn as sns
sns.set_style('darkgrid')
import matplotlib.pyplot as plt
import matplotlib.image as mimg

# %%
accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(accuracy) + 1)

f, axes = plt.subplots(1,2,figsize=(14,4))

axes[0].plot(epochs, accuracy, 'g', label='Training accuracy')
axes[0].plot(epochs, val_accuracy, 'b', label='Validation accuracy')
axes[0].legend()

axes[1].plot(epochs, loss, 'g', label='Training loss')
axes[1].plot(epochs, val_loss, 'b', label='Validation loss')
axes[1].yaxis.set_label_position("right")
axes[1].legend()

plt.show()

# %%
saved_model = tf.keras.models.load_model('best_model.h5')
print("Test Accuracy: {0:.2f}%".format(saved_model.evaluate(x_test,y_test)[1]*100)) #get score acording to test datas
# Out:
# 14/14 [==============================] - 12s 869ms/step - loss: 1.5637 - accuracy: 0.5866
# Test Accuracy: 58.66%

# %%
from sklearn.metrics import confusion_matrix
Y_pred = saved_model.predict(x_test)
Y_pred_classes = np.argmax(Y_pred,axis = 1)
Y_true = np.argmax(y_test,axis = 1)
confusion_mtx = confusion_matrix(Y_true,Y_pred_classes)
f,ax = plt.subplots(figsize = (8,8))
sns.heatmap(confusion_mtx,annot=True,linewidths = 0.01,cmap="Reds",
            linecolor = "gray",fmt = ".2f",ax=ax
            )
plt.xlabel("predicted label")
plt.ylabel("True Label")
plt.title("confusion matrix")
plt.show()

from sklearn.metrics import classification_report

print(classification_report(Y_true, Y_pred_classes))

y_test_inv = label_binarizer.inverse_transform(y_test)
print(classification_report(y_test_inv, Y_pred_classes, target_names = labels))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.50      0.91      0.64       123
#            1       0.86      0.34      0.48        89
#            2       0.66      0.45      0.54        84
#            3       0.84      0.61      0.71        67
#            4       0.50      0.47      0.49        70
#
#     accuracy                           0.59       433
#    macro avg       0.67      0.56      0.57       433
# weighted avg       0.65      0.59      0.57       433
#
#               precision    recall  f1-score   support
#
#    dandelion       0.50      0.91      0.64       123
#        daisy       0.86      0.34      0.48        89
#        tulip       0.66      0.45      0.54        84
#    sunflower       0.84      0.61      0.71        67
#         rose       0.50      0.47      0.49        70
#
#     accuracy                           0.59       433
#    macro avg       0.67      0.56      0.57       433
# weighted avg       0.65      0.59      0.57       433
