# %%
#Train Real with for 90%(60%real, 20%validation) and 10%test data
import keras
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout, Flatten
from keras.layers import Conv2D
from keras.layers import MaxPooling2D,MaxPool2D
from keras.layers.normalization import BatchNormalization
from keras.optimizers import Adam
from keras.preprocessing.image import ImageDataGenerator
from keras import layers
from keras import models
from keras import optimizers

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
import os

# %%
#changing the working directory
# %cd /content/gdrive/My Drive/Thesis
# Out:
# /content/gdrive/My Drive/Thesis

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import keras
from keras.models import Sequential, Model
from keras.layers import Dense, Conv2D , MaxPool2D , Flatten , Dropout , MaxPooling2D
from keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report,confusion_matrix
from keras.applications import VGG19
import cv2
import os
import random
import tensorflow as tf
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
labels = ['dandelion', 'daisy','tulip','sunflower','rose']
img_size = 150
def get_data(data_dir):
    data = [] 
    for label in labels: 
        path = os.path.join(data_dir, label)
        class_num = labels.index(label)
        for img in os.listdir(path):
            try:
                img_arr = cv2.imread(os.path.join(path, img), cv2.IMREAD_COLOR)
                resized_arr = cv2.resize(img_arr, (img_size, img_size)) # Reshaping images to preferred size
                data.append([resized_arr, class_num])
            except Exception as e:
                print(e)
    return np.array(data)

# %%
data = get_data("/content/gdrive/My Drive/Thesis/flowers")
# Out:
# OpenCV(4.1.2) /io/opencv/modules/imgproc/src/resize.cpp:3720: error: (-215:Assertion failed) !ssize.empty() in function 'resize'
#
# OpenCV(4.1.2) /io/opencv/modules/imgproc/src/resize.cpp:3720: error: (-215:Assertion failed) !ssize.empty() in function 'resize'
#
# OpenCV(4.1.2) /io/opencv/modules/imgproc/src/resize.cpp:3720: error: (-215:Assertion failed) !ssize.empty() in function 'resize'

# %%
l = []
for i in data:
    l.append(labels[i[1]])
sns.set_style('dark')
sns.countplot(l)

# %%
fig,ax=plt.subplots(5,2)
fig.set_size_inches(15,15)
for i in range(5):
    for j in range (2):
        l=random.randint(0,len(data))
        ax[i,j].imshow(data[l][0])
        ax[i,j].set_title('Flower: '+labels[data[l][1]])
        
plt.tight_layout()

# %%
x = []
y = []

for feature, label in data:
    x.append(feature)
    y.append(label)

# %%
# Normalize the data
x = np.array(x) / 255

# %%
# Reshaping the data from 1-D to 3-D as required through input by CNN's 
x = x.reshape(-1, img_size, img_size, 3)
y = np.array(y)

# %%
from sklearn.preprocessing import LabelBinarizer
label_binarizer = LabelBinarizer()
y = label_binarizer.fit_transform(y)

# %%
x_train,x_test,y_train,y_test = train_test_split(x , y , test_size = 0.1 , random_state = 42)

# %%
x_train,x_val,y_train,y_val = train_test_split(x_train, y_train, test_size= 0.2, random_state = 42)

# %%
x_train,x_left,y_train,y_left = train_test_split(x_train, y_train, test_size= 0.25, random_state = 42)

# %%
model = Sequential()
# 1st Convolutional Layer
model.add(Conv2D(filters=64, kernel_size=(3,3),padding="Same",activation="relu" , input_shape = (150,150,3)))
model.add(MaxPool2D(pool_size=(2,2),strides=(2,2)))
model.add(BatchNormalization())
model.add(Dropout(0.2))
# 2nd Convolutional Layer
model.add(Conv2D(filters=128, kernel_size=(3,3),padding="Same",activation="relu"))
model.add(MaxPool2D(pool_size=(2,2),strides=(2,2)))
model.add(BatchNormalization())
model.add(Dropout(0.3))
# 3rd Convolutional Layer
model.add(Conv2D(filters=128, kernel_size=(3,3),padding="Same",activation="relu"))
model.add(MaxPool2D(pool_size=(2,2),strides=(2,2)))
model.add(BatchNormalization())
model.add(Dropout(0.2))
# 4th Convolutional Layer
model.add(Conv2D(filters=256, kernel_size=(3,3),padding="Same",activation="relu"))
model.add(MaxPool2D(pool_size=(2,2),strides=(2,2)))
model.add(BatchNormalization())
model.add(Dropout(0.3))
# 5th Convolutional Layer
model.add(Conv2D(filters=256,kernel_size = (3,3),padding="Same",activation="relu"))
model.add(MaxPool2D(pool_size=(2,2),strides=(2,2)))
model.add(BatchNormalization())
model.add(Dropout(0.2))
# 6th Convolutional Layer
model.add(Conv2D(filters=512,kernel_size = (3,3),padding="Same",activation="relu"))
model.add(MaxPool2D(pool_size=(2,2),strides=(2,2)))
model.add(BatchNormalization())
model.add(Dropout(0.2))

model.add(Flatten())
# 1st Fully Connected Layer
model.add(Dense(1024,activation="relu"))
model.add(Dropout(0.5))
model.add(BatchNormalization())
# Output layer
model.add(Dense(5,activation="softmax"))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 150, 150, 64)      1792
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 75, 75, 64)        0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 75, 75, 64)        256
# _________________________________________________________________
# dropout (Dropout)            (None, 75, 75, 64)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 75, 75, 128)       73856
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 37, 37, 128)       0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 37, 37, 128)       512
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 37, 37, 128)       0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 37, 37, 128)       147584
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 18, 18, 128)       0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 18, 18, 128)       512
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 18, 18, 128)       0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 18, 18, 256)       295168
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 9, 9, 256)         0
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 9, 9, 256)         1024
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 9, 9, 256)         0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 9, 9, 256)         590080
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 4, 4, 256)         0
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 4, 4, 256)         1024
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 4, 4, 256)         0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 4, 4, 512)         1180160
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 2, 2, 512)         0
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 2, 2, 512)         2048
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 2, 2, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 2048)              0
# _________________________________________________________________
# dense (Dense)                (None, 1024)              2098176
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 1024)              4096
# _________________________________________________________________
# dense_1 (Dense)              (None, 5)                 5125
# =================================================================
# Total params: 4,401,413
# Trainable params: 4,396,677
# Non-trainable params: 4,736
# _________________________________________________________________

# %%
#defining early stopping
from keras.callbacks import ReduceLROnPlateau
learning_rate = ReduceLROnPlateau(monitor='val_accuracy', patience = 3, verbose=1,factor=0.5, min_lr=0.000001)

es = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss', patience=10, verbose=1, mode='min')

# %%
# !pip install h5py
	
	
mc = tf.keras.callbacks.ModelCheckpoint('best_model.h5', monitor='val_accuracy', mode='max', verbose=1, save_best_only=True)
# Out:
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (2.10.0)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from h5py) (1.15.0)
# Requirement already satisfied: numpy>=1.7 in /usr/local/lib/python3.6/dist-packages (from h5py) (1.18.5)

# %%
model.compile(optimizer = "adam" , loss = 'categorical_crossentropy' , metrics = ['accuracy'])

# %%
#Fitting the augmentation data
history = model.fit(x_train, y_train, batch_size=32, epochs=100, validation_data = (x_val, y_val), callbacks = [learning_rate,es,mc])
# Out:
# Epoch 1/100
# 74/74 [==============================] - ETA: 0s - loss: 1.5993 - accuracy: 0.4421
# Epoch 00001: val_accuracy improved from -inf to 0.21282, saving model to best_model.h5
# 74/74 [==============================] - 311s 4s/step - loss: 1.5993 - accuracy: 0.4421 - val_loss: 4.5522 - val_accuracy: 0.2128
# Epoch 2/100
# 74/74 [==============================] - ETA: 0s - loss: 1.3354 - accuracy: 0.5199
# Epoch 00002: val_accuracy did not improve from 0.21282
# 74/74 [==============================] - 314s 4s/step - loss: 1.3354 - accuracy: 0.5199 - val_loss: 2.4518 - val_accuracy: 0.2128
# Epoch 3/100
# 74/74 [==============================] - ETA: 0s - loss: 1.1317 - accuracy: 0.5682
# Epoch 00003: val_accuracy did not improve from 0.21282
# 74/74 [==============================] - 313s 4s/step - loss: 1.1317 - accuracy: 0.5682 - val_loss: 4.2694 - val_accuracy: 0.2128
# Epoch 4/100
# 74/74 [==============================] - ETA: 0s - loss: 0.9790 - accuracy: 0.6238
# Epoch 00004: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00004: val_accuracy did not improve from 0.21282
# 74/74 [==============================] - 314s 4s/step - loss: 0.9790 - accuracy: 0.6238 - val_loss: 3.5957 - val_accuracy: 0.2128
# Epoch 5/100
# 74/74 [==============================] - ETA: 0s - loss: 0.8959 - accuracy: 0.6554
# Epoch 00005: val_accuracy improved from 0.21282 to 0.22692, saving model to best_model.h5
# 74/74 [==============================] - 314s 4s/step - loss: 0.8959 - accuracy: 0.6554 - val_loss: 3.8940 - val_accuracy: 0.2269
# Epoch 6/100
# 74/74 [==============================] - ETA: 0s - loss: 0.8418 - accuracy: 0.6742
# Epoch 00006: val_accuracy improved from 0.22692 to 0.29615, saving model to best_model.h5
# 74/74 [==============================] - 315s 4s/step - loss: 0.8418 - accuracy: 0.6742 - val_loss: 2.3634 - val_accuracy: 0.2962
# Epoch 7/100
# 74/74 [==============================] - ETA: 0s - loss: 0.7576 - accuracy: 0.7127
# Epoch 00007: val_accuracy improved from 0.29615 to 0.38333, saving model to best_model.h5
# 74/74 [==============================] - 314s 4s/step - loss: 0.7576 - accuracy: 0.7127 - val_loss: 2.2953 - val_accuracy: 0.3833
# Epoch 8/100
# 74/74 [==============================] - ETA: 0s - loss: 0.7481 - accuracy: 0.7148
# Epoch 00008: val_accuracy improved from 0.38333 to 0.46667, saving model to best_model.h5
# 74/74 [==============================] - 315s 4s/step - loss: 0.7481 - accuracy: 0.7148 - val_loss: 1.5271 - val_accuracy: 0.4667
# Epoch 9/100
# 74/74 [==============================] - ETA: 0s - loss: 0.7410 - accuracy: 0.7178
# Epoch 00009: val_accuracy improved from 0.46667 to 0.56795, saving model to best_model.h5
# 74/74 [==============================] - 316s 4s/step - loss: 0.7410 - accuracy: 0.7178 - val_loss: 1.1473 - val_accuracy: 0.5679
# Epoch 10/100
# 74/74 [==============================] - ETA: 0s - loss: 0.6819 - accuracy: 0.7448
# Epoch 00010: val_accuracy improved from 0.56795 to 0.63846, saving model to best_model.h5
# 74/74 [==============================] - 319s 4s/step - loss: 0.6819 - accuracy: 0.7448 - val_loss: 1.0055 - val_accuracy: 0.6385
# Epoch 11/100
# 74/74 [==============================] - ETA: 0s - loss: 0.6413 - accuracy: 0.7606
# Epoch 00011: val_accuracy improved from 0.63846 to 0.63974, saving model to best_model.h5
# 74/74 [==============================] - 318s 4s/step - loss: 0.6413 - accuracy: 0.7606 - val_loss: 0.9982 - val_accuracy: 0.6397
# Epoch 12/100
# 74/74 [==============================] - ETA: 0s - loss: 0.7512 - accuracy: 0.7140
# Epoch 00012: val_accuracy did not improve from 0.63974
# 74/74 [==============================] - 323s 4s/step - loss: 0.7512 - accuracy: 0.7140 - val_loss: 1.1726 - val_accuracy: 0.6026
# Epoch 13/100
# 74/74 [==============================] - ETA: 0s - loss: 0.6469 - accuracy: 0.7550
# Epoch 00013: val_accuracy improved from 0.63974 to 0.74103, saving model to best_model.h5
# 74/74 [==============================] - 314s 4s/step - loss: 0.6469 - accuracy: 0.7550 - val_loss: 0.7419 - val_accuracy: 0.7410
# Epoch 14/100
# 74/74 [==============================] - ETA: 0s - loss: 0.6605 - accuracy: 0.7465
# Epoch 00014: val_accuracy did not improve from 0.74103
# 74/74 [==============================] - 312s 4s/step - loss: 0.6605 - accuracy: 0.7465 - val_loss: 1.1063 - val_accuracy: 0.6218
# Epoch 15/100
# 74/74 [==============================] - ETA: 0s - loss: 0.5628 - accuracy: 0.7845
# Epoch 00015: val_accuracy did not improve from 0.74103
# 74/74 [==============================] - 311s 4s/step - loss: 0.5628 - accuracy: 0.7845 - val_loss: 0.8369 - val_accuracy: 0.6949
# Epoch 16/100
# 74/74 [==============================] - ETA: 0s - loss: 0.5194 - accuracy: 0.8033
# Epoch 00016: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 00016: val_accuracy did not improve from 0.74103
# 74/74 [==============================] - 314s 4s/step - loss: 0.5194 - accuracy: 0.8033 - val_loss: 0.9464 - val_accuracy: 0.6436
# Epoch 17/100
# 74/74 [==============================] - ETA: 0s - loss: 0.4416 - accuracy: 0.8337
# Epoch 00017: val_accuracy improved from 0.74103 to 0.74872, saving model to best_model.h5
# 74/74 [==============================] - 315s 4s/step - loss: 0.4416 - accuracy: 0.8337 - val_loss: 0.7155 - val_accuracy: 0.7487
# Epoch 18/100
# 74/74 [==============================] - ETA: 0s - loss: 0.3935 - accuracy: 0.8534
# Epoch 00018: val_accuracy improved from 0.74872 to 0.75128, saving model to best_model.h5
# 74/74 [==============================] - 317s 4s/step - loss: 0.3935 - accuracy: 0.8534 - val_loss: 0.7295 - val_accuracy: 0.7513
# Epoch 19/100
# 74/74 [==============================] - ETA: 0s - loss: 0.3427 - accuracy: 0.8739
# Epoch 00019: val_accuracy did not improve from 0.75128
# 74/74 [==============================] - 311s 4s/step - loss: 0.3427 - accuracy: 0.8739 - val_loss: 0.7278 - val_accuracy: 0.7449
# Epoch 20/100
# 74/74 [==============================] - ETA: 0s - loss: 0.3923 - accuracy: 0.8534
# Epoch 00020: val_accuracy did not improve from 0.75128
# 74/74 [==============================] - 323s 4s/step - loss: 0.3923 - accuracy: 0.8534 - val_loss: 0.9419 - val_accuracy: 0.7038
# Epoch 21/100
# 74/74 [==============================] - ETA: 0s - loss: 0.3359 - accuracy: 0.8760
# Epoch 00021: val_accuracy improved from 0.75128 to 0.76538, saving model to best_model.h5
# 74/74 [==============================] - 324s 4s/step - loss: 0.3359 - accuracy: 0.8760 - val_loss: 0.7656 - val_accuracy: 0.7654
# Epoch 22/100
# 74/74 [==============================] - ETA: 0s - loss: 0.3154 - accuracy: 0.8829
# Epoch 00022: val_accuracy did not improve from 0.76538
# 74/74 [==============================] - 330s 4s/step - loss: 0.3154 - accuracy: 0.8829 - val_loss: 0.8095 - val_accuracy: 0.7385
# Epoch 23/100
# 74/74 [==============================] - ETA: 0s - loss: 0.2732 - accuracy: 0.8970
# Epoch 00023: val_accuracy did not improve from 0.76538
# 74/74 [==============================] - 331s 4s/step - loss: 0.2732 - accuracy: 0.8970 - val_loss: 0.8040 - val_accuracy: 0.7551
# Epoch 24/100
# 74/74 [==============================] - ETA: 0s - loss: 0.2714 - accuracy: 0.9017
# Epoch 00024: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 00024: val_accuracy did not improve from 0.76538
# 74/74 [==============================] - 318s 4s/step - loss: 0.2714 - accuracy: 0.9017 - val_loss: 0.8386 - val_accuracy: 0.7359
# Epoch 25/100
# 74/74 [==============================] - ETA: 0s - loss: 0.2240 - accuracy: 0.9235
# Epoch 00025: val_accuracy did not improve from 0.76538
# 74/74 [==============================] - 315s 4s/step - loss: 0.2240 - accuracy: 0.9235 - val_loss: 0.7590 - val_accuracy: 0.7526
# Epoch 26/100
# 74/74 [==============================] - ETA: 0s - loss: 0.1813 - accuracy: 0.9406
# Epoch 00026: val_accuracy did not improve from 0.76538
# 74/74 [==============================] - 308s 4s/step - loss: 0.1813 - accuracy: 0.9406 - val_loss: 0.7964 - val_accuracy: 0.7551
# Epoch 27/100
# 74/74 [==============================] - ETA: 0s - loss: 0.1748 - accuracy: 0.9431
# Epoch 00027: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
#
# Epoch 00027: val_accuracy did not improve from 0.76538
# 74/74 [==============================] - 334s 5s/step - loss: 0.1748 - accuracy: 0.9431 - val_loss: 0.9530 - val_accuracy: 0.7295
# Epoch 00027: early stopping

# %%
import seaborn as sns
sns.set_style('darkgrid')
import matplotlib.pyplot as plt
import matplotlib.image as mimg

# %%
accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(accuracy) + 1)

f, axes = plt.subplots(1,2,figsize=(14,4))

axes[0].plot(epochs, accuracy, 'g', label='Training accuracy')
axes[0].plot(epochs, val_accuracy, 'b', label='Validation accuracy')
axes[0].legend()

axes[1].plot(epochs, loss, 'g', label='Training loss')
axes[1].plot(epochs, val_loss, 'b', label='Validation loss')
axes[1].yaxis.set_label_position("right")
axes[1].legend()

plt.show()

# %%
saved_model = tf.keras.models.load_model('best_model.h5')
print("Test Accuracy: {0:.2f}%".format(saved_model.evaluate(x_test,y_test)[1]*100)) #get score acording to test datas
# Out:
# 14/14 [==============================] - 13s 916ms/step - loss: 0.7197 - accuracy: 0.7442
# Test Accuracy: 74.42%

# %%
from sklearn.metrics import confusion_matrix
Y_pred = saved_model.predict(x_test)
Y_pred_classes = np.argmax(Y_pred,axis = 1)
Y_true = np.argmax(y_test,axis = 1)
confusion_mtx = confusion_matrix(Y_true,Y_pred_classes)
f,ax = plt.subplots(figsize = (8,8))
sns.heatmap(confusion_mtx,annot=True,linewidths = 0.01,cmap="Reds",
            linecolor = "gray",ax=ax
            )
plt.xlabel("predicted label")
plt.ylabel("True Label")
plt.title("confusion matrix")
plt.show()

from sklearn.metrics import classification_report

print(classification_report(Y_true, Y_pred_classes))


y_test_inv = label_binarizer.inverse_transform(y_test)
print(classification_report(y_test_inv, Y_pred_classes, target_names = labels))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.71      0.88      0.79       111
#            1       0.84      0.79      0.81        84
#            2       0.73      0.69      0.71       104
#            3       0.90      0.63      0.75        60
#            4       0.64      0.65      0.65        75
#
#     accuracy                           0.74       434
#    macro avg       0.76      0.73      0.74       434
# weighted avg       0.75      0.74      0.74       434
#
#               precision    recall  f1-score   support
#
#    dandelion       0.71      0.88      0.79       111
#        daisy       0.84      0.79      0.81        84
#        tulip       0.73      0.69      0.71       104
#    sunflower       0.90      0.63      0.75        60
#         rose       0.64      0.65      0.65        75
#
#     accuracy                           0.74       434
#    macro avg       0.76      0.73      0.74       434
# weighted avg       0.75      0.74      0.74       434
