# %%
#Train Aug with for 90%(50%augmented, 20%validation) and 10%test data
import keras
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout, Flatten
from keras.layers import Conv2D
from keras.layers import MaxPooling2D,MaxPool2D
from keras.layers.normalization import BatchNormalization
from keras.optimizers import Adam
from keras.preprocessing.image import ImageDataGenerator
from keras import layers
from keras import models
from keras import optimizers

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
import os

# %%
#changing the working directory
# %cd /content/gdrive/My Drive/Thesis
# Out:
# /content/gdrive/My Drive/Thesis

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import keras
from keras.models import Sequential, Model
from keras.layers import Dense, Conv2D , MaxPool2D , Flatten , Dropout , MaxPooling2D
from keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report,confusion_matrix
from keras.applications import VGG19
import cv2
import os
import random
import tensorflow as tf
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
labels = ['dandelion', 'daisy','tulip','sunflower','rose']
img_size = 150
def get_data(data_dir):
    data = [] 
    for label in labels: 
        path = os.path.join(data_dir, label)
        class_num = labels.index(label)
        for img in os.listdir(path):
            try:
                img_arr = cv2.imread(os.path.join(path, img), cv2.IMREAD_COLOR)
                resized_arr = cv2.resize(img_arr, (img_size, img_size)) # Reshaping images to preferred size
                data.append([resized_arr, class_num])
            except Exception as e:
                print(e)
    return np.array(data)

# %%
data = get_data("/content/gdrive/My Drive/Thesis/flowers")
# Out:
# OpenCV(4.1.2) /io/opencv/modules/imgproc/src/resize.cpp:3720: error: (-215:Assertion failed) !ssize.empty() in function 'resize'
#
# OpenCV(4.1.2) /io/opencv/modules/imgproc/src/resize.cpp:3720: error: (-215:Assertion failed) !ssize.empty() in function 'resize'
#
# OpenCV(4.1.2) /io/opencv/modules/imgproc/src/resize.cpp:3720: error: (-215:Assertion failed) !ssize.empty() in function 'resize'

# %%
l = []
for i in data:
    l.append(labels[i[1]])
sns.set_style('dark')
sns.countplot(l)

# %%
fig,ax=plt.subplots(5,2)
fig.set_size_inches(15,15)
for i in range(5):
    for j in range (2):
        l=random.randint(0,len(data))
        ax[i,j].imshow(data[l][0])
        ax[i,j].set_title('Flower: '+labels[data[l][1]])
        
plt.tight_layout()

# %%
x = []
y = []

for feature, label in data:
    x.append(feature)
    y.append(label)

# %%
# Normalize the data
x = np.array(x) / 255

# %%
# Reshaping the data from 1-D to 3-D as required through input by CNN's 
x = x.reshape(-1, img_size, img_size, 3)
y = np.array(y)

# %%
from sklearn.preprocessing import LabelBinarizer
label_binarizer = LabelBinarizer()
y = label_binarizer.fit_transform(y)

# %%
x_train,x_test,y_train,y_test = train_test_split(x , y , test_size = 0.1 , random_state = 42)

# %%
x_train,x_val,y_train,y_val = train_test_split(x_train, y_train, test_size= 0.2, random_state = 42)

# %%
x_train,x_left,y_train,y_left = train_test_split(x_train, y_train, test_size= 0.375, random_state = 42)

# %%
#defining the augmentation
datagen = ImageDataGenerator(
    featurewise_center=False,  # set input mean to 0 over the dataset
    samplewise_center=False,  # set each sample mean to 0
    featurewise_std_normalization=False,  # divide inputs by std of the dataset
    samplewise_std_normalization=False,  # divide each input by its std
    rotation_range=180,  # randomly rotate images in the range (0 to 180)
    zoom_range = 0.1, # Randomly zoom image 
    width_shift_range=0.1,  # randomly shift images horizontally (fraction of total width)
    height_shift_range=0.1,
    shear_range=0.1,
    fill_mode = "reflect"
    ) 
datagen.fit(x_train)

# %%
model = Sequential()
# 1st Convolutional Layer
model.add(Conv2D(filters=64, kernel_size=(3,3),padding="Same",activation="relu" , input_shape = (150,150,3)))
model.add(MaxPool2D(pool_size=(2,2),strides=(2,2)))
model.add(BatchNormalization())
model.add(Dropout(0.2))
# 2nd Convolutional Layer
model.add(Conv2D(filters=128, kernel_size=(3,3),padding="Same",activation="relu"))
model.add(MaxPool2D(pool_size=(2,2),strides=(2,2)))
model.add(BatchNormalization())
model.add(Dropout(0.3))
# 3rd Convolutional Layer
model.add(Conv2D(filters=128, kernel_size=(3,3),padding="Same",activation="relu"))
model.add(MaxPool2D(pool_size=(2,2),strides=(2,2)))
model.add(BatchNormalization())
model.add(Dropout(0.2))
# 4th Convolutional Layer
model.add(Conv2D(filters=256, kernel_size=(3,3),padding="Same",activation="relu"))
model.add(MaxPool2D(pool_size=(2,2),strides=(2,2)))
model.add(BatchNormalization())
model.add(Dropout(0.3))
# 5th Convolutional Layer
model.add(Conv2D(filters=256,kernel_size = (3,3),padding="Same",activation="relu"))
model.add(MaxPool2D(pool_size=(2,2),strides=(2,2)))
model.add(BatchNormalization())
model.add(Dropout(0.2))
# 6th Convolutional Layer
model.add(Conv2D(filters=512,kernel_size = (3,3),padding="Same",activation="relu"))
model.add(MaxPool2D(pool_size=(2,2),strides=(2,2)))
model.add(BatchNormalization())
model.add(Dropout(0.2))

model.add(Flatten())
# 1st Fully Connected Layer
model.add(Dense(1024,activation="relu"))
model.add(Dropout(0.5))
model.add(BatchNormalization())
# Output layer
model.add(Dense(5,activation="softmax"))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 150, 150, 64)      1792
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 75, 75, 64)        0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 75, 75, 64)        256
# _________________________________________________________________
# dropout (Dropout)            (None, 75, 75, 64)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 75, 75, 128)       73856
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 37, 37, 128)       0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 37, 37, 128)       512
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 37, 37, 128)       0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 37, 37, 128)       147584
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 18, 18, 128)       0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 18, 18, 128)       512
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 18, 18, 128)       0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 18, 18, 256)       295168
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 9, 9, 256)         0
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 9, 9, 256)         1024
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 9, 9, 256)         0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 9, 9, 256)         590080
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 4, 4, 256)         0
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 4, 4, 256)         1024
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 4, 4, 256)         0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 4, 4, 512)         1180160
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 2, 2, 512)         0
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 2, 2, 512)         2048
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 2, 2, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 2048)              0
# _________________________________________________________________
# dense (Dense)                (None, 1024)              2098176
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 1024)              4096
# _________________________________________________________________
# dense_1 (Dense)              (None, 5)                 5125
# =================================================================
# Total params: 4,401,413
# Trainable params: 4,396,677
# Non-trainable params: 4,736
# _________________________________________________________________

# %%
#defining early stopping
from keras.callbacks import ReduceLROnPlateau
learning_rate = ReduceLROnPlateau(monitor='val_accuracy', patience = 3, verbose=1,factor=0.5, min_lr=0.000001)

es = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss', patience=10, verbose=1, mode='min')

# %%
# !pip install h5py
	
	
mc = tf.keras.callbacks.ModelCheckpoint('best_model.h5', monitor='val_accuracy', mode='max', verbose=1, save_best_only=True)
# Out:
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (2.10.0)
# Requirement already satisfied: numpy>=1.7 in /usr/local/lib/python3.6/dist-packages (from h5py) (1.18.5)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from h5py) (1.15.0)

# %%
model.compile(optimizer = "adam" , loss = 'categorical_crossentropy' , metrics = ['accuracy'])

# %%
#Fitting the augmentation data
history = model.fit(datagen.flow(x_train, y_train, batch_size=32), epochs=100, validation_data = (x_val, y_val), callbacks = [learning_rate,es,mc])
# Out:
# Epoch 1/100
# 61/61 [==============================] - ETA: 0s - loss: 1.8349 - accuracy: 0.4023
# Epoch 00001: val_accuracy improved from -inf to 0.21282, saving model to best_model.h5
# 61/61 [==============================] - 271s 4s/step - loss: 1.8349 - accuracy: 0.4023 - val_loss: 3.8685 - val_accuracy: 0.2128
# Epoch 2/100
# 61/61 [==============================] - ETA: 0s - loss: 1.3825 - accuracy: 0.4818
# Epoch 00002: val_accuracy did not improve from 0.21282
# 61/61 [==============================] - 271s 4s/step - loss: 1.3825 - accuracy: 0.4818 - val_loss: 4.6782 - val_accuracy: 0.2128
# Epoch 3/100
# 61/61 [==============================] - ETA: 0s - loss: 1.2817 - accuracy: 0.5259
# Epoch 00003: val_accuracy improved from 0.21282 to 0.26282, saving model to best_model.h5
# 61/61 [==============================] - 275s 5s/step - loss: 1.2817 - accuracy: 0.5259 - val_loss: 3.0266 - val_accuracy: 0.2628
# Epoch 4/100
# 61/61 [==============================] - ETA: 0s - loss: 1.1722 - accuracy: 0.5495
# Epoch 00004: val_accuracy did not improve from 0.26282
# 61/61 [==============================] - 275s 5s/step - loss: 1.1722 - accuracy: 0.5495 - val_loss: 3.6351 - val_accuracy: 0.2128
# Epoch 5/100
# 61/61 [==============================] - ETA: 0s - loss: 1.1186 - accuracy: 0.5803
# Epoch 00005: val_accuracy improved from 0.26282 to 0.28590, saving model to best_model.h5
# 61/61 [==============================] - 276s 5s/step - loss: 1.1186 - accuracy: 0.5803 - val_loss: 2.1538 - val_accuracy: 0.2859
# Epoch 6/100
# 61/61 [==============================] - ETA: 0s - loss: 1.0795 - accuracy: 0.5952
# Epoch 00006: val_accuracy improved from 0.28590 to 0.35897, saving model to best_model.h5
# 61/61 [==============================] - 276s 5s/step - loss: 1.0795 - accuracy: 0.5952 - val_loss: 1.7493 - val_accuracy: 0.3590
# Epoch 7/100
# 61/61 [==============================] - ETA: 0s - loss: 1.0428 - accuracy: 0.6193
# Epoch 00007: val_accuracy did not improve from 0.35897
# 61/61 [==============================] - 276s 5s/step - loss: 1.0428 - accuracy: 0.6193 - val_loss: 2.4435 - val_accuracy: 0.2667
# Epoch 8/100
# 61/61 [==============================] - ETA: 0s - loss: 1.0175 - accuracy: 0.6044
# Epoch 00008: val_accuracy improved from 0.35897 to 0.40769, saving model to best_model.h5
# 61/61 [==============================] - 277s 5s/step - loss: 1.0175 - accuracy: 0.6044 - val_loss: 1.7420 - val_accuracy: 0.4077
# Epoch 9/100
# 61/61 [==============================] - ETA: 0s - loss: 0.9504 - accuracy: 0.6311
# Epoch 00009: val_accuracy improved from 0.40769 to 0.55897, saving model to best_model.h5
# 61/61 [==============================] - 278s 5s/step - loss: 0.9504 - accuracy: 0.6311 - val_loss: 1.1064 - val_accuracy: 0.5590
# Epoch 10/100
# 61/61 [==============================] - ETA: 0s - loss: 0.9581 - accuracy: 0.6280
# Epoch 00010: val_accuracy did not improve from 0.55897
# 61/61 [==============================] - 276s 5s/step - loss: 0.9581 - accuracy: 0.6280 - val_loss: 1.6186 - val_accuracy: 0.4372
# Epoch 11/100
# 61/61 [==============================] - ETA: 0s - loss: 0.9092 - accuracy: 0.6465
# Epoch 00011: val_accuracy improved from 0.55897 to 0.56154, saving model to best_model.h5
# 61/61 [==============================] - 277s 5s/step - loss: 0.9092 - accuracy: 0.6465 - val_loss: 1.3275 - val_accuracy: 0.5615
# Epoch 12/100
# 61/61 [==============================] - ETA: 0s - loss: 0.9039 - accuracy: 0.6465
# Epoch 00012: val_accuracy improved from 0.56154 to 0.59744, saving model to best_model.h5
# 61/61 [==============================] - 276s 5s/step - loss: 0.9039 - accuracy: 0.6465 - val_loss: 1.1419 - val_accuracy: 0.5974
# Epoch 13/100
# 61/61 [==============================] - ETA: 0s - loss: 0.8736 - accuracy: 0.6480
# Epoch 00013: val_accuracy improved from 0.59744 to 0.61795, saving model to best_model.h5
# 61/61 [==============================] - 275s 5s/step - loss: 0.8736 - accuracy: 0.6480 - val_loss: 1.0530 - val_accuracy: 0.6179
# Epoch 14/100
# 61/61 [==============================] - ETA: 0s - loss: 0.8819 - accuracy: 0.6650
# Epoch 00014: val_accuracy improved from 0.61795 to 0.63205, saving model to best_model.h5
# 61/61 [==============================] - 276s 5s/step - loss: 0.8819 - accuracy: 0.6650 - val_loss: 1.1333 - val_accuracy: 0.6321
# Epoch 15/100
# 61/61 [==============================] - ETA: 0s - loss: 0.8127 - accuracy: 0.6803
# Epoch 00015: val_accuracy did not improve from 0.63205
# 61/61 [==============================] - 275s 5s/step - loss: 0.8127 - accuracy: 0.6803 - val_loss: 1.1684 - val_accuracy: 0.5923
# Epoch 16/100
# 61/61 [==============================] - ETA: 0s - loss: 0.8114 - accuracy: 0.6778
# Epoch 00016: val_accuracy improved from 0.63205 to 0.65641, saving model to best_model.h5
# 61/61 [==============================] - 277s 5s/step - loss: 0.8114 - accuracy: 0.6778 - val_loss: 0.9453 - val_accuracy: 0.6564
# Epoch 17/100
# 61/61 [==============================] - ETA: 0s - loss: 0.7844 - accuracy: 0.6942
# Epoch 00017: val_accuracy did not improve from 0.65641
# 61/61 [==============================] - 274s 4s/step - loss: 0.7844 - accuracy: 0.6942 - val_loss: 1.1917 - val_accuracy: 0.5731
# Epoch 18/100
# 61/61 [==============================] - ETA: 0s - loss: 0.8104 - accuracy: 0.6819
# Epoch 00018: val_accuracy did not improve from 0.65641
# 61/61 [==============================] - 275s 5s/step - loss: 0.8104 - accuracy: 0.6819 - val_loss: 1.0797 - val_accuracy: 0.6500
# Epoch 19/100
# 61/61 [==============================] - ETA: 0s - loss: 0.7958 - accuracy: 0.6809
# Epoch 00019: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00019: val_accuracy did not improve from 0.65641
# 61/61 [==============================] - 274s 4s/step - loss: 0.7958 - accuracy: 0.6809 - val_loss: 1.3385 - val_accuracy: 0.5295
# Epoch 20/100
# 61/61 [==============================] - ETA: 0s - loss: 0.7514 - accuracy: 0.6993
# Epoch 00020: val_accuracy improved from 0.65641 to 0.71667, saving model to best_model.h5
# 61/61 [==============================] - 279s 5s/step - loss: 0.7514 - accuracy: 0.6993 - val_loss: 0.7466 - val_accuracy: 0.7167
# Epoch 21/100
# 61/61 [==============================] - ETA: 0s - loss: 0.6839 - accuracy: 0.7296
# Epoch 00021: val_accuracy did not improve from 0.71667
# 61/61 [==============================] - 277s 5s/step - loss: 0.6839 - accuracy: 0.7296 - val_loss: 0.8536 - val_accuracy: 0.6987
# Epoch 22/100
# 61/61 [==============================] - ETA: 0s - loss: 0.6997 - accuracy: 0.7265
# Epoch 00022: val_accuracy did not improve from 0.71667
# 61/61 [==============================] - 276s 5s/step - loss: 0.6997 - accuracy: 0.7265 - val_loss: 0.8604 - val_accuracy: 0.6936
# Epoch 23/100
# 61/61 [==============================] - ETA: 0s - loss: 0.6777 - accuracy: 0.7363
# Epoch 00023: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 00023: val_accuracy did not improve from 0.71667
# 61/61 [==============================] - 275s 5s/step - loss: 0.6777 - accuracy: 0.7363 - val_loss: 0.8692 - val_accuracy: 0.6718
# Epoch 24/100
# 61/61 [==============================] - ETA: 0s - loss: 0.6365 - accuracy: 0.7506
# Epoch 00024: val_accuracy did not improve from 0.71667
# 61/61 [==============================] - 276s 5s/step - loss: 0.6365 - accuracy: 0.7506 - val_loss: 0.8211 - val_accuracy: 0.7167
# Epoch 25/100
# 61/61 [==============================] - ETA: 0s - loss: 0.5903 - accuracy: 0.7717
# Epoch 00025: val_accuracy improved from 0.71667 to 0.73974, saving model to best_model.h5
# 61/61 [==============================] - 276s 5s/step - loss: 0.5903 - accuracy: 0.7717 - val_loss: 0.7509 - val_accuracy: 0.7397
# Epoch 26/100
# 61/61 [==============================] - ETA: 0s - loss: 0.6164 - accuracy: 0.7517
# Epoch 00026: val_accuracy did not improve from 0.73974
# 61/61 [==============================] - 275s 5s/step - loss: 0.6164 - accuracy: 0.7517 - val_loss: 0.7533 - val_accuracy: 0.7218
# Epoch 27/100
# 61/61 [==============================] - ETA: 0s - loss: 0.6092 - accuracy: 0.7553
# Epoch 00027: val_accuracy did not improve from 0.73974
# 61/61 [==============================] - 275s 5s/step - loss: 0.6092 - accuracy: 0.7553 - val_loss: 0.8327 - val_accuracy: 0.6923
# Epoch 28/100
# 61/61 [==============================] - ETA: 0s - loss: 0.6132 - accuracy: 0.7671
# Epoch 00028: val_accuracy improved from 0.73974 to 0.75385, saving model to best_model.h5
# 61/61 [==============================] - 275s 5s/step - loss: 0.6132 - accuracy: 0.7671 - val_loss: 0.7144 - val_accuracy: 0.7538
# Epoch 29/100
# 61/61 [==============================] - ETA: 0s - loss: 0.5994 - accuracy: 0.7660
# Epoch 00029: val_accuracy did not improve from 0.75385
# 61/61 [==============================] - 274s 4s/step - loss: 0.5994 - accuracy: 0.7660 - val_loss: 0.7723 - val_accuracy: 0.7141
# Epoch 30/100
# 61/61 [==============================] - ETA: 0s - loss: 0.6049 - accuracy: 0.7558
# Epoch 00030: val_accuracy did not improve from 0.75385
# 61/61 [==============================] - 273s 4s/step - loss: 0.6049 - accuracy: 0.7558 - val_loss: 0.9595 - val_accuracy: 0.6551
# Epoch 31/100
# 61/61 [==============================] - ETA: 0s - loss: 0.5968 - accuracy: 0.7635
# Epoch 00031: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 00031: val_accuracy did not improve from 0.75385
# 61/61 [==============================] - 275s 5s/step - loss: 0.5968 - accuracy: 0.7635 - val_loss: 0.8355 - val_accuracy: 0.7064
# Epoch 32/100
# 61/61 [==============================] - ETA: 0s - loss: 0.5623 - accuracy: 0.7778
# Epoch 00032: val_accuracy did not improve from 0.75385
# 61/61 [==============================] - 272s 4s/step - loss: 0.5623 - accuracy: 0.7778 - val_loss: 0.7272 - val_accuracy: 0.7321
# Epoch 33/100
# 61/61 [==============================] - ETA: 0s - loss: 0.5441 - accuracy: 0.7891
# Epoch 00033: val_accuracy did not improve from 0.75385
# 61/61 [==============================] - 273s 4s/step - loss: 0.5441 - accuracy: 0.7891 - val_loss: 0.8315 - val_accuracy: 0.6949
# Epoch 34/100
# 61/61 [==============================] - ETA: 0s - loss: 0.5328 - accuracy: 0.7871
# Epoch 00034: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
#
# Epoch 00034: val_accuracy did not improve from 0.75385
# 61/61 [==============================] - 273s 4s/step - loss: 0.5328 - accuracy: 0.7871 - val_loss: 0.8449 - val_accuracy: 0.7013
# Epoch 35/100
# 61/61 [==============================] - ETA: 0s - loss: 0.5398 - accuracy: 0.7917
# Epoch 00035: val_accuracy did not improve from 0.75385
# 61/61 [==============================] - 274s 4s/step - loss: 0.5398 - accuracy: 0.7917 - val_loss: 0.7770 - val_accuracy: 0.7244
# Epoch 36/100
# 61/61 [==============================] - ETA: 0s - loss: 0.5121 - accuracy: 0.8014
# Epoch 00036: val_accuracy did not improve from 0.75385
# 61/61 [==============================] - 273s 4s/step - loss: 0.5121 - accuracy: 0.8014 - val_loss: 0.7406 - val_accuracy: 0.7333
# Epoch 37/100
# 61/61 [==============================] - ETA: 0s - loss: 0.5056 - accuracy: 0.8091
# Epoch 00037: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
#
# Epoch 00037: val_accuracy did not improve from 0.75385
# 61/61 [==============================] - 273s 4s/step - loss: 0.5056 - accuracy: 0.8091 - val_loss: 0.8282 - val_accuracy: 0.7090
# Epoch 38/100
# 61/61 [==============================] - ETA: 0s - loss: 0.4895 - accuracy: 0.8158
# Epoch 00038: val_accuracy did not improve from 0.75385
# 61/61 [==============================] - 274s 4s/step - loss: 0.4895 - accuracy: 0.8158 - val_loss: 0.7476 - val_accuracy: 0.7423
# Epoch 00038: early stopping

# %%
import seaborn as sns
sns.set_style('darkgrid')
import matplotlib.pyplot as plt
import matplotlib.image as mimg

# %%
accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(accuracy) + 1)

f, axes = plt.subplots(1,2,figsize=(14,4))

axes[0].plot(epochs, accuracy, 'g', label='Training accuracy')
axes[0].plot(epochs, val_accuracy, 'b', label='Validation accuracy')
axes[0].legend()

axes[1].plot(epochs, loss, 'g', label='Training loss')
axes[1].plot(epochs, val_loss, 'b', label='Validation loss')
axes[1].yaxis.set_label_position("right")
axes[1].legend()

plt.show()

# %%
saved_model = tf.keras.models.load_model('best_model.h5')
print("Test Accuracy: {0:.2f}%".format(saved_model.evaluate(x_test,y_test)[1]*100)) #get score acording to test datas
# Out:
# 14/14 [==============================] - 13s 906ms/step - loss: 0.6340 - accuracy: 0.7512
# Test Accuracy: 75.12%

# %%
from sklearn.metrics import confusion_matrix
Y_pred = saved_model.predict(x_test)
Y_pred_classes = np.argmax(Y_pred,axis = 1)
Y_true = np.argmax(y_test,axis = 1)
confusion_mtx = confusion_matrix(Y_true,Y_pred_classes)
f,ax = plt.subplots(figsize = (8,8))
sns.heatmap(confusion_mtx,annot=True,linewidths = 0.01,cmap="Reds",
            linecolor = "gray",ax=ax
            )
plt.xlabel("predicted label")
plt.ylabel("True Label")
plt.title("confusion matrix")
plt.show()


y_test_inv = label_binarizer.inverse_transform(y_test)
print(classification_report(y_test_inv, Y_pred_classes, target_names = labels))
# Out:
#               precision    recall  f1-score   support
#
#    dandelion       0.76      0.85      0.80       111
#        daisy       0.93      0.76      0.84        84
#        tulip       0.74      0.67      0.71       104
#    sunflower       0.71      0.85      0.77        60
#         rose       0.63      0.63      0.63        75
#
#     accuracy                           0.75       434
#    macro avg       0.75      0.75      0.75       434
# weighted avg       0.76      0.75      0.75       434
