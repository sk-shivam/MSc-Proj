# %%
#Train Aug with for 90%(60%augmented, 20%validation) and 10%test data
import keras
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout, Flatten
from keras.layers import Conv2D
from keras.layers import MaxPooling2D,MaxPool2D
from keras.layers.normalization import BatchNormalization
from keras.optimizers import Adam
from keras.preprocessing.image import ImageDataGenerator
from keras import layers
from keras import models
from keras import optimizers

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
import os

# %%
#changing the working directory
# %cd /content/gdrive/My Drive/Thesis
# Out:
# /content/gdrive/My Drive/Thesis

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import keras
from keras.models import Sequential, Model
from keras.layers import Dense, Conv2D , MaxPool2D , Flatten , Dropout , MaxPooling2D
from keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report,confusion_matrix
from keras.applications import VGG19
import cv2
import os
import random
import tensorflow as tf
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
labels = ['dandelion', 'daisy','tulip','sunflower','rose']
img_size = 150
def get_data(data_dir):
    data = [] 
    for label in labels: 
        path = os.path.join(data_dir, label)
        class_num = labels.index(label)
        for img in os.listdir(path):
            try:
                img_arr = cv2.imread(os.path.join(path, img), cv2.IMREAD_COLOR)
                resized_arr = cv2.resize(img_arr, (img_size, img_size)) # Reshaping images to preferred size
                data.append([resized_arr, class_num])
            except Exception as e:
                print(e)
    return np.array(data)

# %%
data = get_data("/content/gdrive/My Drive/Thesis/flowers")
# Out:
# OpenCV(4.1.2) /io/opencv/modules/imgproc/src/resize.cpp:3720: error: (-215:Assertion failed) !ssize.empty() in function 'resize'
#
# OpenCV(4.1.2) /io/opencv/modules/imgproc/src/resize.cpp:3720: error: (-215:Assertion failed) !ssize.empty() in function 'resize'
#
# OpenCV(4.1.2) /io/opencv/modules/imgproc/src/resize.cpp:3720: error: (-215:Assertion failed) !ssize.empty() in function 'resize'

# %%
l = []
for i in data:
    l.append(labels[i[1]])
sns.set_style('dark')
sns.countplot(l)

# %%
fig,ax=plt.subplots(5,2)
fig.set_size_inches(15,15)
for i in range(5):
    for j in range (2):
        l=random.randint(0,len(data))
        ax[i,j].imshow(data[l][0])
        ax[i,j].set_title('Flower: '+labels[data[l][1]])
        
plt.tight_layout()

# %%
x = []
y = []

for feature, label in data:
    x.append(feature)
    y.append(label)

# %%
# Normalize the data
x = np.array(x) / 255

# %%
# Reshaping the data from 1-D to 3-D as required through input by CNN's 
x = x.reshape(-1, img_size, img_size, 3)
y = np.array(y)

# %%
from sklearn.preprocessing import LabelBinarizer
label_binarizer = LabelBinarizer()
y = label_binarizer.fit_transform(y)

# %%
x_train,x_test,y_train,y_test = train_test_split(x , y , test_size = 0.1 , random_state = 42)

# %%
x_train,x_val,y_train,y_val = train_test_split(x_train, y_train, test_size= 0.2, random_state = 42)

# %%
x_train,x_left,y_train,y_left = train_test_split(x_train, y_train, test_size= 0.25, random_state = 42)

# %%
#defining the augmentation
datagen = ImageDataGenerator(
    featurewise_center=False,  # set input mean to 0 over the dataset
    samplewise_center=False,  # set each sample mean to 0
    featurewise_std_normalization=False,  # divide inputs by std of the dataset
    samplewise_std_normalization=False,  # divide each input by its std
    rotation_range=180,  # randomly rotate images in the range (0 to 180)
    zoom_range = 0.1, # Randomly zoom image 
    width_shift_range=0.1,  # randomly shift images horizontally (fraction of total width)
    height_shift_range=0.1,
    shear_range=0.1,
    fill_mode = "reflect"
    ) 
datagen.fit(x_train)

# %%
model = Sequential()
# 1st Convolutional Layer
model.add(Conv2D(filters=64, kernel_size=(3,3),padding="Same",activation="relu" , input_shape = (150,150,3)))
model.add(MaxPool2D(pool_size=(2,2),strides=(2,2)))
model.add(BatchNormalization())
model.add(Dropout(0.2))
# 2nd Convolutional Layer
model.add(Conv2D(filters=128, kernel_size=(3,3),padding="Same",activation="relu"))
model.add(MaxPool2D(pool_size=(2,2),strides=(2,2)))
model.add(BatchNormalization())
model.add(Dropout(0.3))
# 3rd Convolutional Layer
model.add(Conv2D(filters=128, kernel_size=(3,3),padding="Same",activation="relu"))
model.add(MaxPool2D(pool_size=(2,2),strides=(2,2)))
model.add(BatchNormalization())
model.add(Dropout(0.2))
# 4th Convolutional Layer
model.add(Conv2D(filters=256, kernel_size=(3,3),padding="Same",activation="relu"))
model.add(MaxPool2D(pool_size=(2,2),strides=(2,2)))
model.add(BatchNormalization())
model.add(Dropout(0.3))
# 5th Convolutional Layer
model.add(Conv2D(filters=256,kernel_size = (3,3),padding="Same",activation="relu"))
model.add(MaxPool2D(pool_size=(2,2),strides=(2,2)))
model.add(BatchNormalization())
model.add(Dropout(0.2))
# 6th Convolutional Layer
model.add(Conv2D(filters=512,kernel_size = (3,3),padding="Same",activation="relu"))
model.add(MaxPool2D(pool_size=(2,2),strides=(2,2)))
model.add(BatchNormalization())
model.add(Dropout(0.2))

model.add(Flatten())
# 1st Fully Connected Layer
model.add(Dense(1024,activation="relu"))
model.add(Dropout(0.5))
model.add(BatchNormalization())
# Output layer
model.add(Dense(5,activation="softmax"))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 150, 150, 64)      1792
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 75, 75, 64)        0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 75, 75, 64)        256
# _________________________________________________________________
# dropout (Dropout)            (None, 75, 75, 64)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 75, 75, 128)       73856
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 37, 37, 128)       0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 37, 37, 128)       512
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 37, 37, 128)       0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 37, 37, 128)       147584
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 18, 18, 128)       0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 18, 18, 128)       512
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 18, 18, 128)       0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 18, 18, 256)       295168
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 9, 9, 256)         0
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 9, 9, 256)         1024
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 9, 9, 256)         0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 9, 9, 256)         590080
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 4, 4, 256)         0
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 4, 4, 256)         1024
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 4, 4, 256)         0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 4, 4, 512)         1180160
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 2, 2, 512)         0
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 2, 2, 512)         2048
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 2, 2, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 2048)              0
# _________________________________________________________________
# dense (Dense)                (None, 1024)              2098176
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 1024)              4096
# _________________________________________________________________
# dense_1 (Dense)              (None, 5)                 5125
# =================================================================
# Total params: 4,401,413
# Trainable params: 4,396,677
# Non-trainable params: 4,736
# _________________________________________________________________

# %%
#defining early stopping
from keras.callbacks import ReduceLROnPlateau
learning_rate = ReduceLROnPlateau(monitor='val_accuracy', patience = 3, verbose=1,factor=0.5, min_lr=0.000001)

es = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss', patience=10, verbose=1, mode='min')

# %%
# !pip install h5py
	
	
mc = tf.keras.callbacks.ModelCheckpoint('best_model.h5', monitor='val_accuracy', mode='max', verbose=1, save_best_only=True)
# Out:
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (2.10.0)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from h5py) (1.15.0)
# Requirement already satisfied: numpy>=1.7 in /usr/local/lib/python3.6/dist-packages (from h5py) (1.18.5)

# %%
model.compile(optimizer = "adam" , loss = 'categorical_crossentropy' , metrics = ['accuracy'])

# %%
#Fitting the augmentation data
history = model.fit(datagen.flow(x_train, y_train, batch_size=32), epochs=100, validation_data = (x_val, y_val), callbacks = [learning_rate,es,mc])
# Out:
# Epoch 1/100
# 74/74 [==============================] - ETA: 0s - loss: 1.8173 - accuracy: 0.4027
# Epoch 00001: val_accuracy improved from -inf to 0.21282, saving model to best_model.h5
# 74/74 [==============================] - 345s 5s/step - loss: 1.8173 - accuracy: 0.4027 - val_loss: 5.7510 - val_accuracy: 0.2128
# Epoch 2/100
# 74/74 [==============================] - ETA: 0s - loss: 1.3756 - accuracy: 0.5036
# Epoch 00002: val_accuracy improved from 0.21282 to 0.25256, saving model to best_model.h5
# 74/74 [==============================] - 346s 5s/step - loss: 1.3756 - accuracy: 0.5036 - val_loss: 2.4624 - val_accuracy: 0.2526
# Epoch 3/100
# 74/74 [==============================] - ETA: 0s - loss: 1.2342 - accuracy: 0.5430
# Epoch 00003: val_accuracy did not improve from 0.25256
# 74/74 [==============================] - 345s 5s/step - loss: 1.2342 - accuracy: 0.5430 - val_loss: 3.6067 - val_accuracy: 0.1731
# Epoch 4/100
# 74/74 [==============================] - ETA: 0s - loss: 1.1703 - accuracy: 0.5472
# Epoch 00004: val_accuracy did not improve from 0.25256
# 74/74 [==============================] - 346s 5s/step - loss: 1.1703 - accuracy: 0.5472 - val_loss: 2.9261 - val_accuracy: 0.2128
# Epoch 5/100
# 74/74 [==============================] - ETA: 0s - loss: 1.0415 - accuracy: 0.5968
# Epoch 00005: val_accuracy improved from 0.25256 to 0.26154, saving model to best_model.h5
# 74/74 [==============================] - 344s 5s/step - loss: 1.0415 - accuracy: 0.5968 - val_loss: 2.1350 - val_accuracy: 0.2615
# Epoch 6/100
# 74/74 [==============================] - ETA: 0s - loss: 1.0741 - accuracy: 0.5960
# Epoch 00006: val_accuracy did not improve from 0.26154
# 74/74 [==============================] - 345s 5s/step - loss: 1.0741 - accuracy: 0.5960 - val_loss: 4.8914 - val_accuracy: 0.2128
# Epoch 7/100
# 74/74 [==============================] - ETA: 0s - loss: 1.0566 - accuracy: 0.5917
# Epoch 00007: val_accuracy improved from 0.26154 to 0.35769, saving model to best_model.h5
# 74/74 [==============================] - 346s 5s/step - loss: 1.0566 - accuracy: 0.5917 - val_loss: 2.1574 - val_accuracy: 0.3577
# Epoch 8/100
# 74/74 [==============================] - ETA: 0s - loss: 1.0619 - accuracy: 0.5883
# Epoch 00008: val_accuracy did not improve from 0.35769
# 74/74 [==============================] - 344s 5s/step - loss: 1.0619 - accuracy: 0.5883 - val_loss: 2.3577 - val_accuracy: 0.3321
# Epoch 9/100
# 74/74 [==============================] - ETA: 0s - loss: 0.9483 - accuracy: 0.6238
# Epoch 00009: val_accuracy did not improve from 0.35769
# 74/74 [==============================] - 344s 5s/step - loss: 0.9483 - accuracy: 0.6238 - val_loss: 2.7389 - val_accuracy: 0.3308
# Epoch 10/100
# 74/74 [==============================] - ETA: 0s - loss: 1.0809 - accuracy: 0.5746
# Epoch 00010: val_accuracy improved from 0.35769 to 0.58205, saving model to best_model.h5
# 74/74 [==============================] - 342s 5s/step - loss: 1.0809 - accuracy: 0.5746 - val_loss: 1.1272 - val_accuracy: 0.5821
# Epoch 11/100
# 74/74 [==============================] - ETA: 0s - loss: 0.9968 - accuracy: 0.6139
# Epoch 00011: val_accuracy improved from 0.58205 to 0.59872, saving model to best_model.h5
# 74/74 [==============================] - 343s 5s/step - loss: 0.9968 - accuracy: 0.6139 - val_loss: 1.1948 - val_accuracy: 0.5987
# Epoch 12/100
# 74/74 [==============================] - ETA: 0s - loss: 0.9802 - accuracy: 0.6195
# Epoch 00012: val_accuracy improved from 0.59872 to 0.61538, saving model to best_model.h5
# 74/74 [==============================] - 342s 5s/step - loss: 0.9802 - accuracy: 0.6195 - val_loss: 1.0094 - val_accuracy: 0.6154
# Epoch 13/100
# 74/74 [==============================] - ETA: 0s - loss: 0.9052 - accuracy: 0.6340
# Epoch 00013: val_accuracy improved from 0.61538 to 0.63718, saving model to best_model.h5
# 74/74 [==============================] - 344s 5s/step - loss: 0.9052 - accuracy: 0.6340 - val_loss: 0.9035 - val_accuracy: 0.6372
# Epoch 14/100
# 74/74 [==============================] - ETA: 0s - loss: 0.8933 - accuracy: 0.6601
# Epoch 00014: val_accuracy improved from 0.63718 to 0.67051, saving model to best_model.h5
# 74/74 [==============================] - 343s 5s/step - loss: 0.8933 - accuracy: 0.6601 - val_loss: 0.9003 - val_accuracy: 0.6705
# Epoch 15/100
# 74/74 [==============================] - ETA: 0s - loss: 1.0133 - accuracy: 0.5956
# Epoch 00015: val_accuracy did not improve from 0.67051
# 74/74 [==============================] - 341s 5s/step - loss: 1.0133 - accuracy: 0.5956 - val_loss: 1.3717 - val_accuracy: 0.5359
# Epoch 16/100
# 74/74 [==============================] - ETA: 0s - loss: 0.9525 - accuracy: 0.6204
# Epoch 00016: val_accuracy did not improve from 0.67051
# 74/74 [==============================] - 341s 5s/step - loss: 0.9525 - accuracy: 0.6204 - val_loss: 0.9143 - val_accuracy: 0.6269
# Epoch 17/100
# 74/74 [==============================] - ETA: 0s - loss: 0.9610 - accuracy: 0.6233
# Epoch 00017: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00017: val_accuracy did not improve from 0.67051
# 74/74 [==============================] - 341s 5s/step - loss: 0.9610 - accuracy: 0.6233 - val_loss: 0.9773 - val_accuracy: 0.5987
# Epoch 18/100
# 74/74 [==============================] - ETA: 0s - loss: 0.8774 - accuracy: 0.6528
# Epoch 00018: val_accuracy did not improve from 0.67051
# 74/74 [==============================] - 341s 5s/step - loss: 0.8774 - accuracy: 0.6528 - val_loss: 0.8569 - val_accuracy: 0.6474
# Epoch 19/100
# 74/74 [==============================] - ETA: 0s - loss: 0.8375 - accuracy: 0.6657
# Epoch 00019: val_accuracy did not improve from 0.67051
# 74/74 [==============================] - 340s 5s/step - loss: 0.8375 - accuracy: 0.6657 - val_loss: 0.8554 - val_accuracy: 0.6641
# Epoch 20/100
# 74/74 [==============================] - ETA: 0s - loss: 0.8090 - accuracy: 0.6832
# Epoch 00020: val_accuracy improved from 0.67051 to 0.67179, saving model to best_model.h5
# 74/74 [==============================] - 342s 5s/step - loss: 0.8090 - accuracy: 0.6832 - val_loss: 0.8466 - val_accuracy: 0.6718
# Epoch 21/100
# 74/74 [==============================] - ETA: 0s - loss: 0.8492 - accuracy: 0.6691
# Epoch 00021: val_accuracy did not improve from 0.67179
# 74/74 [==============================] - 341s 5s/step - loss: 0.8492 - accuracy: 0.6691 - val_loss: 0.9358 - val_accuracy: 0.6385
# Epoch 22/100
# 74/74 [==============================] - ETA: 0s - loss: 0.8540 - accuracy: 0.6614
# Epoch 00022: val_accuracy did not improve from 0.67179
# 74/74 [==============================] - 336s 5s/step - loss: 0.8540 - accuracy: 0.6614 - val_loss: 0.8641 - val_accuracy: 0.6654
# Epoch 23/100
# 74/74 [==============================] - ETA: 0s - loss: 0.8055 - accuracy: 0.6811
# Epoch 00023: val_accuracy improved from 0.67179 to 0.68846, saving model to best_model.h5
# 74/74 [==============================] - 321s 4s/step - loss: 0.8055 - accuracy: 0.6811 - val_loss: 0.8062 - val_accuracy: 0.6885
# Epoch 24/100
# 74/74 [==============================] - ETA: 0s - loss: 0.7876 - accuracy: 0.6776
# Epoch 00024: val_accuracy did not improve from 0.68846
# 74/74 [==============================] - 321s 4s/step - loss: 0.7876 - accuracy: 0.6776 - val_loss: 0.8425 - val_accuracy: 0.6667
# Epoch 25/100
# 74/74 [==============================] - ETA: 0s - loss: 0.8352 - accuracy: 0.6644
# Epoch 00025: val_accuracy did not improve from 0.68846
# 74/74 [==============================] - 322s 4s/step - loss: 0.8352 - accuracy: 0.6644 - val_loss: 1.0051 - val_accuracy: 0.6282
# Epoch 26/100
# 74/74 [==============================] - ETA: 0s - loss: 0.7681 - accuracy: 0.6879
# Epoch 00026: val_accuracy improved from 0.68846 to 0.68974, saving model to best_model.h5
# 74/74 [==============================] - 320s 4s/step - loss: 0.7681 - accuracy: 0.6879 - val_loss: 0.8125 - val_accuracy: 0.6897
# Epoch 27/100
# 74/74 [==============================] - ETA: 0s - loss: 0.7454 - accuracy: 0.7020
# Epoch 00027: val_accuracy did not improve from 0.68974
# 74/74 [==============================] - 320s 4s/step - loss: 0.7454 - accuracy: 0.7020 - val_loss: 0.7986 - val_accuracy: 0.6718
# Epoch 28/100
# 74/74 [==============================] - ETA: 0s - loss: 0.7584 - accuracy: 0.6952
# Epoch 00028: val_accuracy did not improve from 0.68974
# 74/74 [==============================] - 321s 4s/step - loss: 0.7584 - accuracy: 0.6952 - val_loss: 0.8423 - val_accuracy: 0.6808
# Epoch 29/100
# 74/74 [==============================] - ETA: 0s - loss: 0.7464 - accuracy: 0.7050
# Epoch 00029: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 00029: val_accuracy did not improve from 0.68974
# 74/74 [==============================] - 322s 4s/step - loss: 0.7464 - accuracy: 0.7050 - val_loss: 0.8421 - val_accuracy: 0.6744
# Epoch 30/100
# 74/74 [==============================] - ETA: 0s - loss: 0.7130 - accuracy: 0.7212
# Epoch 00030: val_accuracy improved from 0.68974 to 0.73590, saving model to best_model.h5
# 74/74 [==============================] - 320s 4s/step - loss: 0.7130 - accuracy: 0.7212 - val_loss: 0.7163 - val_accuracy: 0.7359
# Epoch 31/100
# 74/74 [==============================] - ETA: 0s - loss: 0.6998 - accuracy: 0.7187
# Epoch 00031: val_accuracy did not improve from 0.73590
# 74/74 [==============================] - 319s 4s/step - loss: 0.6998 - accuracy: 0.7187 - val_loss: 0.7973 - val_accuracy: 0.6949
# Epoch 32/100
# 74/74 [==============================] - ETA: 0s - loss: 0.6817 - accuracy: 0.7294
# Epoch 00032: val_accuracy did not improve from 0.73590
# 74/74 [==============================] - 319s 4s/step - loss: 0.6817 - accuracy: 0.7294 - val_loss: 0.7151 - val_accuracy: 0.7256
# Epoch 33/100
# 74/74 [==============================] - ETA: 0s - loss: 0.6588 - accuracy: 0.7482
# Epoch 00033: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 00033: val_accuracy did not improve from 0.73590
# 74/74 [==============================] - 321s 4s/step - loss: 0.6588 - accuracy: 0.7482 - val_loss: 0.7620 - val_accuracy: 0.7269
# Epoch 34/100
# 74/74 [==============================] - ETA: 0s - loss: 0.6480 - accuracy: 0.7512
# Epoch 00034: val_accuracy did not improve from 0.73590
# 74/74 [==============================] - 320s 4s/step - loss: 0.6480 - accuracy: 0.7512 - val_loss: 0.7470 - val_accuracy: 0.7205
# Epoch 35/100
# 74/74 [==============================] - ETA: 0s - loss: 0.6641 - accuracy: 0.7388
# Epoch 00035: val_accuracy did not improve from 0.73590
# 74/74 [==============================] - 321s 4s/step - loss: 0.6641 - accuracy: 0.7388 - val_loss: 0.7564 - val_accuracy: 0.7333
# Epoch 36/100
# 74/74 [==============================] - ETA: 0s - loss: 0.6404 - accuracy: 0.7525
# Epoch 00036: val_accuracy improved from 0.73590 to 0.74744, saving model to best_model.h5
# 74/74 [==============================] - 320s 4s/step - loss: 0.6404 - accuracy: 0.7525 - val_loss: 0.7054 - val_accuracy: 0.7474
# Epoch 37/100
# 74/74 [==============================] - ETA: 0s - loss: 0.6295 - accuracy: 0.7559
# Epoch 00037: val_accuracy did not improve from 0.74744
# 74/74 [==============================] - 319s 4s/step - loss: 0.6295 - accuracy: 0.7559 - val_loss: 0.7490 - val_accuracy: 0.7154
# Epoch 38/100
# 74/74 [==============================] - ETA: 0s - loss: 0.6480 - accuracy: 0.7422
# Epoch 00038: val_accuracy did not improve from 0.74744
# 74/74 [==============================] - 322s 4s/step - loss: 0.6480 - accuracy: 0.7422 - val_loss: 0.7652 - val_accuracy: 0.7205
# Epoch 39/100
# 74/74 [==============================] - ETA: 0s - loss: 0.6404 - accuracy: 0.7431
# Epoch 00039: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
#
# Epoch 00039: val_accuracy did not improve from 0.74744
# 74/74 [==============================] - 323s 4s/step - loss: 0.6404 - accuracy: 0.7431 - val_loss: 0.6967 - val_accuracy: 0.7333
# Epoch 40/100
# 74/74 [==============================] - ETA: 0s - loss: 0.6294 - accuracy: 0.7546
# Epoch 00040: val_accuracy did not improve from 0.74744
# 74/74 [==============================] - 322s 4s/step - loss: 0.6294 - accuracy: 0.7546 - val_loss: 0.7381 - val_accuracy: 0.7423
# Epoch 41/100
# 74/74 [==============================] - ETA: 0s - loss: 0.6301 - accuracy: 0.7572
# Epoch 00041: val_accuracy did not improve from 0.74744
# 74/74 [==============================] - 320s 4s/step - loss: 0.6301 - accuracy: 0.7572 - val_loss: 0.7243 - val_accuracy: 0.7423
# Epoch 42/100
# 74/74 [==============================] - ETA: 0s - loss: 0.5999 - accuracy: 0.7602
# Epoch 00042: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
#
# Epoch 00042: val_accuracy did not improve from 0.74744
# 74/74 [==============================] - 321s 4s/step - loss: 0.5999 - accuracy: 0.7602 - val_loss: 0.7513 - val_accuracy: 0.7231
# Epoch 43/100
# 74/74 [==============================] - ETA: 0s - loss: 0.6023 - accuracy: 0.7576
# Epoch 00043: val_accuracy did not improve from 0.74744
# 74/74 [==============================] - 320s 4s/step - loss: 0.6023 - accuracy: 0.7576 - val_loss: 0.7255 - val_accuracy: 0.7397
# Epoch 44/100
# 74/74 [==============================] - ETA: 0s - loss: 0.6073 - accuracy: 0.7653
# Epoch 00044: val_accuracy did not improve from 0.74744
# 74/74 [==============================] - 320s 4s/step - loss: 0.6073 - accuracy: 0.7653 - val_loss: 0.7423 - val_accuracy: 0.7231
# Epoch 45/100
# 74/74 [==============================] - ETA: 0s - loss: 0.5834 - accuracy: 0.7717
# Epoch 00045: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
#
# Epoch 00045: val_accuracy did not improve from 0.74744
# 74/74 [==============================] - 321s 4s/step - loss: 0.5834 - accuracy: 0.7717 - val_loss: 0.7082 - val_accuracy: 0.7462
# Epoch 46/100
# 74/74 [==============================] - ETA: 0s - loss: 0.5681 - accuracy: 0.7858
# Epoch 00046: val_accuracy did not improve from 0.74744
# 74/74 [==============================] - 323s 4s/step - loss: 0.5681 - accuracy: 0.7858 - val_loss: 0.7001 - val_accuracy: 0.7449
# Epoch 47/100
# 74/74 [==============================] - ETA: 0s - loss: 0.5807 - accuracy: 0.7747
# Epoch 00047: val_accuracy did not improve from 0.74744
# 74/74 [==============================] - 319s 4s/step - loss: 0.5807 - accuracy: 0.7747 - val_loss: 0.7176 - val_accuracy: 0.7410
# Epoch 48/100
# 74/74 [==============================] - ETA: 0s - loss: 0.5596 - accuracy: 0.7850
# Epoch 00048: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
#
# Epoch 00048: val_accuracy did not improve from 0.74744
# 74/74 [==============================] - 320s 4s/step - loss: 0.5596 - accuracy: 0.7850 - val_loss: 0.7042 - val_accuracy: 0.7462
# Epoch 49/100
# 74/74 [==============================] - ETA: 0s - loss: 0.5728 - accuracy: 0.7824
# Epoch 00049: val_accuracy did not improve from 0.74744
# 74/74 [==============================] - 319s 4s/step - loss: 0.5728 - accuracy: 0.7824 - val_loss: 0.7129 - val_accuracy: 0.7436
# Epoch 00049: early stopping

# %%
import seaborn as sns
sns.set_style('darkgrid')
import matplotlib.pyplot as plt
import matplotlib.image as mimg

# %%
accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(accuracy) + 1)

f, axes = plt.subplots(1,2,figsize=(14,4))

axes[0].plot(epochs, accuracy, 'g', label='Training accuracy')
axes[0].plot(epochs, val_accuracy, 'b', label='Validation accuracy')
axes[0].legend()

axes[1].plot(epochs, loss, 'g', label='Training loss')
axes[1].plot(epochs, val_loss, 'b', label='Validation loss')
axes[1].yaxis.set_label_position("right")
axes[1].legend()

plt.show()

# %%
saved_model = tf.keras.models.load_model('best_model.h5')
print("Test Accuracy: {0:.2f}%".format(saved_model.evaluate(x_test,y_test)[1]*100)) #get score acording to test datas
# Out:
# 14/14 [==============================] - 12s 892ms/step - loss: 0.6263 - accuracy: 0.7488
# Test Accuracy: 74.88%

# %%
from sklearn.metrics import confusion_matrix
Y_pred = saved_model.predict(x_test)
Y_pred_classes = np.argmax(Y_pred,axis = 1)
Y_true = np.argmax(y_test,axis = 1)
confusion_mtx = confusion_matrix(Y_true,Y_pred_classes)
f,ax = plt.subplots(figsize = (8,8))
sns.heatmap(confusion_mtx,annot=True,linewidths = 0.01,cmap="Reds",
            linecolor = "gray",ax=ax
            )
plt.xlabel("predicted label")
plt.ylabel("True Label")
plt.title("confusion matrix")
plt.show()

from sklearn.metrics import classification_report

print(classification_report(Y_true, Y_pred_classes))


y_test_inv = label_binarizer.inverse_transform(y_test)
print(classification_report(y_test_inv, Y_pred_classes, target_names = labels))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.77      0.89      0.82       111
#            1       0.94      0.74      0.83        84
#            2       0.70      0.70      0.70       104
#            3       0.74      0.80      0.77        60
#            4       0.61      0.57      0.59        75
#
#     accuracy                           0.75       434
#    macro avg       0.75      0.74      0.74       434
# weighted avg       0.75      0.75      0.75       434
#
#               precision    recall  f1-score   support
#
#    dandelion       0.77      0.89      0.82       111
#        daisy       0.94      0.74      0.83        84
#        tulip       0.70      0.70      0.70       104
#    sunflower       0.74      0.80      0.77        60
#         rose       0.61      0.57      0.59        75
#
#     accuracy                           0.75       434
#    macro avg       0.75      0.74      0.74       434
# weighted avg       0.75      0.75      0.75       434
