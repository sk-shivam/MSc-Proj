# %%
#Train Aug for 90%(40%train augmnented,20%validation) and 10%test data
import keras
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout, Flatten
from keras.layers import Conv2D
from keras.layers import MaxPooling2D,MaxPool2D
from keras.layers.normalization import BatchNormalization
from keras.optimizers import Adam
from keras.preprocessing.image import ImageDataGenerator
from keras import layers
from keras import models
from keras import optimizers

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
import os

# %%
#changing the working directory
# %cd /content/gdrive/My Drive/Thesis
# Out:
# /content/gdrive/My Drive/Thesis

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import keras
from keras.models import Sequential, Model
from keras.layers import Dense, Conv2D , MaxPool2D , Flatten , Dropout , MaxPooling2D
from keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report,confusion_matrix
from keras.applications import VGG19
import cv2
import os
import random
import tensorflow as tf
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
labels = ['dandelion', 'daisy','tulip','sunflower','rose']
img_size = 150
def get_data(data_dir):
    data = [] 
    for label in labels: 
        path = os.path.join(data_dir, label)
        class_num = labels.index(label)
        for img in os.listdir(path):
            try:
                img_arr = cv2.imread(os.path.join(path, img), cv2.IMREAD_COLOR)
                resized_arr = cv2.resize(img_arr, (img_size, img_size)) # Reshaping images to preferred size
                data.append([resized_arr, class_num])
            except Exception as e:
                print(e)
    return np.array(data)

# %%
data = get_data("/content/gdrive/My Drive/Thesis/flowers")
# Out:
# OpenCV(4.1.2) /io/opencv/modules/imgproc/src/resize.cpp:3720: error: (-215:Assertion failed) !ssize.empty() in function 'resize'
#
# OpenCV(4.1.2) /io/opencv/modules/imgproc/src/resize.cpp:3720: error: (-215:Assertion failed) !ssize.empty() in function 'resize'
#
# OpenCV(4.1.2) /io/opencv/modules/imgproc/src/resize.cpp:3720: error: (-215:Assertion failed) !ssize.empty() in function 'resize'

# %%
l = []
for i in data:
    l.append(labels[i[1]])
sns.set_style('dark')
sns.countplot(l)

# %%
fig,ax=plt.subplots(5,2)
fig.set_size_inches(15,15)
for i in range(5):
    for j in range (2):
        l=random.randint(0,len(data))
        ax[i,j].imshow(data[l][0])
        ax[i,j].set_title('Flower: '+labels[data[l][1]])
        
plt.tight_layout()

# %%
x = []
y = []

for feature, label in data:
    x.append(feature)
    y.append(label)

# %%
# Normalize the data
x = np.array(x) / 255

# %%
# Reshaping the data from 1-D to 3-D as required through input by CNN's 
x = x.reshape(-1, img_size, img_size, 3)
y = np.array(y)

# %%
from sklearn.preprocessing import LabelBinarizer
label_binarizer = LabelBinarizer()
y = label_binarizer.fit_transform(y)

# %%
x_train,x_test,y_train,y_test = train_test_split(x , y , test_size = 0.1 , random_state = 42)

# %%
x_train,x_val,y_train,y_val = train_test_split(x_train, y_train, test_size= 0.2, random_state = 42)

# %%
x_train,x_left,y_train,y_left = train_test_split(x_train, y_train, test_size= 0.5, random_state = 42)

# %%
#defining the augmentation
datagen = ImageDataGenerator(
    featurewise_center=False,  # set input mean to 0 over the dataset
    samplewise_center=False,  # set each sample mean to 0
    featurewise_std_normalization=False,  # divide inputs by std of the dataset
    samplewise_std_normalization=False,  # divide each input by its std
    rotation_range=180,  # randomly rotate images in the range (0 to 180)
    zoom_range = 0.1, # Randomly zoom image 
    width_shift_range=0.1,  # randomly shift images horizontally (fraction of total width)
    height_shift_range=0.1,
    shear_range=0.1,
    fill_mode = "reflect"
    ) 
datagen.fit(x_train)

# %%
model = Sequential()
# 1st Convolutional Layer
model.add(Conv2D(filters=64, kernel_size=(3,3),padding="Same",activation="relu" , input_shape = (150,150,3)))
model.add(MaxPool2D(pool_size=(2,2),strides=(2,2)))
model.add(BatchNormalization())
model.add(Dropout(0.2))
# 2nd Convolutional Layer
model.add(Conv2D(filters=128, kernel_size=(3,3),padding="Same",activation="relu"))
model.add(MaxPool2D(pool_size=(2,2),strides=(2,2)))
model.add(BatchNormalization())
model.add(Dropout(0.3))
# 3rd Convolutional Layer
model.add(Conv2D(filters=128, kernel_size=(3,3),padding="Same",activation="relu"))
model.add(MaxPool2D(pool_size=(2,2),strides=(2,2)))
model.add(BatchNormalization())
model.add(Dropout(0.2))
# 4th Convolutional Layer
model.add(Conv2D(filters=256, kernel_size=(3,3),padding="Same",activation="relu"))
model.add(MaxPool2D(pool_size=(2,2),strides=(2,2)))
model.add(BatchNormalization())
model.add(Dropout(0.3))
# 5th Convolutional Layer
model.add(Conv2D(filters=256,kernel_size = (3,3),padding="Same",activation="relu"))
model.add(MaxPool2D(pool_size=(2,2),strides=(2,2)))
model.add(BatchNormalization())
model.add(Dropout(0.2))
# 6th Convolutional Layer
model.add(Conv2D(filters=512,kernel_size = (3,3),padding="Same",activation="relu"))
model.add(MaxPool2D(pool_size=(2,2),strides=(2,2)))
model.add(BatchNormalization())
model.add(Dropout(0.2))

model.add(Flatten())
# 1st Fully Connected Layer
model.add(Dense(1024,activation="relu"))
model.add(Dropout(0.5))
model.add(BatchNormalization())
# Output layer
model.add(Dense(5,activation="softmax"))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 150, 150, 64)      1792
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 75, 75, 64)        0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 75, 75, 64)        256
# _________________________________________________________________
# dropout (Dropout)            (None, 75, 75, 64)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 75, 75, 128)       73856
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 37, 37, 128)       0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 37, 37, 128)       512
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 37, 37, 128)       0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 37, 37, 128)       147584
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 18, 18, 128)       0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 18, 18, 128)       512
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 18, 18, 128)       0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 18, 18, 256)       295168
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 9, 9, 256)         0
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 9, 9, 256)         1024
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 9, 9, 256)         0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 9, 9, 256)         590080
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 4, 4, 256)         0
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 4, 4, 256)         1024
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 4, 4, 256)         0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 4, 4, 512)         1180160
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 2, 2, 512)         0
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 2, 2, 512)         2048
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 2, 2, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 2048)              0
# _________________________________________________________________
# dense (Dense)                (None, 1024)              2098176
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 1024)              4096
# _________________________________________________________________
# dense_1 (Dense)              (None, 5)                 5125
# =================================================================
# Total params: 4,401,413
# Trainable params: 4,396,677
# Non-trainable params: 4,736
# _________________________________________________________________

# %%
#defining early stopping
from keras.callbacks import ReduceLROnPlateau
learning_rate = ReduceLROnPlateau(monitor='val_accuracy', patience = 3, verbose=1,factor=0.5, min_lr=0.000001)

es = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss', patience=10, verbose=1, mode='min')

# %%
# !pip install h5py
	
	
mc = tf.keras.callbacks.ModelCheckpoint('best_model.h5', monitor='val_accuracy', mode='max', verbose=1, save_best_only=True)
# Out:
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (2.10.0)
# Requirement already satisfied: numpy>=1.7 in /usr/local/lib/python3.6/dist-packages (from h5py) (1.18.5)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from h5py) (1.15.0)

# %%
model.compile(optimizer = "adam" , loss = 'categorical_crossentropy' , metrics = ['accuracy'])

# %%
#Fitting the augmentation data
history = model.fit(datagen.flow(x_train, y_train, batch_size=32), epochs=100, validation_data = (x_val, y_val), callbacks = [learning_rate,es,mc])
# Out:
# Epoch 1/100
# 49/49 [==============================] - ETA: 0s - loss: 1.7515 - accuracy: 0.4094
# Epoch 00001: val_accuracy improved from -inf to 0.23265, saving model to best_model.h5
# 49/49 [==============================] - 232s 5s/step - loss: 1.7515 - accuracy: 0.4094 - val_loss: 5.5093 - val_accuracy: 0.2326
# Epoch 2/100
# 49/49 [==============================] - ETA: 0s - loss: 1.4823 - accuracy: 0.4467
# Epoch 00002: val_accuracy did not improve from 0.23265
# 49/49 [==============================] - 229s 5s/step - loss: 1.4823 - accuracy: 0.4467 - val_loss: 5.5548 - val_accuracy: 0.2326
# Epoch 3/100
# 49/49 [==============================] - ETA: 0s - loss: 1.3372 - accuracy: 0.5193
# Epoch 00003: val_accuracy did not improve from 0.23265
# 49/49 [==============================] - 229s 5s/step - loss: 1.3372 - accuracy: 0.5193 - val_loss: 5.3065 - val_accuracy: 0.2326
# Epoch 4/100
# 49/49 [==============================] - ETA: 0s - loss: 1.2887 - accuracy: 0.5129
# Epoch 00004: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00004: val_accuracy did not improve from 0.23265
# 49/49 [==============================] - 231s 5s/step - loss: 1.2887 - accuracy: 0.5129 - val_loss: 4.9302 - val_accuracy: 0.2326
# Epoch 5/100
# 49/49 [==============================] - ETA: 0s - loss: 1.1327 - accuracy: 0.5566
# Epoch 00005: val_accuracy improved from 0.23265 to 0.23650, saving model to best_model.h5
# 49/49 [==============================] - 231s 5s/step - loss: 1.1327 - accuracy: 0.5566 - val_loss: 2.8328 - val_accuracy: 0.2365
# Epoch 6/100
# 49/49 [==============================] - ETA: 0s - loss: 1.0559 - accuracy: 0.5848
# Epoch 00006: val_accuracy did not improve from 0.23650
# 49/49 [==============================] - 233s 5s/step - loss: 1.0559 - accuracy: 0.5848 - val_loss: 3.4128 - val_accuracy: 0.2326
# Epoch 7/100
# 49/49 [==============================] - ETA: 0s - loss: 1.0342 - accuracy: 0.5932
# Epoch 00007: val_accuracy improved from 0.23650 to 0.24165, saving model to best_model.h5
# 49/49 [==============================] - 231s 5s/step - loss: 1.0342 - accuracy: 0.5932 - val_loss: 2.1148 - val_accuracy: 0.2416
# Epoch 8/100
# 49/49 [==============================] - ETA: 0s - loss: 1.0751 - accuracy: 0.5906
# Epoch 00008: val_accuracy did not improve from 0.24165
# 49/49 [==============================] - 231s 5s/step - loss: 1.0751 - accuracy: 0.5906 - val_loss: 2.9119 - val_accuracy: 0.2391
# Epoch 9/100
# 49/49 [==============================] - ETA: 0s - loss: 1.0246 - accuracy: 0.6105
# Epoch 00009: val_accuracy improved from 0.24165 to 0.31362, saving model to best_model.h5
# 49/49 [==============================] - 234s 5s/step - loss: 1.0246 - accuracy: 0.6105 - val_loss: 2.2496 - val_accuracy: 0.3136
# Epoch 10/100
# 49/49 [==============================] - ETA: 0s - loss: 0.9647 - accuracy: 0.6202
# Epoch 00010: val_accuracy did not improve from 0.31362
# 49/49 [==============================] - 229s 5s/step - loss: 0.9647 - accuracy: 0.6202 - val_loss: 3.5167 - val_accuracy: 0.2339
# Epoch 11/100
# 49/49 [==============================] - ETA: 0s - loss: 1.0023 - accuracy: 0.6202
# Epoch 00011: val_accuracy did not improve from 0.31362
# 49/49 [==============================] - 231s 5s/step - loss: 1.0023 - accuracy: 0.6202 - val_loss: 2.0396 - val_accuracy: 0.2853
# Epoch 12/100
# 49/49 [==============================] - ETA: 0s - loss: 0.9314 - accuracy: 0.6382
# Epoch 00012: val_accuracy improved from 0.31362 to 0.36375, saving model to best_model.h5
# 49/49 [==============================] - 232s 5s/step - loss: 0.9314 - accuracy: 0.6382 - val_loss: 1.9501 - val_accuracy: 0.3638
# Epoch 13/100
# 49/49 [==============================] - ETA: 0s - loss: 0.9186 - accuracy: 0.6395
# Epoch 00013: val_accuracy improved from 0.36375 to 0.45630, saving model to best_model.h5
# 49/49 [==============================] - 233s 5s/step - loss: 0.9186 - accuracy: 0.6395 - val_loss: 1.5140 - val_accuracy: 0.4563
# Epoch 14/100
# 49/49 [==============================] - ETA: 0s - loss: 0.8560 - accuracy: 0.6620
# Epoch 00014: val_accuracy did not improve from 0.45630
# 49/49 [==============================] - 227s 5s/step - loss: 0.8560 - accuracy: 0.6620 - val_loss: 1.6789 - val_accuracy: 0.4267
# Epoch 15/100
# 49/49 [==============================] - ETA: 0s - loss: 0.8568 - accuracy: 0.6626
# Epoch 00015: val_accuracy improved from 0.45630 to 0.47558, saving model to best_model.h5
# 49/49 [==============================] - 228s 5s/step - loss: 0.8568 - accuracy: 0.6626 - val_loss: 1.5963 - val_accuracy: 0.4756
# Epoch 16/100
# 49/49 [==============================] - ETA: 0s - loss: 0.8241 - accuracy: 0.6793
# Epoch 00016: val_accuracy improved from 0.47558 to 0.58997, saving model to best_model.h5
# 49/49 [==============================] - 229s 5s/step - loss: 0.8241 - accuracy: 0.6793 - val_loss: 1.2111 - val_accuracy: 0.5900
# Epoch 17/100
# 49/49 [==============================] - ETA: 0s - loss: 0.8351 - accuracy: 0.6735
# Epoch 00017: val_accuracy improved from 0.58997 to 0.59769, saving model to best_model.h5
# 49/49 [==============================] - 228s 5s/step - loss: 0.8351 - accuracy: 0.6735 - val_loss: 1.0683 - val_accuracy: 0.5977
# Epoch 18/100
# 49/49 [==============================] - ETA: 0s - loss: 0.8428 - accuracy: 0.6774
# Epoch 00018: val_accuracy did not improve from 0.59769
# 49/49 [==============================] - 227s 5s/step - loss: 0.8428 - accuracy: 0.6774 - val_loss: 1.3529 - val_accuracy: 0.5463
# Epoch 19/100
# 49/49 [==============================] - ETA: 0s - loss: 0.8410 - accuracy: 0.6613
# Epoch 00019: val_accuracy improved from 0.59769 to 0.62596, saving model to best_model.h5
# 49/49 [==============================] - 228s 5s/step - loss: 0.8410 - accuracy: 0.6613 - val_loss: 1.0644 - val_accuracy: 0.6260
# Epoch 20/100
# 49/49 [==============================] - ETA: 0s - loss: 0.7748 - accuracy: 0.6941
# Epoch 00020: val_accuracy improved from 0.62596 to 0.65938, saving model to best_model.h5
# 49/49 [==============================] - 232s 5s/step - loss: 0.7748 - accuracy: 0.6941 - val_loss: 0.9663 - val_accuracy: 0.6594
# Epoch 21/100
# 49/49 [==============================] - ETA: 0s - loss: 0.8522 - accuracy: 0.6735
# Epoch 00021: val_accuracy did not improve from 0.65938
# 49/49 [==============================] - 231s 5s/step - loss: 0.8522 - accuracy: 0.6735 - val_loss: 1.5125 - val_accuracy: 0.5244
# Epoch 22/100
# 49/49 [==============================] - ETA: 0s - loss: 0.7831 - accuracy: 0.6902
# Epoch 00022: val_accuracy did not improve from 0.65938
# 49/49 [==============================] - 229s 5s/step - loss: 0.7831 - accuracy: 0.6902 - val_loss: 1.1031 - val_accuracy: 0.6170
# Epoch 23/100
# 49/49 [==============================] - ETA: 0s - loss: 0.8063 - accuracy: 0.6992
# Epoch 00023: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 00023: val_accuracy did not improve from 0.65938
# 49/49 [==============================] - 229s 5s/step - loss: 0.8063 - accuracy: 0.6992 - val_loss: 1.7823 - val_accuracy: 0.5154
# Epoch 24/100
# 49/49 [==============================] - ETA: 0s - loss: 0.7217 - accuracy: 0.7224
# Epoch 00024: val_accuracy improved from 0.65938 to 0.67095, saving model to best_model.h5
# 49/49 [==============================] - 231s 5s/step - loss: 0.7217 - accuracy: 0.7224 - val_loss: 0.8702 - val_accuracy: 0.6710
# Epoch 25/100
# 49/49 [==============================] - ETA: 0s - loss: 0.7127 - accuracy: 0.7256
# Epoch 00025: val_accuracy did not improve from 0.67095
# 49/49 [==============================] - 228s 5s/step - loss: 0.7127 - accuracy: 0.7256 - val_loss: 1.1367 - val_accuracy: 0.6131
# Epoch 26/100
# 49/49 [==============================] - ETA: 0s - loss: 0.6766 - accuracy: 0.7468
# Epoch 00026: val_accuracy did not improve from 0.67095
# 49/49 [==============================] - 224s 5s/step - loss: 0.6766 - accuracy: 0.7468 - val_loss: 1.3422 - val_accuracy: 0.5578
# Epoch 27/100
# 49/49 [==============================] - ETA: 0s - loss: 0.6849 - accuracy: 0.7423
# Epoch 00027: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 00027: val_accuracy did not improve from 0.67095
# 49/49 [==============================] - 224s 5s/step - loss: 0.6849 - accuracy: 0.7423 - val_loss: 0.9631 - val_accuracy: 0.6620
# Epoch 28/100
# 49/49 [==============================] - ETA: 0s - loss: 0.6455 - accuracy: 0.7667
# Epoch 00028: val_accuracy did not improve from 0.67095
# 49/49 [==============================] - 224s 5s/step - loss: 0.6455 - accuracy: 0.7667 - val_loss: 0.9817 - val_accuracy: 0.6465
# Epoch 29/100
# 49/49 [==============================] - ETA: 0s - loss: 0.6000 - accuracy: 0.7667
# Epoch 00029: val_accuracy improved from 0.67095 to 0.69280, saving model to best_model.h5
# 49/49 [==============================] - 226s 5s/step - loss: 0.6000 - accuracy: 0.7667 - val_loss: 0.8496 - val_accuracy: 0.6928
# Epoch 30/100
# 49/49 [==============================] - ETA: 0s - loss: 0.6250 - accuracy: 0.7622
# Epoch 00030: val_accuracy did not improve from 0.69280
# 49/49 [==============================] - 226s 5s/step - loss: 0.6250 - accuracy: 0.7622 - val_loss: 1.0003 - val_accuracy: 0.6401
# Epoch 31/100
# 49/49 [==============================] - ETA: 0s - loss: 0.5904 - accuracy: 0.7789
# Epoch 00031: val_accuracy did not improve from 0.69280
# 49/49 [==============================] - 226s 5s/step - loss: 0.5904 - accuracy: 0.7789 - val_loss: 0.9730 - val_accuracy: 0.6658
# Epoch 32/100
# 49/49 [==============================] - ETA: 0s - loss: 0.5962 - accuracy: 0.7674
# Epoch 00032: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
#
# Epoch 00032: val_accuracy did not improve from 0.69280
# 49/49 [==============================] - 226s 5s/step - loss: 0.5962 - accuracy: 0.7674 - val_loss: 0.9518 - val_accuracy: 0.6555
# Epoch 33/100
# 49/49 [==============================] - ETA: 0s - loss: 0.5707 - accuracy: 0.7853
# Epoch 00033: val_accuracy did not improve from 0.69280
# 49/49 [==============================] - 224s 5s/step - loss: 0.5707 - accuracy: 0.7853 - val_loss: 0.9116 - val_accuracy: 0.6838
# Epoch 34/100
# 49/49 [==============================] - ETA: 0s - loss: 0.5689 - accuracy: 0.7828
# Epoch 00034: val_accuracy did not improve from 0.69280
# 49/49 [==============================] - 226s 5s/step - loss: 0.5689 - accuracy: 0.7828 - val_loss: 1.1000 - val_accuracy: 0.6517
# Epoch 35/100
# 49/49 [==============================] - ETA: 0s - loss: 0.5706 - accuracy: 0.7808
# Epoch 00035: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
#
# Epoch 00035: val_accuracy did not improve from 0.69280
# 49/49 [==============================] - 225s 5s/step - loss: 0.5706 - accuracy: 0.7808 - val_loss: 0.9725 - val_accuracy: 0.6710
# Epoch 36/100
# 49/49 [==============================] - ETA: 0s - loss: 0.5501 - accuracy: 0.7821
# Epoch 00036: val_accuracy did not improve from 0.69280
# 49/49 [==============================] - 225s 5s/step - loss: 0.5501 - accuracy: 0.7821 - val_loss: 0.9739 - val_accuracy: 0.6671
# Epoch 37/100
# 49/49 [==============================] - ETA: 0s - loss: 0.5358 - accuracy: 0.8033
# Epoch 00037: val_accuracy did not improve from 0.69280
# 49/49 [==============================] - 227s 5s/step - loss: 0.5358 - accuracy: 0.8033 - val_loss: 0.9657 - val_accuracy: 0.6774
# Epoch 38/100
# 49/49 [==============================] - ETA: 0s - loss: 0.5347 - accuracy: 0.7918
# Epoch 00038: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
#
# Epoch 00038: val_accuracy did not improve from 0.69280
# 49/49 [==============================] - 225s 5s/step - loss: 0.5347 - accuracy: 0.7918 - val_loss: 0.9699 - val_accuracy: 0.6761
# Epoch 39/100
# 49/49 [==============================] - ETA: 0s - loss: 0.5518 - accuracy: 0.7931
# Epoch 00039: val_accuracy did not improve from 0.69280
# 49/49 [==============================] - 225s 5s/step - loss: 0.5518 - accuracy: 0.7931 - val_loss: 0.9646 - val_accuracy: 0.6748
# Epoch 00039: early stopping

# %%
import seaborn as sns
sns.set_style('darkgrid')
import matplotlib.pyplot as plt
import matplotlib.image as mimg

# %%
accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(accuracy) + 1)

f, axes = plt.subplots(1,2,figsize=(14,4))

axes[0].plot(epochs, accuracy, 'g', label='Training accuracy')
axes[0].plot(epochs, val_accuracy, 'b', label='Validation accuracy')
axes[0].legend()

axes[1].plot(epochs, loss, 'g', label='Training loss')
axes[1].plot(epochs, val_loss, 'b', label='Validation loss')
axes[1].yaxis.set_label_position("right")
axes[1].legend()

plt.show()

# %%
saved_model = tf.keras.models.load_model('best_model.h5')
print("Test Accuracy: {0:.2f}%".format(saved_model.evaluate(x_test,y_test)[1]*100)) #get score acording to test datas
# Out:
# 14/14 [==============================] - 13s 895ms/step - loss: 0.7829 - accuracy: 0.7113
# Test Accuracy: 71.13%

# %%
from sklearn.metrics import confusion_matrix
Y_pred = saved_model.predict(x_test)
Y_pred_classes = np.argmax(Y_pred,axis = 1)
Y_true = np.argmax(y_test,axis = 1)
confusion_mtx = confusion_matrix(Y_true,Y_pred_classes)
f,ax = plt.subplots(figsize = (8,8))
sns.heatmap(confusion_mtx,annot=True,linewidths = 0.01,cmap="Reds",
            linecolor = "gray",fmt = ".2f",ax=ax
            )
plt.xlabel("predicted label")
plt.ylabel("True Label")
plt.title("confusion matrix")
plt.show()



y_test_inv = label_binarizer.inverse_transform(y_test)
print(classification_report(y_test_inv, Y_pred_classes, target_names = labels))
# Out:
#               precision    recall  f1-score   support
#
#    dandelion       0.66      0.84      0.74       123
#        daisy       0.86      0.66      0.75        89
#        tulip       0.73      0.62      0.67        84
#    sunflower       0.66      0.75      0.70        67
#         rose       0.73      0.63      0.68        70
#
#     accuracy                           0.71       433
#    macro avg       0.73      0.70      0.71       433
# weighted avg       0.72      0.71      0.71       433
