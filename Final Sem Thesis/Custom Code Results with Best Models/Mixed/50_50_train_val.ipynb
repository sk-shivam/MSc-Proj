# %%
#45-45-10 with for 90%(50%augmented, 50%validation) and 10%test data
import keras
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout, Flatten
from keras.layers import Conv2D
from keras.layers import MaxPooling2D,MaxPool2D
from keras.layers.normalization import BatchNormalization
from keras.optimizers import Adam
from keras.preprocessing.image import ImageDataGenerator
from keras import layers
from keras import models
from keras import optimizers

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
import os

# %%
#changing the working directory
# %cd /content/gdrive/My Drive/Thesis
# Out:
# /content/gdrive/My Drive/Thesis

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import keras
from keras.models import Sequential, Model
from keras.layers import Dense, Conv2D , MaxPool2D , Flatten , Dropout , MaxPooling2D
from keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report,confusion_matrix
from keras.applications import VGG19
import cv2
import os
import random
import tensorflow as tf
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
labels = ['dandelion', 'daisy','tulip','sunflower','rose']
img_size = 150
def get_data(data_dir):
    data = [] 
    for label in labels: 
        path = os.path.join(data_dir, label)
        class_num = labels.index(label)
        for img in os.listdir(path):
            try:
                img_arr = cv2.imread(os.path.join(path, img), cv2.IMREAD_COLOR)
                resized_arr = cv2.resize(img_arr, (img_size, img_size)) # Reshaping images to preferred size
                data.append([resized_arr, class_num])
            except Exception as e:
                print(e)
    return np.array(data)

# %%
data = get_data("/content/gdrive/My Drive/Thesis/flowers")
# Out:
# OpenCV(4.1.2) /io/opencv/modules/imgproc/src/resize.cpp:3720: error: (-215:Assertion failed) !ssize.empty() in function 'resize'
#
# OpenCV(4.1.2) /io/opencv/modules/imgproc/src/resize.cpp:3720: error: (-215:Assertion failed) !ssize.empty() in function 'resize'
#
# OpenCV(4.1.2) /io/opencv/modules/imgproc/src/resize.cpp:3720: error: (-215:Assertion failed) !ssize.empty() in function 'resize'

# %%
l = []
for i in data:
    l.append(labels[i[1]])
sns.set_style('dark')
sns.countplot(l)

# %%
fig,ax=plt.subplots(5,2)
fig.set_size_inches(15,15)
for i in range(5):
    for j in range (2):
        l=random.randint(0,len(data))
        ax[i,j].imshow(data[l][0])
        ax[i,j].set_title('Flower: '+labels[data[l][1]])
        
plt.tight_layout()

# %%
x = []
y = []

for feature, label in data:
    x.append(feature)
    y.append(label)

# %%
# Normalize the data
x = np.array(x) / 255

# %%
# Reshaping the data from 1-D to 3-D as required through input by CNN's 
x = x.reshape(-1, img_size, img_size, 3)
y = np.array(y)

# %%
from sklearn.preprocessing import LabelBinarizer
label_binarizer = LabelBinarizer()
y = label_binarizer.fit_transform(y)

# %%
x_train,x_test,y_train,y_test = train_test_split(x , y , test_size = 0.1 , random_state = 42)

# %%
x_train,x_val,y_train,y_val = train_test_split(x_train, y_train, test_size= 0.5, random_state = 42)

# %%
#defining the augmentation
datagen = ImageDataGenerator(
    featurewise_center=False,  # set input mean to 0 over the dataset
    samplewise_center=False,  # set each sample mean to 0
    featurewise_std_normalization=False,  # divide inputs by std of the dataset
    samplewise_std_normalization=False,  # divide each input by its std
    rotation_range=30,  # randomly rotate images in the range (60, 0 to 180)
    zoom_range = 0.1, # Randomly zoom image 
    width_shift_range=0.1,  # randomly shift images horizontally (fraction of total width)
    height_shift_range=0.1,
    shear_range=0.1,
    fill_mode = "reflect"
    ) 
datagen.fit(x_train)

# %%
model = Sequential()
# 1st Convolutional Layer
model.add(Conv2D(filters=64, kernel_size=(3,3),padding="Same",activation="relu" , input_shape = (150,150,3)))
model.add(MaxPool2D(pool_size=(2,2),strides=(2,2)))
model.add(BatchNormalization())
model.add(Dropout(0.2))
# 2nd Convolutional Layer
model.add(Conv2D(filters=128, kernel_size=(3,3),padding="Same",activation="relu"))
model.add(MaxPool2D(pool_size=(2,2),strides=(2,2)))
model.add(BatchNormalization())
model.add(Dropout(0.3))
# 3rd Convolutional Layer
model.add(Conv2D(filters=128, kernel_size=(3,3),padding="Same",activation="relu"))
model.add(MaxPool2D(pool_size=(2,2),strides=(2,2)))
model.add(BatchNormalization())
model.add(Dropout(0.2))
# 4th Convolutional Layer
model.add(Conv2D(filters=256, kernel_size=(3,3),padding="Same",activation="relu"))
model.add(MaxPool2D(pool_size=(2,2),strides=(2,2)))
model.add(BatchNormalization())
model.add(Dropout(0.3))
# 5th Convolutional Layer
model.add(Conv2D(filters=256,kernel_size = (3,3),padding="Same",activation="relu"))
model.add(MaxPool2D(pool_size=(2,2),strides=(2,2)))
model.add(BatchNormalization())
model.add(Dropout(0.2))
# 6th Convolutional Layer
model.add(Conv2D(filters=512,kernel_size = (3,3),padding="Same",activation="relu"))
model.add(MaxPool2D(pool_size=(2,2),strides=(2,2)))
model.add(BatchNormalization())
model.add(Dropout(0.2))

model.add(Flatten())
# 1st Fully Connected Layer
model.add(Dense(1024,activation="relu"))
model.add(Dropout(0.5))
model.add(BatchNormalization())
# Output layer
model.add(Dense(5,activation="softmax"))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 150, 150, 64)      1792
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 75, 75, 64)        0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 75, 75, 64)        256
# _________________________________________________________________
# dropout (Dropout)            (None, 75, 75, 64)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 75, 75, 128)       73856
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 37, 37, 128)       0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 37, 37, 128)       512
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 37, 37, 128)       0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 37, 37, 128)       147584
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 18, 18, 128)       0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 18, 18, 128)       512
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 18, 18, 128)       0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 18, 18, 256)       295168
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 9, 9, 256)         0
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 9, 9, 256)         1024
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 9, 9, 256)         0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 9, 9, 256)         590080
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 4, 4, 256)         0
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 4, 4, 256)         1024
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 4, 4, 256)         0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 4, 4, 512)         1180160
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 2, 2, 512)         0
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 2, 2, 512)         2048
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 2, 2, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 2048)              0
# _________________________________________________________________
# dense (Dense)                (None, 1024)              2098176
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 1024)              4096
# _________________________________________________________________
# dense_1 (Dense)              (None, 5)                 5125
# =================================================================
# Total params: 4,401,413
# Trainable params: 4,396,677
# Non-trainable params: 4,736
# _________________________________________________________________

# %%
#defining early stopping
from keras.callbacks import ReduceLROnPlateau
learning_rate = ReduceLROnPlateau(monitor='val_accuracy', patience = 3, verbose=1,factor=0.5, min_lr=0.000001)

es = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss', patience=10, verbose=1, mode='min')

# %%
# !pip install h5py
	
	
mc = tf.keras.callbacks.ModelCheckpoint('best_model.h5', monitor='val_accuracy', mode='max', verbose=1, save_best_only=True)
# Out:
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (2.10.0)
# Requirement already satisfied: numpy>=1.7 in /usr/local/lib/python3.6/dist-packages (from h5py) (1.18.5)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from h5py) (1.15.0)

# %%
model.compile(optimizer = "adam" , loss = 'categorical_crossentropy' , metrics = ['accuracy'])

# %%
#Fitting the augmentation data
history = model.fit(datagen.flow(x_train, y_train, batch_size=32), epochs=100, validation_data = (x_val, y_val), callbacks = [learning_rate,es,mc])
# Out:
# Epoch 1/100
# 61/61 [==============================] - ETA: 0s - loss: 1.6930 - accuracy: 0.4218
# Epoch 00001: val_accuracy improved from -inf to 0.24103, saving model to best_model.h5
# 61/61 [==============================] - 258s 4s/step - loss: 1.6930 - accuracy: 0.4218 - val_loss: 4.9954 - val_accuracy: 0.2410
# Epoch 2/100
# 61/61 [==============================] - ETA: 0s - loss: 1.3918 - accuracy: 0.4823
# Epoch 00002: val_accuracy did not improve from 0.24103
# 61/61 [==============================] - 259s 4s/step - loss: 1.3918 - accuracy: 0.4823 - val_loss: 3.3319 - val_accuracy: 0.1846
# Epoch 3/100
# 61/61 [==============================] - ETA: 0s - loss: 1.2836 - accuracy: 0.5310
# Epoch 00003: val_accuracy improved from 0.24103 to 0.25026, saving model to best_model.h5
# 61/61 [==============================] - 260s 4s/step - loss: 1.2836 - accuracy: 0.5310 - val_loss: 2.7704 - val_accuracy: 0.2503
# Epoch 4/100
# 61/61 [==============================] - ETA: 0s - loss: 1.1680 - accuracy: 0.5567
# Epoch 00004: val_accuracy did not improve from 0.25026
# 61/61 [==============================] - 258s 4s/step - loss: 1.1680 - accuracy: 0.5567 - val_loss: 4.3419 - val_accuracy: 0.2410
# Epoch 5/100
# 61/61 [==============================] - ETA: 0s - loss: 1.0941 - accuracy: 0.5880
# Epoch 00005: val_accuracy did not improve from 0.25026
# 61/61 [==============================] - 259s 4s/step - loss: 1.0941 - accuracy: 0.5880 - val_loss: 3.1373 - val_accuracy: 0.2410
# Epoch 6/100
# 61/61 [==============================] - ETA: 0s - loss: 0.9780 - accuracy: 0.6275
# Epoch 00006: val_accuracy improved from 0.25026 to 0.26513, saving model to best_model.h5
# 61/61 [==============================] - 260s 4s/step - loss: 0.9780 - accuracy: 0.6275 - val_loss: 2.5566 - val_accuracy: 0.2651
# Epoch 7/100
# 61/61 [==============================] - ETA: 0s - loss: 0.9853 - accuracy: 0.6408
# Epoch 00007: val_accuracy improved from 0.26513 to 0.27436, saving model to best_model.h5
# 61/61 [==============================] - 260s 4s/step - loss: 0.9853 - accuracy: 0.6408 - val_loss: 2.8313 - val_accuracy: 0.2744
# Epoch 8/100
# 61/61 [==============================] - ETA: 0s - loss: 0.9155 - accuracy: 0.6378
# Epoch 00008: val_accuracy improved from 0.27436 to 0.41795, saving model to best_model.h5
# 61/61 [==============================] - 259s 4s/step - loss: 0.9155 - accuracy: 0.6378 - val_loss: 1.6857 - val_accuracy: 0.4179
# Epoch 9/100
# 61/61 [==============================] - ETA: 0s - loss: 0.9260 - accuracy: 0.6516
# Epoch 00009: val_accuracy improved from 0.41795 to 0.48615, saving model to best_model.h5
# 61/61 [==============================] - 259s 4s/step - loss: 0.9260 - accuracy: 0.6516 - val_loss: 1.7197 - val_accuracy: 0.4862
# Epoch 10/100
# 61/61 [==============================] - ETA: 0s - loss: 0.8314 - accuracy: 0.6783
# Epoch 00010: val_accuracy improved from 0.48615 to 0.57795, saving model to best_model.h5
# 61/61 [==============================] - 259s 4s/step - loss: 0.8314 - accuracy: 0.6783 - val_loss: 1.2529 - val_accuracy: 0.5779
# Epoch 11/100
# 61/61 [==============================] - ETA: 0s - loss: 0.8517 - accuracy: 0.6752
# Epoch 00011: val_accuracy improved from 0.57795 to 0.66256, saving model to best_model.h5
# 61/61 [==============================] - 259s 4s/step - loss: 0.8517 - accuracy: 0.6752 - val_loss: 0.9669 - val_accuracy: 0.6626
# Epoch 12/100
# 61/61 [==============================] - ETA: 0s - loss: 0.8117 - accuracy: 0.6988
# Epoch 00012: val_accuracy improved from 0.66256 to 0.69077, saving model to best_model.h5
# 61/61 [==============================] - 262s 4s/step - loss: 0.8117 - accuracy: 0.6988 - val_loss: 0.8819 - val_accuracy: 0.6908
# Epoch 13/100
# 61/61 [==============================] - ETA: 0s - loss: 0.7659 - accuracy: 0.7214
# Epoch 00013: val_accuracy did not improve from 0.69077
# 61/61 [==============================] - 267s 4s/step - loss: 0.7659 - accuracy: 0.7214 - val_loss: 0.9334 - val_accuracy: 0.6477
# Epoch 14/100
# 61/61 [==============================] - ETA: 0s - loss: 0.7505 - accuracy: 0.7142
# Epoch 00014: val_accuracy did not improve from 0.69077
# 61/61 [==============================] - 261s 4s/step - loss: 0.7505 - accuracy: 0.7142 - val_loss: 1.0945 - val_accuracy: 0.6369
# Epoch 15/100
# 61/61 [==============================] - ETA: 0s - loss: 0.7095 - accuracy: 0.7276
# Epoch 00015: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00015: val_accuracy did not improve from 0.69077
# 61/61 [==============================] - 261s 4s/step - loss: 0.7095 - accuracy: 0.7276 - val_loss: 1.2279 - val_accuracy: 0.5985
# Epoch 16/100
# 61/61 [==============================] - ETA: 0s - loss: 0.6372 - accuracy: 0.7604
# Epoch 00016: val_accuracy improved from 0.69077 to 0.73128, saving model to best_model.h5
# 61/61 [==============================] - 262s 4s/step - loss: 0.6372 - accuracy: 0.7604 - val_loss: 0.7502 - val_accuracy: 0.7313
# Epoch 17/100
# 61/61 [==============================] - ETA: 0s - loss: 0.6365 - accuracy: 0.7558
# Epoch 00017: val_accuracy improved from 0.73128 to 0.73744, saving model to best_model.h5
# 61/61 [==============================] - 262s 4s/step - loss: 0.6365 - accuracy: 0.7558 - val_loss: 0.7249 - val_accuracy: 0.7374
# Epoch 18/100
# 61/61 [==============================] - ETA: 0s - loss: 0.6070 - accuracy: 0.7635
# Epoch 00018: val_accuracy did not improve from 0.73744
# 61/61 [==============================] - 262s 4s/step - loss: 0.6070 - accuracy: 0.7635 - val_loss: 0.7628 - val_accuracy: 0.7277
# Epoch 19/100
# 61/61 [==============================] - ETA: 0s - loss: 0.5938 - accuracy: 0.7737
# Epoch 00019: val_accuracy did not improve from 0.73744
# 61/61 [==============================] - 263s 4s/step - loss: 0.5938 - accuracy: 0.7737 - val_loss: 0.7354 - val_accuracy: 0.7308
# Epoch 20/100
# 61/61 [==============================] - ETA: 0s - loss: 0.5694 - accuracy: 0.7850
# Epoch 00020: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 00020: val_accuracy did not improve from 0.73744
# 61/61 [==============================] - 261s 4s/step - loss: 0.5694 - accuracy: 0.7850 - val_loss: 0.7526 - val_accuracy: 0.7333
# Epoch 21/100
# 61/61 [==============================] - ETA: 0s - loss: 0.4890 - accuracy: 0.8235
# Epoch 00021: val_accuracy did not improve from 0.73744
# 61/61 [==============================] - 262s 4s/step - loss: 0.4890 - accuracy: 0.8235 - val_loss: 0.7972 - val_accuracy: 0.7164
# Epoch 22/100
# 61/61 [==============================] - ETA: 0s - loss: 0.4559 - accuracy: 0.8297
# Epoch 00022: val_accuracy did not improve from 0.73744
# 61/61 [==============================] - 261s 4s/step - loss: 0.4559 - accuracy: 0.8297 - val_loss: 0.7336 - val_accuracy: 0.7287
# Epoch 23/100
# 61/61 [==============================] - ETA: 0s - loss: 0.4456 - accuracy: 0.8348
# Epoch 00023: val_accuracy improved from 0.73744 to 0.74923, saving model to best_model.h5
# 61/61 [==============================] - 262s 4s/step - loss: 0.4456 - accuracy: 0.8348 - val_loss: 0.6821 - val_accuracy: 0.7492
# Epoch 24/100
# 61/61 [==============================] - ETA: 0s - loss: 0.4555 - accuracy: 0.8348
# Epoch 00024: val_accuracy did not improve from 0.74923
# 61/61 [==============================] - 258s 4s/step - loss: 0.4555 - accuracy: 0.8348 - val_loss: 0.8041 - val_accuracy: 0.7210
# Epoch 25/100
# 61/61 [==============================] - ETA: 0s - loss: 0.4224 - accuracy: 0.8450
# Epoch 00025: val_accuracy improved from 0.74923 to 0.75436, saving model to best_model.h5
# 61/61 [==============================] - 274s 4s/step - loss: 0.4224 - accuracy: 0.8450 - val_loss: 0.7040 - val_accuracy: 0.7544
# Epoch 26/100
# 61/61 [==============================] - ETA: 0s - loss: 0.4062 - accuracy: 0.8420
# Epoch 00026: val_accuracy improved from 0.75436 to 0.76000, saving model to best_model.h5
# 61/61 [==============================] - 275s 5s/step - loss: 0.4062 - accuracy: 0.8420 - val_loss: 0.6991 - val_accuracy: 0.7600
# Epoch 27/100
# 61/61 [==============================] - ETA: 0s - loss: 0.4146 - accuracy: 0.8384
# Epoch 00027: val_accuracy did not improve from 0.76000
# 61/61 [==============================] - 270s 4s/step - loss: 0.4146 - accuracy: 0.8384 - val_loss: 0.7051 - val_accuracy: 0.7564
# Epoch 28/100
# 61/61 [==============================] - ETA: 0s - loss: 0.4226 - accuracy: 0.8394
# Epoch 00028: val_accuracy did not improve from 0.76000
# 61/61 [==============================] - 270s 4s/step - loss: 0.4226 - accuracy: 0.8394 - val_loss: 0.7570 - val_accuracy: 0.7385
# Epoch 29/100
# 61/61 [==============================] - ETA: 0s - loss: 0.3741 - accuracy: 0.8630
# Epoch 00029: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 00029: val_accuracy did not improve from 0.76000
# 61/61 [==============================] - 267s 4s/step - loss: 0.3741 - accuracy: 0.8630 - val_loss: 0.7508 - val_accuracy: 0.7456
# Epoch 30/100
# 61/61 [==============================] - ETA: 0s - loss: 0.3479 - accuracy: 0.8671
# Epoch 00030: val_accuracy did not improve from 0.76000
# 61/61 [==============================] - 260s 4s/step - loss: 0.3479 - accuracy: 0.8671 - val_loss: 0.7469 - val_accuracy: 0.7431
# Epoch 31/100
# 61/61 [==============================] - ETA: 0s - loss: 0.3140 - accuracy: 0.8815
# Epoch 00031: val_accuracy improved from 0.76000 to 0.76256, saving model to best_model.h5
# 61/61 [==============================] - 259s 4s/step - loss: 0.3140 - accuracy: 0.8815 - val_loss: 0.6940 - val_accuracy: 0.7626
# Epoch 32/100
# 61/61 [==============================] - ETA: 0s - loss: 0.3084 - accuracy: 0.8861
# Epoch 00032: val_accuracy did not improve from 0.76256
# 61/61 [==============================] - 259s 4s/step - loss: 0.3084 - accuracy: 0.8861 - val_loss: 0.7158 - val_accuracy: 0.7585
# Epoch 33/100
# 61/61 [==============================] - ETA: 0s - loss: 0.3075 - accuracy: 0.8856
# Epoch 00033: val_accuracy improved from 0.76256 to 0.77077, saving model to best_model.h5
# 61/61 [==============================] - 259s 4s/step - loss: 0.3075 - accuracy: 0.8856 - val_loss: 0.7172 - val_accuracy: 0.7708
# Epoch 00033: early stopping

# %%
import seaborn as sns
sns.set_style('darkgrid')
import matplotlib.pyplot as plt
import matplotlib.image as mimg

# %%
accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(accuracy) + 1)

f, axes = plt.subplots(1,2,figsize=(14,4))

axes[0].plot(epochs, accuracy, 'g', label='Training accuracy')
axes[0].plot(epochs, val_accuracy, 'b', label='Validation accuracy')
axes[0].legend()

axes[1].plot(epochs, loss, 'g', label='Training loss')
axes[1].plot(epochs, val_loss, 'b', label='Validation loss')
axes[1].yaxis.set_label_position("right")
axes[1].legend()

plt.show()

# %%
saved_model = tf.keras.models.load_model('best_model.h5')
print("Test Accuracy: {0:.2f}%".format(saved_model.evaluate(x_test,y_test)[1]*100)) #get score acording to test datas
# Out:
# 14/14 [==============================] - 10s 684ms/step - loss: 0.6912 - accuracy: 0.7811
# Test Accuracy: 78.11%

# %%
from sklearn.metrics import confusion_matrix
Y_pred = saved_model.predict(x_test)
Y_pred_classes = np.argmax(Y_pred,axis = 1)
Y_true = np.argmax(y_test,axis = 1)
confusion_mtx = confusion_matrix(Y_true,Y_pred_classes)
f,ax = plt.subplots(figsize = (8,8))
sns.heatmap(confusion_mtx,annot=True,linewidths = 0.01,cmap="Reds",
            linecolor = "gray",ax=ax
            )
plt.xlabel("predicted label")
plt.ylabel("True Label")
plt.title("confusion matrix")
plt.show()


y_test_inv = label_binarizer.inverse_transform(y_test)
print(classification_report(y_test_inv, Y_pred_classes, target_names = labels))
# Out:
#               precision    recall  f1-score   support
#
#    dandelion       0.73      0.88      0.80       111
#        daisy       0.91      0.74      0.82        84
#        tulip       0.82      0.70      0.76       104
#    sunflower       0.78      0.87      0.82        60
#         rose       0.71      0.72      0.72        75
#
#     accuracy                           0.78       434
#    macro avg       0.79      0.78      0.78       434
# weighted avg       0.79      0.78      0.78       434
