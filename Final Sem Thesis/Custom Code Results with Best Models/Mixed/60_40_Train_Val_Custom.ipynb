# %%
#54-36-10 with for 90%(60%augmented, 40%validation) and 10%test data
import keras
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout, Flatten
from keras.layers import Conv2D
from keras.layers import MaxPooling2D,MaxPool2D
from keras.layers.normalization import BatchNormalization
from keras.optimizers import Adam
from keras.preprocessing.image import ImageDataGenerator
from keras import layers
from keras import models
from keras import optimizers

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
import os

# %%
#changing the working directory
# %cd /content/gdrive/My Drive/Thesis
# Out:
# /content/gdrive/My Drive/Thesis

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import keras
from keras.models import Sequential, Model
from keras.layers import Dense, Conv2D , MaxPool2D , Flatten , Dropout , MaxPooling2D
from keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report,confusion_matrix
from keras.applications import VGG19
import cv2
import os
import random
import tensorflow as tf
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
labels = ['dandelion', 'daisy','tulip','sunflower','rose']
img_size = 150
def get_data(data_dir):
    data = [] 
    for label in labels: 
        path = os.path.join(data_dir, label)
        class_num = labels.index(label)
        for img in os.listdir(path):
            try:
                img_arr = cv2.imread(os.path.join(path, img), cv2.IMREAD_COLOR)
                resized_arr = cv2.resize(img_arr, (img_size, img_size)) # Reshaping images to preferred size
                data.append([resized_arr, class_num])
            except Exception as e:
                print(e)
    return np.array(data)

# %%
data = get_data("/content/gdrive/My Drive/Thesis/flowers")
# Out:
# OpenCV(4.1.2) /io/opencv/modules/imgproc/src/resize.cpp:3720: error: (-215:Assertion failed) !ssize.empty() in function 'resize'
#
# OpenCV(4.1.2) /io/opencv/modules/imgproc/src/resize.cpp:3720: error: (-215:Assertion failed) !ssize.empty() in function 'resize'
#
# OpenCV(4.1.2) /io/opencv/modules/imgproc/src/resize.cpp:3720: error: (-215:Assertion failed) !ssize.empty() in function 'resize'

# %%
l = []
for i in data:
    l.append(labels[i[1]])
sns.set_style('dark')
sns.countplot(l)

# %%
fig,ax=plt.subplots(5,2)
fig.set_size_inches(15,15)
for i in range(5):
    for j in range (2):
        l=random.randint(0,len(data))
        ax[i,j].imshow(data[l][0])
        ax[i,j].set_title('Flower: '+labels[data[l][1]])
        
plt.tight_layout()

# %%
x = []
y = []

for feature, label in data:
    x.append(feature)
    y.append(label)

# %%
# Normalize the data
x = np.array(x) / 255

# %%
# Reshaping the data from 1-D to 3-D as required through input by CNN's 
x = x.reshape(-1, img_size, img_size, 3)
y = np.array(y)

# %%
from sklearn.preprocessing import LabelBinarizer
label_binarizer = LabelBinarizer()
y = label_binarizer.fit_transform(y)

# %%
x_train,x_test,y_train,y_test = train_test_split(x , y , test_size = 0.1 , random_state = 42)

# %%
x_train,x_val,y_train,y_val = train_test_split(x_train, y_train, test_size= 0.4, random_state = 42)

# %%
#defining the augmentation
datagen = ImageDataGenerator(
    featurewise_center=False,  # set input mean to 0 over the dataset
    samplewise_center=False,  # set each sample mean to 0
    featurewise_std_normalization=False,  # divide inputs by std of the dataset
    samplewise_std_normalization=False,  # divide each input by its std
    rotation_range=30,  # randomly rotate images in the range (60, 0 to 180)
    zoom_range = 0.1, # Randomly zoom image 
    width_shift_range=0.1,  # randomly shift images horizontally (fraction of total width)
    height_shift_range=0.1,
    shear_range=0.1,
    fill_mode = "reflect"
    ) 
datagen.fit(x_train)

# %%
model = Sequential()
# 1st Convolutional Layer
model.add(Conv2D(filters=64, kernel_size=(3,3),padding="Same",activation="relu" , input_shape = (150,150,3)))
model.add(MaxPool2D(pool_size=(2,2),strides=(2,2)))
model.add(BatchNormalization())
model.add(Dropout(0.2))
# 2nd Convolutional Layer
model.add(Conv2D(filters=128, kernel_size=(3,3),padding="Same",activation="relu"))
model.add(MaxPool2D(pool_size=(2,2),strides=(2,2)))
model.add(BatchNormalization())
model.add(Dropout(0.3))
# 3rd Convolutional Layer
model.add(Conv2D(filters=128, kernel_size=(3,3),padding="Same",activation="relu"))
model.add(MaxPool2D(pool_size=(2,2),strides=(2,2)))
model.add(BatchNormalization())
model.add(Dropout(0.2))
# 4th Convolutional Layer
model.add(Conv2D(filters=256, kernel_size=(3,3),padding="Same",activation="relu"))
model.add(MaxPool2D(pool_size=(2,2),strides=(2,2)))
model.add(BatchNormalization())
model.add(Dropout(0.3))
# 5th Convolutional Layer
model.add(Conv2D(filters=256,kernel_size = (3,3),padding="Same",activation="relu"))
model.add(MaxPool2D(pool_size=(2,2),strides=(2,2)))
model.add(BatchNormalization())
model.add(Dropout(0.2))
# 6th Convolutional Layer
model.add(Conv2D(filters=512,kernel_size = (3,3),padding="Same",activation="relu"))
model.add(MaxPool2D(pool_size=(2,2),strides=(2,2)))
model.add(BatchNormalization())
model.add(Dropout(0.2))

model.add(Flatten())
# 1st Fully Connected Layer
model.add(Dense(1024,activation="relu"))
model.add(Dropout(0.5))
model.add(BatchNormalization())
# Output layer
model.add(Dense(5,activation="softmax"))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 150, 150, 64)      1792
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 75, 75, 64)        0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 75, 75, 64)        256
# _________________________________________________________________
# dropout (Dropout)            (None, 75, 75, 64)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 75, 75, 128)       73856
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 37, 37, 128)       0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 37, 37, 128)       512
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 37, 37, 128)       0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 37, 37, 128)       147584
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 18, 18, 128)       0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 18, 18, 128)       512
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 18, 18, 128)       0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 18, 18, 256)       295168
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 9, 9, 256)         0
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 9, 9, 256)         1024
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 9, 9, 256)         0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 9, 9, 256)         590080
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 4, 4, 256)         0
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 4, 4, 256)         1024
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 4, 4, 256)         0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 4, 4, 512)         1180160
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 2, 2, 512)         0
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 2, 2, 512)         2048
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 2, 2, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 2048)              0
# _________________________________________________________________
# dense (Dense)                (None, 1024)              2098176
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 1024)              4096
# _________________________________________________________________
# dense_1 (Dense)              (None, 5)                 5125
# =================================================================
# Total params: 4,401,413
# Trainable params: 4,396,677
# Non-trainable params: 4,736
# _________________________________________________________________

# %%
#defining early stopping
from keras.callbacks import ReduceLROnPlateau
learning_rate = ReduceLROnPlateau(monitor='val_accuracy', patience = 3, verbose=1,factor=0.5, min_lr=0.000001)

es = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss', patience=10, verbose=1, mode='min')

# %%
# !pip install h5py
	
	
mc = tf.keras.callbacks.ModelCheckpoint('best_model.h5', monitor='val_accuracy', mode='max', verbose=1, save_best_only=True)
# Out:
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (2.10.0)
# Requirement already satisfied: numpy>=1.7 in /usr/local/lib/python3.6/dist-packages (from h5py) (1.18.5)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from h5py) (1.15.0)

# %%
model.compile(optimizer = "adam" , loss = 'categorical_crossentropy' , metrics = ['accuracy'])

# %%
#Fitting the augmentation data
history = model.fit(datagen.flow(x_train, y_train, batch_size=32), epochs=100, validation_data = (x_val, y_val), callbacks = [learning_rate,es,mc])
# Out:
# Epoch 1/100
# 74/74 [==============================] - ETA: 0s - loss: 1.6943 - accuracy: 0.4130
# Epoch 00001: val_accuracy improved from -inf to 0.25256, saving model to best_model.h5
# 74/74 [==============================] - 314s 4s/step - loss: 1.6943 - accuracy: 0.4130 - val_loss: 5.6595 - val_accuracy: 0.2526
# Epoch 2/100
# 74/74 [==============================] - ETA: 0s - loss: 1.3467 - accuracy: 0.4955
# Epoch 00002: val_accuracy improved from 0.25256 to 0.26218, saving model to best_model.h5
# 74/74 [==============================] - 316s 4s/step - loss: 1.3467 - accuracy: 0.4955 - val_loss: 4.4540 - val_accuracy: 0.2622
# Epoch 3/100
# 74/74 [==============================] - ETA: 0s - loss: 1.2661 - accuracy: 0.5237
# Epoch 00003: val_accuracy improved from 0.26218 to 0.27628, saving model to best_model.h5
# 74/74 [==============================] - 316s 4s/step - loss: 1.2661 - accuracy: 0.5237 - val_loss: 2.4153 - val_accuracy: 0.2763
# Epoch 4/100
# 74/74 [==============================] - ETA: 0s - loss: 1.1574 - accuracy: 0.5588
# Epoch 00004: val_accuracy did not improve from 0.27628
# 74/74 [==============================] - 315s 4s/step - loss: 1.1574 - accuracy: 0.5588 - val_loss: 4.1537 - val_accuracy: 0.2359
# Epoch 5/100
# 74/74 [==============================] - ETA: 0s - loss: 1.1175 - accuracy: 0.5776
# Epoch 00005: val_accuracy did not improve from 0.27628
# 74/74 [==============================] - 316s 4s/step - loss: 1.1175 - accuracy: 0.5776 - val_loss: 2.5675 - val_accuracy: 0.2538
# Epoch 6/100
# 74/74 [==============================] - ETA: 0s - loss: 1.1882 - accuracy: 0.5391
# Epoch 00006: val_accuracy improved from 0.27628 to 0.36218, saving model to best_model.h5
# 74/74 [==============================] - 315s 4s/step - loss: 1.1882 - accuracy: 0.5391 - val_loss: 2.1615 - val_accuracy: 0.3622
# Epoch 7/100
# 74/74 [==============================] - ETA: 0s - loss: 1.1944 - accuracy: 0.5289
# Epoch 00007: val_accuracy improved from 0.36218 to 0.43718, saving model to best_model.h5
# 74/74 [==============================] - 316s 4s/step - loss: 1.1944 - accuracy: 0.5289 - val_loss: 1.7520 - val_accuracy: 0.4372
# Epoch 8/100
# 74/74 [==============================] - ETA: 0s - loss: 1.0659 - accuracy: 0.5827
# Epoch 00008: val_accuracy improved from 0.43718 to 0.55513, saving model to best_model.h5
# 74/74 [==============================] - 316s 4s/step - loss: 1.0659 - accuracy: 0.5827 - val_loss: 1.1670 - val_accuracy: 0.5551
# Epoch 9/100
# 74/74 [==============================] - ETA: 0s - loss: 1.0077 - accuracy: 0.6105
# Epoch 00009: val_accuracy improved from 0.55513 to 0.59808, saving model to best_model.h5
# 74/74 [==============================] - 315s 4s/step - loss: 1.0077 - accuracy: 0.6105 - val_loss: 1.0436 - val_accuracy: 0.5981
# Epoch 10/100
# 74/74 [==============================] - ETA: 0s - loss: 0.9414 - accuracy: 0.6417
# Epoch 00010: val_accuracy improved from 0.59808 to 0.62692, saving model to best_model.h5
# 74/74 [==============================] - 315s 4s/step - loss: 0.9414 - accuracy: 0.6417 - val_loss: 0.9692 - val_accuracy: 0.6269
# Epoch 11/100
# 74/74 [==============================] - ETA: 0s - loss: 0.9062 - accuracy: 0.6486
# Epoch 00011: val_accuracy improved from 0.62692 to 0.65128, saving model to best_model.h5
# 74/74 [==============================] - 316s 4s/step - loss: 0.9062 - accuracy: 0.6486 - val_loss: 0.9704 - val_accuracy: 0.6513
# Epoch 12/100
# 74/74 [==============================] - ETA: 0s - loss: 0.8697 - accuracy: 0.6802
# Epoch 00012: val_accuracy improved from 0.65128 to 0.69936, saving model to best_model.h5
# 74/74 [==============================] - 315s 4s/step - loss: 0.8697 - accuracy: 0.6802 - val_loss: 0.8080 - val_accuracy: 0.6994
# Epoch 13/100
# 74/74 [==============================] - ETA: 0s - loss: 0.8988 - accuracy: 0.6499
# Epoch 00013: val_accuracy did not improve from 0.69936
# 74/74 [==============================] - 316s 4s/step - loss: 0.8988 - accuracy: 0.6499 - val_loss: 1.1064 - val_accuracy: 0.5910
# Epoch 14/100
# 74/74 [==============================] - ETA: 0s - loss: 0.8665 - accuracy: 0.6631
# Epoch 00014: val_accuracy did not improve from 0.69936
# 74/74 [==============================] - 314s 4s/step - loss: 0.8665 - accuracy: 0.6631 - val_loss: 1.1101 - val_accuracy: 0.6147
# Epoch 15/100
# 74/74 [==============================] - ETA: 0s - loss: 0.8068 - accuracy: 0.7024
# Epoch 00015: val_accuracy improved from 0.69936 to 0.71795, saving model to best_model.h5
# 74/74 [==============================] - 315s 4s/step - loss: 0.8068 - accuracy: 0.7024 - val_loss: 0.7752 - val_accuracy: 0.7179
# Epoch 16/100
# 74/74 [==============================] - ETA: 0s - loss: 0.8094 - accuracy: 0.6922
# Epoch 00016: val_accuracy improved from 0.71795 to 0.73397, saving model to best_model.h5
# 74/74 [==============================] - 315s 4s/step - loss: 0.8094 - accuracy: 0.6922 - val_loss: 0.7275 - val_accuracy: 0.7340
# Epoch 17/100
# 74/74 [==============================] - ETA: 0s - loss: 0.7270 - accuracy: 0.7281
# Epoch 00017: val_accuracy did not improve from 0.73397
# 74/74 [==============================] - 315s 4s/step - loss: 0.7270 - accuracy: 0.7281 - val_loss: 0.8974 - val_accuracy: 0.6853
# Epoch 18/100
# 74/74 [==============================] - ETA: 0s - loss: 0.7042 - accuracy: 0.7354
# Epoch 00018: val_accuracy did not improve from 0.73397
# 74/74 [==============================] - 315s 4s/step - loss: 0.7042 - accuracy: 0.7354 - val_loss: 0.8631 - val_accuracy: 0.7051
# Epoch 19/100
# 74/74 [==============================] - ETA: 0s - loss: 0.7754 - accuracy: 0.7067
# Epoch 00019: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00019: val_accuracy did not improve from 0.73397
# 74/74 [==============================] - 316s 4s/step - loss: 0.7754 - accuracy: 0.7067 - val_loss: 0.7801 - val_accuracy: 0.7250
# Epoch 20/100
# 74/74 [==============================] - ETA: 0s - loss: 0.6632 - accuracy: 0.7478
# Epoch 00020: val_accuracy did not improve from 0.73397
# 74/74 [==============================] - 314s 4s/step - loss: 0.6632 - accuracy: 0.7478 - val_loss: 0.7325 - val_accuracy: 0.7327
# Epoch 21/100
# 74/74 [==============================] - ETA: 0s - loss: 0.6151 - accuracy: 0.7606
# Epoch 00021: val_accuracy did not improve from 0.73397
# 74/74 [==============================] - 314s 4s/step - loss: 0.6151 - accuracy: 0.7606 - val_loss: 0.7397 - val_accuracy: 0.7333
# Epoch 22/100
# 74/74 [==============================] - ETA: 0s - loss: 0.6238 - accuracy: 0.7661
# Epoch 00022: val_accuracy improved from 0.73397 to 0.73910, saving model to best_model.h5
# 74/74 [==============================] - 315s 4s/step - loss: 0.6238 - accuracy: 0.7661 - val_loss: 0.7027 - val_accuracy: 0.7391
# Epoch 23/100
# 74/74 [==============================] - ETA: 0s - loss: 0.6089 - accuracy: 0.7713
# Epoch 00023: val_accuracy did not improve from 0.73910
# 74/74 [==============================] - 315s 4s/step - loss: 0.6089 - accuracy: 0.7713 - val_loss: 0.7371 - val_accuracy: 0.7301
# Epoch 24/100
# 74/74 [==============================] - ETA: 0s - loss: 0.5857 - accuracy: 0.7747
# Epoch 00024: val_accuracy did not improve from 0.73910
# 74/74 [==============================] - 316s 4s/step - loss: 0.5857 - accuracy: 0.7747 - val_loss: 1.0068 - val_accuracy: 0.6288
# Epoch 25/100
# 74/74 [==============================] - ETA: 0s - loss: 0.6544 - accuracy: 0.7516
# Epoch 00025: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 00025: val_accuracy did not improve from 0.73910
# 74/74 [==============================] - 314s 4s/step - loss: 0.6544 - accuracy: 0.7516 - val_loss: 1.2101 - val_accuracy: 0.6269
# Epoch 26/100
# 74/74 [==============================] - ETA: 0s - loss: 0.5897 - accuracy: 0.7661
# Epoch 00026: val_accuracy did not improve from 0.73910
# 74/74 [==============================] - 314s 4s/step - loss: 0.5897 - accuracy: 0.7661 - val_loss: 0.8087 - val_accuracy: 0.7160
# Epoch 27/100
# 74/74 [==============================] - ETA: 0s - loss: 0.5764 - accuracy: 0.7747
# Epoch 00027: val_accuracy improved from 0.73910 to 0.75833, saving model to best_model.h5
# 74/74 [==============================] - 315s 4s/step - loss: 0.5764 - accuracy: 0.7747 - val_loss: 0.6668 - val_accuracy: 0.7583
# Epoch 28/100
# 74/74 [==============================] - ETA: 0s - loss: 0.5234 - accuracy: 0.7978
# Epoch 00028: val_accuracy did not improve from 0.75833
# 74/74 [==============================] - 315s 4s/step - loss: 0.5234 - accuracy: 0.7978 - val_loss: 0.7254 - val_accuracy: 0.7397
# Epoch 29/100
# 74/74 [==============================] - ETA: 0s - loss: 0.5221 - accuracy: 0.8021
# Epoch 00029: val_accuracy did not improve from 0.75833
# 74/74 [==============================] - 315s 4s/step - loss: 0.5221 - accuracy: 0.8021 - val_loss: 0.7322 - val_accuracy: 0.7442
# Epoch 30/100
# 74/74 [==============================] - ETA: 0s - loss: 0.4900 - accuracy: 0.8243
# Epoch 00030: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 00030: val_accuracy did not improve from 0.75833
# 74/74 [==============================] - 314s 4s/step - loss: 0.4900 - accuracy: 0.8243 - val_loss: 0.6982 - val_accuracy: 0.7436
# Epoch 31/100
# 74/74 [==============================] - ETA: 0s - loss: 0.4726 - accuracy: 0.8234
# Epoch 00031: val_accuracy improved from 0.75833 to 0.77628, saving model to best_model.h5
# 74/74 [==============================] - 316s 4s/step - loss: 0.4726 - accuracy: 0.8234 - val_loss: 0.6081 - val_accuracy: 0.7763
# Epoch 32/100
# 74/74 [==============================] - ETA: 0s - loss: 0.4511 - accuracy: 0.8294
# Epoch 00032: val_accuracy did not improve from 0.77628
# 74/74 [==============================] - 315s 4s/step - loss: 0.4511 - accuracy: 0.8294 - val_loss: 0.6315 - val_accuracy: 0.7712
# Epoch 33/100
# 74/74 [==============================] - ETA: 0s - loss: 0.4596 - accuracy: 0.8294
# Epoch 00033: val_accuracy did not improve from 0.77628
# 74/74 [==============================] - 314s 4s/step - loss: 0.4596 - accuracy: 0.8294 - val_loss: 0.6303 - val_accuracy: 0.7731
# Epoch 34/100
# 74/74 [==============================] - ETA: 0s - loss: 0.4348 - accuracy: 0.8401
# Epoch 00034: val_accuracy improved from 0.77628 to 0.78013, saving model to best_model.h5
# 74/74 [==============================] - 315s 4s/step - loss: 0.4348 - accuracy: 0.8401 - val_loss: 0.6104 - val_accuracy: 0.7801
# Epoch 35/100
# 74/74 [==============================] - ETA: 0s - loss: 0.4195 - accuracy: 0.8422
# Epoch 00035: val_accuracy did not improve from 0.78013
# 74/74 [==============================] - 315s 4s/step - loss: 0.4195 - accuracy: 0.8422 - val_loss: 0.6630 - val_accuracy: 0.7564
# Epoch 36/100
# 74/74 [==============================] - ETA: 0s - loss: 0.4249 - accuracy: 0.8388
# Epoch 00036: val_accuracy did not improve from 0.78013
# 74/74 [==============================] - 314s 4s/step - loss: 0.4249 - accuracy: 0.8388 - val_loss: 0.6481 - val_accuracy: 0.7737
# Epoch 37/100
# 74/74 [==============================] - ETA: 0s - loss: 0.4439 - accuracy: 0.8354
# Epoch 00037: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
#
# Epoch 00037: val_accuracy did not improve from 0.78013
# 74/74 [==============================] - 314s 4s/step - loss: 0.4439 - accuracy: 0.8354 - val_loss: 0.6657 - val_accuracy: 0.7724
# Epoch 38/100
# 74/74 [==============================] - ETA: 0s - loss: 0.4107 - accuracy: 0.8427
# Epoch 00038: val_accuracy did not improve from 0.78013
# 74/74 [==============================] - 314s 4s/step - loss: 0.4107 - accuracy: 0.8427 - val_loss: 0.6390 - val_accuracy: 0.7750
# Epoch 39/100
# 74/74 [==============================] - ETA: 0s - loss: 0.3993 - accuracy: 0.8516
# Epoch 00039: val_accuracy did not improve from 0.78013
# 74/74 [==============================] - 314s 4s/step - loss: 0.3993 - accuracy: 0.8516 - val_loss: 0.6563 - val_accuracy: 0.7750
# Epoch 40/100
# 74/74 [==============================] - ETA: 0s - loss: 0.3868 - accuracy: 0.8521
# Epoch 00040: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
#
# Epoch 00040: val_accuracy did not improve from 0.78013
# 74/74 [==============================] - 315s 4s/step - loss: 0.3868 - accuracy: 0.8521 - val_loss: 0.6627 - val_accuracy: 0.7718
# Epoch 41/100
# 74/74 [==============================] - ETA: 0s - loss: 0.3897 - accuracy: 0.8525
# Epoch 00041: val_accuracy did not improve from 0.78013
# 74/74 [==============================] - 315s 4s/step - loss: 0.3897 - accuracy: 0.8525 - val_loss: 0.6557 - val_accuracy: 0.7692
# Epoch 00041: early stopping

# %%
import seaborn as sns
sns.set_style('darkgrid')
import matplotlib.pyplot as plt
import matplotlib.image as mimg

# %%
accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(accuracy) + 1)

f, axes = plt.subplots(1,2,figsize=(14,4))

axes[0].plot(epochs, accuracy, 'g', label='Training accuracy')
axes[0].plot(epochs, val_accuracy, 'b', label='Validation accuracy')
axes[0].legend()

axes[1].plot(epochs, loss, 'g', label='Training loss')
axes[1].plot(epochs, val_loss, 'b', label='Validation loss')
axes[1].yaxis.set_label_position("right")
axes[1].legend()

plt.show()

# %%
saved_model = tf.keras.models.load_model('best_model.h5')
print("Test Accuracy: {0:.2f}%".format(saved_model.evaluate(x_test,y_test)[1]*100)) #get score acording to test datas
# Out:
# 14/14 [==============================] - 12s 856ms/step - loss: 0.5792 - accuracy: 0.7788
# Test Accuracy: 77.88%

# %%
from sklearn.metrics import confusion_matrix
Y_pred = saved_model.predict(x_test)
Y_pred_classes = np.argmax(Y_pred,axis = 1)
Y_true = np.argmax(y_test,axis = 1)
confusion_mtx = confusion_matrix(Y_true,Y_pred_classes)
f,ax = plt.subplots(figsize = (8,8))
sns.heatmap(confusion_mtx,annot=True,linewidths = 0.01,cmap="Reds",
            linecolor = "gray",ax=ax
            )
plt.xlabel("predicted label")
plt.ylabel("True Label")
plt.title("confusion matrix")
plt.show()

from sklearn.metrics import classification_report

print(classification_report(Y_true, Y_pred_classes))


y_test_inv = label_binarizer.inverse_transform(y_test)
print(classification_report(y_test_inv, Y_pred_classes, target_names = labels))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.85      0.83       111
#            1       0.83      0.80      0.81        84
#            2       0.83      0.66      0.74       104
#            3       0.85      0.87      0.86        60
#            4       0.60      0.75      0.66        75
#
#     accuracy                           0.78       434
#    macro avg       0.78      0.78      0.78       434
# weighted avg       0.79      0.78      0.78       434
#
#               precision    recall  f1-score   support
#
#    dandelion       0.82      0.85      0.83       111
#        daisy       0.83      0.80      0.81        84
#        tulip       0.83      0.66      0.74       104
#    sunflower       0.85      0.87      0.86        60
#         rose       0.60      0.75      0.66        75
#
#     accuracy                           0.78       434
#    macro avg       0.78      0.78      0.78       434
# weighted avg       0.79      0.78      0.78       434
