# %%
#20-70-10 with for 90%(20%augmented, 80%validation) and 10%test data
import keras
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout, Flatten
from keras.layers import Conv2D
from keras.layers import MaxPooling2D,MaxPool2D
from keras.layers.normalization import BatchNormalization
from keras.optimizers import Adam
from keras.preprocessing.image import ImageDataGenerator
from keras import layers
from keras import models
from keras import optimizers

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
import os

# %%
#changing the working directory
# %cd /content/gdrive/My Drive/Thesis
# Out:
# /content/gdrive/My Drive/Thesis

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import keras
from keras.models import Sequential, Model
from keras.layers import Dense, Conv2D , MaxPool2D , Flatten , Dropout , MaxPooling2D
from keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report,confusion_matrix
from keras.applications import VGG19
import cv2
import os
import random
import tensorflow as tf
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
labels = ['dandelion', 'daisy','tulip','sunflower','rose']
img_size = 150
def get_data(data_dir):
    data = [] 
    for label in labels: 
        path = os.path.join(data_dir, label)
        class_num = labels.index(label)
        for img in os.listdir(path):
            try:
                img_arr = cv2.imread(os.path.join(path, img), cv2.IMREAD_COLOR)
                resized_arr = cv2.resize(img_arr, (img_size, img_size)) # Reshaping images to preferred size
                data.append([resized_arr, class_num])
            except Exception as e:
                print(e)
    return np.array(data)

# %%
data = get_data("/content/gdrive/My Drive/Thesis/flowers")
# Out:
# OpenCV(4.1.2) /io/opencv/modules/imgproc/src/resize.cpp:3720: error: (-215:Assertion failed) !ssize.empty() in function 'resize'
#
# OpenCV(4.1.2) /io/opencv/modules/imgproc/src/resize.cpp:3720: error: (-215:Assertion failed) !ssize.empty() in function 'resize'
#
# OpenCV(4.1.2) /io/opencv/modules/imgproc/src/resize.cpp:3720: error: (-215:Assertion failed) !ssize.empty() in function 'resize'

# %%
l = []
for i in data:
    l.append(labels[i[1]])
sns.set_style('dark')
sns.countplot(l)

# %%
fig,ax=plt.subplots(5,2)
fig.set_size_inches(15,15)
for i in range(5):
    for j in range (2):
        l=random.randint(0,len(data))
        ax[i,j].imshow(data[l][0])
        ax[i,j].set_title('Flower: '+labels[data[l][1]])
        
plt.tight_layout()

# %%
x = []
y = []

for feature, label in data:
    x.append(feature)
    y.append(label)

# %%
# Normalize the data
x = np.array(x) / 255

# %%
# Reshaping the data from 1-D to 3-D as required through input by CNN's 
x = x.reshape(-1, img_size, img_size, 3)
y = np.array(y)

# %%
from sklearn.preprocessing import LabelBinarizer
label_binarizer = LabelBinarizer()
y = label_binarizer.fit_transform(y)

# %%
x_train,x_test,y_train,y_test = train_test_split(x , y , test_size = 0.1 , random_state = 42)

# %%
x_train,x_val,y_train,y_val = train_test_split(x_train, y_train, test_size= 0.8, random_state = 42)

# %%
#defining the augmentation
datagen = ImageDataGenerator(
    featurewise_center=False,  # set input mean to 0 over the dataset
    samplewise_center=False,  # set each sample mean to 0
    featurewise_std_normalization=False,  # divide inputs by std of the dataset
    samplewise_std_normalization=False,  # divide each input by its std
    rotation_range=30,  # randomly rotate images in the range (60, 0 to 180)
    zoom_range = 0.1, # Randomly zoom image 
    width_shift_range=0.1,  # randomly shift images horizontally (fraction of total width)
    height_shift_range=0.1,
    shear_range=0.1,
    fill_mode = "reflect"
    ) 
datagen.fit(x_train)

# %%
model = Sequential()
# 1st Convolutional Layer
model.add(Conv2D(filters=64, kernel_size=(3,3),padding="Same",activation="relu" , input_shape = (150,150,3)))
model.add(MaxPool2D(pool_size=(2,2),strides=(2,2)))
model.add(BatchNormalization())
model.add(Dropout(0.2))
# 2nd Convolutional Layer
model.add(Conv2D(filters=128, kernel_size=(3,3),padding="Same",activation="relu"))
model.add(MaxPool2D(pool_size=(2,2),strides=(2,2)))
model.add(BatchNormalization())
model.add(Dropout(0.3))
# 3rd Convolutional Layer
model.add(Conv2D(filters=128, kernel_size=(3,3),padding="Same",activation="relu"))
model.add(MaxPool2D(pool_size=(2,2),strides=(2,2)))
model.add(BatchNormalization())
model.add(Dropout(0.2))
# 4th Convolutional Layer
model.add(Conv2D(filters=256, kernel_size=(3,3),padding="Same",activation="relu"))
model.add(MaxPool2D(pool_size=(2,2),strides=(2,2)))
model.add(BatchNormalization())
model.add(Dropout(0.3))
# 5th Convolutional Layer
model.add(Conv2D(filters=256,kernel_size = (3,3),padding="Same",activation="relu"))
model.add(MaxPool2D(pool_size=(2,2),strides=(2,2)))
model.add(BatchNormalization())
model.add(Dropout(0.2))
# 6th Convolutional Layer
model.add(Conv2D(filters=512,kernel_size = (3,3),padding="Same",activation="relu"))
model.add(MaxPool2D(pool_size=(2,2),strides=(2,2)))
model.add(BatchNormalization())
model.add(Dropout(0.2))

model.add(Flatten())
# 1st Fully Connected Layer
model.add(Dense(1024,activation="relu"))
model.add(Dropout(0.5))
model.add(BatchNormalization())
# Output layer
model.add(Dense(5,activation="softmax"))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 150, 150, 64)      1792
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 75, 75, 64)        0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 75, 75, 64)        256
# _________________________________________________________________
# dropout (Dropout)            (None, 75, 75, 64)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 75, 75, 128)       73856
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 37, 37, 128)       0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 37, 37, 128)       512
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 37, 37, 128)       0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 37, 37, 128)       147584
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 18, 18, 128)       0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 18, 18, 128)       512
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 18, 18, 128)       0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 18, 18, 256)       295168
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 9, 9, 256)         0
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 9, 9, 256)         1024
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 9, 9, 256)         0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 9, 9, 256)         590080
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 4, 4, 256)         0
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 4, 4, 256)         1024
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 4, 4, 256)         0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 4, 4, 512)         1180160
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 2, 2, 512)         0
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 2, 2, 512)         2048
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 2, 2, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 2048)              0
# _________________________________________________________________
# dense (Dense)                (None, 1024)              2098176
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 1024)              4096
# _________________________________________________________________
# dense_1 (Dense)              (None, 5)                 5125
# =================================================================
# Total params: 4,401,413
# Trainable params: 4,396,677
# Non-trainable params: 4,736
# _________________________________________________________________

# %%
#defining early stopping
from keras.callbacks import ReduceLROnPlateau
learning_rate = ReduceLROnPlateau(monitor='val_accuracy', patience = 3, verbose=1,factor=0.5, min_lr=0.000001)

es = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss', patience=10, verbose=1, mode='min')

# %%
# !pip install h5py
	
	
mc = tf.keras.callbacks.ModelCheckpoint('best_model.h5', monitor='val_accuracy', mode='max', verbose=1, save_best_only=True)
# Out:
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (2.10.0)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from h5py) (1.15.0)
# Requirement already satisfied: numpy>=1.7 in /usr/local/lib/python3.6/dist-packages (from h5py) (1.18.5)

# %%
model.compile(optimizer = "adam" , loss = 'categorical_crossentropy' , metrics = ['accuracy'])

# %%
#Fitting the augmentation data
history = model.fit(datagen.flow(x_train, y_train, batch_size=32), epochs=100, validation_data = (x_val, y_val), callbacks = [learning_rate,es,mc])
# Out:
# Epoch 1/100
# 25/25 [==============================] - ETA: 0s - loss: 1.2326 - accuracy: 0.5430
# Epoch 00001: val_accuracy improved from -inf to 0.45737, saving model to best_model.h5
# 25/25 [==============================] - 196s 8s/step - loss: 1.2326 - accuracy: 0.5430 - val_loss: 5.5910 - val_accuracy: 0.4574
# Epoch 2/100
# 25/25 [==============================] - ETA: 0s - loss: 1.0838 - accuracy: 0.6021
# Epoch 00002: val_accuracy improved from 0.45737 to 0.53622, saving model to best_model.h5
# 25/25 [==============================] - 196s 8s/step - loss: 1.0838 - accuracy: 0.6021 - val_loss: 3.1137 - val_accuracy: 0.5362
# Epoch 3/100
# 25/25 [==============================] - ETA: 0s - loss: 0.9949 - accuracy: 0.6470
# Epoch 00003: val_accuracy improved from 0.53622 to 0.55256, saving model to best_model.h5
# 25/25 [==============================] - 197s 8s/step - loss: 0.9949 - accuracy: 0.6470 - val_loss: 1.9940 - val_accuracy: 0.5526
# Epoch 4/100
# 25/25 [==============================] - ETA: 0s - loss: 0.9567 - accuracy: 0.6393
# Epoch 00004: val_accuracy improved from 0.55256 to 0.58846, saving model to best_model.h5
# 25/25 [==============================] - 196s 8s/step - loss: 0.9567 - accuracy: 0.6393 - val_loss: 1.9123 - val_accuracy: 0.5885
# Epoch 5/100
# 25/25 [==============================] - ETA: 0s - loss: 0.9618 - accuracy: 0.6470
# Epoch 00005: val_accuracy did not improve from 0.58846
# 25/25 [==============================] - 195s 8s/step - loss: 0.9618 - accuracy: 0.6470 - val_loss: 2.0800 - val_accuracy: 0.5471
# Epoch 6/100
# 25/25 [==============================] - ETA: 0s - loss: 0.8740 - accuracy: 0.6727
# Epoch 00006: val_accuracy improved from 0.58846 to 0.60096, saving model to best_model.h5
# 25/25 [==============================] - 197s 8s/step - loss: 0.8740 - accuracy: 0.6727 - val_loss: 1.7752 - val_accuracy: 0.6010
# Epoch 7/100
# 25/25 [==============================] - ETA: 0s - loss: 0.8554 - accuracy: 0.6919
# Epoch 00007: val_accuracy improved from 0.60096 to 0.60865, saving model to best_model.h5
# 25/25 [==============================] - 197s 8s/step - loss: 0.8554 - accuracy: 0.6919 - val_loss: 1.4783 - val_accuracy: 0.6087
# Epoch 8/100
# 25/25 [==============================] - ETA: 0s - loss: 0.7888 - accuracy: 0.7150
# Epoch 00008: val_accuracy improved from 0.60865 to 0.63173, saving model to best_model.h5
# 25/25 [==============================] - 196s 8s/step - loss: 0.7888 - accuracy: 0.7150 - val_loss: 1.4932 - val_accuracy: 0.6317
# Epoch 9/100
# 25/25 [==============================] - ETA: 0s - loss: 0.7382 - accuracy: 0.7343
# Epoch 00009: val_accuracy did not improve from 0.63173
# 25/25 [==============================] - 195s 8s/step - loss: 0.7382 - accuracy: 0.7343 - val_loss: 1.8587 - val_accuracy: 0.6199
# Epoch 10/100
# 25/25 [==============================] - ETA: 0s - loss: 0.7356 - accuracy: 0.7471
# Epoch 00010: val_accuracy did not improve from 0.63173
# 25/25 [==============================] - 195s 8s/step - loss: 0.7356 - accuracy: 0.7471 - val_loss: 1.6416 - val_accuracy: 0.6173
# Epoch 11/100
# 25/25 [==============================] - ETA: 0s - loss: 0.6331 - accuracy: 0.7664
# Epoch 00011: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00011: val_accuracy did not improve from 0.63173
# 25/25 [==============================] - 195s 8s/step - loss: 0.6331 - accuracy: 0.7664 - val_loss: 2.6032 - val_accuracy: 0.5362
# Epoch 12/100
# 25/25 [==============================] - ETA: 0s - loss: 0.6330 - accuracy: 0.7574
# Epoch 00012: val_accuracy improved from 0.63173 to 0.68173, saving model to best_model.h5
# 25/25 [==============================] - 200s 8s/step - loss: 0.6330 - accuracy: 0.7574 - val_loss: 0.9988 - val_accuracy: 0.6817
# Epoch 13/100
# 25/25 [==============================] - ETA: 0s - loss: 0.5719 - accuracy: 0.7933
# Epoch 00013: val_accuracy did not improve from 0.68173
# 25/25 [==============================] - 195s 8s/step - loss: 0.5719 - accuracy: 0.7933 - val_loss: 1.3377 - val_accuracy: 0.6333
# Epoch 14/100
# 25/25 [==============================] - ETA: 0s - loss: 0.5850 - accuracy: 0.7754
# Epoch 00014: val_accuracy did not improve from 0.68173
# 25/25 [==============================] - 195s 8s/step - loss: 0.5850 - accuracy: 0.7754 - val_loss: 1.2413 - val_accuracy: 0.6308
# Epoch 15/100
# 25/25 [==============================] - ETA: 0s - loss: 0.5245 - accuracy: 0.8087
# Epoch 00015: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 00015: val_accuracy did not improve from 0.68173
# 25/25 [==============================] - 195s 8s/step - loss: 0.5245 - accuracy: 0.8087 - val_loss: 1.1761 - val_accuracy: 0.6372
# Epoch 16/100
# 25/25 [==============================] - ETA: 0s - loss: 0.4957 - accuracy: 0.8228
# Epoch 00016: val_accuracy did not improve from 0.68173
# 25/25 [==============================] - 195s 8s/step - loss: 0.4957 - accuracy: 0.8228 - val_loss: 1.0425 - val_accuracy: 0.6798
# Epoch 17/100
# 25/25 [==============================] - ETA: 0s - loss: 0.4688 - accuracy: 0.8074
# Epoch 00017: val_accuracy did not improve from 0.68173
# 25/25 [==============================] - 195s 8s/step - loss: 0.4688 - accuracy: 0.8074 - val_loss: 0.9619 - val_accuracy: 0.6721
# Epoch 18/100
# 25/25 [==============================] - ETA: 0s - loss: 0.4154 - accuracy: 0.8395
# Epoch 00018: val_accuracy improved from 0.68173 to 0.69103, saving model to best_model.h5
# 25/25 [==============================] - 197s 8s/step - loss: 0.4154 - accuracy: 0.8395 - val_loss: 0.9201 - val_accuracy: 0.6910
# Epoch 19/100
# 25/25 [==============================] - ETA: 0s - loss: 0.3631 - accuracy: 0.8703
# Epoch 00019: val_accuracy did not improve from 0.69103
# 25/25 [==============================] - 195s 8s/step - loss: 0.3631 - accuracy: 0.8703 - val_loss: 0.9540 - val_accuracy: 0.6788
# Epoch 20/100
# 25/25 [==============================] - ETA: 0s - loss: 0.4399 - accuracy: 0.8370
# Epoch 00020: val_accuracy did not improve from 0.69103
# 25/25 [==============================] - 195s 8s/step - loss: 0.4399 - accuracy: 0.8370 - val_loss: 0.9421 - val_accuracy: 0.6843
# Epoch 21/100
# 25/25 [==============================] - ETA: 0s - loss: 0.3871 - accuracy: 0.8498
# Epoch 00021: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 00021: val_accuracy did not improve from 0.69103
# 25/25 [==============================] - 197s 8s/step - loss: 0.3871 - accuracy: 0.8498 - val_loss: 0.9645 - val_accuracy: 0.6795
# Epoch 22/100
# 25/25 [==============================] - ETA: 0s - loss: 0.3528 - accuracy: 0.8665
# Epoch 00022: val_accuracy improved from 0.69103 to 0.69519, saving model to best_model.h5
# 25/25 [==============================] - 196s 8s/step - loss: 0.3528 - accuracy: 0.8665 - val_loss: 0.9012 - val_accuracy: 0.6952
# Epoch 23/100
# 25/25 [==============================] - ETA: 0s - loss: 0.3030 - accuracy: 0.8947
# Epoch 00023: val_accuracy improved from 0.69519 to 0.69968, saving model to best_model.h5
# 25/25 [==============================] - 196s 8s/step - loss: 0.3030 - accuracy: 0.8947 - val_loss: 0.8795 - val_accuracy: 0.6997
# Epoch 24/100
# 25/25 [==============================] - ETA: 0s - loss: 0.3145 - accuracy: 0.8896
# Epoch 00024: val_accuracy improved from 0.69968 to 0.70096, saving model to best_model.h5
# 25/25 [==============================] - 197s 8s/step - loss: 0.3145 - accuracy: 0.8896 - val_loss: 0.9102 - val_accuracy: 0.7010
# Epoch 25/100
# 25/25 [==============================] - ETA: 0s - loss: 0.2780 - accuracy: 0.8935
# Epoch 00025: val_accuracy did not improve from 0.70096
# 25/25 [==============================] - 196s 8s/step - loss: 0.2780 - accuracy: 0.8935 - val_loss: 0.9198 - val_accuracy: 0.6952
# Epoch 26/100
# 25/25 [==============================] - ETA: 0s - loss: 0.3069 - accuracy: 0.8883
# Epoch 00026: val_accuracy improved from 0.70096 to 0.70353, saving model to best_model.h5
# 25/25 [==============================] - 197s 8s/step - loss: 0.3069 - accuracy: 0.8883 - val_loss: 0.8969 - val_accuracy: 0.7035
# Epoch 27/100
# 25/25 [==============================] - ETA: 0s - loss: 0.2909 - accuracy: 0.8909
# Epoch 00027: val_accuracy did not improve from 0.70353
# 25/25 [==============================] - 196s 8s/step - loss: 0.2909 - accuracy: 0.8909 - val_loss: 0.9293 - val_accuracy: 0.6994
# Epoch 28/100
# 25/25 [==============================] - ETA: 0s - loss: 0.3300 - accuracy: 0.8832
# Epoch 00028: val_accuracy did not improve from 0.70353
# 25/25 [==============================] - 195s 8s/step - loss: 0.3300 - accuracy: 0.8832 - val_loss: 0.9410 - val_accuracy: 0.6978
# Epoch 29/100
# 25/25 [==============================] - ETA: 0s - loss: 0.2677 - accuracy: 0.9076
# Epoch 00029: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
#
# Epoch 00029: val_accuracy did not improve from 0.70353
# 25/25 [==============================] - 195s 8s/step - loss: 0.2677 - accuracy: 0.9076 - val_loss: 0.9474 - val_accuracy: 0.7022
# Epoch 30/100
# 25/25 [==============================] - ETA: 0s - loss: 0.2960 - accuracy: 0.8896
# Epoch 00030: val_accuracy did not improve from 0.70353
# 25/25 [==============================] - 196s 8s/step - loss: 0.2960 - accuracy: 0.8896 - val_loss: 0.9571 - val_accuracy: 0.6994
# Epoch 31/100
# 25/25 [==============================] - ETA: 0s - loss: 0.2430 - accuracy: 0.9153
# Epoch 00031: val_accuracy did not improve from 0.70353
# 25/25 [==============================] - 195s 8s/step - loss: 0.2430 - accuracy: 0.9153 - val_loss: 0.9412 - val_accuracy: 0.7022
# Epoch 32/100
# 25/25 [==============================] - ETA: 0s - loss: 0.2594 - accuracy: 0.9050
# Epoch 00032: val_accuracy improved from 0.70353 to 0.70577, saving model to best_model.h5
# 25/25 [==============================] - 196s 8s/step - loss: 0.2594 - accuracy: 0.9050 - val_loss: 0.9441 - val_accuracy: 0.7058
# Epoch 33/100
# 25/25 [==============================] - ETA: 0s - loss: 0.2493 - accuracy: 0.9063
# Epoch 00033: val_accuracy did not improve from 0.70577
# 25/25 [==============================] - 196s 8s/step - loss: 0.2493 - accuracy: 0.9063 - val_loss: 0.9530 - val_accuracy: 0.7026
# Epoch 00033: early stopping

# %%
import seaborn as sns
sns.set_style('darkgrid')
import matplotlib.pyplot as plt
import matplotlib.image as mimg

# %%
accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(accuracy) + 1)

f, axes = plt.subplots(1,2,figsize=(14,4))

axes[0].plot(epochs, accuracy, 'g', label='Training accuracy')
axes[0].plot(epochs, val_accuracy, 'b', label='Validation accuracy')
axes[0].legend()

axes[1].plot(epochs, loss, 'g', label='Training loss')
axes[1].plot(epochs, val_loss, 'b', label='Validation loss')
axes[1].yaxis.set_label_position("right")
axes[1].legend()

plt.show()

# %%
saved_model = tf.keras.models.load_model('best_model.h5')
print("Test Accuracy: {0:.2f}%".format(saved_model.evaluate(x_test,y_test)[1]*100)) #get score acording to test datas
# Out:
# 14/14 [==============================] - 13s 910ms/step - loss: 0.8916 - accuracy: 0.7258
# Test Accuracy: 72.58%

# %%
from sklearn.metrics import confusion_matrix
Y_pred = saved_model.predict(x_test)
Y_pred_classes = np.argmax(Y_pred,axis = 1)
Y_true = np.argmax(y_test,axis = 1)
confusion_mtx = confusion_matrix(Y_true,Y_pred_classes)
f,ax = plt.subplots(figsize = (8,8))
sns.heatmap(confusion_mtx,annot=True,linewidths = 0.01,cmap="Reds",
            linecolor = "gray",fmt = ".2f",ax=ax
            )
plt.xlabel("predicted label")
plt.ylabel("True Label")
plt.title("confusion matrix")
plt.show()


y_test_inv = label_binarizer.inverse_transform(y_test)
print(classification_report(y_test_inv, Y_pred_classes, target_names = labels))
# Out:
#               precision    recall  f1-score   support
#
#    dandelion       0.81      0.77      0.79       111
#        daisy       0.78      0.73      0.75        84
#        tulip       0.69      0.68      0.69       104
#    sunflower       0.77      0.85      0.81        60
#         rose       0.57      0.63      0.60        75
#
#     accuracy                           0.73       434
#    macro avg       0.73      0.73      0.73       434
# weighted avg       0.73      0.73      0.73       434
