# %%
#90-10 with for 90%(80%training,20%validation augmented) and 10%test data
import keras
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout, Flatten
from keras.layers import Conv2D
from keras.layers import MaxPooling2D,MaxPool2D
from keras.layers.normalization import BatchNormalization
from keras.optimizers import Adam
from keras.preprocessing.image import ImageDataGenerator
from keras import layers
from keras import models
from keras import optimizers

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
import os

# %%
#changing the working directory
# %cd /content/gdrive/My Drive/Thesis
# Out:
# /content/gdrive/My Drive/Thesis

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import keras
from keras.models import Sequential, Model
from keras.layers import Dense, Conv2D , MaxPool2D , Flatten , Dropout , MaxPooling2D
from keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report,confusion_matrix
from keras.applications import VGG19
import cv2
import os
import random
import tensorflow as tf
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
labels = ['dandelion', 'daisy','tulip','sunflower','rose']
img_size = 150
def get_data(data_dir):
    data = [] 
    for label in labels: 
        path = os.path.join(data_dir, label)
        class_num = labels.index(label)
        for img in os.listdir(path):
            try:
                img_arr = cv2.imread(os.path.join(path, img), cv2.IMREAD_COLOR)
                resized_arr = cv2.resize(img_arr, (img_size, img_size)) # Reshaping images to preferred size
                data.append([resized_arr, class_num])
            except Exception as e:
                print(e)
    return np.array(data)

# %%
data = get_data("/content/gdrive/My Drive/Thesis/flowers")
# Out:
# OpenCV(4.1.2) /io/opencv/modules/imgproc/src/resize.cpp:3720: error: (-215:Assertion failed) !ssize.empty() in function 'resize'
#
# OpenCV(4.1.2) /io/opencv/modules/imgproc/src/resize.cpp:3720: error: (-215:Assertion failed) !ssize.empty() in function 'resize'
#
# OpenCV(4.1.2) /io/opencv/modules/imgproc/src/resize.cpp:3720: error: (-215:Assertion failed) !ssize.empty() in function 'resize'

# %%
l = []
for i in data:
    l.append(labels[i[1]])
sns.set_style('dark')
sns.countplot(l)

# %%
fig,ax=plt.subplots(5,2)
fig.set_size_inches(15,15)
for i in range(5):
    for j in range (2):
        l=random.randint(0,len(data))
        ax[i,j].imshow(data[l][0])
        ax[i,j].set_title('Flower: '+labels[data[l][1]])
        
plt.tight_layout()

# %%
x = []
y = []

for feature, label in data:
    x.append(feature)
    y.append(label)

# %%
# Normalize the data
x = np.array(x) / 255

# %%
# Reshaping the data from 1-D to 3-D as required through input by CNN's 
x = x.reshape(-1, img_size, img_size, 3)
y = np.array(y)

# %%
from sklearn.preprocessing import LabelBinarizer
label_binarizer = LabelBinarizer()
y = label_binarizer.fit_transform(y)

# %%
x_train,x_test,y_train,y_test = train_test_split(x , y , test_size = 0.1 , random_state = 42)

# %%
x_train,x_val,y_train,y_val = train_test_split(x_train, y_train, test_size= 0.2, random_state = 42)

# %%
#defining the augmentation
datagen = ImageDataGenerator(
    featurewise_center=False,  # set input mean to 0 over the dataset
    samplewise_center=False,  # set each sample mean to 0
    featurewise_std_normalization=False,  # divide inputs by std of the dataset
    samplewise_std_normalization=False,  # divide each input by its std
    rotation_range=30,  # randomly rotate images in the range (60, 0 to 180)
    zoom_range = 0.1, # Randomly zoom image 
    width_shift_range=0.1,  # randomly shift images horizontally (fraction of total width)
    height_shift_range=0.1,
    shear_range=0.1,
    fill_mode = "reflect"
    ) 
datagen.fit(x_train)
datagen.fit(x_val)

# %%
model = Sequential()
# 1st Convolutional Layer
model.add(Conv2D(filters=64, kernel_size=(3,3),padding="Same",activation="relu" , input_shape = (150,150,3)))
model.add(MaxPool2D(pool_size=(2,2),strides=(2,2)))
model.add(BatchNormalization())
model.add(Dropout(0.2))
# 2nd Convolutional Layer
model.add(Conv2D(filters=128, kernel_size=(3,3),padding="Same",activation="relu"))
model.add(MaxPool2D(pool_size=(2,2),strides=(2,2)))
model.add(BatchNormalization())
model.add(Dropout(0.3))
# 3rd Convolutional Layer
model.add(Conv2D(filters=128, kernel_size=(3,3),padding="Same",activation="relu"))
model.add(MaxPool2D(pool_size=(2,2),strides=(2,2)))
model.add(BatchNormalization())
model.add(Dropout(0.2))
# 4th Convolutional Layer
model.add(Conv2D(filters=256, kernel_size=(3,3),padding="Same",activation="relu"))
model.add(MaxPool2D(pool_size=(2,2),strides=(2,2)))
model.add(BatchNormalization())
model.add(Dropout(0.3))
# 5th Convolutional Layer
model.add(Conv2D(filters=256,kernel_size = (3,3),padding="Same",activation="relu"))
model.add(MaxPool2D(pool_size=(2,2),strides=(2,2)))
model.add(BatchNormalization())
model.add(Dropout(0.2))
# 6th Convolutional Layer
model.add(Conv2D(filters=512,kernel_size = (3,3),padding="Same",activation="relu"))
model.add(MaxPool2D(pool_size=(2,2),strides=(2,2)))
model.add(BatchNormalization())
model.add(Dropout(0.2))

model.add(Flatten())
# 1st Fully Connected Layer
model.add(Dense(1024,activation="relu"))
model.add(Dropout(0.5))
model.add(BatchNormalization())
# Output layer
model.add(Dense(5,activation="softmax"))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 150, 150, 64)      1792
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 75, 75, 64)        0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 75, 75, 64)        256
# _________________________________________________________________
# dropout (Dropout)            (None, 75, 75, 64)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 75, 75, 128)       73856
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 37, 37, 128)       0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 37, 37, 128)       512
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 37, 37, 128)       0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 37, 37, 128)       147584
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 18, 18, 128)       0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 18, 18, 128)       512
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 18, 18, 128)       0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 18, 18, 256)       295168
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 9, 9, 256)         0
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 9, 9, 256)         1024
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 9, 9, 256)         0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 9, 9, 256)         590080
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 4, 4, 256)         0
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 4, 4, 256)         1024
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 4, 4, 256)         0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 4, 4, 512)         1180160
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 2, 2, 512)         0
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 2, 2, 512)         2048
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 2, 2, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 2048)              0
# _________________________________________________________________
# dense (Dense)                (None, 1024)              2098176
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 1024)              4096
# _________________________________________________________________
# dense_1 (Dense)              (None, 5)                 5125
# =================================================================
# Total params: 4,401,413
# Trainable params: 4,396,677
# Non-trainable params: 4,736
# _________________________________________________________________

# %%
#defining early stopping
from keras.callbacks import ReduceLROnPlateau
learning_rate = ReduceLROnPlateau(monitor='val_accuracy', patience = 3, verbose=1,factor=0.5, min_lr=0.000001)

es = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss', patience=10, verbose=1, mode='min')

# %%
# !pip install h5py
	
	
mc = tf.keras.callbacks.ModelCheckpoint('best_model.h5', monitor='val_accuracy', mode='max', verbose=1, save_best_only=True)
# Out:
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (2.10.0)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from h5py) (1.15.0)
# Requirement already satisfied: numpy>=1.7 in /usr/local/lib/python3.6/dist-packages (from h5py) (1.18.5)

# %%
model.compile(optimizer = "adam" , loss = 'categorical_crossentropy' , metrics = ['accuracy'])

# %%
#Fitting the augmentation data
history = model.fit(datagen.flow(x_train, y_train, batch_size=32), epochs=100, validation_data = datagen.flow(x_val, y_val), callbacks = [learning_rate,es,mc])
# Out:
# Epoch 1/100
# 98/98 [==============================] - ETA: 0s - loss: 1.6701 - accuracy: 0.4325
# Epoch 00001: val_accuracy improved from -inf to 0.23265, saving model to best_model.h5
# 98/98 [==============================] - 422s 4s/step - loss: 1.6701 - accuracy: 0.4325 - val_loss: 4.0071 - val_accuracy: 0.2326
# Epoch 2/100
# 98/98 [==============================] - ETA: 0s - loss: 1.3226 - accuracy: 0.5119
# Epoch 00002: val_accuracy did not improve from 0.23265
# 98/98 [==============================] - 423s 4s/step - loss: 1.3226 - accuracy: 0.5119 - val_loss: 3.1520 - val_accuracy: 0.2326
# Epoch 3/100
# 98/98 [==============================] - ETA: 0s - loss: 1.1688 - accuracy: 0.5646
# Epoch 00003: val_accuracy improved from 0.23265 to 0.25835, saving model to best_model.h5
# 98/98 [==============================] - 424s 4s/step - loss: 1.1688 - accuracy: 0.5646 - val_loss: 3.0845 - val_accuracy: 0.2584
# Epoch 4/100
# 98/98 [==============================] - ETA: 0s - loss: 1.0911 - accuracy: 0.5906
# Epoch 00004: val_accuracy improved from 0.25835 to 0.31491, saving model to best_model.h5
# 98/98 [==============================] - 424s 4s/step - loss: 1.0911 - accuracy: 0.5906 - val_loss: 2.5776 - val_accuracy: 0.3149
# Epoch 5/100
# 98/98 [==============================] - ETA: 0s - loss: 1.0220 - accuracy: 0.6163
# Epoch 00005: val_accuracy improved from 0.31491 to 0.42031, saving model to best_model.h5
# 98/98 [==============================] - 426s 4s/step - loss: 1.0220 - accuracy: 0.6163 - val_loss: 1.7635 - val_accuracy: 0.4203
# Epoch 6/100
# 98/98 [==============================] - ETA: 0s - loss: 0.9010 - accuracy: 0.6607
# Epoch 00006: val_accuracy improved from 0.42031 to 0.55784, saving model to best_model.h5
# 98/98 [==============================] - 426s 4s/step - loss: 0.9010 - accuracy: 0.6607 - val_loss: 1.0944 - val_accuracy: 0.5578
# Epoch 7/100
# 98/98 [==============================] - ETA: 0s - loss: 0.8902 - accuracy: 0.6600
# Epoch 00007: val_accuracy improved from 0.55784 to 0.64139, saving model to best_model.h5
# 98/98 [==============================] - 423s 4s/step - loss: 0.8902 - accuracy: 0.6600 - val_loss: 0.9449 - val_accuracy: 0.6414
# Epoch 8/100
# 98/98 [==============================] - ETA: 0s - loss: 0.8332 - accuracy: 0.6873
# Epoch 00008: val_accuracy did not improve from 0.64139
# 98/98 [==============================] - 422s 4s/step - loss: 0.8332 - accuracy: 0.6873 - val_loss: 1.5437 - val_accuracy: 0.5566
# Epoch 9/100
# 98/98 [==============================] - ETA: 0s - loss: 0.7925 - accuracy: 0.7044
# Epoch 00009: val_accuracy improved from 0.64139 to 0.66710, saving model to best_model.h5
# 98/98 [==============================] - 422s 4s/step - loss: 0.7925 - accuracy: 0.7044 - val_loss: 0.9236 - val_accuracy: 0.6671
# Epoch 10/100
# 98/98 [==============================] - ETA: 0s - loss: 0.8621 - accuracy: 0.6738
# Epoch 00010: val_accuracy did not improve from 0.66710
# 98/98 [==============================] - 422s 4s/step - loss: 0.8621 - accuracy: 0.6738 - val_loss: 0.9572 - val_accuracy: 0.6581
# Epoch 11/100
# 98/98 [==============================] - ETA: 0s - loss: 0.7782 - accuracy: 0.7040
# Epoch 00011: val_accuracy improved from 0.66710 to 0.67609, saving model to best_model.h5
# 98/98 [==============================] - 422s 4s/step - loss: 0.7782 - accuracy: 0.7040 - val_loss: 0.9465 - val_accuracy: 0.6761
# Epoch 12/100
# 98/98 [==============================] - ETA: 0s - loss: 0.7552 - accuracy: 0.7179
# Epoch 00012: val_accuracy did not improve from 0.67609
# 98/98 [==============================] - 422s 4s/step - loss: 0.7552 - accuracy: 0.7179 - val_loss: 1.2394 - val_accuracy: 0.6195
# Epoch 13/100
# 98/98 [==============================] - ETA: 0s - loss: 0.7273 - accuracy: 0.7301
# Epoch 00013: val_accuracy did not improve from 0.67609
# 98/98 [==============================] - 424s 4s/step - loss: 0.7273 - accuracy: 0.7301 - val_loss: 1.0197 - val_accuracy: 0.6568
# Epoch 14/100
# 98/98 [==============================] - ETA: 0s - loss: 0.6982 - accuracy: 0.7391
# Epoch 00014: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00014: val_accuracy did not improve from 0.67609
# 98/98 [==============================] - 427s 4s/step - loss: 0.6982 - accuracy: 0.7391 - val_loss: 1.3394 - val_accuracy: 0.5810
# Epoch 15/100
# 98/98 [==============================] - ETA: 0s - loss: 0.6147 - accuracy: 0.7664
# Epoch 00015: val_accuracy improved from 0.67609 to 0.77763, saving model to best_model.h5
# 98/98 [==============================] - 429s 4s/step - loss: 0.6147 - accuracy: 0.7664 - val_loss: 0.6629 - val_accuracy: 0.7776
# Epoch 16/100
# 98/98 [==============================] - ETA: 0s - loss: 0.5571 - accuracy: 0.7876
# Epoch 00016: val_accuracy did not improve from 0.77763
# 98/98 [==============================] - 425s 4s/step - loss: 0.5571 - accuracy: 0.7876 - val_loss: 0.6313 - val_accuracy: 0.7506
# Epoch 17/100
# 98/98 [==============================] - ETA: 0s - loss: 0.5684 - accuracy: 0.7870
# Epoch 00017: val_accuracy did not improve from 0.77763
# 98/98 [==============================] - 421s 4s/step - loss: 0.5684 - accuracy: 0.7870 - val_loss: 0.7889 - val_accuracy: 0.7082
# Epoch 18/100
# 98/98 [==============================] - ETA: 0s - loss: 0.5317 - accuracy: 0.7979
# Epoch 00018: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 00018: val_accuracy did not improve from 0.77763
# 98/98 [==============================] - 421s 4s/step - loss: 0.5317 - accuracy: 0.7979 - val_loss: 0.7107 - val_accuracy: 0.7352
# Epoch 19/100
# 98/98 [==============================] - ETA: 0s - loss: 0.4907 - accuracy: 0.8120
# Epoch 00019: val_accuracy did not improve from 0.77763
# 98/98 [==============================] - 421s 4s/step - loss: 0.4907 - accuracy: 0.8120 - val_loss: 0.6168 - val_accuracy: 0.7712
# Epoch 20/100
# 98/98 [==============================] - ETA: 0s - loss: 0.4629 - accuracy: 0.8274
# Epoch 00020: val_accuracy improved from 0.77763 to 0.79563, saving model to best_model.h5
# 98/98 [==============================] - 425s 4s/step - loss: 0.4629 - accuracy: 0.8274 - val_loss: 0.5957 - val_accuracy: 0.7956
# Epoch 21/100
# 98/98 [==============================] - ETA: 0s - loss: 0.4363 - accuracy: 0.8374
# Epoch 00021: val_accuracy did not improve from 0.79563
# 98/98 [==============================] - 424s 4s/step - loss: 0.4363 - accuracy: 0.8374 - val_loss: 0.6455 - val_accuracy: 0.7584
# Epoch 22/100
# 98/98 [==============================] - ETA: 0s - loss: 0.4466 - accuracy: 0.8339
# Epoch 00022: val_accuracy did not improve from 0.79563
# 98/98 [==============================] - 425s 4s/step - loss: 0.4466 - accuracy: 0.8339 - val_loss: 0.6914 - val_accuracy: 0.7635
# Epoch 23/100
# 98/98 [==============================] - ETA: 0s - loss: 0.4305 - accuracy: 0.8432
# Epoch 00023: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 00023: val_accuracy did not improve from 0.79563
# 98/98 [==============================] - 426s 4s/step - loss: 0.4305 - accuracy: 0.8432 - val_loss: 0.6804 - val_accuracy: 0.7519
# Epoch 24/100
# 98/98 [==============================] - ETA: 0s - loss: 0.3892 - accuracy: 0.8596
# Epoch 00024: val_accuracy did not improve from 0.79563
# 98/98 [==============================] - 422s 4s/step - loss: 0.3892 - accuracy: 0.8596 - val_loss: 0.5660 - val_accuracy: 0.7892
# Epoch 25/100
# 98/98 [==============================] - ETA: 0s - loss: 0.3711 - accuracy: 0.8576
# Epoch 00025: val_accuracy did not improve from 0.79563
# 98/98 [==============================] - 421s 4s/step - loss: 0.3711 - accuracy: 0.8576 - val_loss: 0.6058 - val_accuracy: 0.7943
# Epoch 26/100
# 98/98 [==============================] - ETA: 0s - loss: 0.3874 - accuracy: 0.8557
# Epoch 00026: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
#
# Epoch 00026: val_accuracy did not improve from 0.79563
# 98/98 [==============================] - 421s 4s/step - loss: 0.3874 - accuracy: 0.8557 - val_loss: 0.6074 - val_accuracy: 0.7841
# Epoch 27/100
# 98/98 [==============================] - ETA: 0s - loss: 0.3353 - accuracy: 0.8795
# Epoch 00027: val_accuracy improved from 0.79563 to 0.80077, saving model to best_model.h5
# 98/98 [==============================] - 421s 4s/step - loss: 0.3353 - accuracy: 0.8795 - val_loss: 0.5551 - val_accuracy: 0.8008
# Epoch 28/100
# 98/98 [==============================] - ETA: 0s - loss: 0.3238 - accuracy: 0.8805
# Epoch 00028: val_accuracy did not improve from 0.80077
# 98/98 [==============================] - 421s 4s/step - loss: 0.3238 - accuracy: 0.8805 - val_loss: 0.6272 - val_accuracy: 0.7763
# Epoch 29/100
# 98/98 [==============================] - ETA: 0s - loss: 0.3231 - accuracy: 0.8792
# Epoch 00029: val_accuracy did not improve from 0.80077
# 98/98 [==============================] - 421s 4s/step - loss: 0.3231 - accuracy: 0.8792 - val_loss: 0.5721 - val_accuracy: 0.7943
# Epoch 30/100
# 98/98 [==============================] - ETA: 0s - loss: 0.3137 - accuracy: 0.8785
# Epoch 00030: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
#
# Epoch 00030: val_accuracy did not improve from 0.80077
# 98/98 [==============================] - 421s 4s/step - loss: 0.3137 - accuracy: 0.8785 - val_loss: 0.5926 - val_accuracy: 0.7918
# Epoch 31/100
# 98/98 [==============================] - ETA: 0s - loss: 0.2952 - accuracy: 0.8917
# Epoch 00031: val_accuracy improved from 0.80077 to 0.80848, saving model to best_model.h5
# 98/98 [==============================] - 421s 4s/step - loss: 0.2952 - accuracy: 0.8917 - val_loss: 0.5658 - val_accuracy: 0.8085
# Epoch 32/100
# 98/98 [==============================] - ETA: 0s - loss: 0.2967 - accuracy: 0.8875
# Epoch 00032: val_accuracy did not improve from 0.80848
# 98/98 [==============================] - 421s 4s/step - loss: 0.2967 - accuracy: 0.8875 - val_loss: 0.5786 - val_accuracy: 0.8059
# Epoch 33/100
# 98/98 [==============================] - ETA: 0s - loss: 0.2996 - accuracy: 0.8904
# Epoch 00033: val_accuracy did not improve from 0.80848
# 98/98 [==============================] - 422s 4s/step - loss: 0.2996 - accuracy: 0.8904 - val_loss: 0.5841 - val_accuracy: 0.8059
# Epoch 34/100
# 98/98 [==============================] - ETA: 0s - loss: 0.2821 - accuracy: 0.8930
# Epoch 00034: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
#
# Epoch 00034: val_accuracy did not improve from 0.80848
# 98/98 [==============================] - 421s 4s/step - loss: 0.2821 - accuracy: 0.8930 - val_loss: 0.6199 - val_accuracy: 0.7892
# Epoch 35/100
# 98/98 [==============================] - ETA: 0s - loss: 0.2846 - accuracy: 0.8943
# Epoch 00035: val_accuracy did not improve from 0.80848
# 98/98 [==============================] - 422s 4s/step - loss: 0.2846 - accuracy: 0.8943 - val_loss: 0.5994 - val_accuracy: 0.7905
# Epoch 36/100
# 98/98 [==============================] - ETA: 0s - loss: 0.2576 - accuracy: 0.9075
# Epoch 00036: val_accuracy improved from 0.80848 to 0.81105, saving model to best_model.h5
# 98/98 [==============================] - 422s 4s/step - loss: 0.2576 - accuracy: 0.9075 - val_loss: 0.5909 - val_accuracy: 0.8111
# Epoch 37/100
# 98/98 [==============================] - ETA: 0s - loss: 0.2611 - accuracy: 0.9017
# Epoch 00037: val_accuracy did not improve from 0.81105
# 98/98 [==============================] - 420s 4s/step - loss: 0.2611 - accuracy: 0.9017 - val_loss: 0.6088 - val_accuracy: 0.7982
# Epoch 00037: early stopping

# %%
import seaborn as sns
sns.set_style('darkgrid')
import matplotlib.pyplot as plt
import matplotlib.image as mimg

# %%
accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(accuracy) + 1)

f, axes = plt.subplots(1,2,figsize=(14,4))

axes[0].plot(epochs, accuracy, 'g', label='Training accuracy')
axes[0].plot(epochs, val_accuracy, 'b', label='Validation accuracy')
axes[0].legend()

axes[1].plot(epochs, loss, 'g', label='Training loss')
axes[1].plot(epochs, val_loss, 'b', label='Validation loss')
axes[1].yaxis.set_label_position("right")
axes[1].legend()

plt.show()

# %%
saved_model = tf.keras.models.load_model('best_model.h5')
print("Test Accuracy: {0:.2f}%".format(saved_model.evaluate(x_test,y_test)[1]*100)) #get score acording to test datas
# Out:
# 14/14 [==============================] - 13s 904ms/step - loss: 0.5216 - accuracy: 0.8222
# Test Accuracy: 82.22%

# %%
from sklearn.metrics import confusion_matrix
Y_pred = saved_model.predict(x_test)
Y_pred_classes = np.argmax(Y_pred,axis = 1)
Y_true = np.argmax(y_test,axis = 1)
confusion_mtx = confusion_matrix(Y_true,Y_pred_classes)
f,ax = plt.subplots(figsize = (8,8))
sns.heatmap(confusion_mtx,annot=True,linewidths = 0.01,cmap="Reds",
            linecolor = "gray",fmt = ".2f",ax=ax
            )
plt.xlabel("predicted label")
plt.ylabel("True Label")
plt.title("confusion matrix")
plt.show()


y_test_inv = label_binarizer.inverse_transform(y_test)
print(classification_report(y_test_inv, Y_pred_classes, target_names = labels))
# Out:
#               precision    recall  f1-score   support
#
#    dandelion       0.80      0.84      0.82       123
#        daisy       0.91      0.79      0.84        89
#        tulip       0.78      0.89      0.83        84
#    sunflower       0.83      0.88      0.86        67
#         rose       0.82      0.70      0.75        70
#
#     accuracy                           0.82       433
#    macro avg       0.83      0.82      0.82       433
# weighted avg       0.83      0.82      0.82       433
