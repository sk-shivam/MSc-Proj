# %%
#70-20-10 with for 90%(80%augmented, 20%validation) and 10%test data
import keras
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout, Flatten
from keras.layers import Conv2D
from keras.layers import MaxPooling2D,MaxPool2D
from keras.layers.normalization import BatchNormalization
from keras.optimizers import Adam
from keras.preprocessing.image import ImageDataGenerator
from keras import layers
from keras import models
from keras import optimizers

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
import os

# %%
#changing the working directory
# %cd /content/gdrive/My Drive/Thesis
# Out:
# /content/gdrive/My Drive/Thesis

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import keras
from keras.models import Sequential, Model
from keras.layers import Dense, Conv2D , MaxPool2D , Flatten , Dropout , MaxPooling2D
from keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report,confusion_matrix
from keras.applications import VGG19
import cv2
import os
import random
import tensorflow as tf
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
labels = ['dandelion', 'daisy','tulip','sunflower','rose']
img_size = 150
def get_data(data_dir):
    data = [] 
    for label in labels: 
        path = os.path.join(data_dir, label)
        class_num = labels.index(label)
        for img in os.listdir(path):
            try:
                img_arr = cv2.imread(os.path.join(path, img), cv2.IMREAD_COLOR)
                resized_arr = cv2.resize(img_arr, (img_size, img_size)) # Reshaping images to preferred size
                data.append([resized_arr, class_num])
            except Exception as e:
                print(e)
    return np.array(data)

# %%
data = get_data("/content/gdrive/My Drive/Thesis/flowers")
# Out:
# OpenCV(4.1.2) /io/opencv/modules/imgproc/src/resize.cpp:3720: error: (-215:Assertion failed) !ssize.empty() in function 'resize'
#
# OpenCV(4.1.2) /io/opencv/modules/imgproc/src/resize.cpp:3720: error: (-215:Assertion failed) !ssize.empty() in function 'resize'
#
# OpenCV(4.1.2) /io/opencv/modules/imgproc/src/resize.cpp:3720: error: (-215:Assertion failed) !ssize.empty() in function 'resize'

# %%
l = []
for i in data:
    l.append(labels[i[1]])
sns.set_style('dark')
sns.countplot(l)

# %%
fig,ax=plt.subplots(5,2)
fig.set_size_inches(15,15)
for i in range(5):
    for j in range (2):
        l=random.randint(0,len(data))
        ax[i,j].imshow(data[l][0])
        ax[i,j].set_title('Flower: '+labels[data[l][1]])
        
plt.tight_layout()

# %%
x = []
y = []

for feature, label in data:
    x.append(feature)
    y.append(label)

# %%
# Normalize the data
x = np.array(x) / 255

# %%
# Reshaping the data from 1-D to 3-D as required through input by CNN's 
x = x.reshape(-1, img_size, img_size, 3)
y = np.array(y)

# %%
from sklearn.preprocessing import LabelBinarizer
label_binarizer = LabelBinarizer()
y = label_binarizer.fit_transform(y)

# %%
x_train,x_test,y_train,y_test = train_test_split(x , y , test_size = 0.1 , random_state = 42)

# %%
x_train,x_val,y_train,y_val = train_test_split(x_train, y_train, test_size= 0.2, random_state = 42)

# %%
#defining the augmentation
datagen = ImageDataGenerator(
    featurewise_center=False,  # set input mean to 0 over the dataset
    samplewise_center=False,  # set each sample mean to 0
    featurewise_std_normalization=False,  # divide inputs by std of the dataset
    samplewise_std_normalization=False,  # divide each input by its std
    rotation_range=30,  # randomly rotate images in the range (60, 0 to 180)
    zoom_range = 0.1, # Randomly zoom image 
    width_shift_range=0.1,  # randomly shift images horizontally (fraction of total width)
    height_shift_range=0.1,
    shear_range=0.1,
    fill_mode = "reflect"
    ) 
datagen.fit(x_train)

# %%
model = Sequential()
# 1st Convolutional Layer
model.add(Conv2D(filters=64, kernel_size=(3,3),padding="Same",activation="relu" , input_shape = (150,150,3)))
model.add(MaxPool2D(pool_size=(2,2),strides=(2,2)))
model.add(BatchNormalization())
model.add(Dropout(0.2))
# 2nd Convolutional Layer
model.add(Conv2D(filters=128, kernel_size=(3,3),padding="Same",activation="relu"))
model.add(MaxPool2D(pool_size=(2,2),strides=(2,2)))
model.add(BatchNormalization())
model.add(Dropout(0.3))
# 3rd Convolutional Layer
model.add(Conv2D(filters=128, kernel_size=(3,3),padding="Same",activation="relu"))
model.add(MaxPool2D(pool_size=(2,2),strides=(2,2)))
model.add(BatchNormalization())
model.add(Dropout(0.2))
# 4th Convolutional Layer
model.add(Conv2D(filters=256, kernel_size=(3,3),padding="Same",activation="relu"))
model.add(MaxPool2D(pool_size=(2,2),strides=(2,2)))
model.add(BatchNormalization())
model.add(Dropout(0.3))
# 5th Convolutional Layer
model.add(Conv2D(filters=256,kernel_size = (3,3),padding="Same",activation="relu"))
model.add(MaxPool2D(pool_size=(2,2),strides=(2,2)))
model.add(BatchNormalization())
model.add(Dropout(0.2))
# 6th Convolutional Layer
model.add(Conv2D(filters=512,kernel_size = (3,3),padding="Same",activation="relu"))
model.add(MaxPool2D(pool_size=(2,2),strides=(2,2)))
model.add(BatchNormalization())
model.add(Dropout(0.2))

model.add(Flatten())
# 1st Fully Connected Layer
model.add(Dense(1024,activation="relu"))
model.add(Dropout(0.5))
model.add(BatchNormalization())
# Output layer
model.add(Dense(5,activation="softmax"))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 150, 150, 64)      1792
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 75, 75, 64)        0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 75, 75, 64)        256
# _________________________________________________________________
# dropout (Dropout)            (None, 75, 75, 64)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 75, 75, 128)       73856
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 37, 37, 128)       0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 37, 37, 128)       512
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 37, 37, 128)       0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 37, 37, 128)       147584
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 18, 18, 128)       0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 18, 18, 128)       512
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 18, 18, 128)       0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 18, 18, 256)       295168
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 9, 9, 256)         0
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 9, 9, 256)         1024
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 9, 9, 256)         0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 9, 9, 256)         590080
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 4, 4, 256)         0
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 4, 4, 256)         1024
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 4, 4, 256)         0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 4, 4, 512)         1180160
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 2, 2, 512)         0
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 2, 2, 512)         2048
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 2, 2, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 2048)              0
# _________________________________________________________________
# dense (Dense)                (None, 1024)              2098176
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 1024)              4096
# _________________________________________________________________
# dense_1 (Dense)              (None, 5)                 5125
# =================================================================
# Total params: 4,401,413
# Trainable params: 4,396,677
# Non-trainable params: 4,736
# _________________________________________________________________

# %%
#defining early stopping
from keras.callbacks import ReduceLROnPlateau
learning_rate = ReduceLROnPlateau(monitor='val_accuracy', patience = 3, verbose=1,factor=0.5, min_lr=0.000001)

es = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss', patience=10, verbose=1, mode='min')

# %%
# !pip install h5py
	
	
mc = tf.keras.callbacks.ModelCheckpoint('best_model.h5', monitor='val_accuracy', mode='max', verbose=1, save_best_only=True)
# Out:
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (2.10.0)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from h5py) (1.15.0)
# Requirement already satisfied: numpy>=1.7 in /usr/local/lib/python3.6/dist-packages (from h5py) (1.18.5)

# %%
model.compile(optimizer = "adam" , loss = 'categorical_crossentropy' , metrics = ['accuracy'])

# %%
#Fitting the augmentation data
history = model.fit(datagen.flow(x_train, y_train, batch_size=32), epochs=100, validation_data = (x_val, y_val), callbacks = [learning_rate,es,mc])
# Out:
# Epoch 1/100
# 98/98 [==============================] - ETA: 0s - loss: 1.6653 - accuracy: 0.4261
# Epoch 00001: val_accuracy improved from -inf to 0.23265, saving model to best_model.h5
# 98/98 [==============================] - 450s 5s/step - loss: 1.6653 - accuracy: 0.4261 - val_loss: 7.0546 - val_accuracy: 0.2326
# Epoch 2/100
# 98/98 [==============================] - ETA: 0s - loss: 1.3197 - accuracy: 0.4990
# Epoch 00002: val_accuracy improved from 0.23265 to 0.25835, saving model to best_model.h5
# 98/98 [==============================] - 452s 5s/step - loss: 1.3197 - accuracy: 0.4990 - val_loss: 2.5119 - val_accuracy: 0.2584
# Epoch 3/100
# 98/98 [==============================] - ETA: 0s - loss: 1.2174 - accuracy: 0.5312
# Epoch 00003: val_accuracy improved from 0.25835 to 0.33933, saving model to best_model.h5
# 98/98 [==============================] - 460s 5s/step - loss: 1.2174 - accuracy: 0.5312 - val_loss: 1.4742 - val_accuracy: 0.3393
# Epoch 4/100
# 98/98 [==============================] - ETA: 0s - loss: 1.0906 - accuracy: 0.5990
# Epoch 00004: val_accuracy improved from 0.33933 to 0.36761, saving model to best_model.h5
# 98/98 [==============================] - 452s 5s/step - loss: 1.0906 - accuracy: 0.5990 - val_loss: 1.5818 - val_accuracy: 0.3676
# Epoch 5/100
# 98/98 [==============================] - ETA: 0s - loss: 1.0036 - accuracy: 0.6176
# Epoch 00005: val_accuracy did not improve from 0.36761
# 98/98 [==============================] - 443s 5s/step - loss: 1.0036 - accuracy: 0.6176 - val_loss: 2.1509 - val_accuracy: 0.3188
# Epoch 6/100
# 98/98 [==============================] - ETA: 0s - loss: 0.9026 - accuracy: 0.6616
# Epoch 00006: val_accuracy improved from 0.36761 to 0.47815, saving model to best_model.h5
# 98/98 [==============================] - 470s 5s/step - loss: 0.9026 - accuracy: 0.6616 - val_loss: 1.5068 - val_accuracy: 0.4781
# Epoch 7/100
# 98/98 [==============================] - ETA: 0s - loss: 0.8918 - accuracy: 0.6591
# Epoch 00007: val_accuracy improved from 0.47815 to 0.53728, saving model to best_model.h5
# 98/98 [==============================] - 457s 5s/step - loss: 0.8918 - accuracy: 0.6591 - val_loss: 1.5084 - val_accuracy: 0.5373
# Epoch 8/100
# 98/98 [==============================] - ETA: 0s - loss: 0.8463 - accuracy: 0.6793
# Epoch 00008: val_accuracy improved from 0.53728 to 0.62468, saving model to best_model.h5
# 98/98 [==============================] - 448s 5s/step - loss: 0.8463 - accuracy: 0.6793 - val_loss: 1.1349 - val_accuracy: 0.6247
# Epoch 9/100
# 98/98 [==============================] - ETA: 0s - loss: 0.7837 - accuracy: 0.7069
# Epoch 00009: val_accuracy improved from 0.62468 to 0.62596, saving model to best_model.h5
# 98/98 [==============================] - 459s 5s/step - loss: 0.7837 - accuracy: 0.7069 - val_loss: 1.2296 - val_accuracy: 0.6260
# Epoch 10/100
# 98/98 [==============================] - ETA: 0s - loss: 0.7898 - accuracy: 0.6963
# Epoch 00010: val_accuracy did not improve from 0.62596
# 98/98 [==============================] - 455s 5s/step - loss: 0.7898 - accuracy: 0.6963 - val_loss: 1.4176 - val_accuracy: 0.5591
# Epoch 11/100
# 98/98 [==============================] - ETA: 0s - loss: 0.7474 - accuracy: 0.7211
# Epoch 00011: val_accuracy improved from 0.62596 to 0.63625, saving model to best_model.h5
# 98/98 [==============================] - 454s 5s/step - loss: 0.7474 - accuracy: 0.7211 - val_loss: 1.0403 - val_accuracy: 0.6362
# Epoch 12/100
# 98/98 [==============================] - ETA: 0s - loss: 0.7090 - accuracy: 0.7397
# Epoch 00012: val_accuracy improved from 0.63625 to 0.72237, saving model to best_model.h5
# 98/98 [==============================] - 468s 5s/step - loss: 0.7090 - accuracy: 0.7397 - val_loss: 0.7361 - val_accuracy: 0.7224
# Epoch 13/100
# 98/98 [==============================] - ETA: 0s - loss: 0.7055 - accuracy: 0.7326
# Epoch 00013: val_accuracy did not improve from 0.72237
# 98/98 [==============================] - 452s 5s/step - loss: 0.7055 - accuracy: 0.7326 - val_loss: 0.8458 - val_accuracy: 0.6954
# Epoch 14/100
# 98/98 [==============================] - ETA: 0s - loss: 0.6676 - accuracy: 0.7564
# Epoch 00014: val_accuracy did not improve from 0.72237
# 98/98 [==============================] - 448s 5s/step - loss: 0.6676 - accuracy: 0.7564 - val_loss: 0.8716 - val_accuracy: 0.7224
# Epoch 15/100
# 98/98 [==============================] - ETA: 0s - loss: 0.6524 - accuracy: 0.7548
# Epoch 00015: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 00015: val_accuracy did not improve from 0.72237
# 98/98 [==============================] - 463s 5s/step - loss: 0.6524 - accuracy: 0.7548 - val_loss: 1.0496 - val_accuracy: 0.7005
# Epoch 16/100
# 98/98 [==============================] - ETA: 0s - loss: 0.5758 - accuracy: 0.7808
# Epoch 00016: val_accuracy improved from 0.72237 to 0.73136, saving model to best_model.h5
# 98/98 [==============================] - 462s 5s/step - loss: 0.5758 - accuracy: 0.7808 - val_loss: 0.7736 - val_accuracy: 0.7314
# Epoch 17/100
# 98/98 [==============================] - ETA: 0s - loss: 0.5495 - accuracy: 0.7979
# Epoch 00017: val_accuracy improved from 0.73136 to 0.74293, saving model to best_model.h5
# 98/98 [==============================] - 453s 5s/step - loss: 0.5495 - accuracy: 0.7979 - val_loss: 0.7458 - val_accuracy: 0.7429
# Epoch 18/100
# 98/98 [==============================] - ETA: 0s - loss: 0.5452 - accuracy: 0.7966
# Epoch 00018: val_accuracy improved from 0.74293 to 0.75964, saving model to best_model.h5
# 98/98 [==============================] - 457s 5s/step - loss: 0.5452 - accuracy: 0.7966 - val_loss: 0.6498 - val_accuracy: 0.7596
# Epoch 19/100
# 98/98 [==============================] - ETA: 0s - loss: 0.4850 - accuracy: 0.8162
# Epoch 00019: val_accuracy did not improve from 0.75964
# 98/98 [==============================] - 450s 5s/step - loss: 0.4850 - accuracy: 0.8162 - val_loss: 0.6829 - val_accuracy: 0.7301
# Epoch 20/100
# 98/98 [==============================] - ETA: 0s - loss: 0.4913 - accuracy: 0.8146
# Epoch 00020: val_accuracy improved from 0.75964 to 0.76093, saving model to best_model.h5
# 98/98 [==============================] - 455s 5s/step - loss: 0.4913 - accuracy: 0.8146 - val_loss: 0.6126 - val_accuracy: 0.7609
# Epoch 21/100
# 98/98 [==============================] - ETA: 0s - loss: 0.5117 - accuracy: 0.8082
# Epoch 00021: val_accuracy did not improve from 0.76093
# 98/98 [==============================] - 453s 5s/step - loss: 0.5117 - accuracy: 0.8082 - val_loss: 0.7793 - val_accuracy: 0.7442
# Epoch 22/100
# 98/98 [==============================] - ETA: 0s - loss: 0.4635 - accuracy: 0.8226
# Epoch 00022: val_accuracy improved from 0.76093 to 0.78021, saving model to best_model.h5
# 98/98 [==============================] - 453s 5s/step - loss: 0.4635 - accuracy: 0.8226 - val_loss: 0.6384 - val_accuracy: 0.7802
# Epoch 23/100
# 98/98 [==============================] - ETA: 0s - loss: 0.4557 - accuracy: 0.8361
# Epoch 00023: val_accuracy improved from 0.78021 to 0.78278, saving model to best_model.h5
# 98/98 [==============================] - 439s 4s/step - loss: 0.4557 - accuracy: 0.8361 - val_loss: 0.6989 - val_accuracy: 0.7828
# Epoch 24/100
# 98/98 [==============================] - ETA: 0s - loss: 0.4521 - accuracy: 0.8323
# Epoch 00024: val_accuracy improved from 0.78278 to 0.78535, saving model to best_model.h5
# 98/98 [==============================] - 439s 4s/step - loss: 0.4521 - accuracy: 0.8323 - val_loss: 0.6075 - val_accuracy: 0.7853
# Epoch 25/100
# 98/98 [==============================] - ETA: 0s - loss: 0.4375 - accuracy: 0.8393
# Epoch 00025: val_accuracy improved from 0.78535 to 0.80077, saving model to best_model.h5
# 98/98 [==============================] - 449s 5s/step - loss: 0.4375 - accuracy: 0.8393 - val_loss: 0.6105 - val_accuracy: 0.8008
# Epoch 26/100
# 98/98 [==============================] - ETA: 0s - loss: 0.4674 - accuracy: 0.8217
# Epoch 00026: val_accuracy did not improve from 0.80077
# 98/98 [==============================] - 441s 5s/step - loss: 0.4674 - accuracy: 0.8217 - val_loss: 0.7445 - val_accuracy: 0.7622
# Epoch 27/100
# 98/98 [==============================] - ETA: 0s - loss: 0.4194 - accuracy: 0.8470
# Epoch 00027: val_accuracy did not improve from 0.80077
# 98/98 [==============================] - 443s 5s/step - loss: 0.4194 - accuracy: 0.8470 - val_loss: 0.7045 - val_accuracy: 0.7609
# Epoch 28/100
# 98/98 [==============================] - ETA: 0s - loss: 0.4188 - accuracy: 0.8416
# Epoch 00028: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 00028: val_accuracy did not improve from 0.80077
# 98/98 [==============================] - 451s 5s/step - loss: 0.4188 - accuracy: 0.8416 - val_loss: 0.6645 - val_accuracy: 0.7789
# Epoch 29/100
# 98/98 [==============================] - ETA: 0s - loss: 0.3657 - accuracy: 0.8654
# Epoch 00029: val_accuracy improved from 0.80077 to 0.81234, saving model to best_model.h5
# 98/98 [==============================] - 442s 5s/step - loss: 0.3657 - accuracy: 0.8654 - val_loss: 0.5278 - val_accuracy: 0.8123
# Epoch 30/100
# 98/98 [==============================] - ETA: 0s - loss: 0.3119 - accuracy: 0.8875
# Epoch 00030: val_accuracy did not improve from 0.81234
# 98/98 [==============================] - 455s 5s/step - loss: 0.3119 - accuracy: 0.8875 - val_loss: 0.5641 - val_accuracy: 0.8072
# Epoch 31/100
# 98/98 [==============================] - ETA: 0s - loss: 0.3120 - accuracy: 0.8827
# Epoch 00031: val_accuracy did not improve from 0.81234
# 98/98 [==============================] - 454s 5s/step - loss: 0.3120 - accuracy: 0.8827 - val_loss: 0.7564 - val_accuracy: 0.7635
# Epoch 32/100
# 98/98 [==============================] - ETA: 0s - loss: 0.2904 - accuracy: 0.8965
# Epoch 00032: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 00032: val_accuracy did not improve from 0.81234
# 98/98 [==============================] - 435s 4s/step - loss: 0.2904 - accuracy: 0.8965 - val_loss: 0.6090 - val_accuracy: 0.7892
# Epoch 33/100
# 98/98 [==============================] - ETA: 0s - loss: 0.2725 - accuracy: 0.8959
# Epoch 00033: val_accuracy improved from 0.81234 to 0.82519, saving model to best_model.h5
# 98/98 [==============================] - 443s 5s/step - loss: 0.2725 - accuracy: 0.8959 - val_loss: 0.5216 - val_accuracy: 0.8252
# Epoch 34/100
# 98/98 [==============================] - ETA: 0s - loss: 0.2502 - accuracy: 0.9078
# Epoch 00034: val_accuracy did not improve from 0.82519
# 98/98 [==============================] - 451s 5s/step - loss: 0.2502 - accuracy: 0.9078 - val_loss: 0.5712 - val_accuracy: 0.8162
# Epoch 35/100
# 98/98 [==============================] - ETA: 0s - loss: 0.2537 - accuracy: 0.9020
# Epoch 00035: val_accuracy did not improve from 0.82519
# 98/98 [==============================] - 442s 5s/step - loss: 0.2537 - accuracy: 0.9020 - val_loss: 0.6322 - val_accuracy: 0.8008
# Epoch 36/100
# 98/98 [==============================] - ETA: 0s - loss: 0.2294 - accuracy: 0.9145
# Epoch 00036: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
#
# Epoch 00036: val_accuracy did not improve from 0.82519
# 98/98 [==============================] - 451s 5s/step - loss: 0.2294 - accuracy: 0.9145 - val_loss: 0.5789 - val_accuracy: 0.7982
# Epoch 37/100
# 98/98 [==============================] - ETA: 0s - loss: 0.2107 - accuracy: 0.9248
# Epoch 00037: val_accuracy did not improve from 0.82519
# 98/98 [==============================] - 449s 5s/step - loss: 0.2107 - accuracy: 0.9248 - val_loss: 0.5805 - val_accuracy: 0.8021
# Epoch 38/100
# 98/98 [==============================] - ETA: 0s - loss: 0.1886 - accuracy: 0.9303
# Epoch 00038: val_accuracy did not improve from 0.82519
# 98/98 [==============================] - 452s 5s/step - loss: 0.1886 - accuracy: 0.9303 - val_loss: 0.5756 - val_accuracy: 0.8201
# Epoch 39/100
# 98/98 [==============================] - ETA: 0s - loss: 0.2081 - accuracy: 0.9235
# Epoch 00039: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
#
# Epoch 00039: val_accuracy did not improve from 0.82519
# 98/98 [==============================] - 460s 5s/step - loss: 0.2081 - accuracy: 0.9235 - val_loss: 0.6021 - val_accuracy: 0.8085
# Epoch 40/100
# 98/98 [==============================] - ETA: 0s - loss: 0.1857 - accuracy: 0.9267
# Epoch 00040: val_accuracy did not improve from 0.82519
# 98/98 [==============================] - 463s 5s/step - loss: 0.1857 - accuracy: 0.9267 - val_loss: 0.5713 - val_accuracy: 0.8136
# Epoch 41/100
# 98/98 [==============================] - ETA: 0s - loss: 0.1973 - accuracy: 0.9335
# Epoch 00041: val_accuracy did not improve from 0.82519
# 98/98 [==============================] - 450s 5s/step - loss: 0.1973 - accuracy: 0.9335 - val_loss: 0.5959 - val_accuracy: 0.7931
# Epoch 42/100
# 98/98 [==============================] - ETA: 0s - loss: 0.1773 - accuracy: 0.9380
# Epoch 00042: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
#
# Epoch 00042: val_accuracy did not improve from 0.82519
# 98/98 [==============================] - 449s 5s/step - loss: 0.1773 - accuracy: 0.9380 - val_loss: 0.5673 - val_accuracy: 0.8136
# Epoch 43/100
# 98/98 [==============================] - ETA: 0s - loss: 0.1857 - accuracy: 0.9335
# Epoch 00043: val_accuracy did not improve from 0.82519
# 98/98 [==============================] - 445s 5s/step - loss: 0.1857 - accuracy: 0.9335 - val_loss: 0.5640 - val_accuracy: 0.8201
# Epoch 00043: early stopping

# %%
import seaborn as sns
sns.set_style('darkgrid')
import matplotlib.pyplot as plt
import matplotlib.image as mimg

# %%
accuracy = history.history['accuracy']
val_accuracy = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(accuracy) + 1)

f, axes = plt.subplots(1,2,figsize=(14,4))

axes[0].plot(epochs, accuracy, 'g', label='Training accuracy')
axes[0].plot(epochs, val_accuracy, 'b', label='Validation accuracy')
axes[0].legend()

axes[1].plot(epochs, loss, 'g', label='Training loss')
axes[1].plot(epochs, val_loss, 'b', label='Validation loss')
axes[1].yaxis.set_label_position("right")
axes[1].legend()

plt.show()

# %%
saved_model = tf.keras.models.load_model('best_model.h5')
print("Test Accuracy: {0:.2f}%".format(saved_model.evaluate(x_test,y_test)[1]*100)) #get score acording to test datas
# Out:
# 14/14 [==============================] - 13s 922ms/step - loss: 0.4890 - accuracy: 0.8337
# Test Accuracy: 83.37%

# %%
from sklearn.metrics import confusion_matrix
Y_pred = saved_model.predict(x_test)
Y_pred_classes = np.argmax(Y_pred,axis = 1)
Y_true = np.argmax(y_test,axis = 1)
confusion_mtx = confusion_matrix(Y_true,Y_pred_classes)
f,ax = plt.subplots(figsize = (8,8))
sns.heatmap(confusion_mtx,annot=True,linewidths = 0.01,cmap="Reds",
            linecolor = "gray",fmt = ".2f",ax=ax
            )
plt.xlabel("predicted label")
plt.ylabel("True Label")
plt.title("confusion matrix")
plt.show()

from sklearn.metrics import classification_report

print(classification_report(Y_true, Y_pred_classes))

y_test_inv = label_binarizer.inverse_transform(y_test)
print(classification_report(y_test_inv, Y_pred_classes, target_names = labels))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.83      0.86      0.85       123
#            1       0.94      0.81      0.87        89
#            2       0.78      0.90      0.84        84
#            3       0.83      0.88      0.86        67
#            4       0.79      0.69      0.73        70
#
#     accuracy                           0.83       433
#    macro avg       0.83      0.83      0.83       433
# weighted avg       0.84      0.83      0.83       433
#
#               precision    recall  f1-score   support
#
#    dandelion       0.83      0.86      0.85       123
#        daisy       0.94      0.81      0.87        89
#        tulip       0.78      0.90      0.84        84
#    sunflower       0.83      0.88      0.86        67
#         rose       0.79      0.69      0.73        70
#
#     accuracy                           0.83       433
#    macro avg       0.83      0.83      0.83       433
# weighted avg       0.84      0.83      0.83       433
