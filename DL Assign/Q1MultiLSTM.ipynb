# %% [markdown]
# Importing all required Libraries and packages for the model building and data

# %%
# !pip install scikit-learn
# !pip install 'nltk==3.4.5'
# Out:
# ...
#      |████████████████████████████████| 1.5MB 2.8MB/s
# ...
#   Created wheel for nltk: filename=nltk-3.4.5-cp36-none-any.whl size=1449906 sha256=2657c15cea9f8f6a6458ab58a12f3dc3a326f384337b795b56cf020ef6c0806e
#   Stored in directory: /root/.cache/pip/wheels/96/86/f6/68ab24c23f207c0077381a5e3904b2815136b879538a24b483
# Successfully built nltk
# ...
#   Found existing installation: nltk 3.2.5
#     Uninstalling nltk-3.2.5:
#       Successfully uninstalled nltk-3.2.5
# ...

# %%
import re
from sklearn.model_selection import train_test_split

# %%
import tensorflow as tf
from tensorflow import keras
import pandas as pd
import numpy as np
import nltk
from nltk import word_tokenize
from keras import Sequential
from keras.layers import Embedding, LSTM, Dense, Dropout
from keras.preprocessing import sequence
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.preprocessing.text import one_hot
from tensorflow.keras import layers
# Out:
# Using TensorFlow backend.

# %% [markdown]
# Getting our dataset from Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
path = "drive/My Drive/Colab Dataset/IMDB-Dataset.csv"
IMDBFull = pd.read_csv(path)

# %% [markdown]
# Clearing the data of unwanted spaces and other signs

# %%
def preprocess_text(sen):
    # Removing html tags
    sentence = remove_tags(sen)

    # Remove punctuations and numbers
    sentence = re.sub('[^a-zA-Z]', ' ', sentence)

    # Single character removal
    sentence = re.sub(r"\s+[a-zA-Z]\s+", ' ', sentence)

    # Removing multiple spaces
    sentence = re.sub(r'\s+', ' ', sentence)

    return sentence

# %%
TAG_RE = re.compile(r'<[^>]+>')

def remove_tags(text):
    return TAG_RE.sub('', text)

# %%
X = []
sentences = list(IMDBFull['review'])
for sen in sentences:
    X.append(preprocess_text(sen))

# %% [markdown]
# Defining the sentiments as 1 for Positive and 0 for negative

# %%
y = IMDBFull['sentiment']

y = np.array(list(map(lambda x: 1 if x=="positive" else 0, y)))

# %% [markdown]
# Splitting the data as per the requirements

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2)

# %%
X_train,X_val,y_train,Y_val=train_test_split(X_train,y_train,test_size=0.375)

# %% [markdown]
# Making words as individual tokens

# %%
tokenizer = Tokenizer(num_words=5000)
tokenizer.fit_on_texts(X_train)

X_train = tokenizer.texts_to_sequences(X_train)
X_test = tokenizer.texts_to_sequences(X_test)
X_val=tokenizer.texts_to_sequences(X_val)

# %% [markdown]
# Padding to define a set limit of the input sequences.

# %%
max_words = 500
X_train = sequence.pad_sequences(X_train, maxlen=max_words)
X_test = sequence.pad_sequences(X_test, maxlen=max_words)
X_val = sequence.pad_sequences(X_val, maxlen=max_words)

# %% [markdown]
# We will create a two LSTM-layer model now, with state size=256 (basic) and 16 for the second layer (To comapare performance with single-LSTM model). We are also adding a dropout layer in both the LSTM layer, so that overfitting is avoided. Since this dataset is already built on indexing, so we will be taking top 5000 words.

# %%
embedding_vector_len = 32
num_words=5000
model = Sequential()
model.add(Embedding(num_words, embedding_vector_len, input_length=max_words))
model.add(LSTM(256, dropout=0.1, return_sequences=True))
model.add(LSTM(16, dropout=0.2, return_sequences=False))
model.add(Dense(1, activation='sigmoid'))
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
print(model.summary())
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# embedding_4 (Embedding)      (None, 500, 32)           160000
# _________________________________________________________________
# lstm_7 (LSTM)                (None, 500, 256)          295936
# _________________________________________________________________
# lstm_8 (LSTM)                (None, 16)                17472
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 17
# ...
# Total params: 473,425
# Trainable params: 473,425
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# Training the model on training data and validation data.

# %%
history = model.fit(X_train, y_train, validation_data=(X_val, Y_val), epochs=3, batch_size=64)
# Out:
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/indexed_slices.py:434: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "
# Train on 25000 samples, validate on 15000 samples
# Epoch 1/3
# 25000/25000 [==============================] - 1344s 54ms/step - loss: 0.5449 - accuracy: 0.7254 - val_loss: 0.8539 - val_accuracy: 0.6071
# Epoch 2/3
# 25000/25000 [==============================] - 1340s 54ms/step - loss: 0.6981 - accuracy: 0.5246 - val_loss: 0.6910 - val_accuracy: 0.5369
# Epoch 3/3
# 25000/25000 [==============================] - 1346s 54ms/step - loss: 0.6785 - accuracy: 0.5755 - val_loss: 0.6525 - val_accuracy: 0.6375

# %%
scores = model.evaluate(X_test, y_test, verbose=1)
print("Test Loss:", scores[0])
print("Test Accuracy:", scores[1])
# Out:
# 10000/10000 [==============================] - 149s 15ms/step
# Test Loss: 0.65423319606781
# Test Accuracy: 0.6352999806404114

# %%
import matplotlib.pyplot as plt

plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])

plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train','validation'], loc='upper left')
plt.show()

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])

plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train','validation'], loc='upper left')
plt.show()
